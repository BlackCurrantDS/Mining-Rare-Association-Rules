# %% [markdown]
# <a href="https://colab.research.google.com/github/BlackCurrantDS/DBSE_Project/blob/main/Part2_Rules_to_Feature_Vectors_BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook takes the association rules generated and results the feature vector of each rule. Also this generated co-relation matrix.
#
# Input-
#
# input transaction file
# Association rules files(the multiple temprory ones to make it run in parallel)
#
# How to run:
#
# Step1 :
#
# Change the inputfilepath.
#
# Change the folder path(if different from part1) in cell 1
#
# Output-
#
# This generates file item_relation.csv and miner.tmp.non_redundant_rules

# %%
inputfilepath = "/content/drive/MyDrive/Adult_DataSet1202/adult_train_transactions.csv"
file_path = "/content/drive/MyDrive/Adult_DataSet1202/Apriori1202/"

# %% [markdown]
# RuleFormatter

# %%
class RuleFormatter(object):
    
    @staticmethod
    def mydefaultLeft(item):
        return True
    
    @staticmethod
    def mydefaultRight(item):
        return True
    
    @staticmethod
    def mydefault(rule):
        #return True
        return len(rule.right_items) == 1#<= 2
    
    
    @staticmethod
    def massLeft(item):
        return item.isdigit()
    
    @staticmethod
    def massRight(item):
        return not item.isdigit()
    
    @staticmethod
    def mass(rule):
        return rule.lhs_string().isdigit() and (not rule.rhs_string().isdigit())
    
    @staticmethod
    def rna(rule):
        condition = (len(rule.right_items) == 1)
        condition &= ('rna_' in rule.rhs_string())
        condition &=  ('rna_' not in rule.lhs_string())
        return condition
    
    @staticmethod
    def tcrLeft(item):
        return item != 'CD4' and item != 'CD8'
    
    @staticmethod
    def tcrRight(item):
        return item == 'CD4' or item == 'CD8'    
    
    @staticmethod
    def tcr(rule):
        left_key = rule.lhs_string()
        right_key = rule.rhs_string()
        return ('CD4' not in left_key) and ('CD8' not in left_key) and (right_key == 'CD4' or right_key == 'CD8')
    
    @staticmethod
    def ank3Left(item):
        return item != 'CASE' and item != 'HEALTHY'
    
    @staticmethod
    def ank3Right(item):
        return item == 'CASE' or item == 'HEALTHY'
        
    @staticmethod
    def ank3(rule):
        left_key = rule.lhs_string()
        right_key = rule.rhs_string()
        return ('CASE' not in left_key) and ('HEALTHY' not in left_key) and (right_key == 'CASE' or right_key == 'HEALTHY')
    
    @staticmethod
    def spectLeft(item):
        return 'class@' not in item
    
    @staticmethod
    def spectRight(item):
        return 'class@' in item
        
    @staticmethod
    def spect(rule):
        flag = True
        for item in rule.right_items:
            if 'class@' not in item:
                flag = False
                break
        left_key = rule.lhs_string()
        return ('class@' not in left_key) and flag == True
    
    @staticmethod
    def kddLeft(item):
        return ('c_' in item) == False
    
    @staticmethod
    def kddRight(item):
        return 'c_' in item
        
    @staticmethod
    def kdd(rule):
        left_key = rule.lhs_string()
        right_key = rule.rhs_string()
        return ('c_' not in left_key) and (len(rule.right_items) == 1 and 'c_' in right_key)
    
    @staticmethod
    def tcrmLeft(item):
        return True
    
    @staticmethod
    def tcrmRight(item):
        return True
        
    @staticmethod
    def tcrm(rule):
        a_count1 = 0
        b_count1 = 0
        for item in rule.left_items:
            if 'b_' in item:
                b_count1 += 1
            if 'a_' in item:
                a_count1 += 1
        if a_count1 > 0 and b_count1 > 0: return False
        
        a_count2 = 0
        b_count2 = 0
        for item in rule.right_items:
            if 'b_' in item:
                b_count2 += 1
            if 'a_' in item:
                a_count2 += 1
        if a_count2 > 0 and b_count2 > 0: return False
        
        return (a_count1 > 0 and b_count2 > 0) or (b_count1 > 0 and a_count2 > 0)
    
    @staticmethod
    def ppiLeft(item):
        return True
    
    @staticmethod
    def ppiRight(item):
        return True
        
    @staticmethod
    def ppi(rule):
        a_count1 = 0
        b_count1 = 0
        for item in rule.left_items:
            if 'h@' in item:
                b_count1 += 1
            if 'v@' in item:
                a_count1 += 1
        if a_count1 > 0 and b_count1 > 0: return False
        
        a_count2 = 0
        b_count2 = 0
        for item in rule.right_items:
            if 'h@' in item:
                b_count2 += 1
            if 'v@' in item:
                a_count2 += 1
        if a_count2 > 0 and b_count2 > 0: return False
        
        return (a_count1 > 0 and b_count2 > 0) or (b_count1 > 0 and a_count2 > 0)
    
    
    @staticmethod
    def spliceLeft(item):
        return item != 'EI' and item != 'IE' and item != 'N@'
    
    @staticmethod
    def spliceRight(item):
        return item == 'D_0' or item == 'D_1' or item == 'N@'
        
    @staticmethod
    def splice(rule):
        left_key = rule.lhs_string()
        right_key = rule.rhs_string()
        return ('EI' not in left_key) and ('IE' not in left_key) and ('N@' not in left_key) and (right_key == 'EI' or right_key == 'IE' or right_key == 'N@')

# %% [markdown]
# Argument tuple

# %%
class ContrastParams(object):
    '''
    classdocs
    '''

    def __init__(self, delta1, delta2, share_threshold, n_lhs_features, n_rhs_features):
        '''
        Constructor
        '''
        self.delta1 = delta1 
        self.delta2 = delta2 
    
        self.share_threshold = share_threshold
        self.n_lhs_features = n_lhs_features
        self.n_rhs_features = n_rhs_features
        
class ARMParams(object):
    '''
    classdocs
    '''

    def __init__(self, minsup, minconf, itemset_max_size=-1):
        '''
        Constructor
        '''
        self.min_sup = minsup 
        self.min_conf = minconf
        self.itemset_max_size = itemset_max_size
        
class dbscanParams(object):
    
    def __init__(self, minpts, eps):
        self.min_pts = minpts
        self.eps = eps
        
class ARMFiles(object):
    '''
    classdocs
    '''

    def __init__(self, default_folder = file_path):
        '''
        Constructor
        '''
        self.temp_folder = default_folder
        
        self.itemset_tmp_file = self.temp_folder + 'miner.tmp.itemsets'
        self.rules_tmp_file = self.temp_folder + 'miner.tmp.rules'
        self.best_rules_file = self.temp_folder + 'miner.best_tmp.rules'
        
        self.interestingness_tmp_file = self.temp_folder +'miner.tmp.interestingness'
        self.probabilities_tmp_file = self.temp_folder +'miner.tmp.probabilities'
        
        self.feature_tmp_file = self.temp_folder +'miner.tmp.features'
        self.non_redundant_rule_tmp_file = self.temp_folder +'miner.tmp.non_redundant_rules'
        self.non_redundant_rule_feature_tmp_file = self.temp_folder + 'miner.tmp.non_redundant_rules.features'
        self.relation_tmp_file = self.temp_folder + 'relation_matrix.csv'
        
    def get_rule_file(self, i):
        return self.rules_tmp_file + '.' + str(i)

# %% [markdown]
# RuleMining helper

# %%
def string_2_itemset(key):
    if key == '':
        return []
    else: 
        return key.split(',')

def itemset_2_string(itemset):
    return ",".join(itemset)

def merge_itemsets(itemset_1, itemset_2):
    merged_items = []
    merged_items.extend(itemset_1)
    merged_items.extend(itemset_2)
    merged_items = list(set(merged_items))
    merged_items = sorted(merged_items)
    
    return merged_items

def get_full_path(prefix, file_name):
    if prefix == '': return file_name
    return prefix + '//' + file_name

# %% [markdown]
# Association Rule

# %%
class AssociationRule:
    def __init__(self, left, right):
        self.left_items = left
        self.right_items = right
        self.scores = []
        
    def length(self):
        return len(self.left_items) + len(self.right_items)
     
    def score(self, index):
        return self.scores[index]
    
    def lhs_string(self):
        return itemset_2_string(self.left_items)
        
    def rhs_string(self):
        return itemset_2_string(self.right_items)
    
    def serialize(self):
        left_key = self.lhs_string()
        right_key = self.rhs_string()
        return left_key + ">" + right_key
    
    @staticmethod        
    def string_2_rule(s):
        subStrings = s.split(">")
        left = string_2_itemset(subStrings[0].strip())
        right = string_2_itemset(subStrings[1].strip())
        return AssociationRule(left, right)

    def append_score(self, score):
        self.scores.append(score)
        
    def get_itemset(self):
        itemset = []
        itemset.extend(self.left_items)
        itemset.extend(self.right_items)
        itemset.sort()
        return itemset
        
        
    def rule_itemset_2_string(self):
        itemset = self.get_itemset()
        return itemset_2_string(itemset)
    
    def compute_basic_probs(self,frequent_itemsets, nTransactions):  
        
        left = frequent_itemsets[self.lhs_string()]
        right = frequent_itemsets[self.rhs_string()]
        
        both = frequent_itemsets[self.rule_itemset_2_string()]
        
        vector = {}
        
        ''' 1. P(A)'''
        p_A = left/nTransactions
        vector['A'] = p_A
        
        ''' 2. P(B)'''
        p_B = right/nTransactions
        vector['B'] = p_B
        
        ''' 3. P(~A)'''
        p_not_A = 1 - p_A
        vector['~A'] = p_not_A
        
        ''' 4. P(~B)'''
        p_not_B = 1 - p_B
        vector['~B'] = p_not_B
        
        ''' 5. P(AB) '''
        p_A_and_B = both/nTransactions
        vector['AB'] = p_A_and_B
        
        ''' 6. P(~AB)'''
        p_not_A_and_B = (right - both)/nTransactions
        vector['~AB'] = p_not_A_and_B
        
        ''' 7. P(A~B)'''
        p_A_and_not_B = (left - both)/nTransactions
        vector['A~B'] = p_A_and_not_B
        
        ''' 8. P(~A~B)'''
        p_not_A_and_not_B = 1 - (left + right - both)/nTransactions
        vector['~A~B'] = p_not_A_and_not_B 
        
        '''
        9. P(A|B)
        '''
        p_A_if_B = p_A_and_B / p_B
        vector['A|B'] = p_A_if_B
        
        '''
        10. P(~A|~B)
        '''
        p_not_A_if_not_B = p_not_A_and_not_B / p_not_B
        vector['~A|~B'] = p_not_A_if_not_B
        
        '''
        11. P(A|~B)
        '''
        p_A_if_not_B = p_A_and_not_B/p_not_B
        vector['A|~B'] = p_A_if_not_B
        
        '''
        12. p(~A|B)
        '''
        p_not_A_if_B = p_not_A_and_B / p_B
        vector['~A|B'] = p_not_A_if_B
        
        '''
        13. P(B|A)
        '''
        p_B_if_A = p_A_and_B / p_A
        vector['B|A'] = p_B_if_A
        
        '''
        14. P(~B|~A)
        '''
        p_not_B_if_not_A = p_not_A_and_not_B / p_not_A
        vector['~B|~A'] = p_not_B_if_not_A
        
        '''
        15. P(B|~A)
        '''
        p_B_if_not_A = p_not_A_and_B/p_not_A
        vector['B|~A'] = p_B_if_not_A
        
        '''
        16. p(~B|A)
        '''
        p_not_B_if_A = p_A_and_not_B / p_A
        vector['~B|A'] = p_not_B_if_A
        
        return vector
    
    def is_redundant_(self, bits, k, itemset, freq_itemset_dict): 
        '''
        Run out of items --> create rule and check format criterion
        '''
        if k >= len(itemset):
            items_1 = []
            items_2 = []
            for index in range(len(bits)):
                if bits[index] == True:
                    items_1.append(itemset[index])
                else:
                    items_2.append(itemset[index])
            for item in items_2:
                rule = AssociationRule(items_1, [item])
                confidence = freq_itemset_dict.getConfidence(rule)
                if confidence == 1: return True
            return False 
      
        value_domain = [True, False]
        for value in value_domain:
            bits[k] = value
            checker = self.is_redundant_(bits, k+1, itemset, freq_itemset_dict)
            if checker == True: return True
            bits[k] = True    
        return False
    
    '''
    Expand an item-set with equivalent items.
    '''
    def is_redundant(self, freq_itemset_dict):
        bits = [True for _ in self.left_items]
        checker = self.is_redundant_(bits, 0, self.left_items, freq_itemset_dict)
        if checker == True: return True
        
        bits =  [True for _ in self.right_items]
        return self.is_redundant_(bits, 0, self.right_items, freq_itemset_dict)
    
    '''
    Check if an item-set is satisfied condition of the rule. 
    '''
    def satisfy_rule(self, itemset, is_lhs = True):
        condition = self.left_items
        if is_lhs == False: condition = self.right_items
        if len(condition) > len(itemset) or len(itemset) == 0:
            return False
        for item in condition:
            if item not in itemset:
                return False
        return True

# %% [markdown]
# Getting realtion matrix

# %%
class RelationArray2D(object):
    '''
    classdocs
    '''

    def __init__(self, item_dict, relation_values):
        '''
        Constructor
        '''
        self.item_dict = item_dict
        self.relation_matrix = relation_values
        
        
    def get_value(self, item1, item2):
        i = self.item_dict[item1]
        j = self.item_dict[item2]
        return self.relation_matrix[i, j]
    
    def get_items(self):
        return self.item_dict.keys()
        
    def get_index(self, item):
        return self.item_dict[item]
    
class RelationArray1D(object):
    '''
    classdocs
    '''

    def __init__(self, item_dict, values):
        '''
        Constructor
        '''
        self.item_dict = item_dict
        self.values = values
        
        
    def get_value_at(self, index):
        return self.values[index]
    
    def get_items(self):
        return self.item_dict.keys()
        
    def get_value(self, item):
        return self.item_dict[item]

# %%
# Transaction databases, each transaction is a set of items
import numpy as np
from scipy import sparse
from scipy import stats
#from common.RelationArray import RelationArray2D
#from common.RelationArray import RelationArray1D

class DataSet:
    def __init__(self):
        self.current = 0
        self.train_data = []
        self.data_labels = []
        
    
    def __iter__(self):
        return iter(self.train_data)
                
    def size(self):
        return len(self.train_data)
    
    def get_transaction(self, index):
        return self.train_data[index]
    
    def clear(self):
        self.train_data.clear()
        
    def add_transaction(self, t):
        return self.train_data.append(t) 
        
    '''
    Load data set from a file. The input file must be formated in CSV (comma separated)
    class_index is used in the case of data-set with labels. 
    '''
    def load(self, file_path, class_index = -1, has_header = False):
        self.train_data = []
        if class_index != -1: self.data_labels = []
        
        with open(file_path, "r") as text_in_file:
            if has_header == True:
                text_in_file.readline()
                
            for line in text_in_file:
                #print("dataset script line", line)
                transaction = [x.strip() for x in line.split(',')]
                transaction = list(filter(None, transaction))
                #print("datset script transaction" , transaction)
                
                if (class_index != -1):
                    self.data_labels.append(transaction[class_index])
                    del transaction[class_index]
                
                self.train_data.append(list(set(transaction)))
            print("loading done")

    '''
    Return number of classes in data (if have).
    '''            
    def number_of_classes(self):
        if self.data_labels == None: return 0
        return len(set(self.data_labels))

    def convert_data_labels(self, inlier_name):
        Y_train = np.zeros(len(self.data_labels))
        for i in range(Y_train.shape[0]):
            if self.data_labels[i] == inlier_name:
                Y_train[i] = 1
            else: 
                Y_train[i] = -1
        return Y_train

    def convert_2_binary_format_with(self, items_dict, classes_dict = None):
        n_items = len(items_dict)
        X_train = np.zeros((self.size(), n_items))
        
        k = 0
        for transaction in self.train_data:
            for item in transaction:
                if item not in items_dict: 
                    print('not in features...')
                    continue
                i = items_dict[item]
                X_train[k, i] = 1.0
            k += 1
            
        Y_train = []
        if classes_dict is not None:
            for label in self.data_labels:
                if label not in classes_dict:
                    print('not in classes')
                    Y_train.append(-1)
                else:
                    Y_train.append(classes_dict[label]) 
        return X_train, np.array(Y_train)        
    
    def get_items_dict_(self):
        attr_dict = {}
        #check existing data
        for transaction in self.train_data:
            #print("get_items_dict_ transactions",transaction)
            for index in range (len(transaction)):
                item_name = transaction[index]
                if item_name not in attr_dict:
                    attr_dict[item_name] = True
        return attr_dict
    
    def get_class_list_(self):
        # Sort items and classes in alphabet order.
        return sorted(set(self.data_labels))
        
        

    '''
    Convert transaction data into binary format
    '''
    def convert_2_binary_format(self):
        
        attr_dict = self.get_items_dict_()
        print("convert_2_binary_format attr_dict", attr_dict)
      
         
        # Sort items and classes in alphabet order.
        classes_list = sorted(set(self.data_labels))
        print("classes_list", classes_list)
        items_list = sorted(attr_dict.keys())
        
        classes_dict = {classes_list[i] : i for i in range(len(classes_list))}
        print("classes_dict",classes_dict)
        attr_dict = {items_list[i] : i for i in range(len(items_list))}
        print("attr_dict",attr_dict)
        
        #Generate binary matrix (X_train) and array of labels(Y_train)
        X_train, Y_train = self.convert_2_binary_format_with(attr_dict, classes_dict)
                
        return RelationArray2D(attr_dict, sparse.csr_matrix(X_train)), RelationArray1D(classes_dict, np.array(Y_train))
        
    @staticmethod
    def write_relation_matrix_(matrix):
        with open(file_path+'item_relation.csv', 'w') as file_writer:
            item_names = sorted(matrix.item_dict.keys())
            print("item_names in static method",item_names)
            file_writer.write('o0o,')
            file_writer.write(','.join(item_names))
            file_writer.write('\n')
            for i in range(len(item_names)):
                print("in static method i ",i)
                file_writer.write(item_names[i] + ',')
                print(matrix.relation_matrix[i])
                file_writer.write(','.join(str(x) for x in matrix.relation_matrix[i].tolist()))
                file_writer.write('\n')
                
                
   
    '''
    This method estimates relationship among items. There're two kinds of relationship
    - Correlation:including negative correlation (<= -0.3) and positive correlation (>= 0.3)
    - Cover: threshold 1.0, including cover (2) and covered (-2) 
    '''
    def items_relationship(self):
        
        print ('Computing item relation matrix...')
        
        X_train, _ = self.convert_2_binary_format()
        
        print("X_train",X_train)
    
        correlation_matrix, p_values = stats.spearmanr(X_train.relation_matrix.todense(), axis = 0)

        print(correlation_matrix)
        
        #zeros_mask = (p_values <= 0.05).astype(int)
        #small_mask = (np.abs(correlation_matrix) >= 0.1).astype(int)
        
        #relation_matrix = correlation_matrix * small_mask * zeros_mask
        relation_matrix = correlation_matrix
        print(X_train.item_dict)
        print(relation_matrix)
        a = RelationArray2D(X_train.item_dict, relation_matrix)
        print(type(a))
        print("items_relationship a", a)
        DataSet.write_relation_matrix_(a)
        
        return a

# %% [markdown]
# Rule Miner

# %%
#from rules_mining.Apriori import Apriori
#from rules_mining.Generator import Generator
#from rules_mining.ItemsetDictionary import ItemsetDictionary

#from rules_mining.ItemsetFormatter import ItemsetFormatter
#from rules_mining.RuleFormatter import RuleFormatter
#from rules_mining.AssociationRule import AssociationRule

#from objective_measures.Interestingness import ObjectiveMeasure as om
#from rules_mining.RulesCollection import RulesDictionary

import json
import numpy as np
#from common.ArgumentTuple import ARMFiles

class RuleMiner(object):    
    '''
    This class is used to generate_itemsets_and_rules and store a Naive Belief System 
    by using the most confident association rules
    '''

    def __init__(self, filter_name, train_data_set):
        
        self.nthreads = 2
        self.files_info = ARMFiles(file_path)
        
        self.filter_name = filter_name
        self.data_set = train_data_set #taking input the dataset
        print("self.data_set is none or not", self.data_set)
        self.relation_matrix = None 
        if self.data_set is not None:
            print("Not none")
            self.relation_matrix = self.data_set.items_relationship() #calling
            print(self.data_set.items_relationship()) 
            print(type(self.relation_matrix))
            print("realation matrix",self.relation_matrix )
        
        
    '''
    Load generated frequent itemsets from file. 
    This method must be called after generate_frequent_itemsets is called
    '''
    def load_frequent_itemsets_as_dict(self):
        freq_itemset_dict = ItemsetDictionary(0)
        freq_itemset_dict.load_from_file(self.files_info.itemset_tmp_file)
        return freq_itemset_dict
    
    '''
    Load generated association rules from file. 
    This method must be called after generate_association_rules is called
    '''
    def load_rules_as_dict(self):
        rules_dict = RulesDictionary()
        
        for i in range(self.nthreads):
            rules_dict.load_from_file(self.files_info.get_rule_file(i))
                
        return rules_dict

        
    '''
    Generate frequent itemsets from data-set
    '''
    def generate_frequent_itemsets(self, arm_params):
        
        print ('generating frequent item-sets...')
        apriori = Apriori(self.data_set)
        apriori.generate_frequent_itemsets_vw(arm_params.min_sup * self.data_set.size(), 
                                              self.nthreads, 
                                              arm_params.itemset_max_size, 
                                              self.files_info.itemset_tmp_file)
        
    '''
    Generate association rules from data-set. 
    This method must be called after generate_frequent_itemsets(...) is called
    '''
    def generate_association_rules(self, arm_params):
        freq_itemsets_dict = self.load_frequent_itemsets_as_dict()
        
        print ('generating rules ....')
        itemset_formatter = getattr(ItemsetFormatter, self.filter_name)
        rule_formatter = getattr(RuleFormatter, self.filter_name)
        rule_generator = Generator(freq_itemsets_dict, 
                                   arm_params.min_conf, 
                                   itemset_formatter, 
                                   rule_formatter, 
                                   self.nthreads)
        rule_generator.execute(self.files_info.rules_tmp_file)
        
    '''
    Generate association rules and select K patterns with highest confidence.
    '''    
    def generate_itemsets_and_rules(self, arm_params):
        self.generate_frequent_itemsets(arm_params)
        self.generate_association_rules(arm_params)
        self.extract_features_4_all_rules()
         
    '''
    Compute confidence for all association rules generated from data-set
    '''
    def compute_confidence(self, association_rules_list):
        freq_itemset_dict = self.load_frequent_itemsets_as_dict()
        
        rule_confidence_dict = {}
        for rule in association_rules_list:
            left, _, both = freq_itemset_dict.get_frequency_combo(rule)
            rule_confidence_dict[rule.serialize()] = (both/left, both)
        return rule_confidence_dict

    '''
    Compute values of 31 interestingness measures for all association rules generated from data-set
    '''
    def compute_interestingness(self, output_file):
        print ('computing correlation among interestingness measures...')
        #measures = [om.confidence, om.lift]
        
        measures = [om.confidence, om.coverage, om.prevalence, om.recall, om.specificity, 
                    om.accuracy, om.lift, om.leverage, om.change_of_support, om.relative_risk, 
                    om.jaccard, om.certainty_factor, om.odd_ratio, om.yuleQ, om.yuleY, 
                    om.klosgen, om.conviction, om.weighting_dependancy, 
                    om.collective_strength, om.laplace_correction, om.jmeasure, 
                    om.one_way_support, om.two_way_support, om.two_ways_support_variation, 
                    om.linear_correlation_coefficient, om.piatetsky_shapiro, om.loevinger,
                    om.information_gain, om.sebag_schoenauner, om.least_contradiction, 
                    om.odd_multiplier, om.counter_example_rate, om.zhang]
        
        print('loading frequent item-sets....')
        freq_itemsets_dict =  self.load_frequent_itemsets_as_dict()
        association_rules = self.load_association_rules()
        
        print ('computing interestingness for all rules ....')
        
        with open(output_file, 'w') as write_file:
            total = freq_itemsets_dict.ntransactions
            for rule in association_rules:
                left, right, both = freq_itemsets_dict.get_frequency_combo(rule)
                interestingness = []
                for index in range(len(measures)):
                    value = measures[index](left, right, both, total)
                    interestingness.append(value)
                write_file.write(rule.serialize() + ';')            
                write_file.write(';'.join([str(x) for x in interestingness]))
                write_file.write('\n')
                
    '''
    Determine collection of features for LHS and RHS of rules.
    This method returns two dictionaries for LHS and RHS respectively. 
    Each entry of the dictionaries are (the name of item : its index in feature vector)
    ''' 
    def _get_feature_names(self):
        
        left_features = []
        right_features = []
        
        left_filter = getattr(RuleFormatter, self.filter_name + 'Left')
        print("_get_feature_names left_filter ",left_filter) #this gives memory location
        right_filter = getattr(RuleFormatter, self.filter_name + 'Right')
        print("_get_feature_names right_filter",right_filter) #this gives memory location
        for item in self.relation_matrix.get_items():
            #print("_get_feature_names item ",item) #gives item one by one a1@30-39
            #print("_get_feature_names left_filter(item)",left_filter(item))
            if left_filter(item):
                left_features.append(item) #true or false
            if right_filter(item):
                right_features.append(item) 
        print("_get_feature_names",sorted(left_features)) #list of all the items wihtout class lables
        print("_get_feature_names",sorted(right_features))   #list of items with class labels  
        return sorted(left_features), sorted(right_features)
    
    '''
    Extract feature for an item-set.
    '''
    def _extract_features_4_itemset(self, itemset, feature_names):
        n = len(feature_names)
        f_vector = [0 for _ in range(n)]
        for item in itemset:
            print("_extract_features_4_itemset",item)
            for i in range(n):
                print("_extract_features_4_itemset i ", i)
                a = self.relation_matrix.get_value(item, feature_names[i])
                print("_extract_features_4_itemset a", a)
                if (abs(f_vector[i]) < abs(a)):
                    f_vector[i] = a
      
        return np.array(f_vector) 
    '''
    Extract feature vectors for all rules 
    '''
    def extract_features_4_all_rules(self):
        left_features, right_features  = self._get_feature_names()
        left_count = len(left_features)
        right_count = len(right_features)
        
        print('Write number of features for LHS and RHS')
        features_writer = open(self.files_info.non_redundant_rule_tmp_file, 'w')
        features_writer.write(str(left_count))
        features_writer.write('\n')
        features_writer.write(str(right_count))
        features_writer.write('\n')
        
        print('Starting extraction...')
        for i in range(self.nthreads):
            input_file = self.files_info.get_rule_file(i)
            
            with open(input_file, 'r') as rules_reader:
                for line in rules_reader:
                    print("line",line) #for each rule a3@0-4>class@no
                    rule = AssociationRule.string_2_rule(line.strip())
                    print("string to rule",rule) #memory location from class
                    a = self._extract_features_4_itemset(rule.left_items, left_features)
                    print("a",a) 
                    b = self._extract_features_4_itemset(rule.right_items, right_features)
                    print("b",b)
                    f_vector = np.concatenate((a, b))
                    print("f_vector",f_vector)
                    '''
                    Write a feature vector to file
                    '''               
                    features_writer.write(json.dumps((rule.serialize(),f_vector.tolist())))
                    features_writer.write('\n')
        features_writer.close()
        
    '''
    Load feature vectors for all non-redundant rules
    '''
    def load_feature_vectors(self):
        data = []
        lengths = []
        
        with open(self.files_info.non_redundant_rule_tmp_file, 'r') as feature_reader:
            print('Loading number of LHS and RHS features...')
            lhs_count = int(feature_reader.readline())
            rhs_count = int(feature_reader.readline())
            print('Loading feature vectors... ')
            for line in feature_reader:
                rule_text, f_vector = json.loads(line.strip())
                rule = AssociationRule.string_2_rule(rule_text.strip())
                lengths.append(rule.length())
                data.append(f_vector)
                
                
        return np.array(data), lengths, lhs_count, rhs_count
        
    '''
    Load non-redundant rules from a file.
    '''
    def load_association_rules(self):
        association_rules_list = []
        with open(self.files_info.non_redundant_rule_tmp_file, 'r') as rules_reader:
            rules_reader.readline()
            rules_reader.readline()
            
            for line in rules_reader:
                rule_text, _ = json.loads(line.strip())
                association_rules_list.append(AssociationRule.string_2_rule(rule_text.strip()))
        return association_rules_list
        
    '''
    Load non-redundant rules and their feature vectors from a file
    '''
    def load_rules_and_features(self):
        rules_and_their_features = {}
        with open(self.files_info.non_redundant_rule_tmp_file, 'r') as feature_reader:
            lhs_count = int(feature_reader.readline())
            rhs_count = int(feature_reader.readline())
            
            for line in feature_reader:
                rule_text, f_vector = json.loads(line.strip())
                rules_and_their_features[rule_text] = f_vector
        return rules_and_their_features, lhs_count, rhs_count

# %%
train_data_set = DataSet()

# %%
train_data_set.load(inputfilepath)
# Out:
# loading done

# %%
ruleminer = RuleMiner('spect',train_data_set)
# Out:
# Streaming output truncated to the last 5000 lines.
#   1.74796487e-02  8.22318879e-03  2.40605105e-03  5.73240825e-07
#  -1.39401071e-02 -9.50264581e-04  2.69148852e-03 -1.83260890e-02
#  -3.87325393e-03  6.82140124e-03 -1.16118509e-03  5.23319879e-02
#   4.40553678e-02 -8.14999726e-03 -1.04831008e-02 -8.34356477e-03
 'a4@4', 'a4@5', 'a4@6', 'a4@7', 'a4@8', 'a4@9', 'a5@di', 'a5@mas', 'a5@mcs', 'a5@msa', 'a5@nm', 'a5@se', 'a5@wi', 'a6@?', 'a6@ac', 'a6@af', 'a6@cr', 'a6@em', 'a6@ff', 'a6@hc', 'a6@moi', 'a6@os', 'a6@phs', 'a6@pse', 'a6@psp', 'a6@sa', 'a6@tm', 'a6@ts', 'a7@ch', 'a7@hu', 'a7@nif', 'a7@or', 'a7@um', 'a7@w', 'a8@aie', 'a8@api', 'a8@b', 'a8@o', 'a8@w', 'a9@F', 'a9@M']
# _get_feature_names ['class@g50', 'class@l50']

# %%
extract_features_4_all_rules = ruleminer.extract_features_4_all_rules()
# Out:
# Streaming output truncated to the last 5000 lines.
# _extract_features_4_itemset i  48
# _extract_features_4_itemset a 0.0074631643739331305
# _extract_features_4_itemset i  49
# _extract_features_4_itemset a 0.0004681035130805398
# _extract_features_4_itemset i  50
# _extract_features_4_itemset a 0.0065794941671574285
# _extract_features_4_itemset i  51
# _extract_features_4_itemset a 0.0007786346474138424
# _extract_features_4_itemset i  52
# _extract_features_4_itemset a -0.01301575961284925
# _extract_features_4_itemset i  53
# _extract_features_4_itemset a 0.00648012323811701
# _extract_features_4_itemset i  54
# _extract_features_4_itemset a 0.00015026958439615508
# _extract_features_4_itemset i  55
# _extract_features_4_itemset a -0.0029108389428967197
# _extract_features_4_itemset i  56
# _extract_features_4_itemset a -0.0029108389428967197
# _extract_features_4_itemset i  57
# _extract_features_4_itemset a -0.006255658599781259
# _extract_features_4_itemset i  58
# _extract_features_4_itemset a 0.0006004535571591217
# _extract_features_4_itemset i  59
# _extract_features_4_itemset a 0.011004831272194872
# _extract_features_4_itemset i  60
# _extract_features_4_itemset a 0.002921038413766256
# _extract_features_4_itemset i  61
# _extract_features_4_itemset a 0.02287525835016824
# _extract_features_4_itemset i  62
# _extract_features_4_itemset a -0.025148316229162287
# _extract_features_4_itemset i  63
# _extract_features_4_itemset a -0.001924579509304885
# _extract_features_4_itemset i  64
# _extract_features_4_itemset a 0.004570433822796268
# _extract_features_4_itemset i  65
# _extract_features_4_itemset a -0.0015601714927390884
# _extract_features_4_itemset i  66
# _extract_features_4_itemset a 0.006061004626191074
# _extract_features_4_itemset i  67
# _extract_features_4_itemset a 0.007432720038764921
# _extract_features_4_itemset i  68
# _extract_features_4_itemset a 0.0031659970291940567
# _extract_features_4_itemset i  69
# _extract_features_4_itemset a 0.004231269494921761
# _extract_features_4_itemset i  70
# _extract_features_4_itemset a -0.009726015556794892
# _extract_features_4_itemset i  71
# _extract_features_4_itemset a -0.006053052168304712
# _extract_features_4_itemset i  72
# _extract_features_4_itemset a 0.005182703318580855
# _extract_features_4_itemset i  73
# _extract_features_4_itemset a -0.006777731964933423
# _extract_features_4_itemset i  74
# _extract_features_4_itemset a -0.009112849595861023
# _extract_features_4_itemset i  75
# _extract_features_4_itemset a 0.0003320795345023738
# _extract_features_4_itemset i  76
# _extract_features_4_itemset a 0.004886149406496123
# _extract_features_4_itemset i  77
# _extract_features_4_itemset a 0.01839170774704978
# _extract_features_4_itemset i  78
# _extract_features_4_itemset a -0.011696616322038545
# _extract_features_4_itemset i  79
# _extract_features_4_itemset a -0.01731948462384891
# _extract_features_4_itemset i  80
# _extract_features_4_itemset a 0.0032314372693454693
# _extract_features_4_itemset i  81
# _extract_features_4_itemset a 0.02452436033882067
# _extract_features_4_itemset i  82
# _extract_features_4_itemset a -0.025955912247243966
# _extract_features_4_itemset i  83
# _extract_features_4_itemset a -0.01869672925243669
# _extract_features_4_itemset i  84
# _extract_features_4_itemset a 0.0015793325583508245
# _extract_features_4_itemset i  85
# _extract_features_4_itemset a 0.004570433822796268
# _extract_features_4_itemset i  86
# _extract_features_4_itemset a 0.0027309790676265985
# _extract_features_4_itemset i  87
# _extract_features_4_itemset a 0.0017271432438358165
# _extract_features_4_itemset i  88
# _extract_features_4_itemset a 0.0021153423150515813
# _extract_features_4_itemset i  89
# _extract_features_4_itemset a 0.005153648646142264
# _extract_features_4_itemset i  90
# _extract_features_4_itemset a 0.0004439122971852335
# _extract_features_4_itemset i  91
# _extract_features_4_itemset a 0.009139302105250227
# _extract_features_4_itemset i  92
# _extract_features_4_itemset a 0.00470461508548312
# _extract_features_4_itemset i  93
# _extract_features_4_itemset a -0.0013605277334416902
# _extract_features_4_itemset i  94
# _extract_features_4_itemset a 0.0038624842504867804
# _extract_features_4_itemset i  95
# _extract_features_4_itemset a -0.008469230349232316
# _extract_features_4_itemset i  96
# _extract_features_4_itemset a 0.007711260491730488
# _extract_features_4_itemset i  97
# _extract_features_4_itemset a 0.006423180602675839
# _extract_features_4_itemset i  98
# _extract_features_4_itemset a 0.007249826005694695
# _extract_features_4_itemset i  99
# _extract_features_4_itemset a -0.004583430929821173
# _extract_features_4_itemset i  100
# _extract_features_4_itemset a 0.007252084532431102
# _extract_features_4_itemset i  101
# _extract_features_4_itemset a -0.034688357486930034
# _extract_features_4_itemset i  102
# _extract_features_4_itemset a -0.044232664159671996
# _extract_features_4_itemset i  103
# _extract_features_4_itemset a 0.01419888476512862
# _extract_features_4_itemset i  104
# _extract_features_4_itemset a 0.017565177874220066
# _extract_features_4_itemset i  105
# _extract_features_4_itemset a 0.015377114865850429
# _extract_features_4_itemset i  106
# _extract_features_4_itemset a 0.017357057295202177
# _extract_features_4_itemset i  107
# _extract_features_4_itemset a 0.026677627960747557
# _extract_features_4_itemset i  108
# _extract_features_4_itemset a -0.043214989727906945
# _extract_features_4_itemset i  109
# _extract_features_4_itemset a 0.0013375819869438901
# _extract_features_4_itemset i  110
# _extract_features_4_itemset a -0.04137568499651873
# _extract_features_4_itemset i  111
# _extract_features_4_itemset a 0.019164047498272833
# _extract_features_4_itemset i  112
# _extract_features_4_itemset a 0.0013375819869438901
# _extract_features_4_itemset i  113
# _extract_features_4_itemset a 0.019164047498272833
# _extract_features_4_itemset i  114
# _extract_features_4_itemset a 0.007252084532431102
# _extract_features_4_itemset i  115
# _extract_features_4_itemset a -0.004583430929821173
# _extract_features_4_itemset i  116
# _extract_features_4_itemset a -0.034688357486930034
# _extract_features_4_itemset i  117
# _extract_features_4_itemset a -0.043214989727906945
# _extract_features_4_itemset i  118
# _extract_features_4_itemset a -0.04137568499651873
# _extract_features_4_itemset i  119
# _extract_features_4_itemset a -0.044232664159671996
# _extract_features_4_itemset i  120
# _extract_features_4_itemset a 0.007711260491730488
# _extract_features_4_itemset i  121
# _extract_features_4_itemset a 0.006423180602675839
# _extract_features_4_itemset i  122
# _extract_features_4_itemset a 0.007249826005694695
# _extract_features_4_itemset i  123
# _extract_features_4_itemset a 0.017357057295202177
# _extract_features_4_itemset i  124
# _extract_features_4_itemset a 0.01419888476512862
# _extract_features_4_itemset i  125
# _extract_features_4_itemset a 0.017565177874220066
# _extract_features_4_itemset i  126
# _extract_features_4_itemset a 0.015377114865850429
# _extract_features_4_itemset i  127
# _extract_features_4_itemset a 0.026677627960747557
# _extract_features_4_itemset i  128
# _extract_features_4_itemset a 0.01948436319928911
# _extract_features_4_itemset i  129
# _extract_features_4_itemset a 0.00585891745961939
# _extract_features_4_itemset i  130
# _extract_features_4_itemset a -0.07664915233863191
# _extract_features_4_itemset i  131
# _extract_features_4_itemset a 0.006956435219422007
# _extract_features_4_itemset i  132
# _extract_features_4_itemset a 0.05688295011647444
# _extract_features_4_itemset i  133
# _extract_features_4_itemset a 0.015458527429850665
# _extract_features_4_itemset i  134
# _extract_features_4_itemset a 0.006789427453601909
# _extract_features_4_itemset i  135
# _extract_features_4_itemset a 0.01856385470012751
# _extract_features_4_itemset i  136
# _extract_features_4_itemset a 0.02219652973628732
# _extract_features_4_itemset i  137
# _extract_features_4_itemset a -0.005126719412029786
# _extract_features_4_itemset i  138
# _extract_features_4_itemset a -0.0031553750197002525
# _extract_features_4_itemset i  139
# _extract_features_4_itemset a -0.045837244315869434
# _extract_features_4_itemset i  140
# _extract_features_4_itemset a 0.011922131296115924
# _extract_features_4_itemset i  141
# _extract_features_4_itemset a 0.021435794875141783
# _extract_features_4_itemset i  142
# _extract_features_4_itemset a 0.0156456617969665
# _extract_features_4_itemset i  143
# _extract_features_4_itemset a 0.04050889215716142
# _extract_features_4_itemset i  144
# _extract_features_4_itemset a 0.010610912745280627
# _extract_features_4_itemset i  145
# _extract_features_4_itemset a 0.0031964479614574317
# _extract_features_4_itemset i  146
# _extract_features_4_itemset a -0.04354283024318157
# _extract_features_4_itemset i  147
# _extract_features_4_itemset a -0.01063378137967003
# _extract_features_4_itemset i  148
# _extract_features_4_itemset a 0.0020042240884616115
# _extract_features_4_itemset i  149
# _extract_features_4_itemset a -0.007044577087607086
# _extract_features_4_itemset i  150
# _extract_features_4_itemset a 0.04785422208757213
# _extract_features_4_itemset i  151
# _extract_features_4_itemset a -0.07203298826512607
# _extract_features_4_itemset i  152
# _extract_features_4_itemset a 0.017308867782037607
# _extract_features_4_itemset i  153
# _extract_features_4_itemset a 0.01661297345483931
# _extract_features_4_itemset i  154
# _extract_features_4_itemset a 0.03638554074789384
# _extract_features_4_itemset i  155
# _extract_features_4_itemset a -0.016641548763178117
# _extract_features_4_itemset i  156
# _extract_features_4_itemset a 0.012625643041256933
# _extract_features_4_itemset i  157
# _extract_features_4_itemset a -0.0040580199765046145
# _extract_features_4_itemset i  158
# _extract_features_4_itemset a 0.021178158469968334
# _extract_features_4_itemset i  159
# _extract_features_4_itemset a 0.004103083440736516
# _extract_features_4_itemset i  160
# _extract_features_4_itemset a -0.020193135887400526
# _extract_features_4_itemset i  161
# _extract_features_4_itemset a 0.04281125826987535
# _extract_features_4_itemset i  162
# _extract_features_4_itemset a -0.04281125826987535
# _extract_features_4_itemset a12@20.6_30.4
# _extract_features_4_itemset i  0
# _extract_features_4_itemset a -0.02827974408371776
# _extract_features_4_itemset i  1
# _extract_features_4_itemset a -0.0621615520273719
# _extract_features_4_itemset i  2
# _extract_features_4_itemset a -0.05566966290642593
# _extract_features_4_itemset i  3
# _extract_features_4_itemset a -0.0497737307572934
# _extract_features_4_itemset i  4
# _extract_features_4_itemset a -0.02664869004017719
# _extract_features_4_itemset i  5
# _extract_features_4_itemset a 0.030164978709147538
# _extract_features_4_itemset i  6
# _extract_features_4_itemset a 0.03580032404390557
# _extract_features_4_itemset i  7
# _extract_features_4_itemset a 0.028868288498537596
# _extract_features_4_itemset i  8
# _extract_features_4_itemset a -0.004659818303302812
# _extract_features_4_itemset i  9
# _extract_features_4_itemset a 0.17944136457771653
# _extract_features_4_itemset i  10
# _extract_features_4_itemset a -0.005069819698653431
# _extract_features_4_itemset i  11
# _extract_features_4_itemset a -0.0034301482020968207
# _extract_features_4_itemset i  12
# _extract_features_4_itemset a 0.013073477588875783
# _extract_features_4_itemset i  13
# _extract_features_4_itemset a -0.010820610964790037
# _extract_features_4_itemset i  14
# _extract_features_4_itemset a -0.02846777047831832
# _extract_features_4_itemset i  15
# _extract_features_4_itemset a 0.029711202875729942
# _extract_features_4_itemset i  16
# _extract_features_4_itemset a -0.002835426952390755
# _extract_features_4_itemset i  17
# _extract_features_4_itemset a -0.032389081261991984
# _extract_features_4_itemset i  18
# _extract_features_4_itemset a -0.010115142973600173
# _extract_features_4_itemset i  19
# _extract_features_4_itemset a 2.176722067052003e-05
# _extract_features_4_itemset i  20
# _extract_features_4_itemset a -0.0037575968019348416
# _extract_features_4_itemset i  21
# _extract_features_4_itemset a -0.002656899763460801
# _extract_features_4_itemset i  22
# _extract_features_4_itemset a -0.006326046752980281
# _extract_features_4_itemset i  23
# _extract_features_4_itemset a -0.007031440000510623
# _extract_features_4_itemset i  24
# _extract_features_4_itemset a 0.030868931690803025
# _extract_features_4_itemset i  25
# _extract_features_4_itemset a -0.07436154959723504
# _extract_features_4_itemset i  26
# _extract_features_4_itemset a 1.0
# _extract_features_4_itemset i  27
# _extract_features_4_itemset a -0.3027241027893168
# _extract_features_4_itemset i  28
# _extract_features_4_itemset a -0.13071788209167973
# _extract_features_4_itemset i  29
# _extract_features_4_itemset a -0.050723624568142785
# _extract_features_4_itemset i  30
# _extract_features_4_itemset a -0.06687566423835696
# _extract_features_4_itemset i  31
# _extract_features_4_itemset a -0.03269203608002236
# _extract_features_4_itemset i  32
# _extract_features_4_itemset a -0.02186862819693024
# _extract_features_4_itemset i  33
# _extract_features_4_itemset a -0.01812303384924887
# _extract_features_4_itemset i  34
# _extract_features_4_itemset a -0.04209185863982472
# _extract_features_4_itemset i  35
# _extract_features_4_itemset a -0.0022391217822115192
# _extract_features_4_itemset i  36
# _extract_features_4_itemset a -0.002040349769485862
# _extract_features_4_itemset i  37
# _extract_features_4_itemset a 0.0030926239778477317
# _extract_features_4_itemset i  38
# _extract_features_4_itemset a -0.005543005466688105
# _extract_features_4_itemset i  39
# _extract_features_4_itemset a -0.006509548418355734
# _extract_features_4_itemset i  40
# _extract_features_4_itemset a 0.006949182861622864
# _extract_features_4_itemset i  41
# _extract_features_4_itemset a -0.006688027994758763
# _extract_features_4_itemset i  42
# _extract_features_4_itemset a 0.004691827118404826
# _extract_features_4_itemset i  43
# _extract_features_4_itemset a -0.0008395474450559247
# _extract_features_4_itemset i  44
# _extract_features_4_itemset a 0.0050605834219329075
# _extract_features_4_itemset i  45
# _extract_features_4_itemset a -0.006113089408895694
# _extract_features_4_itemset i  46
# _extract_features_4_itemset a -0.00510967942791168
# _extract_features_4_itemset i  47
# _extract_features_4_itemset a 0.020407967916546206
# _extract_features_4_itemset i  48
# _extract_features_4_itemset a 0.01354140616718741
# _extract_features_4_itemset i  49
# _extract_features_4_itemset a -0.010021244561898401
# _extract_features_4_itemset i  50
# _extract_features_4_itemset a -0.00425932285283094
# _extract_features_4_itemset i  51
# _extract_features_4_itemset a 0.00046369261816674027
# _extract_features_4_itemset i  52
# _extract_features_4_itemset a -0.0002547082937229406
# _extract_features_4_itemset i  53
# _extract_features_4_itemset a 0.006596773066568117
# _extract_features_4_itemset i  54
# _extract_features_4_itemset a 0.012581544306512678
# _extract_features_4_itemset i  55
# _extract_features_4_itemset a 0.0064278242120599976
# _extract_features_4_itemset i  56
# _extract_features_4_itemset a 0.0064278242120599976
# _extract_features_4_itemset i  57
# _extract_features_4_itemset a -0.004567979282506341
# _extract_features_4_itemset i  58
# _extract_features_4_itemset a -0.0031155691561785743
# _extract_features_4_itemset i  59
# _extract_features_4_itemset a 0.005362457268393458
# _extract_features_4_itemset i  60
# _extract_features_4_itemset a 0.0016116768990529964
# _extract_features_4_itemset i  61
# _extract_features_4_itemset a -0.0015069105841913385
# _extract_features_4_itemset i  62
# _extract_features_4_itemset a -0.0015339146810717632
# _extract_features_4_itemset i  63
# _extract_features_4_itemset a 0.0206411900917776
# _extract_features_4_itemset i  64
# _extract_features_4_itemset a 0.005784063743051031
# _extract_features_4_itemset i  65
# _extract_features_4_itemset a -0.006283782250056016
# _extract_features_4_itemset i  66
# _extract_features_4_itemset a -0.006321586225715268
# _extract_features_4_itemset i  67
# _extract_features_4_itemset a -0.0022440333206458843
# _extract_features_4_itemset i  68
# _extract_features_4_itemset a -0.004271587656316989
# _extract_features_4_itemset i  69
# _extract_features_4_itemset a -0.0053145341253774325
# _extract_features_4_itemset i  70
# _extract_features_4_itemset a -0.006497456199427613
# _extract_features_4_itemset i  71
# _extract_features_4_itemset a -0.001900371736829567
# _extract_features_4_itemset i  72
# _extract_features_4_itemset a -0.001427368251231554
# _extract_features_4_itemset i  73
# _extract_features_4_itemset a -0.0017413210566277844
# _extract_features_4_itemset i  74
# _extract_features_4_itemset a 0.0008992521620139409
# _extract_features_4_itemset i  75
# _extract_features_4_itemset a -0.0020236319148490825
# _extract_features_4_itemset i  76
# _extract_features_4_itemset a -0.006137072524849067
# _extract_features_4_itemset i  77
# _extract_features_4_itemset a 0.07941888534251416
# _extract_features_4_itemset i  78
# _extract_features_4_itemset a -0.03482452471089781
# _extract_features_4_itemset i  79
# _extract_features_4_itemset a -0.02578419431123638
# _extract_features_4_itemset i  80
# _extract_features_4_itemset a 0.00408951094627809
# _extract_features_4_itemset i  81
# _extract_features_4_itemset a 0.00025502541291406067
# _extract_features_4_itemset i  82
# _extract_features_4_itemset a -0.027848888559898487
# _extract_features_4_itemset i  83
# _extract_features_4_itemset a 0.014334063265589074
# _extract_features_4_itemset i  84
# _extract_features_4_itemset a -0.027089043322449567
# _extract_features_4_itemset i  85
# _extract_features_4_itemset a 0.011546360265431542
# _extract_features_4_itemset i  86
# _extract_features_4_itemset a 0.006210685255691231
# _extract_features_4_itemset i  87
# _extract_features_4_itemset a -0.002169316258346775
# _extract_features_4_itemset i  88
# _extract_features_4_itemset a 0.009788980426158984
# _extract_features_4_itemset i  89
# _extract_features_4_itemset a 0.008457907774914177
# _extract_features_4_itemset i  90
# _extract_features_4_itemset a -0.005523597322486946
# _extract_features_4_itemset i  91
# _extract_features_4_itemset a 0.004166163820196643
# _extract_features_4_itemset i  92
# _extract_features_4_itemset a 0.0012691890727662262
# _extract_features_4_itemset i  93
# _extract_features_4_itemset a 0.009362272954841008
# _extract_features_4_itemset i  94
# _extract_features_4_itemset a -0.004851334660338016
# _extract_features_4_itemset i  95
# _extract_features_4_itemset a -0.006846038272076211
# _extract_features_4_itemset i  96
# _extract_features_4_itemset a 0.006745107320737536
# _extract_features_4_itemset i  97
# _extract_features_4_itemset a -0.003200915066569377
# _extract_features_4_itemset i  98
# _extract_features_4_itemset a 0.010306693037653055
# _extract_features_4_itemset i  99
# _extract_features_4_itemset a -0.0019635878820192156
# _extract_features_4_itemset i  100
# _extract_features_4_itemset a -0.019164110740316334
# _extract_features_4_itemset i  101
# _extract_features_4_itemset a -0.04803412109033667
# _extract_features_4_itemset i  102
# _extract_features_4_itemset a -0.013224645249233917
# _extract_features_4_itemset i  103
# _extract_features_4_itemset a 0.022633287103624708
# _extract_features_4_itemset i  104
# _extract_features_4_itemset a 0.028431408058526453
# _extract_features_4_itemset i  105
# _extract_features_4_itemset a 0.020010822948644633
# _extract_features_4_itemset i  106
# _extract_features_4_itemset a 0.007115434342780681
# _extract_features_4_itemset i  107
# _extract_features_4_itemset a -0.0023608895683446215
# _extract_features_4_itemset i  108
# _extract_features_4_itemset a -0.03340788236807128
# _extract_features_4_itemset i  109
# _extract_features_4_itemset a 0.013203612866496819
# _extract_features_4_itemset i  110
# _extract_features_4_itemset a -0.012675610564623225
# _extract_features_4_itemset i  111
# _extract_features_4_itemset a 0.046475109815423556
# _extract_features_4_itemset i  112
# _extract_features_4_itemset a 0.013203612866496819
# _extract_features_4_itemset i  113
# _extract_features_4_itemset a 0.046475109815423556
# _extract_features_4_itemset i  114
# _extract_features_4_itemset a -0.019164110740316334
# _extract_features_4_itemset i  115
# _extract_features_4_itemset a -0.0019635878820192156
# _extract_features_4_itemset i  116
# _extract_features_4_itemset a -0.04803412109033667
# _extract_features_4_itemset i  117
# _extract_features_4_itemset a -0.03340788236807128
# _extract_features_4_itemset i  118
# _extract_features_4_itemset a -0.012675610564623225
# _extract_features_4_itemset i  119
# _extract_features_4_itemset a -0.013224645249233917
# _extract_features_4_itemset i  120
# _extract_features_4_itemset a 0.006745107320737536
# _extract_features_4_itemset i  121
# _extract_features_4_itemset a -0.003200915066569377
# _extract_features_4_itemset i  122
# _extract_features_4_itemset a 0.010306693037653055
# _extract_features_4_itemset i  123
# _extract_features_4_itemset a 0.007115434342780681
# _extract_features_4_itemset i  124
# _extract_features_4_itemset a 0.022633287103624708
# _extract_features_4_itemset i  125
# _extract_features_4_itemset a 0.028431408058526453
# _extract_features_4_itemset i  126
# _extract_features_4_itemset a 0.020010822948644633
# _extract_features_4_itemset i  127
# _extract_features_4_itemset a -0.0023608895683446215
# _extract_features_4_itemset i  128
# _extract_features_4_itemset a -0.020239350539112456
# _extract_features_4_itemset i  129
# _extract_features_4_itemset a 0.0016337269654720244
# _extract_features_4_itemset i  130
# _extract_features_4_itemset a -0.11425282047923953
# _extract_features_4_itemset i  131
# _extract_features_4_itemset a 0.001332447251925948
# _extract_features_4_itemset i  132
# _extract_features_4_itemset a 0.11927860710553531
# _extract_features_4_itemset i  133
# _extract_features_4_itemset a 0.0116731216121828
# _extract_features_4_itemset i  134
# _extract_features_4_itemset a 0.0328881431906334
# _extract_features_4_itemset i  135
# _extract_features_4_itemset a 0.07953640631481161
# _extract_features_4_itemset i  136
# _extract_features_4_itemset a -0.0012202869795949695
# _extract_features_4_itemset i  137
# _extract_features_4_itemset a -0.004602309472232993
# _extract_features_4_itemset i  138
# _extract_features_4_itemset a -0.06146463822594596
# _extract_features_4_itemset i  139
# _extract_features_4_itemset a -0.06372016817557843
# _extract_features_4_itemset i  140
# _extract_features_4_itemset a -0.0012025465978353946
# _extract_features_4_itemset i  141
# _extract_features_4_itemset a 0.024701266144501504
# _extract_features_4_itemset i  142
# _extract_features_4_itemset a -0.033050087807662935
# _extract_features_4_itemset i  143
# _extract_features_4_itemset a 0.12419024321329222
# _extract_features_4_itemset i  144
# _extract_features_4_itemset a 0.04318288443010972
# _extract_features_4_itemset i  145
# _extract_features_4_itemset a -0.019813771982712253
# _extract_features_4_itemset i  146
# _extract_features_4_itemset a -0.04109313999923976
# _extract_features_4_itemset i  147
# _extract_features_4_itemset a 0.030015742407830823
# _extract_features_4_itemset i  148
# _extract_features_4_itemset a -0.02303298732334572
# _extract_features_4_itemset i  149
# _extract_features_4_itemset a -0.010076116750113268
# _extract_features_4_itemset i  150
# _extract_features_4_itemset a 0.12138555209685614
# _extract_features_4_itemset i  151
# _extract_features_4_itemset a -0.1277004945021886
# _extract_features_4_itemset i  152
# _extract_features_4_itemset a 0.010147276221693115
# _extract_features_4_itemset i  153
# _extract_features_4_itemset a 0.027389620418460495
# _extract_features_4_itemset i  154
# _extract_features_4_itemset a 0.013897087775292414
# _extract_features_4_itemset i  155
# _extract_features_4_itemset a 0.024786714209728788
# _extract_features_4_itemset i  156
# _extract_features_4_itemset a -0.0026165270376881937
# _extract_features_4_itemset i  157
# _extract_features_4_itemset a -0.006072163370335282
# _extract_features_4_itemset i  158
# _extract_features_4_itemset a 0.014886058326584389
# _extract_features_4_itemset i  159
# _extract_features_4_itemset a 0.003571271604045472
# _extract_features_4_itemset i  160
# _extract_features_4_itemset a -0.009599074672407372
# _extract_features_4_itemset i  161
# _extract_features_4_itemset a 0.10322181789211532
# _extract_features_4_itemset i  162
# _extract_features_4_itemset a -0.10322181789211532
# _extract_features_4_itemset a13@us
# _extract_features_4_itemset i  0
# _extract_features_4_itemset a -0.03411332801135841
# _extract_features_4_itemset i  1
# _extract_features_4_itemset a -0.008827428986675363
# _extract_features_4_itemset i  2
# _extract_features_4_itemset a 0.002267281144877794
# _extract_features_4_itemset i  3
# _extract_features_4_itemset a 0.00618948018630562
# _extract_features_4_itemset i  4
# _extract_features_4_itemset a 0.006997493970678628
# _extract_features_4_itemset i  5
# _extract_features_4_itemset a 0.015423276506958893
# _extract_features_4_itemset i  6
# _extract_features_4_itemset a 0.01285168714584482
# _extract_features_4_itemset i  7
# _extract_features_4_itemset a 0.002924973274541657
# _extract_features_4_itemset i  8
# _extract_features_4_itemset a -4.974526643151871e-05
# _extract_features_4_itemset i  9
# _extract_features_4_itemset a 0.017643119897726815
# _extract_features_4_itemset i  10
# _extract_features_4_itemset a 0.00011772412337021193
# _extract_features_4_itemset i  11
# _extract_features_4_itemset a 0.004225374067632129
# _extract_features_4_itemset i  12
# _extract_features_4_itemset a -0.010157420464577358
# _extract_features_4_itemset i  13
# _extract_features_4_itemset a -0.0006364726392160598
# _extract_features_4_itemset i  14
# _extract_features_4_itemset a 0.013546864416979783
# _extract_features_4_itemset i  15
# _extract_features_4_itemset a -0.010713165788165413
# _extract_features_4_itemset i  16
# _extract_features_4_itemset a 0.002561636931978244
# _extract_features_4_itemset i  17
# _extract_features_4_itemset a 0.011269314871885703
# _extract_features_4_itemset i  18
# _extract_features_4_itemset a -0.0030898210466779896
# _extract_features_4_itemset i  19
# _extract_features_4_itemset a -0.0026287173153615164
# _extract_features_4_itemset i  20
# _extract_features_4_itemset a 0.004628736470863641
# _extract_features_4_itemset i  21
# _extract_features_4_itemset a 0.003272860150463063
# _extract_features_4_itemset i  22
# _extract_features_4_itemset a 0.003391090515398563
# _extract_features_4_itemset i  23
# _extract_features_4_itemset a 0.0007406200122832304
# _extract_features_4_itemset i  24
# _extract_features_4_itemset a -0.009112849595861023
# _extract_features_4_itemset i  25
# _extract_features_4_itemset a 0.02057739168512847
# _extract_features_4_itemset i  26
# _extract_features_4_itemset a 0.0008992521620139408
# _extract_features_4_itemset i  27
# _extract_features_4_itemset a -0.04684583354801958
# _extract_features_4_itemset i  28
# _extract_features_4_itemset a 0.03786035695951623
# _extract_features_4_itemset i  29
# _extract_features_4_itemset a 0.011445604236235024
# _extract_features_4_itemset i  30
# _extract_features_4_itemset a 0.006184097637128693
# _extract_features_4_itemset i  31
# _extract_features_4_itemset a -0.011517818442827225
# _extract_features_4_itemset i  32
# _extract_features_4_itemset a 0.002608307693192648
# _extract_features_4_itemset i  33
# _extract_features_4_itemset a 0.00690265829627227
# _extract_features_4_itemset i  34
# _extract_features_4_itemset a 0.0038214903261701806
# _extract_features_4_itemset i  35
# _extract_features_4_itemset a -0.39601619617611866
# _extract_features_4_itemset i  36
# _extract_features_4_itemset a -0.07271162825769195
# _extract_features_4_itemset i  37
# _extract_features_4_itemset a -0.10665387377985543
# _extract_features_4_itemset i  38
# _extract_features_4_itemset a -0.13902863585265732
# _extract_features_4_itemset i  39
# _extract_features_4_itemset a -0.06897818760304991
# _extract_features_4_itemset i  40
# _extract_features_4_itemset a -0.09054055137681227
# _extract_features_4_itemset i  41
# _extract_features_4_itemset a -0.07086943979340549
# _extract_features_4_itemset i  42
# _extract_features_4_itemset a -0.17912515617656924
# _extract_features_4_itemset i  43
# _extract_features_4_itemset a -0.1409246066804307
# _extract_features_4_itemset i  44
# _extract_features_4_itemset a -0.12496122745920628
# _extract_features_4_itemset i  45
# _extract_features_4_itemset a -0.15865425722138182
# _extract_features_4_itemset i  46
# _extract_features_4_itemset a -0.13613562846636248
# _extract_features_4_itemset i  47
# _extract_features_4_itemset a -0.0860441361410566
# _extract_features_4_itemset i  48
# _extract_features_4_itemset a -0.16761637559220874
# _extract_features_4_itemset i  49
# _extract_features_4_itemset a -0.1544108247124274
# _extract_features_4_itemset i  50
# _extract_features_4_itemset a -0.08756850529496066
# _extract_features_4_itemset i  51
# _extract_features_4_itemset a -0.19064758482422986
# _extract_features_4_itemset i  52
# _extract_features_4_itemset a -0.08756850529496066
# _extract_features_4_itemset i  53
# _extract_features_4_itemset a -0.1301585409063525
# _extract_features_4_itemset i  54
# _extract_features_4_itemset a -0.10788856642159744
# _extract_features_4_itemset i  55
# _extract_features_4_itemset a -0.05861568466523417
# _extract_features_4_itemset i  56
# _extract_features_4_itemset a -0.05861568466523417
# _extract_features_4_itemset i  57
# _extract_features_4_itemset a -0.1627883691540471
# _extract_features_4_itemset i  58
# _extract_features_4_itemset a -0.07965649389168786
# _extract_features_4_itemset i  59
# _extract_features_4_itemset a -0.14646667373605823
# _extract_features_4_itemset i  60
# _extract_features_4_itemset a -0.12810473000858255
# _extract_features_4_itemset i  61
# _extract_features_4_itemset a -0.4162861585833683
# _extract_features_4_itemset i  62
# _extract_features_4_itemset a -0.016254069842953335
# _extract_features_4_itemset i  63
# _extract_features_4_itemset a -0.09482476462168456
# _extract_features_4_itemset i  64
# _extract_features_4_itemset a -0.06082930514774117
# _extract_features_4_itemset i  65
# _extract_features_4_itemset a -0.22941009681394472
# _extract_features_4_itemset i  66
# _extract_features_4_itemset a -0.126017709910982
# _extract_features_4_itemset i  67
# _extract_features_4_itemset a -0.09892435003886411
# _extract_features_4_itemset i  68
# _extract_features_4_itemset a -0.17384790879280101
# _extract_features_4_itemset i  69
# _extract_features_4_itemset a -0.05631526311247448
# _extract_features_4_itemset i  70
# _extract_features_4_itemset a -0.14555750991963654
# _extract_features_4_itemset i  71
# _extract_features_4_itemset a -0.1161665049082878
# _extract_features_4_itemset i  72
# _extract_features_4_itemset a -0.06897818760304991
# _extract_features_4_itemset i  73
# _extract_features_4_itemset a -0.07086943979340549
# _extract_features_4_itemset i  74
# _extract_features_4_itemset a 0.9999999999999998
# _extract_features_4_itemset i  75
# _extract_features_4_itemset a -0.13318034419328198
# _extract_features_4_itemset i  76
# _extract_features_4_itemset a -0.06503126065686302
# _extract_features_4_itemset i  77
# _extract_features_4_itemset a 0.006192578480889959
# _extract_features_4_itemset i  78
# _extract_features_4_itemset a 0.015440919576042093
# _extract_features_4_itemset i  79
# _extract_features_4_itemset a 0.03319632952097671
# _extract_features_4_itemset i  80
# _extract_features_4_itemset a 0.004999683593671254
# _extract_features_4_itemset i  81
# _extract_features_4_itemset a -0.04318420614661532
# _extract_features_4_itemset i  82
# _extract_features_4_itemset a -0.00485037267723411
# _extract_features_4_itemset i  83
# _extract_features_4_itemset a 0.013729774191884507
# _extract_features_4_itemset i  84
# _extract_features_4_itemset a 0.024246488134440292
# _extract_features_4_itemset i  85
# _extract_features_4_itemset a 0.002221331670670121
# _extract_features_4_itemset i  86
# _extract_features_4_itemset a -0.003889188304303569
# _extract_features_4_itemset i  87
# _extract_features_4_itemset a 0.0026722380849049086
# _extract_features_4_itemset i  88
# _extract_features_4_itemset a 0.003272860150463063
# _extract_features_4_itemset i  89
# _extract_features_4_itemset a -0.03044349686336045
# _extract_features_4_itemset i  90
# _extract_features_4_itemset a -0.029016099280676937
# _extract_features_4_itemset i  91
# _extract_features_4_itemset a -0.035609602234649984
# _extract_features_4_itemset i  92
# _extract_features_4_itemset a -0.009211113076023078
# _extract_features_4_itemset i  93
# _extract_features_4_itemset a -0.005412010678246706
# _extract_features_4_itemset i  94
# _extract_features_4_itemset a 0.005976040234840725
# _extract_features_4_itemset i  95
# _extract_features_4_itemset a 0.058838125637119335
# _extract_features_4_itemset i  96
# _extract_features_4_itemset a -0.14666220744125932
# _extract_features_4_itemset i  97
# _extract_features_4_itemset a -0.20119379342657007
# _extract_features_4_itemset i  98
# _extract_features_4_itemset a -0.05748294193290777
# _extract_features_4_itemset i  99
# _extract_features_4_itemset a 0.014752044534129177
# _extract_features_4_itemset i  100
# _extract_features_4_itemset a 0.02539901109857024
# _extract_features_4_itemset i  101
# _extract_features_4_itemset a -0.008493679229377578
# _extract_features_4_itemset i  102
# _extract_features_4_itemset a -0.03772667839670261
# _extract_features_4_itemset i  103
# _extract_features_4_itemset a 0.007331887309047588
# _extract_features_4_itemset i  104
# _extract_features_4_itemset a 0.007745965138753443
# _extract_features_4_itemset i  105
# _extract_features_4_itemset a -0.020106231537546666
# _extract_features_4_itemset i  106
# _extract_features_4_itemset a -0.05281241689625626
# _extract_features_4_itemset i  107
# _extract_features_4_itemset a 0.06337069888539709
# _extract_features_4_itemset i  108
# _extract_features_4_itemset a -0.007438455568196416
# _extract_features_4_itemset i  109
# _extract_features_4_itemset a -0.07294290113364765
# _extract_features_4_itemset i  110
# _extract_features_4_itemset a -0.010688875941312116
# _extract_features_4_itemset i  111
# _extract_features_4_itemset a 0.05024263500333926
# _extract_features_4_itemset i  112
# _extract_features_4_itemset a -0.07294290113364765
# _extract_features_4_itemset i  113
# _extract_features_4_itemset a 0.05024263500333926
# _extract_features_4_itemset i  114
# _extract_features_4_itemset a 0.02539901109857024
# _extract_features_4_itemset i  115
# _extract_features_4_itemset a 0.014752044534129177
# _extract_features_4_itemset i  116
# _extract_features_4_itemset a -0.008493679229377578
# _extract_features_4_itemset i  117
# _extract_features_4_itemset a -0.007438455568196416
# _extract_features_4_itemset i  118
# _extract_features_4_itemset a -0.010688875941312116
# _extract_features_4_itemset i  119
# _extract_features_4_itemset a -0.03772667839670261
# _extract_features_4_itemset i  120
# _extract_features_4_itemset a -0.14666220744125932
# _extract_features_4_itemset i  121
# _extract_features_4_itemset a -0.20119379342657007
# _extract_features_4_itemset i  122
# _extract_features_4_itemset a -0.05748294193290777
# _extract_features_4_itemset i  123
# _extract_features_4_itemset a -0.05281241689625626
# _extract_features_4_itemset i  124
# _extract_features_4_itemset a 0.007331887309047588
# _extract_features_4_itemset i  125
# _extract_features_4_itemset a 0.007745965138753443
# _extract_features_4_itemset i  126
# _extract_features_4_itemset a -0.020106231537546666
# _extract_features_4_itemset i  127
# _extract_features_4_itemset a 0.06337069888539709
# _extract_features_4_itemset i  128
# _extract_features_4_itemset a 0.05322402011072174
# _extract_features_4_itemset i  129
# _extract_features_4_itemset a 0.009064924074935362
# _extract_features_4_itemset i  130
# _extract_features_4_itemset a -0.009755145024199231
# _extract_features_4_itemset i  131
# _extract_features_4_itemset a -0.1084918160324237
# _extract_features_4_itemset i  132
# _extract_features_4_itemset a 0.001833025304839817
# _extract_features_4_itemset i  133
# _extract_features_4_itemset a -0.020300268954844162
# _extract_features_4_itemset i  134
# _extract_features_4_itemset a 0.007259035742068683
# _extract_features_4_itemset i  135
# _extract_features_4_itemset a 0.006498712332065547
# _extract_features_4_itemset i  136
# _extract_features_4_itemset a 0.022505845761441445
# _extract_features_4_itemset i  137
# _extract_features_4_itemset a 0.0056692824768631075
# _extract_features_4_itemset i  138
# _extract_features_4_itemset a 0.003904645402652924
# _extract_features_4_itemset i  139
# _extract_features_4_itemset a 0.028117905090025194
# _extract_features_4_itemset i  140
# _extract_features_4_itemset a -0.006710705906859434
# _extract_features_4_itemset i  141
# _extract_features_4_itemset a -0.019193874447527577
# _extract_features_4_itemset i  142
# _extract_features_4_itemset a -0.04457968373636227
# _extract_features_4_itemset i  143
# _extract_features_4_itemset a -0.058293345512013255
# _extract_features_4_itemset i  144
# _extract_features_4_itemset a -0.06477926543027887
# _extract_features_4_itemset i  145
# _extract_features_4_itemset a 0.017689014764790668
# _extract_features_4_itemset i  146
# _extract_features_4_itemset a -0.0047832212346336726
# _extract_features_4_itemset i  147
# _extract_features_4_itemset a 0.02999704237806312
# _extract_features_4_itemset i  148
# _extract_features_4_itemset a 0.028081465093310547
# _extract_features_4_itemset i  149
# _extract_features_4_itemset a 0.011266182731736978
# _extract_features_4_itemset i  150
# _extract_features_4_itemset a 0.04182424043143367
# _extract_features_4_itemset i  151
# _extract_features_4_itemset a 0.008593528049060111
# _extract_features_4_itemset i  152
# _extract_features_4_itemset a 0.020277407593789487
# _extract_features_4_itemset i  153
# _extract_features_4_itemset a -0.10754398213778468
# _extract_features_4_itemset i  154
# _extract_features_4_itemset a -0.017690227702965373
# _extract_features_4_itemset i  155
# _extract_features_4_itemset a -0.020524843569704226
# _extract_features_4_itemset i  156
# _extract_features_4_itemset a 0.017975540710311887
# _extract_features_4_itemset i  157
# _extract_features_4_itemset a -0.36543721231618476
# _extract_features_4_itemset i  158
# _extract_features_4_itemset a 0.011383196722724805
# _extract_features_4_itemset i  159
# _extract_features_4_itemset a -0.12592222391853514
# _extract_features_4_itemset i  160
# _extract_features_4_itemset a 0.2000042482932955
# _extract_features_4_itemset i  161
# _extract_features_4_itemset a 0.0069932291541564455
# _extract_features_4_itemset i  162
# _extract_features_4_itemset a -0.0069932291541564455
# _extract_features_4_itemset a2@l160096.5
# _extract_features_4_itemset i  0
# _extract_features_4_itemset a -0.01648396954696981
# _extract_features_4_itemset i  1
# _extract_features_4_itemset a -0.01746986327203982
# _extract_features_4_itemset i  2
# _extract_features_4_itemset a -0.000855318616150217
# _extract_features_4_itemset i  3
# _extract_features_4_itemset a 0.03778455971443289
# _extract_features_4_itemset i  4
# _extract_features_4_itemset a 0.02600820832121276
# _extract_features_4_itemset i  5
# _extract_features_4_itemset a 0.02408342231245719
# _extract_features_4_itemset i  6
# _extract_features_4_itemset a 0.01354491940302032
# _extract_features_4_itemset i  7
# _extract_features_4_itemset a 0.025150994458699696
# _extract_features_4_itemset i  8
# _extract_features_4_itemset a 0.006603436269357714
# _extract_features_4_itemset i  9
# _extract_features_4_itemset a -0.03960389842944693
# _extract_features_4_itemset i  10
# _extract_features_4_itemset a 0.012915041216126006
# _extract_features_4_itemset i  11
# _extract_features_4_itemset a -0.0052029725496906655
# _extract_features_4_itemset i  12
# _extract_features_4_itemset a -0.006482188259993259
# _extract_features_4_itemset i  13
# _extract_features_4_itemset a 0.0012698567587616284
# _extract_features_4_itemset i  14
# _extract_features_4_itemset a 0.0030010474561445928
# _extract_features_4_itemset i  15
# _extract_features_4_itemset a -0.006680384366077902
# _extract_features_4_itemset i  16
# _extract_features_4_itemset a -0.004369046001682844
# _extract_features_4_itemset i  17
# _extract_features_4_itemset a 0.006783505862327457
# _extract_features_4_itemset i  18
# _extract_features_4_itemset a 0.010164122619772894
# _extract_features_4_itemset i  19
# _extract_features_4_itemset a 0.003961524242763195
# _extract_features_4_itemset i  20
# _extract_features_4_itemset a 0.002593107715861695
# _extract_features_4_itemset i  21
# _extract_features_4_itemset a 0.005091075677281398
# _extract_features_4_itemset i  22
# _extract_features_4_itemset a 0.008471813084271147
# _extract_features_4_itemset i  23
# _extract_features_4_itemset a 0.0036207973668416506
# _extract_features_4_itemset i  24
# _extract_features_4_itemset a -0.008469230349232316
# _extract_features_4_itemset i  25
# _extract_features_4_itemset a 0.0014046085036533
# _extract_features_4_itemset i  26
# _extract_features_4_itemset a -0.006846038272076212
# _extract_features_4_itemset i  27
# _extract_features_4_itemset a -0.026596284514759948
# _extract_features_4_itemset i  28
# _extract_features_4_itemset a 0.0014631787825929532
# _extract_features_4_itemset i  29
# _extract_features_4_itemset a 0.01560631507180528
# _extract_features_4_itemset i  30
# _extract_features_4_itemset a 0.023962893359318983
# _extract_features_4_itemset i  31
# _extract_features_4_itemset a 0.013434680166615932
# _extract_features_4_itemset i  32
# _extract_features_4_itemset a 0.009516594433895709
# _extract_features_4_itemset i  33
# _extract_features_4_itemset a 0.009149652114383075
# _extract_features_4_itemset i  34
# _extract_features_4_itemset a 0.019791745547379207
# _extract_features_4_itemset i  35
# _extract_features_4_itemset a -0.008398584304138488
# _extract_features_4_itemset i  36
# _extract_features_4_itemset a -0.005360440909297087
# _extract_features_4_itemset i  37
# _extract_features_4_itemset a -0.0008028194612416551
# _extract_features_4_itemset i  38
# _extract_features_4_itemset a 0.0031044948699156995
# _extract_features_4_itemset i  39
# _extract_features_4_itemset a -0.0008285703527865022
# _extract_features_4_itemset i  40
# _extract_features_4_itemset a -0.01742125742341969
# _extract_features_4_itemset i  41
# _extract_features_4_itemset a 0.0033206508935893627
# _extract_features_4_itemset i  42
# _extract_features_4_itemset a 0.002929882347770452
# _extract_features_4_itemset i  43
# _extract_features_4_itemset a 0.0059165874538850945
# _extract_features_4_itemset i  44
# _extract_features_4_itemset a -0.016123179684944585
# _extract_features_4_itemset i  45
# _extract_features_4_itemset a -0.04010172062035064
# _extract_features_4_itemset i  46
# _extract_features_4_itemset a -0.0073358874551925765
# _extract_features_4_itemset i  47
# _extract_features_4_itemset a -0.002929914532993695
# _extract_features_4_itemset i  48
# _extract_features_4_itemset a -0.02091973119171242
# _extract_features_4_itemset i  49
# _extract_features_4_itemset a -0.003045876345977139
# _extract_features_4_itemset i  50
# _extract_features_4_itemset a -0.0037305060104122073
# _extract_features_4_itemset i  51
# _extract_features_4_itemset a -0.0015923388264893858
# _extract_features_4_itemset i  52
# _extract_features_4_itemset a 0.019328983639169295
# _extract_features_4_itemset i  53
# _extract_features_4_itemset a -0.016937347107189065
# _extract_features_4_itemset i  54
# _extract_features_4_itemset a -0.013401033518643303
# _extract_features_4_itemset i  55
# _extract_features_4_itemset a -0.0071384763532082495
# _extract_features_4_itemset i  56
# _extract_features_4_itemset a -0.0008779975023076015
# _extract_features_4_itemset i  57
# _extract_features_4_itemset a 0.015122175868533165
# _extract_features_4_itemset i  58
# _extract_features_4_itemset a 0.012100199487544617
# _extract_features_4_itemset i  59
# _extract_features_4_itemset a -0.019961775986453763
# _extract_features_4_itemset i  60
# _extract_features_4_itemset a 0.008342853700351344
# _extract_features_4_itemset i  61
# _extract_features_4_itemset a -0.09536626514492813
# _extract_features_4_itemset i  62
# _extract_features_4_itemset a 0.006700629899491598
# _extract_features_4_itemset i  63
# _extract_features_4_itemset a -0.022867493116094005
# _extract_features_4_itemset i  64
# _extract_features_4_itemset a -0.008104157853311672
# _extract_features_4_itemset i  65
# _extract_features_4_itemset a 0.01815786112261939
# _extract_features_4_itemset i  66
# _extract_features_4_itemset a 0.0023745347688048863
# _extract_features_4_itemset i  67
# _extract_features_4_itemset a 0.018507323305694004
# _extract_features_4_itemset i  68
# _extract_features_4_itemset a -0.018321626242235687
# _extract_features_4_itemset i  69
# _extract_features_4_itemset a 0.0036675460868048388
# _extract_features_4_itemset i  70
# _extract_features_4_itemset a 0.018321454773824835
# _extract_features_4_itemset i  71
# _extract_features_4_itemset a -0.002713160156067498
# _extract_features_4_itemset i  72
# _extract_features_4_itemset a -0.003488966690137976
# _extract_features_4_itemset i  73
# _extract_features_4_itemset a -0.0018583079734283952
# _extract_features_4_itemset i  74
# _extract_features_4_itemset a 0.05883812563711933
# _extract_features_4_itemset i  75
# _extract_features_4_itemset a 0.0176432662349084
# _extract_features_4_itemset i  76
# _extract_features_4_itemset a -0.007051581241100481
# _extract_features_4_itemset i  77
# _extract_features_4_itemset a 0.004671722686097266
# _extract_features_4_itemset i  78
# _extract_features_4_itemset a 0.010371802548023742
# _extract_features_4_itemset i  79
# _extract_features_4_itemset a -0.007944825682022268
# _extract_features_4_itemset i  80
# _extract_features_4_itemset a -0.0035971867573084642
# _extract_features_4_itemset i  81
# _extract_features_4_itemset a -0.0429899628264277
# _extract_features_4_itemset i  82
# _extract_features_4_itemset a 0.027047360192815458
# _extract_features_4_itemset i  83
# _extract_features_4_itemset a 0.03400652697941729
# _extract_features_4_itemset i  84
# _extract_features_4_itemset a 0.024856184224214133
# _extract_features_4_itemset i  85
# _extract_features_4_itemset a 0.0009451037187444779
# _extract_features_4_itemset i  86
# _extract_features_4_itemset a -0.010249711779053405
# _extract_features_4_itemset i  87
# _extract_features_4_itemset a -0.006482188259993259
# _extract_features_4_itemset i  88
# _extract_features_4_itemset a -0.007939148747176989
# _extract_features_4_itemset i  89
# _extract_features_4_itemset a -0.7766109163711871
# _extract_features_4_itemset i  90
# _extract_features_4_itemset a -0.2858759201949175
# _extract_features_4_itemset i  91
# _extract_features_4_itemset a -0.09922415460243826
# _extract_features_4_itemset i  92
# _extract_features_4_itemset a -0.0468171155512061
# _extract_features_4_itemset i  93
# _extract_features_4_itemset a -0.018903018790624934
# _extract_features_4_itemset i  94
# _extract_features_4_itemset a -0.014496394640266643
# _extract_features_4_itemset i  95
# _extract_features_4_itemset a 1.0
# _extract_features_4_itemset i  96
# _extract_features_4_itemset a -0.019411949729115124
# _extract_features_4_itemset i  97
# _extract_features_4_itemset a -0.028753763452842026
# _extract_features_4_itemset i  98
# _extract_features_4_itemset a 0.0038566682629791902
# _extract_features_4_itemset i  99
# _extract_features_4_itemset a -0.014192672232205683
# _extract_features_4_itemset i  100
# _extract_features_4_itemset a 0.010435812166137289
# _extract_features_4_itemset i  101
# _extract_features_4_itemset a 0.006046790103854175
# _extract_features_4_itemset i  102
# _extract_features_4_itemset a 0.006282591697745103
# _extract_features_4_itemset i  103
# _extract_features_4_itemset a -0.0018653911874781323
# _extract_features_4_itemset i  104
# _extract_features_4_itemset a -0.010150982019355137
# _extract_features_4_itemset i  105
# _extract_features_4_itemset a 0.0006109340190785721
# _extract_features_4_itemset i  106
# _extract_features_4_itemset a -0.00440605349964193
# _extract_features_4_itemset i  107
# _extract_features_4_itemset a -0.005942065569227046
# _extract_features_4_itemset i  108
# _extract_features_4_itemset a 0.017355687717301393
# _extract_features_4_itemset i  109
# _extract_features_4_itemset a -0.010619724661205934
# _extract_features_4_itemset i  110
# _extract_features_4_itemset a -0.0009327645607905694
# _extract_features_4_itemset i  111
# _extract_features_4_itemset a 0.008019156468883569
# _extract_features_4_itemset i  112
# _extract_features_4_itemset a -0.010619724661205934
# _extract_features_4_itemset i  113
# _extract_features_4_itemset a 0.008019156468883569
# _extract_features_4_itemset i  114
# _extract_features_4_itemset a 0.010435812166137289
# _extract_features_4_itemset i  115
# _extract_features_4_itemset a -0.014192672232205683
# _extract_features_4_itemset i  116
# _extract_features_4_itemset a 0.006046790103854175
# _extract_features_4_itemset i  117
# ...
# _extract_features_4_itemset a 0.04281125826987535
# _extract_features_4_itemset i  25
# _extract_features_4_itemset a 0.1198029518678159
# _extract_features_4_itemset i  26
# _extract_features_4_itemset a 0.1032218178921153
# _extract_features_4_itemset i  27
# _extract_features_4_itemset a 0.05758818903272577
# _extract_features_4_itemset i  28
# _extract_features_4_itemset a -0.13274090328607235
# _extract_features_4_itemset i  29
# _extract_features_4_itemset a -0.05926466465081706
# _extract_features_4_itemset i  30
# _extract_features_4_itemset a -0.09781858177124432
# _extract_features_4_itemset i  31
# _extract_features_4_itemset a -0.045498384146344543
# _extract_features_4_itemset i  32
# _extract_features_4_itemset a -0.028946946829997617
# _extract_features_4_itemset i  33
# _extract_features_4_itemset a -0.02300764051653347
# _extract_features_4_itemset i  34
# _extract_features_4_itemset a 0.053372828802100855
# _extract_features_4_itemset i  35
# _extract_features_4_itemset a -0.014695083226358551
# _extract_features_4_itemset i  36
# _extract_features_4_itemset a -0.0016226092120314704
# _extract_features_4_itemset i  37
# _extract_features_4_itemset a -0.011187318018602671
# _extract_features_4_itemset i  38
# _extract_features_4_itemset a -0.004344629962658183
# _extract_features_4_itemset i  39
# _extract_features_4_itemset a 0.005680908050058665
# _extract_features_4_itemset i  40
# _extract_features_4_itemset a 0.007927075264000898
# _extract_features_4_itemset i  41
# _extract_features_4_itemset a -0.008879534658809932
# _extract_features_4_itemset i  42
# _extract_features_4_itemset a -0.0011008109393679897
# _extract_features_4_itemset i  43
# _extract_features_4_itemset a -0.005187288259542015
# _extract_features_4_itemset i  44
# _extract_features_4_itemset a 0.0068808296655197545
# _extract_features_4_itemset i  45
# _extract_features_4_itemset a 0.010377071605481548
# _extract_features_4_itemset i  46
# _extract_features_4_itemset a 0.016692563625166263
# _extract_features_4_itemset i  47
# _extract_features_4_itemset a -0.0005839952479657005
# _extract_features_4_itemset i  48
# _extract_features_4_itemset a -7.358743502991869e-05
# _extract_features_4_itemset i  49
# _extract_features_4_itemset a 0.0027706618823041544
# _extract_features_4_itemset i  50
# _extract_features_4_itemset a 0.0052669047259297054
# _extract_features_4_itemset i  51
# _extract_features_4_itemset a 0.01480497475695225
# _extract_features_4_itemset i  52
# _extract_features_4_itemset a -0.010050485108158308
# _extract_features_4_itemset i  53
# _extract_features_4_itemset a -0.0017255605790144736
# _extract_features_4_itemset i  54
# _extract_features_4_itemset a 0.009675217476093992
# _extract_features_4_itemset i  55
# _extract_features_4_itemset a 0.008821007266890522
# _extract_features_4_itemset i  56
# _extract_features_4_itemset a 0.0055535698622533915
# _extract_features_4_itemset i  57
# _extract_features_4_itemset a -0.026046443254416945
# _extract_features_4_itemset i  58
# _extract_features_4_itemset a -0.0022586236466288928
# _extract_features_4_itemset i  59
# _extract_features_4_itemset a 0.021235226708897586
# _extract_features_4_itemset i  60
# _extract_features_4_itemset a -0.0007625168393768278
# _extract_features_4_itemset i  61
# _extract_features_4_itemset a -0.03129314968863855
# _extract_features_4_itemset i  62
# _extract_features_4_itemset a 0.007882398807327695
# _extract_features_4_itemset i  63
# _extract_features_4_itemset a 0.001521832831817359
# _extract_features_4_itemset i  64
# _extract_features_4_itemset a 0.007458716413126308
# _extract_features_4_itemset i  65
# _extract_features_4_itemset a 0.006299425853797185
# _extract_features_4_itemset i  66
# _extract_features_4_itemset a -0.0012901618687098258
# _extract_features_4_itemset i  67
# _extract_features_4_itemset a -0.00046382766997571964
# _extract_features_4_itemset i  68
# _extract_features_4_itemset a 0.015791238391877977
# _extract_features_4_itemset i  69
# _extract_features_4_itemset a 0.003504412982824519
# _extract_features_4_itemset i  70
# _extract_features_4_itemset a 0.00466280898847081
# _extract_features_4_itemset i  71
# _extract_features_4_itemset a -0.0030875206952257813
# _extract_features_4_itemset i  72
# _extract_features_4_itemset a 0.014011911518815317
# _extract_features_4_itemset i  73
# _extract_features_4_itemset a 0.012744273132489
# _extract_features_4_itemset i  74
# _extract_features_4_itemset a 0.0069932291541564455
# _extract_features_4_itemset i  75
# _extract_features_4_itemset a 0.0012053332437303925
# _extract_features_4_itemset i  76
# _extract_features_4_itemset a -0.006752871841588725
# _extract_features_4_itemset i  77
# _extract_features_4_itemset a 0.06555597443583097
# _extract_features_4_itemset i  78
# _extract_features_4_itemset a -0.0009889120331747602
# _extract_features_4_itemset i  79
# _extract_features_4_itemset a 0.037966227402499345
# _extract_features_4_itemset i  80
# _extract_features_4_itemset a -0.0014049924901725081
# _extract_features_4_itemset i  81
# _extract_features_4_itemset a 0.03469922139999827
# _extract_features_4_itemset i  82
# _extract_features_4_itemset a -0.08401528263720415
# _extract_features_4_itemset i  83
# _extract_features_4_itemset a -0.10745142628225929
# _extract_features_4_itemset i  84
# _extract_features_4_itemset a 0.019895001534781496
# _extract_features_4_itemset i  85
# _extract_features_4_itemset a 0.0011614567414473711
# _extract_features_4_itemset i  86
# _extract_features_4_itemset a 0.001822850888097683
# _extract_features_4_itemset i  87
# _extract_features_4_itemset a -0.005510345965832905
# _extract_features_4_itemset i  88
# _extract_features_4_itemset a 0.006852465831480558
# _extract_features_4_itemset i  89
# _extract_features_4_itemset a 0.007203341441859683
# _extract_features_4_itemset i  90
# _extract_features_4_itemset a -0.023785723712744795
# _extract_features_4_itemset i  91
# _extract_features_4_itemset a -0.018669756769182387
# _extract_features_4_itemset i  92
# _extract_features_4_itemset a -0.0016226058426058777
# _extract_features_4_itemset i  93
# _extract_features_4_itemset a 0.0010758172179113749
# _extract_features_4_itemset i  94
# _extract_features_4_itemset a 0.002578098429872626
# _extract_features_4_itemset i  95
# _extract_features_4_itemset a 0.012083010269544187
# _extract_features_4_itemset i  96
# _extract_features_4_itemset a -0.008722291556376348
# _extract_features_4_itemset i  97
# _extract_features_4_itemset a -0.016968752680403074
# _extract_features_4_itemset i  98
# _extract_features_4_itemset a -0.025133162347836236
# _extract_features_4_itemset i  99
# _extract_features_4_itemset a 0.02494730918983005
# _extract_features_4_itemset i  100
# _extract_features_4_itemset a 0.013871570002562356
# _extract_features_4_itemset i  101
# _extract_features_4_itemset a -0.02683657456237336
# _extract_features_4_itemset i  102
# _extract_features_4_itemset a -0.029525360951356446
# _extract_features_4_itemset i  103
# _extract_features_4_itemset a -0.00533336064916952
# _extract_features_4_itemset i  104
# _extract_features_4_itemset a 0.015160274556494026
# _extract_features_4_itemset i  105
# _extract_features_4_itemset a 0.0004364871276625517
# _extract_features_4_itemset i  106
# _extract_features_4_itemset a -0.013630536608216882
# _extract_features_4_itemset i  107
# _extract_features_4_itemset a -0.011684471462177453
# _extract_features_4_itemset i  108
# _extract_features_4_itemset a -0.009901693371532024
# _extract_features_4_itemset i  109
# _extract_features_4_itemset a -0.0014368990593073715
# _extract_features_4_itemset i  110
# _extract_features_4_itemset a -0.04879314711142997
# _extract_features_4_itemset i  111
# _extract_features_4_itemset a 0.06172150065289379
# _extract_features_4_itemset i  112
# _extract_features_4_itemset a -0.0014368990593073715
# _extract_features_4_itemset i  113
# _extract_features_4_itemset a 0.06172150065289379
# _extract_features_4_itemset i  114
# _extract_features_4_itemset a 0.013871570002562356
# _extract_features_4_itemset i  115
# _extract_features_4_itemset a 0.02494730918983005
# _extract_features_4_itemset i  116
# _extract_features_4_itemset a -0.02683657456237336
# _extract_features_4_itemset i  117
# _extract_features_4_itemset a -0.009901693371532024
# _extract_features_4_itemset i  118
# _extract_features_4_itemset a -0.04879314711142997
# _extract_features_4_itemset i  119
# _extract_features_4_itemset a -0.029525360951356446
# _extract_features_4_itemset i  120
# _extract_features_4_itemset a -0.008722291556376348
# _extract_features_4_itemset i  121
# _extract_features_4_itemset a -0.016968752680403074
# _extract_features_4_itemset i  122
# _extract_features_4_itemset a -0.025133162347836236
# _extract_features_4_itemset i  123
# _extract_features_4_itemset a -0.013630536608216882
# _extract_features_4_itemset i  124
# _extract_features_4_itemset a -0.00533336064916952
# _extract_features_4_itemset i  125
# _extract_features_4_itemset a 0.015160274556494026
# _extract_features_4_itemset i  126
# _extract_features_4_itemset a 0.0004364871276625517
# _extract_features_4_itemset i  127
# _extract_features_4_itemset a -0.011684471462177453
# _extract_features_4_itemset i  128
# _extract_features_4_itemset a 0.22862112530312287
# _extract_features_4_itemset i  129
# _extract_features_4_itemset a 0.01570362552966136
# _extract_features_4_itemset i  130
# _extract_features_4_itemset a -0.43180545811313015
# _extract_features_4_itemset i  131
# _extract_features_4_itemset a 0.03869164444351874
# _extract_features_4_itemset i  132
# _extract_features_4_itemset a 0.17143394597881662
# _extract_features_4_itemset i  133
# _extract_features_4_itemset a 0.10913472805837873
# _extract_features_4_itemset i  134
# _extract_features_4_itemset a 0.18848665862323669
# _extract_features_4_itemset i  135
# _extract_features_4_itemset a 0.06534967626766945
# _extract_features_4_itemset i  136
# _extract_features_4_itemset a 0.2631477628435179
# _extract_features_4_itemset i  137
# _extract_features_4_itemset a -0.011690465756782096
# _extract_features_4_itemset i  138
# _extract_features_4_itemset a -0.2231281775027529
# _extract_features_4_itemset i  139
# _extract_features_4_itemset a -0.0367291167517455
# _extract_features_4_itemset i  140
# _extract_features_4_itemset a -0.1000972365096254
# _extract_features_4_itemset i  141
# _extract_features_4_itemset a -0.09402582601868055
# _extract_features_4_itemset i  142
# _extract_features_4_itemset a -0.03050199157934415
# _extract_features_4_itemset i  143
# _extract_features_4_itemset a 0.15367728949875067
# _extract_features_4_itemset i  144
# _extract_features_4_itemset a 0.08869914085853024
# _extract_features_4_itemset i  145
# _extract_features_4_itemset a -0.06476990040722636
# _extract_features_4_itemset i  146
# _extract_features_4_itemset a 0.028511252013974118
# _extract_features_4_itemset i  147
# _extract_features_4_itemset a 0.01150371846669631
# _extract_features_4_itemset i  148
# _extract_features_4_itemset a -0.1324678882067733
# _extract_features_4_itemset i  149
# _extract_features_4_itemset a 0.01609241132457549
# _extract_features_4_itemset i  150
# _extract_features_4_itemset a 0.10236883084143356
# _extract_features_4_itemset i  151
# _extract_features_4_itemset a -0.580135264800069
# _extract_features_4_itemset i  152
# _extract_features_4_itemset a 0.16887880592468404
# _extract_features_4_itemset i  153
# _extract_features_4_itemset a 0.040282298953921984
# _extract_features_4_itemset i  154
# _extract_features_4_itemset a 0.3212732037336032
# _extract_features_4_itemset i  155
# _extract_features_4_itemset a 0.31931054800340236
# _extract_features_4_itemset i  156
# _extract_features_4_itemset a 0.010820302987519567
# _extract_features_4_itemset i  157
# _extract_features_4_itemset a 0.0008558628553601692
# _extract_features_4_itemset i  158
# _extract_features_4_itemset a 0.11560448927231712
# _extract_features_4_itemset i  159
# _extract_features_4_itemset a 0.013906204634581932
# _extract_features_4_itemset i  160
# _extract_features_4_itemset a -0.1034862469439024
# _extract_features_4_itemset i  161
# _extract_features_4_itemset a 1.0
# _extract_features_4_itemset i  162
# _extract_features_4_itemset a -1.0
# a [-0.03411333 -0.06216155 -0.05566966 -0.04977373 -0.03378833  0.03016498
#   0.03580032  0.02886829 -0.00465982  0.17944136 -0.02680175  0.00735713
#   0.01307348 -0.02865009 -0.05294634  0.0645684  -0.54381234 -0.71044298
#  -0.36297131 -0.09411517 -0.06160527 -0.0435595  -0.10371465 -0.11527947
#   1.          0.11980295  1.         -0.3027241  -0.1327409  -0.05926466
#  -0.09781858 -0.04549838 -0.02894695 -0.02300764  0.05337283 -0.3960162
#  -0.07271163 -0.10665387 -0.13902864 -0.06897819 -0.09054055 -0.07086944
#  -0.17912516 -0.14092461 -0.12496123 -0.15865426 -0.13613563 -0.08604414
#  -0.16761638 -0.15441082 -0.08756851 -0.19064758 -0.08756851 -0.13015854
#  -0.10788857 -0.05861568 -0.05861568 -0.16278837 -0.07965649 -0.14646667
#  -0.12810473 -0.41628616 -0.02514832 -0.09482476 -0.06082931 -0.2294101
#  -0.12601771 -0.09892435 -0.17384791 -0.05631526 -0.14555751 -0.1161665
#  -0.06897819 -0.07086944  1.         -0.13318034 -0.06503126  0.07941889
#  -0.03482452 -0.04607816 -0.00563563  0.06583743 -0.08401528 -0.10745143
#  -0.05057959  0.0142141   0.00621069 -0.00551035  0.00978898 -0.0304435
#  -0.0290161  -0.0356096  -0.00921111  0.00936227  0.00597604  0.05883813
#  -0.14666221 -0.20119379 -0.09815929 -0.12699332 -0.14525648 -0.30609763
#  -0.0782007  -0.11849978 -0.13349455 -0.08009671 -0.08737767  1.
#  -0.16308428 -0.0729429  -0.09258713 -0.37059837 -0.0729429  -0.37059837
