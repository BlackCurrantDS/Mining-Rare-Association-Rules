# %% [markdown]
# <a href="https://colab.research.google.com/github/BlackCurrantDS/DBSE_Project/blob/main/optics%2Bevaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Loading Feature vector

# %%
def string_2_itemset(key):
    if key == '':
        return []
    else: 
        return key.split(',')

def itemset_2_string(itemset):
    return ",".join(itemset)

# %%
class AssociationRule:
    def __init__(self, left, right):
        self.left_items = left
        self.right_items = right
        self.scores = []
        
    def length(self):
        return len(self.left_items) + len(self.right_items)
     
    def score(self, index):
        return self.scores[index]
    
    def lhs_string(self):
        return itemset_2_string(self.left_items)
        
    def rhs_string(self):
        return itemset_2_string(self.right_items)
    
    def serialize(self):
        left_key = self.lhs_string()
        right_key = self.rhs_string()
        return left_key + ">" + right_key
    
    @staticmethod        
    def string_2_rule(s):
        subStrings = s.split(">")
        left = string_2_itemset(subStrings[0].strip())
        right = string_2_itemset(subStrings[1].strip())
        #print("AssociationRule(left, right",AssociationRule(left, right))
        return AssociationRule(left, right)

    def append_score(self, score):
        self.scores.append(score)
        
    def get_itemset(self):
        itemset = []
        itemset.extend(self.left_items)
        itemset.extend(self.right_items)
        itemset.sort()
        return itemset
        
        
    def rule_itemset_2_string(self):
        itemset = self.get_itemset()
        return itemset_2_string(itemset)
    
    def compute_basic_probs(self,frequent_itemsets, nTransactions):  
        
        left = frequent_itemsets[self.lhs_string()]
        right = frequent_itemsets[self.rhs_string()]
        
        both = frequent_itemsets[self.rule_itemset_2_string()]
        
        vector = {}
        
        ''' 1. P(A)'''
        p_A = left/nTransactions
        vector['A'] = p_A
        
        ''' 2. P(B)'''
        p_B = right/nTransactions
        vector['B'] = p_B
        
        ''' 3. P(~A)'''
        p_not_A = 1 - p_A
        vector['~A'] = p_not_A
        
        ''' 4. P(~B)'''
        p_not_B = 1 - p_B
        vector['~B'] = p_not_B
        
        ''' 5. P(AB) '''
        p_A_and_B = both/nTransactions
        vector['AB'] = p_A_and_B
        
        ''' 6. P(~AB)'''
        p_not_A_and_B = (right - both)/nTransactions
        vector['~AB'] = p_not_A_and_B
        
        ''' 7. P(A~B)'''
        p_A_and_not_B = (left - both)/nTransactions
        vector['A~B'] = p_A_and_not_B
        
        ''' 8. P(~A~B)'''
        p_not_A_and_not_B = 1 - (left + right - both)/nTransactions
        vector['~A~B'] = p_not_A_and_not_B 
        
        '''
        9. P(A|B)
        '''
        p_A_if_B = p_A_and_B / p_B
        vector['A|B'] = p_A_if_B
        
        '''
        10. P(~A|~B)
        '''
        p_not_A_if_not_B = p_not_A_and_not_B / p_not_B
        vector['~A|~B'] = p_not_A_if_not_B
        
        '''
        11. P(A|~B)
        '''
        p_A_if_not_B = p_A_and_not_B/p_not_B
        vector['A|~B'] = p_A_if_not_B
        
        '''
        12. p(~A|B)
        '''
        p_not_A_if_B = p_not_A_and_B / p_B
        vector['~A|B'] = p_not_A_if_B
        
        '''
        13. P(B|A)
        '''
        p_B_if_A = p_A_and_B / p_A
        vector['B|A'] = p_B_if_A
        
        '''
        14. P(~B|~A)
        '''
        p_not_B_if_not_A = p_not_A_and_not_B / p_not_A
        vector['~B|~A'] = p_not_B_if_not_A
        
        '''
        15. P(B|~A)
        '''
        p_B_if_not_A = p_not_A_and_B/p_not_A
        vector['B|~A'] = p_B_if_not_A
        
        '''
        16. p(~B|A)
        '''
        p_not_B_if_A = p_A_and_not_B / p_A
        vector['~B|A'] = p_not_B_if_A
        
        return vector
    
    def is_redundant_(self, bits, k, itemset, freq_itemset_dict): 
        '''
        Run out of items --> create rule and check format criterion
        '''
        if k >= len(itemset):
            items_1 = []
            items_2 = []
            for index in range(len(bits)):
                if bits[index] == True:
                    items_1.append(itemset[index])
                else:
                    items_2.append(itemset[index])
            for item in items_2:
                rule = AssociationRule(items_1, [item])
                confidence = freq_itemset_dict.getConfidence(rule)
                if confidence == 1: return True
            return False 
      
        value_domain = [True, False]
        for value in value_domain:
            bits[k] = value
            checker = self.is_redundant_(bits, k+1, itemset, freq_itemset_dict)
            if checker == True: return True
            bits[k] = True    
        return False
    
    '''
    Expand an item-set with equivalent items.
    '''
    def is_redundant(self, freq_itemset_dict):
        bits = [True for _ in self.left_items]
        checker = self.is_redundant_(bits, 0, self.left_items, freq_itemset_dict)
        if checker == True: return True
        
        bits =  [True for _ in self.right_items]
        return self.is_redundant_(bits, 0, self.right_items, freq_itemset_dict)
    
    '''
    Check if an item-set is satisfied condition of the rule. 
    '''
    def satisfy_rule(self, itemset, is_lhs = True):
        condition = self.left_items
        if is_lhs == False: condition = self.right_items
        if len(condition) > len(itemset) or len(itemset) == 0:
            return False
        for item in condition:
            if item not in itemset:
                return False
        return True

# %%
def string_2_rule(s):
        subStrings = s.split(">")
        left = string_2_itemset(subStrings[0].strip())
        right = string_2_itemset(subStrings[1].strip())
        return AssociationRule(left, right)

# %%
 import json
 import numpy as np
 def load_feature_vectors():
        data = []
        lengths = []
        
        with open("/content/miner.tmp.non_redundant_rules", 'r') as feature_reader:
            print('Loading number of LHS and RHS features...')
            lhs_count = int(feature_reader.readline())
            rhs_count = int(feature_reader.readline())
            print('Loading feature vectors... ')
            for line in feature_reader:
                rule_text, f_vector = json.loads(line.strip())
                rule = string_2_rule(rule_text.strip())
                lengths.append(rule.length())
                #print(rule) this rule as an object of the assocition rule class
                data.append(f_vector)
                
                
        return np.array(data), lengths, lhs_count, rhs_count

# %%
X_train, lengths, lhs_feature_count, rhs_feature_count = load_feature_vectors() #step 1
# Out:
# Loading number of LHS and RHS features...
# Loading feature vectors...

# %%
lhs_feature_count,rhs_feature_count
# Out:
# (42, 2)

# %% [markdown]
# Loading Association Rules

# %%
def load_association_rules():
        association_rules_list = []
        with open("/content/miner.tmp.non_redundant_rules", 'r') as rules_reader:
            rules_reader.readline()
            rules_reader.readline()
            
            for line in rules_reader:
                rule_text, _ = json.loads(line.strip())
                association_rules_list.append(AssociationRule.string_2_rule(rule_text.strip()))
        print(association_rules_list)
        return association_rules_list

# %%
association_rules_list = load_association_rules() #step 2
# Out:
# [<__main__.AssociationRule object at 0x7f6b67ee2128>, <__main__.AssociationRule object at 0x7f6b67ee2dd8>, <__main__.AssociationRule object at 0x7f6b67ee2e80>, <__main__.AssociationRule object at 0x7f6b67ee2908>, <__main__.AssociationRule object at 0x7f6b67ee2748>, <__main__.AssociationRule object at 0x7f6b67ef1be0>, <__main__.AssociationRule object at 0x7f6b67ef1668>, <__main__.AssociationRule object at 0x7f6b67ef1b00>, <__main__.AssociationRule object at 0x7f6b67ef1240>, <__main__.AssociationRule object at 0x7f6b67ef1b70>, <__main__.AssociationRule object at 0x7f6b89798630>, <__main__.AssociationRule object at 0x7f6b674074a8>, <__main__.AssociationRule object at 0x7f6b67407cc0>, <__main__.AssociationRule object at 0x7f6b672652b0>, <__main__.AssociationRule object at 0x7f6b651a64e0>, <__main__.AssociationRule object at 0x7f6b651a6780>, <__main__.AssociationRule object at 0x7f6b651a6198>, <__main__.AssociationRule object at 0x7f6b67d79470>, <__main__.AssociationRule object at 0x7f6b681eecc0>, <__main__.AssociationRule object at 0x7f6b681ee780>, <__main__.AssociationRule object at 0x7f6b67c040f0>, <__main__.AssociationRule object at 0x7f6b67ec6588>, <__main__.AssociationRule object at 0x7f6b67ec62b0>, <__main__.AssociationRule object at 0x7f6b691d7908>, <__main__.AssociationRule object at 0x7f6b691d7128>, <__main__.AssociationRule object at 0x7f6b65190fd0>, <__main__.AssociationRule object at 0x7f6b684ea4e0>, <__main__.AssociationRule object at 0x7f6b655a6748>, <__main__.AssociationRule object at 0x7f6b66d9aac8>, <__main__.AssociationRule object at 0x7f6b67235be0>, <__main__.AssociationRule object at 0x7f6b67235e48>, <__main__.AssociationRule object at 0x7f6b67235908>, <__main__.AssociationRule object at 0x7f6b685372b0>, <__main__.AssociationRule object at 0x7f6b6821ebe0>, <__main__.AssociationRule object at 0x7f6b683617f0>, <__main__.AssociationRule object at 0x7f6b680a6a20>, <__main__.AssociationRule object at 0x7f6b680a6e80>, <__main__.AssociationRule object at 0x7f6b680a6358>, <__main__.AssociationRule object at 0x7f6b68371d68>, <__main__.AssociationRule object at 0x7f6b680efda0>, <__main__.AssociationRule object at 0x7f6b67f5ac50>, <__main__.AssociationRule object at 0x7f6b67f5afd0>, <__main__.AssociationRule object at 0x7f6b67f5a400>, <__main__.AssociationRule object at 0x7f6b675195c0>, <__main__.AssociationRule object at 0x7f6b67519a20>, <__main__.AssociationRule object at 0x7f6b685111d0>, <__main__.AssociationRule object at 0x7f6b66ed3550>, <__main__.AssociationRule object at 0x7f6b66ed3e10>, <__main__.AssociationRule object at 0x7f6b66854550>, <__main__.AssociationRule object at 0x7f6b6626fcc0>, <__main__.AssociationRule object at 0x7f6b69200898>, <__main__.AssociationRule object at 0x7f6b67b3dbe0>, <__main__.AssociationRule object at 0x7f6b898a95c0>, <__main__.AssociationRule object at 0x7f6b6839e898>, <__main__.AssociationRule object at 0x7f6b6839e940>, <__main__.AssociationRule object at 0x7f6b66564f98>, <__main__.AssociationRule object at 0x7f6b66564b38>, <__main__.AssociationRule object at 0x7f6b66564780>, <__main__.AssociationRule object at 0x7f6b66564c50>, <__main__.AssociationRule object at 0x7f6b66564dd8>, <__main__.AssociationRule object at 0x7f6b665646d8>, <__main__.AssociationRule object at 0x7f6b67e7beb8>, <__main__.AssociationRule object at 0x7f6b67962898>, <__main__.AssociationRule object at 0x7f6b65b61588>, <__main__.AssociationRule object at 0x7f6b65b61240>, <__main__.AssociationRule object at 0x7f6b664db6a0>, <__main__.AssociationRule object at 0x7f6b664dbe10>, <__main__.AssociationRule object at 0x7f6b664db240>, <__main__.AssociationRule object at 0x7f6b664db518>, <__main__.AssociationRule object at 0x7f6b664db9b0>, <__main__.AssociationRule object at 0x7f6b664dbc88>, <__main__.AssociationRule object at 0x7f6b664db710>, <__main__.AssociationRule object at 0x7f6b664db048>, <__main__.AssociationRule object at 0x7f6b664dbb70>, <__main__.AssociationRule object at 0x7f6b664db780>, <__main__.AssociationRul ...

# %% [markdown]
# Loading frequent itemsetes

# %%
class ItemsetDictionary(object):
    

    def __init__(self, ntransactions = 0):
        self.itemsets = {}
        self.ntransactions = ntransactions
            
    def size(self):
        return len(self.itemsets)
    
    def exists(self, itemset_key):
        return itemset_key in self.itemsets
    
    def add_itemset(self, itemset_key, amount):
        self.itemsets[itemset_key] = amount
        
    def clear(self):
        self.itemsets.clear()
    
    def convert_2_indexes(self):
        k = 0
        dict_items_indexes = {}
        for item_name, _ in self.itemsets.items():
            dict_items_indexes[item_name] = k
            k += 1
        return dict_items_indexes
            
    def get_names(self):
        return self.itemsets.keys()
        
    def get_frequency(self, itemset_key):
        if self.exists(itemset_key):
            return self.itemsets[itemset_key]
        return 0
        
    def getConfidence(self, rule):
        left = self.get_frequency(rule.lhs_string())
        both = self.get_frequency(rule.rule_itemset_2_string())
        if left == 0: return 0
        return both/left
    
    def get_frequency_combo(self, rule):
        left = self.get_frequency(rule.lhs_string())
        right =self.get_frequency(rule.rhs_string())
        both = self.get_frequency(rule.rule_itemset_2_string())
        
        return left, right, both
    
    def get_support(self, itemset_key):     
        return self.get_frequency(itemset_key)/self.ntransactions
       
    def split(self, nchunks):
        itemsets_names = self.itemsets.keys()
        nitemsets = len(itemsets_names)
        
        print ('Number of frequent item-sets: ' + str(nitemsets))
        itemset_chunks = [[] for _ in range(nchunks)]
        size_of_chunk = (int)(nitemsets/nchunks) + 1
                    
        index = 0
        counter = 0
        
        for itemset_key in itemsets_names:
            if counter < size_of_chunk:
                itemset_chunks[index].append(string_2_itemset(itemset_key))
                counter += 1
            elif counter == size_of_chunk:
                index += 1
                itemset_chunks[index].append(string_2_itemset(itemset_key))
                counter = 1  
                  
        return itemset_chunks
    
    def save_2_file(self, file_name, write_mode = 'a', write_support = False):
        with open(file_name, write_mode) as text_file:
            for key, value in self.itemsets.items():
                t = value
                if write_support == True:
                    t = value/self.ntransactions
                text_file.write(key + ':' + str(t))
                text_file.write('\n')
            
    def load_from_file(self,file_name):
        self.itemsets.clear()
        
        with open(file_name, "r") as text_file:
            self.ntransactions = int(text_file.readline())
            for line in text_file:
                print (line)
                subStrings = line.split(':')
                itemset_key = subStrings[0].strip()
                frequency = int(subStrings[1].strip())
                
                self.itemsets[itemset_key] = frequency
                
    def _complement_condition(self, r1, r2):
        merged_itemset = merge_itemsets(r1.left_items, 
                                        r2.left_items)
        
        s = self.get_frequency(itemset_2_string(merged_itemset))
        sl = self.get_frequency(r1.lhs_string())
        sr = self.get_frequency(r2.lhs_string())
    
        #if s > 0: return True
        return max(s/sl, s/sr)
     
        
    '''
    Check if two rules are contrary each other based on the matching function
    r1, r2: dictionaries includes {'r': rule, 'f': feature vector}
    contrast_params: contains thresholds, and size of LHS, RHS features 
    '''
    def is_contrast(self, r1, r2, contrast_params):
        
        n = contrast_params.n_lhs_features
        a = cosine_similarity(np.reshape(r1['f'][n:], (1, -1)),
                              np.reshape(r2['f'][n:], (1, -1)))[0,0]
        if a > contrast_params.delta2: return (False, 0, 0)
        
        b = cosine_similarity(np.reshape(r1['f'][:n], (1, -1)), 
                              np.reshape(r2['f'][:n], (1, -1)))[0,0]
        if b <= contrast_params.delta1: return (False, 0, 0)
        
        t = self._complement_condition(r1['r'], r2['r'])
        if t > contrast_params.share_threshold:
            return (True, b, t)
        return (False, 0, 0)
    
    
    def is_inner_contrast(self, group, contrast_params):
        #print('check inner')
        both_condition = self.find_pottential_contrast_locs(group, group, contrast_params)
        if both_condition is None: return False 
        
        for i in range(len(both_condition[0])):
            x = both_condition[0][i]
            y = both_condition[1][i]
            if x >= y: continue
            t = self._complement_condition(group['r'][x], group['r'][y])
            if t > contrast_params.share_threshold: return True 
            
        return False

        
        
    def find_pottential_contrast_locs(self, group1, group2, contrast_params):
        rhs_sim = cosine_similarity(group1['rhs'], group2['rhs']) 
        rhs_condition = (rhs_sim > contrast_params.delta2).astype(int) 
        if np.all(rhs_condition > 0) == True: return None 
    
        
        lhs_sim = cosine_similarity(group1['lhs'], group2['lhs'])
        lhs_condition = (lhs_sim <= contrast_params.delta1).astype(int)
        if np.all(lhs_condition > 0) == True: return None 
        
        locs = np.where(lhs_condition + rhs_condition <= 0)
        return locs 
        
    def is_outer_contrast(self, group1, group2, contrast_params):
        #print('check outer')
        both_condition = self.find_pottential_contrast_locs(group1, group2, contrast_params)
        if both_condition is None: return False 
        
        for i in range(len(both_condition[0])):
            x = both_condition[0][i]
            y = both_condition[1][i]
            t = self._complement_condition(group1['r'][x], group2['r'][y])
            if t > contrast_params.share_threshold: return True 
            
        return False

# %%
def load_frequent_itemsets_as_dict():
        freq_itemset_dict = ItemsetDictionary(0)
        freq_itemset_dict.load_from_file("/content/miner.tmp.itemsets")
        return freq_itemset_dict

# %%
freq_itemset_dict = load_frequent_itemsets_as_dict()
# Out:
# Streaming output truncated to the last 5000 lines.
# a1@40-49,a2@premeno,a6@2,a7@left,a9@no,class@yes:3
#
# a1@40-49,a4@0-2,a6@2,a7@left,class@yes:3
#
# a1@40-49,a4@0-2,a6@2,a7@left,a9@no,class@yes:2
#
# a1@40-49,a2@premeno,a4@0-2,a6@2,a7@left,class@yes:3
#
# a1@40-49,a2@premeno,a4@0-2,a6@2,a7@left,a9@no,class@yes:2
#
# a1@40-49,a5@no,a6@2,a7@left,class@yes:3
#
# a1@40-49,a4@0-2,a5@no,a6@2,a7@left,class@yes:3
#
# a1@40-49,a5@no,a6@2,a7@left,a9@no,class@yes:2
#
# a1@40-49,a2@premeno,a5@no,a6@2,a7@left,class@yes:3
#
# a1@40-49,a4@0-2,a5@no,a6@2,a7@left,a9@no,class@yes:2
#
# a1@40-49,a2@premeno,a4@0-2,a5@no,a6@2,a7@left,class@yes:3
#
# a1@40-49,a2@premeno,a5@no,a6@2,a7@left,a9@no,class@yes:2
#
# a1@40-49,a2@premeno,a4@0-2,a5@no,a6@2,a7@left,a9@no,class@yes:2
#
# a1@40-49,a2@premeno,a6@2,a7@left,class@yes:5
#
# a1@40-49,a4@0-2,a6@2,class@yes:7
#
# a1@40-49,a4@0-2,a5@no,a6@2,class@yes:7
#
# a1@40-49,a2@premeno,a4@0-2,a6@2,class@yes:6
#
# a1@40-49,a2@premeno,a4@0-2,a5@no,a6@2,class@yes:6
#
# a1@40-49,a4@0-2,a6@2,a9@no,class@yes:5
#
# a1@40-49,a2@premeno,a4@0-2,a6@2,a9@no,class@yes:4
#
# a1@40-49,a4@0-2,a5@no,a6@2,a9@no,class@yes:5
#
# a1@40-49,a2@premeno,a4@0-2,a5@no,a6@2,a9@no,class@yes:4
#
# a1@40-49,a5@no,a6@2,a9@no,class@yes:6
#
# a1@40-49,a2@premeno,a6@2,a9@no,class@yes:6
#
# a1@40-49,a2@premeno,a5@no,a6@2,a9@no,class@yes:5
#
# a1@40-49,a5@no,a6@2,class@yes:8
#
# a1@40-49,a2@premeno,a5@no,a6@2,class@yes:7
#
# a1@40-49,a2@premeno,a6@2,class@yes:10
#
# a4@0-2,a6@2,a7@left,a9@no,class@yes:6
#
# a4@0-2,a5@no,a6@2,a7@left,a9@no,class@yes:6
#
# a2@premeno,a4@0-2,a6@2,a7@left,class@yes:6
#
# a2@premeno,a4@0-2,a6@2,a7@left,a9@no,class@yes:5
#
# a2@premeno,a4@0-2,a5@no,a6@2,a7@left,class@yes:6
#
# a2@premeno,a4@0-2,a5@no,a6@2,a7@left,a9@no,class@yes:5
#
# a4@0-2,a5@no,a6@2,a7@left,class@yes:7
#
# a6@2,a7@left,a9@no,class@yes:8
#
# a2@premeno,a6@2,a7@left,a9@no,class@yes:7
#
# a5@no,a6@2,a7@left,a9@no,class@yes:6
#
# a2@premeno,a5@no,a6@2,a7@left,class@yes:6
#
# a2@premeno,a5@no,a6@2,a7@left,a9@no,class@yes:5
#
# a2@premeno,a6@2,a7@left,class@yes:9
#
# a2@premeno,a4@0-2,a6@2,class@yes:10
#
# a2@premeno,a4@0-2,a6@2,a9@no,class@yes:8
#
# a2@premeno,a4@0-2,a5@no,a6@2,class@yes:10
#
# a2@premeno,a4@0-2,a5@no,a6@2,a9@no,class@yes:8
#
# a4@0-2,a6@2,a9@no,class@yes:12
#
# a4@0-2,a5@no,a6@2,a9@no,class@yes:12
#
# a4@0-2,a5@no,a6@2,class@yes:14
#
# a2@premeno,a6@2,class@yes:16
#
# a2@premeno,a5@no,a6@2,class@yes:12
#
# a2@premeno,a6@2,a9@no,class@yes:11
#
# a2@premeno,a5@no,a6@2,a9@no,class@yes:9
#
# a5@no,a6@2,a9@no,class@yes:14
#
# a5@no,a6@2,class@yes:18
#
# a1@40-49,a2@ge40,a4@0-2,class@yes:1
#
# a1@40-49,a2@ge40,a4@0-2,a9@no,class@yes:1
#
# a1@40-49,a2@ge40,a4@0-2,a7@right,class@yes:1
#
# a1@40-49,a2@ge40,a4@0-2,a5@no,class@yes:1
#
# a1@40-49,a2@ge40,a4@0-2,a7@right,a9@no,class@yes:1
#
# a1@40-49,a2@ge40,a4@0-2,a5@no,a9@no,class@yes:1
#
# a1@40-49,a2@ge40,a4@0-2,a5@no,a7@right,class@yes:1
#
# a1@40-49,a2@ge40,a4@0-2,a5@no,a7@right,a9@no,class@yes:1
#
# a1@40-49,a2@ge40,a7@right,class@yes:2
#
# a1@40-49,a2@ge40,a5@no,a7@right,class@yes:2
#
# a1@40-49,a2@ge40,a7@right,a8@left_low,class@yes:1
#
# a1@40-49,a2@ge40,a5@no,a7@right,a8@left_low,class@yes:1
#
# a1@40-49,a2@ge40,a7@right,a9@no,class@yes:1
#
# a1@40-49,a2@ge40,a5@no,a7@right,a9@no,class@yes:1
#
# a1@40-49,a2@ge40,a7@left,a9@no,class@yes:1
#
# a1@40-49,a2@ge40,a5@no,a7@left,a9@no,class@yes:1
#
# a1@40-49,a2@ge40,a8@left_low,a9@no,class@yes:1
#
# a1@40-49,a2@ge40,a7@left,a8@left_low,a9@no,class@yes:1
#
# a1@40-49,a2@ge40,a5@no,a8@left_low,a9@no,class@yes:1
#
# a1@40-49,a2@ge40,a5@no,a7@left,a8@left_low,a9@no,class@yes:1
#
# a1@40-49,a2@ge40,a5@no,a9@no,class@yes:2
#
# a1@40-49,a2@ge40,a8@left_low,class@yes:2
#
# a1@40-49,a2@ge40,a5@no,a8@left_low,class@yes:2
#
# a1@40-49,a2@ge40,a7@left,class@yes:2
#
# a1@40-49,a2@ge40,a7@left,a8@left_low,class@yes:1
#
# a1@40-49,a2@ge40,a5@no,a7@left,class@yes:1
#
# a1@40-49,a2@ge40,a5@no,a7@left,a8@left_low,class@yes:1
#
# a1@40-49,a2@ge40,a5@no,class@yes:3
#
# a1@40-49,a7@right,a8@left_low,class@yes:4
#
# a1@40-49,a5@no,a7@right,a8@left_low,class@yes:4
#
# a1@40-49,a7@right,a8@left_low,a9@no,class@yes:2
#
# a1@40-49,a4@0-2,a7@right,a8@left_low,class@yes:3
#
# a1@40-49,a2@premeno,a7@right,a8@left_low,class@yes:3
#
# a1@40-49,a5@no,a7@right,a8@left_low,a9@no,class@yes:2
#
# a1@40-49,a4@0-2,a5@no,a7@right,a8@left_low,class@yes:3
#
# a1@40-49,a2@premeno,a5@no,a7@right,a8@left_low,class@yes:3
#
# a1@40-49,a4@0-2,a7@right,a8@left_low,a9@no,class@yes:2
#
# a1@40-49,a2@premeno,a7@right,a8@left_low,a9@no,class@yes:2
#
# a1@40-49,a2@premeno,a4@0-2,a7@right,a8@left_low,class@yes:3
#
# a1@40-49,a4@0-2,a5@no,a7@right,a8@left_low,a9@no,class@yes:2
#
# a1@40-49,a2@premeno,a5@no,a7@right,a8@left_low,a9@no,class@yes:2
#
# a1@40-49,a2@premeno,a4@0-2,a5@no,a7@right,a8@left_low,class@yes:3
#
# a1@40-49,a2@premeno,a4@0-2,a7@right,a8@left_low,a9@no,class@yes:2
#
# a1@40-49,a2@premeno,a4@0-2,a5@no,a7@right,a8@left_low,a9@no,class@yes:2
#
# a1@40-49,a4@0-2,a8@left_low,class@yes:7
#
# a1@40-49,a4@0-2,a7@left,a8@left_low,class@yes:4
#
# a1@40-49,a4@0-2,a5@no,a8@left_low,class@yes:7
#
# a1@40-49,a2@premeno,a4@0-2,a8@left_low,class@yes:7
#
# a1@40-49,a4@0-2,a5@no,a7@left,a8@left_low,class@yes:4
#
# a1@40-49,a2@premeno,a4@0-2,a7@left,a8@left_low,class@yes:4
#
# a1@40-49,a2@premeno,a4@0-2,a5@no,a8@left_low,class@yes:7
#
# a1@40-49,a2@premeno,a4@0-2,a5@no,a7@left,a8@left_low,class@yes:4
#
# a1@40-49,a4@0-2,a8@left_low,a9@no,class@yes:4
#
# a1@40-49,a4@0-2,a5@no,a8@left_low,a9@no,class@yes:4
#
# a1@40-49,a4@0-2,a7@left,a8@left_low,a9@no,class@yes:2
#
# a1@40-49,a2@premeno,a4@0-2,a8@left_low,a9@no,class@yes:4
#
# a1@40-49,a4@0-2,a5@no,a7@left,a8@left_low,a9@no,class@yes:2
#
# a1@40-49,a2@premeno,a4@0-2,a5@no,a8@left_low,a9@no,class@yes:4
#
# a1@40-49,a2@premeno,a4@0-2,a7@left,a8@left_low,a9@no,class@yes:2
#
# a1@40-49,a2@premeno,a4@0-2,a5@no,a7@left,a8@left_low,a9@no,class@yes:2
#
# a1@40-49,a7@left,a8@left_low,a9@no,class@yes:5
#
# a1@40-49,a2@premeno,a7@left,a8@left_low,a9@no,class@yes:4
#
# a1@40-49,a5@no,a7@left,a8@left_low,a9@no,class@yes:3
#
# a1@40-49,a2@premeno,a5@no,a7@left,a8@left_low,a9@no,class@yes:2
#
# a1@40-49,a2@premeno,a5@no,a8@left_low,a9@no,class@yes:4
#
# a1@40-49,a2@premeno,a8@left_low,a9@no,class@yes:6
#
# a1@40-49,a5@no,a7@left,a8@left_low,class@yes:5
#
# a1@40-49,a2@premeno,a5@no,a7@left,a8@left_low,class@yes:4
#
# a1@40-49,a2@premeno,a7@left,a8@left_low,class@yes:7
#
# a1@40-49,a5@no,a8@left_low,class@yes:9
#
# a1@40-49,a2@premeno,a5@no,a8@left_low,class@yes:7
#
# a1@40-49,a2@premeno,a8@left_low,class@yes:10
#
# a1@40-49,a4@0-2,a7@right,a9@no,class@yes:7
#
# a1@40-49,a2@premeno,a4@0-2,a7@right,class@yes:7
#
# a1@40-49,a2@premeno,a4@0-2,a7@right,a9@no,class@yes:6
#
# a1@40-49,a4@0-2,a5@no,a7@right,class@yes:6
#
# a1@40-49,a5@no,a7@right,a9@no,class@yes:6
#
# a1@40-49,a4@0-2,a5@no,a7@right,a9@no,class@yes:5
#
# a1@40-49,a2@premeno,a5@no,a7@right,a9@no,class@yes:5
#
# a1@40-49,a2@premeno,a4@0-2,a5@no,a7@right,class@yes:5
#
# a1@40-49,a2@premeno,a4@0-2,a5@no,a7@right,a9@no,class@yes:4
#
# a1@40-49,a7@right,a9@no,class@yes:9
#
# a1@40-49,a2@premeno,a7@right,a9@no,class@yes:8
#
# a1@40-49,a2@premeno,a7@right,class@yes:10
#
# a1@40-49,a4@0-2,a7@left,class@yes:7
#
# a1@40-49,a4@0-2,a5@no,a7@left,class@yes:7
#
# a1@40-49,a4@0-2,a7@left,a9@no,class@yes:5
#
# a1@40-49,a2@premeno,a4@0-2,a7@left,class@yes:7
#
# a1@40-49,a4@0-2,a5@no,a7@left,a9@no,class@yes:5
#
# a1@40-49,a2@premeno,a4@0-2,a5@no,a7@left,class@yes:7
#
# a1@40-49,a2@premeno,a4@0-2,a7@left,a9@no,class@yes:5
#
# a1@40-49,a2@premeno,a4@0-2,a5@no,a7@left,a9@no,class@yes:5
#
# a1@40-49,a5@no,a7@left,a9@no,class@yes:6
#
# a1@40-49,a2@premeno,a5@no,a7@left,a9@no,class@yes:5
#
# a1@40-49,a2@premeno,a5@no,a7@left,class@yes:7
#
# a1@40-49,a7@left,a9@no,class@yes:9
#
# a1@40-49,a2@premeno,a7@left,a9@no,class@yes:8
#
# a1@40-49,a2@premeno,a7@left,class@yes:11
#
# a1@40-49,a4@0-2,a5@no,a9@no,class@yes:10
#
# a1@40-49,a2@premeno,a4@0-2,a5@no,a9@no,class@yes:9
#
# a1@40-49,a2@premeno,a4@0-2,a9@no,class@yes:11
#
# a1@40-49,a4@0-2,a5@no,class@yes:13
#
# a1@40-49,a2@premeno,a4@0-2,a5@no,class@yes:12
#
# a1@40-49,a2@premeno,a4@0-2,class@yes:14
#
# a1@40-49,a5@no,a9@no,class@yes:12
#
# a1@40-49,a2@premeno,a5@no,a9@no,class@yes:10
#
# a1@40-49,a2@premeno,a5@no,class@yes:13
#
# a1@40-49,a9@no,class@yes:18
#
# a1@40-49,a2@premeno,a9@no,class@yes:16
#
# a1@40-49,a2@premeno,class@yes:21
#
# a2@ge40,a4@0-2,a8@left_low,class@yes:3
#
# a2@ge40,a4@0-2,a8@left_low,a9@no,class@yes:3
#
# a2@ge40,a4@0-2,a5@no,a8@left_low,class@yes:3
#
# a2@ge40,a4@0-2,a7@right,a8@left_low,class@yes:2
#
# a2@ge40,a4@0-2,a5@no,a8@left_low,a9@no,class@yes:3
#
# a2@ge40,a4@0-2,a7@right,a8@left_low,a9@no,class@yes:2
#
# a2@ge40,a4@0-2,a5@no,a7@right,a8@left_low,class@yes:2
#
# a2@ge40,a4@0-2,a5@no,a7@right,a8@left_low,a9@no,class@yes:2
#
# a2@ge40,a4@0-2,a7@left,class@yes:3
#
# a2@ge40,a4@0-2,a7@left,a8@left_low,class@yes:1
#
# a2@ge40,a4@0-2,a7@left,a9@no,class@yes:2
#
# a2@ge40,a4@0-2,a5@no,a7@left,class@yes:3
#
# a2@ge40,a4@0-2,a7@left,a8@left_low,a9@no,class@yes:1
#
# a2@ge40,a4@0-2,a5@no,a7@left,a8@left_low,class@yes:1
#
# a2@ge40,a4@0-2,a5@no,a7@left,a9@no,class@yes:2
#
# a2@ge40,a4@0-2,a5@no,a7@left,a8@left_low,a9@no,class@yes:1
#
# a2@ge40,a4@0-2,a9@no,class@yes:8
#
# a2@ge40,a4@0-2,a5@no,a9@no,class@yes:8
#
# a2@ge40,a4@0-2,a7@right,a9@no,class@yes:6
#
# a2@ge40,a4@0-2,a5@no,a7@right,a9@no,class@yes:6
#
# a2@ge40,a4@0-2,a7@right,class@yes:8
#
# a2@ge40,a4@0-2,a5@no,a7@right,class@yes:8
#
# a2@ge40,a4@0-2,a5@no,class@yes:11
#
# a2@ge40,a7@right,a8@left_low,a9@no,class@yes:3
#
# a2@ge40,a5@no,a7@right,a8@left_low,class@yes:3
#
# a2@ge40,a5@no,a7@right,a8@left_low,a9@no,class@yes:2
#
# a2@ge40,a7@left,a8@left_low,a9@no,class@yes:4
#
# a2@ge40,a5@no,a7@left,a8@left_low,a9@no,class@yes:3
#
# a2@ge40,a5@no,a8@left_low,a9@no,class@yes:5
#
# a2@ge40,a7@left,a8@left_low,class@yes:8
#
# a2@ge40,a5@no,a8@left_low,class@yes:8
#
# a2@ge40,a5@no,a7@left,a8@left_low,class@yes:5
#
# a2@ge40,a7@right,a9@no,class@yes:10
#
# a2@ge40,a5@no,a7@right,a9@no,class@yes:8
#
# a2@ge40,a5@no,a7@right,class@yes:11
#
# a2@ge40,a7@left,a9@no,class@yes:6
#
# a2@ge40,a5@no,a7@left,a9@no,class@yes:4
#
# a2@ge40,a5@no,a7@left,class@yes:7
#
# a2@ge40,a9@no,class@yes:16
#
# a2@ge40,a5@no,a9@no,class@yes:12
#
# a2@ge40,a5@no,class@yes:18
#
# a2@premeno,a7@right,a8@left_low,class@yes:5
#
# a2@premeno,a7@right,a8@left_low,a9@no,class@yes:3
#
# a2@premeno,a4@0-2,a7@right,a8@left_low,class@yes:5
#
# a2@premeno,a5@no,a7@right,a8@left_low,class@yes:5
#
# a2@premeno,a4@0-2,a7@right,a8@left_low,a9@no,class@yes:3
#
# a2@premeno,a5@no,a7@right,a8@left_low,a9@no,class@yes:3
#
# a2@premeno,a4@0-2,a5@no,a7@right,a8@left_low,class@yes:5
#
# a2@premeno,a4@0-2,a5@no,a7@right,a8@left_low,a9@no,class@yes:3
#
# a7@right,a8@left_low,a9@no,class@yes:6
#
# a4@0-2,a7@right,a8@left_low,a9@no,class@yes:5
#
# a5@no,a7@right,a8@left_low,a9@no,class@yes:5
#
# a4@0-2,a5@no,a7@right,a8@left_low,a9@no,class@yes:5
#
# a4@0-2,a7@right,a8@left_low,class@yes:7
#
# a4@0-2,a5@no,a7@right,a8@left_low,class@yes:7
#
# a5@no,a7@right,a8@left_low,class@yes:8
#
# a2@premeno,a4@0-2,a5@no,a7@right,class@yes:10
#
# a2@premeno,a4@0-2,a7@right,a9@no,class@yes:10
#
# a2@premeno,a4@0-2,a5@no,a7@right,a9@no,class@yes:8
#
# a2@premeno,a7@right,a9@no,class@yes:13
#
# a2@premeno,a5@no,a7@right,class@yes:13
#
# a2@premeno,a5@no,a7@right,a9@no,class@yes:9
#
# a4@0-2,a7@right,a9@no,class@yes:16
#
# a4@0-2,a5@no,a7@right,a9@no,class@yes:14
#
# a4@0-2,a5@no,a7@right,class@yes:18
#
# a7@right,a9@no,class@yes:23
#
# a5@no,a7@right,a9@no,class@yes:17
#
# a5@no,a7@right,class@yes:24
#
# a2@premeno,a4@0-2,a7@left,a8@left_low,class@yes:7
#
# a2@premeno,a4@0-2,a5@no,a7@left,a8@left_low,class@yes:7
#
# a4@0-2,a7@left,a8@left_low,a9@no,class@yes:7
#
# a2@premeno,a4@0-2,a7@left,a8@left_low,a9@no,class@yes:5
#
# a4@0-2,a5@no,a7@left,a8@left_low,a9@no,class@yes:6
#
# a2@premeno,a4@0-2,a5@no,a7@left,a8@left_low,a9@no,class@yes:5
#
# a4@0-2,a5@no,a7@left,a8@left_low,class@yes:8
#
# a4@0-2,a8@left_low,a9@no,class@yes:12
#
# a4@0-2,a5@no,a8@left_low,a9@no,class@yes:11
#
# a2@premeno,a4@0-2,a8@left_low,class@yes:12
#
# a2@premeno,a4@0-2,a8@left_low,a9@no,class@yes:8
#
# a2@premeno,a4@0-2,a5@no,a8@left_low,class@yes:12
#
# a2@premeno,a4@0-2,a5@no,a8@left_low,a9@no,class@yes:8
#
# a4@0-2,a5@no,a8@left_low,class@yes:15
#
# a2@premeno,a5@no,a8@left_low,class@yes:12
#
# a2@premeno,a5@no,a7@left,a8@left_low,class@yes:7
#
# a2@premeno,a7@left,a8@left_low,class@yes:14
#
# a2@premeno,a7@left,a8@left_low,a9@no,class@yes:8
#
# a2@premeno,a5@no,a8@left_low,a9@no,class@yes:8
#
# a2@premeno,a5@no,a7@left,a8@left_low,a9@no,class@yes:5
#
# a5@no,a8@left_low,a9@no,class@yes:13
#
# a7@left,a8@left_low,a9@no,class@yes:13
#
# a5@no,a7@left,a8@left_low,a9@no,class@yes:8
#
# a5@no,a8@left_low,class@yes:20
#
# a5@no,a7@left,a8@left_low,class@yes:12
#
# a7@left,a8@left_low,class@yes:23
#
# a2@premeno,a5@no,a7@left,class@yes:15
#
# a2@premeno,a5@no,a7@left,a9@no,class@yes:12
#
# a5@no,a7@left,a9@no,class@yes:16
#
# a2@premeno,a7@left,class@yes:23
#
# a2@premeno,a7@left,a9@no,class@yes:16
#
# a7@left,a9@no,class@yes:24
#
# a2@premeno,a4@0-2,a7@left,class@yes:15
#
# a2@premeno,a4@0-2,a7@left,a9@no,class@yes:12
#
# a2@premeno,a4@0-2,a5@no,a7@left,class@yes:15
#
# a2@premeno,a4@0-2,a5@no,a7@left,a9@no,class@yes:12
#
# a4@0-2,a7@left,a9@no,class@yes:16
#
# a4@0-2,a5@no,a7@left,a9@no,class@yes:14
#
# a4@0-2,a5@no,a7@left,class@yes:18
#
# a2@premeno,a4@0-2,a9@no,class@yes:22
#
# a2@premeno,a4@0-2,a5@no,a9@no,class@yes:20
#
# a2@premeno,a4@0-2,a5@no,class@yes:25
#
# a4@0-2,a9@no,class@yes:32
#
# a4@0-2,a5@no,a9@no,class@yes:28
#
# a4@0-2,a5@no,class@yes:36
#
# a2@premeno,a5@no,class@yes:28
#
# a2@premeno,a5@no,a9@no,class@yes:21
#
# a2@premeno,a9@no,class@yes:29
#
# a5@no,class@yes:46
#
# a5@no,a9@no,class@yes:33
#
# a9@no,class@yes:47
#
# a1@50-59,a2@premeno,a7@left,a8@left_up:2
#
# a1@50-59,a2@premeno,a6@2,a7@left,a8@left_up:2
#
# a1@50-59,a2@premeno,a7@left,a8@left_up,a9@no:2
#
# a1@50-59,a2@premeno,a5@no,a7@left,a8@left_up:1
#
# a1@50-59,a2@premeno,a4@0-2,a7@left,a8@left_up:2
#
# a1@50-59,a2@premeno,a7@left,a8@left_up,class@no:2
#
# a1@50-59,a2@premeno,a6@2,a7@left,a8@left_up,a9@no:2
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@left,a8@left_up:1
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@left,a8@left_up:2
#
# a1@50-59,a2@premeno,a6@2,a7@left,a8@left_up,class@no:2
#
# a1@50-59,a2@premeno,a5@no,a7@left,a8@left_up,a9@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a7@left,a8@left_up,a9@no:2
#
# a1@50-59,a2@premeno,a7@left,a8@left_up,a9@no,class@no:2
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@left,a8@left_up:1
#
# a1@50-59,a2@premeno,a5@no,a7@left,a8@left_up,class@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a7@left,a8@left_up,class@no:2
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@left,a8@left_up,a9@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@left,a8@left_up,a9@no:2
#
# a1@50-59,a2@premeno,a6@2,a7@left,a8@left_up,a9@no,class@no:2
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@left,a8@left_up:1
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@left,a8@left_up,class@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@left,a8@left_up,class@no:2
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@left,a8@left_up,a9@no:1
#
# a1@50-59,a2@premeno,a5@no,a7@left,a8@left_up,a9@no,class@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a7@left,a8@left_up,a9@no,class@no:2
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@left,a8@left_up,class@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@left,a8@left_up,a9@no:1
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@left,a8@left_up,a9@no,class@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@left,a8@left_up,a9@no,class@no:2
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@left,a8@left_up,class@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@left,a8@left_up,a9@no,class@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@left,a8@left_up,a9@no,class@no:1
#
# a1@50-59,a2@premeno,a6@2,a7@right,a8@left_up:3
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@right,a8@left_up:2
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@right,a8@left_up:3
#
# a1@50-59,a2@premeno,a6@2,a7@right,a8@left_up,a9@no:2
#
# a1@50-59,a2@premeno,a6@2,a7@right,a8@left_up,class@no:3
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@right,a8@left_up:2
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@right,a8@left_up,a9@no:2
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@right,a8@left_up,class@no:2
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@right,a8@left_up,a9@no:2
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@right,a8@left_up,class@no:3
#
# a1@50-59,a2@premeno,a6@2,a7@right,a8@left_up,a9@no,class@no:2
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@right,a8@left_up,a9@no:2
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@right,a8@left_up,class@no:2
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@right,a8@left_up,a9@no,class@no:2
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@right,a8@left_up,a9@no,class@no:2
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@right,a8@left_up,a9@no,class@no:2
#
# a1@50-59,a2@premeno,a6@2,a8@left_up,a9@no:4
#
# a1@50-59,a2@premeno,a6@2,a8@left_up,a9@no,class@no:4
#
# a1@50-59,a2@premeno,a5@no,a6@2,a8@left_up:4
#
# a1@50-59,a2@premeno,a5@no,a6@2,a8@left_up,a9@no:3
#
# a1@50-59,a2@premeno,a5@no,a6@2,a8@left_up,class@no:4
#
# a1@50-59,a2@premeno,a5@no,a6@2,a8@left_up,a9@no,class@no:3
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a8@left_up:4
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a8@left_up:3
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a8@left_up,a9@no:4
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a8@left_up,class@no:4
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a8@left_up,a9@no:3
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a8@left_up,class@no:3
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a8@left_up,a9@no,class@no:4
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a8@left_up,a9@no,class@no:3
#
# a1@50-59,a2@premeno,a6@2,a8@left_up,class@no:5
#
# a1@50-59,a2@premeno,a7@right,a8@left_up,a9@no:4
#
# a1@50-59,a2@premeno,a5@no,a7@right,a8@left_up,a9@no:4
#
# a1@50-59,a2@premeno,a4@0-2,a7@right,a8@left_up:4
#
# a1@50-59,a2@premeno,a4@0-2,a7@right,a8@left_up,a9@no:4
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@right,a8@left_up:4
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@right,a8@left_up,a9@no:4
#
# a1@50-59,a2@premeno,a7@right,a8@left_up,class@no:4
#
# a1@50-59,a2@premeno,a4@0-2,a7@right,a8@left_up,class@no:3
#
# a1@50-59,a2@premeno,a7@right,a8@left_up,a9@no,class@no:3
#
# a1@50-59,a2@premeno,a5@no,a7@right,a8@left_up,class@no:4
#
# a1@50-59,a2@premeno,a4@0-2,a7@right,a8@left_up,a9@no,class@no:3
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@right,a8@left_up,class@no:3
#
# a1@50-59,a2@premeno,a5@no,a7@right,a8@left_up,a9@no,class@no:3
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@right,a8@left_up,a9@no,class@no:3
#
# a1@50-59,a2@premeno,a5@no,a7@right,a8@left_up:5
#
# a1@50-59,a2@premeno,a8@left_up,class@no:6
#
# a1@50-59,a2@premeno,a4@0-2,a8@left_up:6
#
# a1@50-59,a2@premeno,a4@0-2,a8@left_up,class@no:5
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a8@left_up:5
#
# a1@50-59,a2@premeno,a5@no,a8@left_up,class@no:5
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a8@left_up,class@no:4
#
# a1@50-59,a2@premeno,a5@no,a8@left_up,a9@no:5
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a8@left_up,a9@no:5
#
# a1@50-59,a2@premeno,a8@left_up,a9@no,class@no:5
#
# a1@50-59,a2@premeno,a5@no,a8@left_up,a9@no,class@no:4
#
# a1@50-59,a2@premeno,a4@0-2,a8@left_up,a9@no,class@no:5
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a8@left_up,a9@no,class@no:4
#
# a1@50-59,a2@premeno,a4@0-2,a8@left_up,a9@no:6
#
# a1@50-59,a2@premeno,a7@right,a8@left_low:2
#
# a1@50-59,a2@premeno,a6@2,a7@right,a8@left_low:1
#
# a1@50-59,a2@premeno,a7@right,a8@left_low,class@no:1
#
# a1@50-59,a2@premeno,a7@right,a8@left_low,a9@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a7@right,a8@left_low:2
#
# a1@50-59,a2@premeno,a5@no,a7@right,a8@left_low:2
#
# a1@50-59,a2@premeno,a6@2,a7@right,a8@left_low,class@no:1
#
# a1@50-59,a2@premeno,a6@2,a7@right,a8@left_low,a9@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@right,a8@left_low:1
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@right,a8@left_low:1
#
# a1@50-59,a2@premeno,a7@right,a8@left_low,a9@no,class@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a7@right,a8@left_low,class@no:1
#
# a1@50-59,a2@premeno,a5@no,a7@right,a8@left_low,class@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a7@right,a8@left_low,a9@no:1
#
# a1@50-59,a2@premeno,a5@no,a7@right,a8@left_low,a9@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@right,a8@left_low:2
#
# a1@50-59,a2@premeno,a6@2,a7@right,a8@left_low,a9@no,class@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@right,a8@left_low,class@no:1
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@right,a8@left_low,class@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@right,a8@left_low,a9@no:1
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@right,a8@left_low,a9@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@right,a8@left_low:1
#
# a1@50-59,a2@premeno,a4@0-2,a7@right,a8@left_low,a9@no,class@no:1
#
# a1@50-59,a2@premeno,a5@no,a7@right,a8@left_low,a9@no,class@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@right,a8@left_low,class@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@right,a8@left_low,a9@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@right,a8@left_low,a9@no,class@no:1
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@right,a8@left_low,a9@no,class@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@right,a8@left_low,class@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@right,a8@left_low,a9@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@right,a8@left_low,a9@no,class@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@right,a8@left_low,a9@no,class@no:1
#
# a1@50-59,a2@premeno,a6@2,a7@right:5
#
# a1@50-59,a2@premeno,a6@2,a7@right,class@no:5
#
# a1@50-59,a2@premeno,a6@2,a7@right,a9@no:4
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@right:4
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@right:5
#
# a1@50-59,a2@premeno,a6@2,a7@right,a9@no,class@no:4
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@right,class@no:4
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@right,class@no:5
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@right,a9@no:4
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@right,a9@no:4
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@right:4
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@right,a9@no,class@no:4
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@right,a9@no,class@no:4
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@right,class@no:4
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@right,a9@no:4
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@right,a9@no,class@no:4
#
# a1@50-59,a2@premeno,a7@right,class@no:6
#
# a1@50-59,a2@premeno,a7@right,a9@no,class@no:5
#
# a1@50-59,a2@premeno,a4@0-2,a7@right,class@no:5
#
# a1@50-59,a2@premeno,a5@no,a7@right,class@no:6
#
# a1@50-59,a2@premeno,a4@0-2,a7@right,a9@no,class@no:5
#
# a1@50-59,a2@premeno,a5@no,a7@right,a9@no,class@no:5
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@right,class@no:5
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@right,a9@no,class@no:5
#
# a1@50-59,a2@premeno,a4@0-2,a7@right:7
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@right:7
#
# a1@50-59,a2@premeno,a7@right,a9@no:7
#
# a1@50-59,a2@premeno,a4@0-2,a7@right,a9@no:6
#
# a1@50-59,a2@premeno,a5@no,a7@right,a9@no:6
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@right,a9@no:6
#
# a1@50-59,a2@premeno,a5@no,a7@right:8
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@left:4
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@left:4
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@left,class@no:2
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@left,a9@no:4
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@left,class@no:2
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@left,a9@no:4
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@left,a9@no,class@no:2
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@left,a9@no,class@no:2
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@left:5
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@left,class@no:3
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@left,a9@no:5
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@left,a9@no,class@no:3
#
# a1@50-59,a2@premeno,a6@2,a7@left,a9@no:6
#
# a1@50-59,a2@premeno,a6@2,a7@left,class@no:6
#
# a1@50-59,a2@premeno,a6@2,a7@left,a9@no,class@no:4
#
# a1@50-59,a2@premeno,a4@0-2,a6@2:9
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a9@no:9
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,class@no:7
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a9@no,class@no:7
#
# a1@50-59,a2@premeno,a5@no,a6@2,class@no:7
#
# a1@50-59,a2@premeno,a5@no,a6@2,a9@no,class@no:6
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,class@no:6
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a9@no,class@no:6
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2:8
#
# a1@50-59,a2@premeno,a5@no,a6@2,a9@no:8
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a9@no:8
#
# a1@50-59,a2@premeno,a6@2,a9@no:10
#
# a1@50-59,a2@premeno,a6@2,a9@no,class@no:8
#
# a1@50-59,a2@premeno,a6@2,class@no:11
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@left,a8@left_low:2
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@left,a8@left_low,a9@no:2
#
# a1@50-59,a2@premeno,a5@no,a6@2,a8@left_low,class@no:2
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@left,a8@left_low,class@no:1
#
# a1@50-59,a2@premeno,a5@no,a6@2,a8@left_low,a9@no,class@no:2
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@left,a8@left_low,a9@no,class@no:1
#
# a1@50-59,a2@premeno,a5@no,a6@2,a8@left_low,a9@no:3
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@left,a8@left_low:2
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@left,a8@left_low,a9@no:2
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@left,a8@left_low:2
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,a9@no:2
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a8@left_low,class@no:2
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@left,a8@left_low,class@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a8@left_low,a9@no,class@no:2
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a8@left_low,class@no:2
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@left,a8@left_low,a9@no,class@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,class@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a8@left_low,a9@no,class@no:2
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,a9@no,class@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a8@left_low:3
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a8@left_low,a9@no:3
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a8@left_low,a9@no:3
#
# a1@50-59,a2@premeno,a6@2,a7@left,a8@left_low,a9@no:3
#
# a1@50-59,a2@premeno,a6@2,a8@left_low,a9@no,class@no:3
#
# a1@50-59,a2@premeno,a6@2,a7@left,a8@left_low,a9@no,class@no:2
#
# a1@50-59,a2@premeno,a6@2,a8@left_low,class@no:5
#
# a1@50-59,a2@premeno,a6@2,a7@left,a8@left_low:5
#
# a1@50-59,a2@premeno,a6@2,a7@left,a8@left_low,class@no:4
#
# a1@50-59,a2@premeno,a4@0-2,a8@left_low,class@no:7
#
# a1@50-59,a2@premeno,a4@0-2,a7@left,a8@left_low:7
#
# a1@50-59,a2@premeno,a4@0-2,a7@left,a8@left_low,class@no:6
#
# a1@50-59,a2@premeno,a5@no,a8@left_low,class@no:7
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a8@left_low,class@no:7
#
# a1@50-59,a2@premeno,a5@no,a7@left,a8@left_low:7
#
# a1@50-59,a2@premeno,a5@no,a7@left,a8@left_low,class@no:6
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@left,a8@left_low:7
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@left,a8@left_low,class@no:6
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a8@left_low:9
#
# a1@50-59,a2@premeno,a5@no,a8@left_low,a9@no:8
#
# a1@50-59,a2@premeno,a4@0-2,a8@left_low,a9@no:8
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a8@left_low,a9@no:8
#
# a1@50-59,a2@premeno,a8@left_low,a9@no,class@no:8
#
# a1@50-59,a2@premeno,a4@0-2,a8@left_low,a9@no,class@no:7
#
# a1@50-59,a2@premeno,a5@no,a8@left_low,a9@no,class@no:7
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a8@left_low,a9@no,class@no:7
#
# a1@50-59,a2@premeno,a7@left,a8@left_low,a9@no,class@no:7
#
# a1@50-59,a2@premeno,a4@0-2,a7@left,a8@left_low,a9@no:7
#
# a1@50-59,a2@premeno,a4@0-2,a7@left,a8@left_low,a9@no,class@no:6
#
# a1@50-59,a2@premeno,a5@no,a7@left,a8@left_low,a9@no:7
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@left,a8@left_low,a9@no:7
#
# a1@50-59,a2@premeno,a5@no,a7@left,a8@left_low,a9@no,class@no:6
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@left,a8@left_low,a9@no,class@no:6
#
# a1@50-59,a2@premeno,a8@left_low,class@no:10
#
# a1@50-59,a2@premeno,a7@left,a8@left_low,class@no:9
#
# a1@50-59,a2@premeno,a7@left,a8@left_low:11
#
# a1@50-59,a2@premeno,a5@no,a7@left:11
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@left:11
#
# a1@50-59,a2@premeno,a5@no,a7@left,class@no:8
#
# a1@50-59,a2@premeno,a5@no,a7@left,a9@no:11
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@left,class@no:8
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@left,a9@no:11
#
# a1@50-59,a2@premeno,a5@no,a7@left,a9@no,class@no:8
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@left,a9@no,class@no:8
#
# a1@50-59,a2@premeno,a7@left,class@no:12
#
# a1@50-59,a2@premeno,a7@left,a9@no,class@no:10
#
# a1@50-59,a2@premeno,a4@0-2,a7@left:12
#
# a1@50-59,a2@premeno,a4@0-2,a7@left,class@no:9
#
# a1@50-59,a2@premeno,a4@0-2,a7@left,a9@no:12
#
# a1@50-59,a2@premeno,a4@0-2,a7@left,a9@no,class@no:9
#
# a1@50-59,a2@premeno,a7@left,a9@no:13
#
# a1@50-59,a2@premeno,a4@0-2,class@no:14
#
# a1@50-59,a2@premeno,a4@0-2,a9@no,class@no:14
#
# a1@50-59,a2@premeno,a5@no,class@no:14
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,class@no:13
#
# a1@50-59,a2@premeno,a5@no,a9@no,class@no:13
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a9@no,class@no:13
#
# a1@50-59,a2@premeno,a9@no,class@no:15
#
# a1@50-59,a2@premeno,a5@no:19
#
# a1@50-59,a2@premeno,a5@no,a9@no:17
#
# a1@50-59,a2@premeno,a4@0-2,a5@no:18
#
# a1@50-59,a2@premeno,a4@0-2,a9@no:18
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a9@no:17
#
# a1@50-59,a2@premeno,a9@no:20
#
# a1@50-59,a2@ge40,a5@no,a6@2,a8@left_up:3
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a8@left_up:3
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@right,a8@left_up:2
#
# a1@50-59,a2@ge40,a5@no,a6@2,a8@left_up,class@no:3
#
# a1@50-59,a2@ge40,a5@no,a6@2,a8@left_up,a9@no:3
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@right,a8@left_up:2
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a8@left_up,class@no:3
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a8@left_up,a9@no:3
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@right,a8@left_up,class@no:2
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@right,a8@left_up,a9@no:2
#
# a1@50-59,a2@ge40,a5@no,a6@2,a8@left_up,a9@no,class@no:3
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@right,a8@left_up,class@no:2
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@right,a8@left_up,a9@no:2
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a8@left_up,a9@no,class@no:3
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@right,a8@left_up,a9@no,class@no:2
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@right,a8@left_up,a9@no,class@no:2
#
# a1@50-59,a2@ge40,a6@2,a7@right,a8@left_up:4
#
# a1@50-59,a2@ge40,a6@2,a7@right,a8@left_up,class@no:4
#
# a1@50-59,a2@ge40,a6@2,a7@right,a8@left_up,a9@no:4
#
# a1@50-59,a2@ge40,a6@2,a7@right,a8@left_up,a9@no,class@no:4
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a8@left_up:4
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@right,a8@left_up:3
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a8@left_up,class@no:4
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a8@left_up,a9@no:4
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@right,a8@left_up,class@no:3
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@right,a8@left_up,a9@no:3
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a8@left_up,a9@no,class@no:4
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@right,a8@left_up,a9@no,class@no:3
#
# a1@50-59,a2@ge40,a6@2,a8@left_up,a9@no:5
#
# a1@50-59,a2@ge40,a6@2,a8@left_up,class@no:5
#
# a1@50-59,a2@ge40,a6@2,a8@left_up,a9@no,class@no:5
#
# a1@50-59,a5@no,a6@2,a7@right,a8@left_up:5
#
# a1@50-59,a5@no,a6@2,a7@right,a8@left_up,a9@no:4
#
# a1@50-59,a4@0-2,a5@no,a6@2,a7@right,a8@left_up:4
#
# a1@50-59,a5@no,a6@2,a7@right,a8@left_up,class@no:5
#
# a1@50-59,a4@0-2,a5@no,a6@2,a7@right,a8@left_up,a9@no:4
#
# a1@50-59,a5@no,a6@2,a7@right,a8@left_up,a9@no,class@no:4
#
# a1@50-59,a4@0-2,a5@no,a6@2,a7@right,a8@left_up,class@no:4
#
# a1@50-59,a4@0-2,a5@no,a6@2,a7@right,a8@left_up,a9@no,class@no:4
#
# a1@50-59,a4@0-2,a5@no,a6@2,a8@left_up:6
#
# a1@50-59,a4@0-2,a5@no,a6@2,a8@left_up,class@no:6
#
# a1@50-59,a5@no,a6@2,a8@left_up,a9@no:6
#
# a1@50-59,a4@0-2,a5@no,a6@2,a8@left_up,a9@no:6
#
# a1@50-59,a5@no,a6@2,a8@left_up,a9@no,class@no:6
#
# a1@50-59,a4@0-2,a5@no,a6@2,a8@left_up,a9@no,class@no:6
#
# a1@50-59,a5@no,a6@2,a8@left_up,class@no:7
#
# a1@50-59,a6@2,a7@right,a8@left_up:7
#
# a1@50-59,a4@0-2,a6@2,a7@right,a8@left_up:5
#
# a1@50-59,a6@2,a7@right,a8@left_up,a9@no:6
#
# a1@50-59,a6@2,a7@right,a8@left_up,class@no:7
#
# a1@50-59,a4@0-2,a6@2,a7@right,a8@left_up,a9@no:5
#
# a1@50-59,a4@0-2,a6@2,a7@right,a8@left_up,class@no:5
#
# a1@50-59,a6@2,a7@right,a8@left_up,a9@no,class@no:6
#
# a1@50-59,a4@0-2,a6@2,a7@right,a8@left_up,a9@no,class@no:5
#
# a1@50-59,a4@0-2,a6@2,a8@left_up:8
#
# a1@50-59,a4@0-2,a6@2,a8@left_up,a9@no:8
#
# a1@50-59,a4@0-2,a6@2,a8@left_up,class@no:8
#
# a1@50-59,a4@0-2,a6@2,a8@left_up,a9@no,class@no:8
#
# a1@50-59,a6@2,a8@left_up,a9@no:9
#
# a1@50-59,a6@2,a8@left_up,a9@no,class@no:9
#
# a1@50-59,a6@2,a8@left_up,class@no:10
#
# a1@50-59,a6@2,a7@left,a8@left_up:3
#
# a1@50-59,a5@no,a6@2,a7@left,a8@left_up:2
#
# a1@50-59,a6@2,a7@left,a8@left_up,a9@no:3
#
# a1@50-59,a6@2,a7@left,a8@left_up,class@no:3
#
# a1@50-59,a4@0-2,a6@2,a7@left,a8@left_up:3
#
# a1@50-59,a2@ge40,a6@2,a7@left,a8@left_up:1
#
# a1@50-59,a5@no,a6@2,a7@left,a8@left_up,a9@no:2
#
# a1@50-59,a5@no,a6@2,a7@left,a8@left_up,class@no:2
#
# a1@50-59,a4@0-2,a5@no,a6@2,a7@left,a8@left_up:2
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@left,a8@left_up:1
#
# a1@50-59,a6@2,a7@left,a8@left_up,a9@no,class@no:3
#
# a1@50-59,a4@0-2,a6@2,a7@left,a8@left_up,a9@no:3
#
# a1@50-59,a2@ge40,a6@2,a7@left,a8@left_up,a9@no:1
#
# a1@50-59,a4@0-2,a6@2,a7@left,a8@left_up,class@no:3
#
# a1@50-59,a2@ge40,a6@2,a7@left,a8@left_up,class@no:1
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@left,a8@left_up:1
#
# a1@50-59,a5@no,a6@2,a7@left,a8@left_up,a9@no,class@no:2
#
# a1@50-59,a4@0-2,a5@no,a6@2,a7@left,a8@left_up,a9@no:2
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@left,a8@left_up,a9@no:1
#
# a1@50-59,a4@0-2,a5@no,a6@2,a7@left,a8@left_up,class@no:2
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@left,a8@left_up,class@no:1
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@left,a8@left_up:1
#
# a1@50-59,a4@0-2,a6@2,a7@left,a8@left_up,a9@no,class@no:3
#
# a1@50-59,a2@ge40,a6@2,a7@left,a8@left_up,a9@no,class@no:1
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@left,a8@left_up,a9@no:1
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@left,a8@left_up,class@no:1
#
# a1@50-59,a4@0-2,a5@no,a6@2,a7@left,a8@left_up,a9@no,class@no:2
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@left,a8@left_up,a9@no,class@no:1
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@left,a8@left_up,a9@no:1
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@left,a8@left_up,class@no:1
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@left,a8@left_up,a9@no,class@no:1
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@left,a8@left_up,a9@no,class@no:1
#
# a1@50-59,a5@no,a7@left,a8@left_up:7
#
# a1@50-59,a5@no,a7@left,a8@left_up,a9@no:7
#
# a1@50-59,a5@no,a7@left,a8@left_up,class@no:7
#
# a1@50-59,a4@0-2,a5@no,a7@left,a8@left_up:7
#
# a1@50-59,a2@ge40,a5@no,a7@left,a8@left_up:6
#
# a1@50-59,a5@no,a7@left,a8@left_up,a9@no,class@no:7
#
# a1@50-59,a4@0-2,a5@no,a7@left,a8@left_up,a9@no:7
#
# a1@50-59,a2@ge40,a5@no,a7@left,a8@left_up,a9@no:6
#
# a1@50-59,a4@0-2,a5@no,a7@left,a8@left_up,class@no:7
#
# a1@50-59,a2@ge40,a5@no,a7@left,a8@left_up,class@no:6
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a7@left,a8@left_up:6
#
# a1@50-59,a4@0-2,a5@no,a7@left,a8@left_up,a9@no,class@no:7
#
# a1@50-59,a2@ge40,a5@no,a7@left,a8@left_up,a9@no,class@no:6
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a7@left,a8@left_up,a9@no:6
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a7@left,a8@left_up,class@no:6
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a7@left,a8@left_up,a9@no,class@no:6
#
# a1@50-59,a2@ge40,a7@left,a8@left_up:7
#
# a1@50-59,a2@ge40,a7@left,a8@left_up,a9@no:6
#
# a1@50-59,a2@ge40,a7@left,a8@left_up,class@no:7
#
# a1@50-59,a2@ge40,a4@0-2,a7@left,a8@left_up:6
#
# a1@50-59,a2@ge40,a7@left,a8@left_up,a9@no,class@no:6
#
# a1@50-59,a2@ge40,a4@0-2,a7@left,a8@left_up,a9@no:6
#
# a1@50-59,a2@ge40,a4@0-2,a7@left,a8@left_up,class@no:6
#
# a1@50-59,a2@ge40,a4@0-2,a7@left,a8@left_up,a9@no,class@no:6
#
# a1@50-59,a4@0-2,a7@left,a8@left_up:9
#
# a1@50-59,a7@left,a8@left_up,class@no:9
#
# a1@50-59,a4@0-2,a7@left,a8@left_up,class@no:8
#
# a1@50-59,a7@left,a8@left_up,a9@no:9
#
# a1@50-59,a7@left,a8@left_up,a9@no,class@no:8
#
# a1@50-59,a4@0-2,a7@left,a8@left_up,a9@no:9
#
# a1@50-59,a4@0-2,a7@left,a8@left_up,a9@no,class@no:8
#
# a1@50-59,a2@ge40,a4@0-2,a7@right,a8@left_up:5
#
# a1@50-59,a2@ge40,a4@0-2,a7@right,a8@left_up,class@no:5
#
# a1@50-59,a2@ge40,a4@0-2,a7@right,a8@left_up,a9@no:5
#
# a1@50-59,a2@ge40,a4@0-2,a7@right,a8@left_up,a9@no,class@no:5
#
# a1@50-59,a2@ge40,a5@no,a7@right,a8@left_up:5
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a7@right,a8@left_up:4
#
# a1@50-59,a2@ge40,a5@no,a7@right,a8@left_up,class@no:4
#
# a1@50-59,a2@ge40,a5@no,a7@right,a8@left_up,a9@no:5
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a7@right,a8@left_up,class@no:4
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a7@right,a8@left_up,a9@no:4
#
# a1@50-59,a2@ge40,a5@no,a7@right,a8@left_up,a9@no,class@no:4
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a7@right,a8@left_up,a9@no,class@no:4
#
# a1@50-59,a2@ge40,a7@right,a8@left_up,class@no:8
#
# a1@50-59,a2@ge40,a7@right,a8@left_up,a9@no,class@no:8
#
# a1@50-59,a2@ge40,a7@right,a8@left_up,a9@no:9
#
# a1@50-59,a4@0-2,a5@no,a7@right,a8@left_up:9
#
# a1@50-59,a4@0-2,a5@no,a7@right,a8@left_up,a9@no:9
#
# a1@50-59,a4@0-2,a7@right,a8@left_up,class@no:9
#
# a1@50-59,a4@0-2,a5@no,a7@right,a8@left_up,class@no:8
#
# a1@50-59,a4@0-2,a7@right,a8@left_up,a9@no,class@no:9
#
# a1@50-59,a4@0-2,a5@no,a7@right,a8@left_up,a9@no,class@no:8
#
# a1@50-59,a4@0-2,a7@right,a8@left_up,a9@no:10
#
# a1@50-59,a5@no,a7@right,a8@left_up,class@no:9
#
# a1@50-59,a5@no,a7@right,a8@left_up,a9@no,class@no:8
#
# a1@50-59,a5@no,a7@right,a8@left_up,a9@no:10
#
# a1@50-59,a7@right,a8@left_up,class@no:13
#
# a1@50-59,a7@right,a8@left_up,a9@no,class@no:12
#
# a1@50-59,a7@right,a8@left_up,a9@no:14
#
# a1@50-59,a2@ge40,a5@no,a8@left_up:11
#
# a1@50-59,a2@ge40,a5@no,a8@left_up,a9@no:11
#
# a1@50-59,a2@ge40,a5@no,a8@left_up,class@no:10
#
# a1@50-59,a2@ge40,a5@no,a8@left_up,a9@no,class@no:10
#
# a1@50-59,a2@ge40,a4@0-2,a8@left_up:11
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a8@left_up:10
#
# a1@50-59,a2@ge40,a4@0-2,a8@left_up,a9@no:11
#
# a1@50-59,a2@ge40,a4@0-2,a8@left_up,class@no:11
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a8@left_up,a9@no:10
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a8@left_up,class@no:10
#
# a1@50-59,a2@ge40,a4@0-2,a8@left_up,a9@no,class@no:11
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a8@left_up,a9@no,class@no:10
#
# a1@50-59,a2@ge40,a8@left_up,class@no:15
#
# a1@50-59,a2@ge40,a8@left_up,a9@no:15
#
# a1@50-59,a2@ge40,a8@left_up,a9@no,class@no:14
#
# a1@50-59,a4@0-2,a5@no,a8@left_up:16
#
# a1@50-59,a4@0-2,a5@no,a8@left_up,a9@no:16
#
# a1@50-59,a5@no,a8@left_up,class@no:16
#
# a1@50-59,a4@0-2,a5@no,a8@left_up,class@no:15
#
# a1@50-59,a5@no,a8@left_up,a9@no,class@no:15
#
# a1@50-59,a4@0-2,a5@no,a8@left_up,a9@no,class@no:15
#
# a1@50-59,a5@no,a8@left_up,a9@no:17
#
# a1@50-59,a4@0-2,a8@left_up:19
#
# a1@50-59,a4@0-2,a8@left_up,class@no:17
#
# a1@50-59,a4@0-2,a8@left_up,a9@no:19
#
# a1@50-59,a4@0-2,a8@left_up,a9@no,class@no:17
#
# a1@50-59,a8@left_up,class@no:22
#
# a1@50-59,a8@left_up,a9@no,class@no:20
#
# a1@50-59,a8@left_up,a9@no:23
#
# a1@50-59,a7@right,a8@left_low:6
#
# a1@50-59,a4@0-2,a7@right,a8@left_low:6
#
# a1@50-59,a5@no,a7@right,a8@left_low:6
#
# a1@50-59,a7@right,a8@left_low,class@no:5
#
# a1@50-59,a7@right,a8@left_low,a9@no:5
#
# a1@50-59,a2@ge40,a7@right,a8@left_low:4
#
# a1@50-59,a4@0-2,a5@no,a7@right,a8@left_low:6
#
# a1@50-59,a4@0-2,a7@right,a8@left_low,class@no:5
#
# a1@50-59,a4@0-2,a7@right,a8@left_low,a9@no:5
#
# a1@50-59,a2@ge40,a4@0-2,a7@right,a8@left_low:4
#
# a1@50-59,a5@no,a7@right,a8@left_low,class@no:5
#
# a1@50-59,a5@no,a7@right,a8@left_low,a9@no:5
#
# a1@50-59,a2@ge40,a5@no,a7@right,a8@left_low:4
#
# a1@50-59,a7@right,a8@left_low,a9@no,class@no:5
#
# a1@50-59,a2@ge40,a7@right,a8@left_low,class@no:4
#
# a1@50-59,a2@ge40,a7@right,a8@left_low,a9@no:4
#
# a1@50-59,a4@0-2,a5@no,a7@right,a8@left_low,class@no:5
#
# a1@50-59,a4@0-2,a5@no,a7@right,a8@left_low,a9@no:5
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a7@right,a8@left_low:4
#
# a1@50-59,a4@0-2,a7@right,a8@left_low,a9@no,class@no:5
#
# a1@50-59,a2@ge40,a4@0-2,a7@right,a8@left_low,class@no:4
#
# a1@50-59,a2@ge40,a4@0-2,a7@right,a8@left_low,a9@no:4
#
# a1@50-59,a5@no,a7@right,a8@left_low,a9@no,class@no:5
#
# a1@50-59,a2@ge40,a5@no,a7@right,a8@left_low,class@no:4
#
# a1@50-59,a2@ge40,a5@no,a7@right,a8@left_low,a9@no:4
#
# a1@50-59,a2@ge40,a7@right,a8@left_low,a9@no,class@no:4
#
# a1@50-59,a4@0-2,a5@no,a7@right,a8@left_low,a9@no,class@no:5
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a7@right,a8@left_low,class@no:4
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a7@right,a8@left_low,a9@no:4
#
# a1@50-59,a2@ge40,a4@0-2,a7@right,a8@left_low,a9@no,class@no:4
#
# a1@50-59,a2@ge40,a5@no,a7@right,a8@left_low,a9@no,class@no:4
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a7@right,a8@left_low,a9@no,class@no:4
#
# a1@50-59,a2@ge40,a4@0-2,a7@left,a8@left_low:6
#
# a1@50-59,a2@ge40,a4@0-2,a7@left,a8@left_low,class@no:5
#
# a1@50-59,a2@ge40,a4@0-2,a7@left,a8@left_low,a9@no:6
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a7@left,a8@left_low:6
#
# a1@50-59,a2@ge40,a4@0-2,a7@left,a8@left_low,a9@no,class@no:5
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a7@left,a8@left_low,class@no:5
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a7@left,a8@left_low,a9@no:6
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a7@left,a8@left_low,a9@no,class@no:5
#
# a1@50-59,a2@ge40,a4@0-2,a8@left_low,class@no:9
#
# a1@50-59,a2@ge40,a4@0-2,a8@left_low,a9@no,class@no:9
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a8@left_low,class@no:9
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a8@left_low,a9@no,class@no:9
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a8@left_low:10
#
# a1@50-59,a2@ge40,a4@0-2,a8@left_low,a9@no:10
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a8@left_low,a9@no:10
#
# a1@50-59,a2@ge40,a7@left,a8@left_low,class@no:9
#
# a1@50-59,a2@ge40,a7@left,a8@left_low,a9@no,class@no:8
#
# a1@50-59,a2@ge40,a5@no,a7@left,a8@left_low:9
#
# a1@50-59,a2@ge40,a5@no,a7@left,a8@left_low,class@no:6
#
# a1@50-59,a2@ge40,a5@no,a7@left,a8@left_low,a9@no:8
#
# a1@50-59,a2@ge40,a5@no,a7@left,a8@left_low,a9@no,class@no:6
#
# a1@50-59,a2@ge40,a7@left,a8@left_low,a9@no:10
#
# a1@50-59,a2@ge40,a5@no,a8@left_low:13
#
# a1@50-59,a2@ge40,a5@no,a8@left_low,a9@no:12
#
# a1@50-59,a2@ge40,a8@left_low,class@no:13
#
# a1@50-59,a2@ge40,a5@no,a8@left_low,class@no:10
#
# a1@50-59,a2@ge40,a8@left_low,a9@no,class@no:12
#
# a1@50-59,a2@ge40,a5@no,a8@left_low,a9@no,class@no:10
#
# a1@50-59,a2@ge40,a8@left_low,a9@no:14
#
# a1@50-59,a4@0-2,a7@left,a8@left_low:15
#
# a1@50-59,a4@0-2,a7@left,a8@left_low,class@no:12
#
# a1@50-59,a4@0-2,a7@left,a8@left_low,a9@no:15
#
# a1@50-59,a4@0-2,a5@no,a7@left,a8@left_low:14
#
# a1@50-59,a4@0-2,a7@left,a8@left_low,a9@no,class@no:12
#
# a1@50-59,a4@0-2,a5@no,a7@left,a8@left_low,class@no:12
#
# a1@50-59,a4@0-2,a5@no,a7@left,a8@left_low,a9@no:14
#
# a1@50-59,a4@0-2,a5@no,a7@left,a8@left_low,a9@no,class@no:12
#
# a1@50-59,a4@0-2,a8@left_low,class@no:17
#
# a1@50-59,a4@0-2,a8@left_low,a9@no,class@no:17
#
# a1@50-59,a4@0-2,a5@no,a8@left_low,class@no:17
#
# a1@50-59,a4@0-2,a5@no,a8@left_low,a9@no,class@no:17
#
# a1@50-59,a4@0-2,a5@no,a8@left_low:20
#
# a1@50-59,a4@0-2,a8@left_low,a9@no:20
#
# a1@50-59,a4@0-2,a5@no,a8@left_low,a9@no:19
#
# a1@50-59,a5@no,a7@left,a8@left_low:17
#
# a1@50-59,a5@no,a7@left,a8@left_low,class@no:13
#
# a1@50-59,a5@no,a7@left,a8@left_low,a9@no:16
#
# a1@50-59,a5@no,a7@left,a8@left_low,a9@no,class@no:13
#
# a1@50-59,a5@no,a8@left_low,class@no:18
#
# a1@50-59,a5@no,a8@left_low,a9@no,class@no:18
#
# a1@50-59,a5@no,a8@left_low,a9@no:21
#
# a1@50-59,a7@left,a8@left_low,class@no:19
#
# a1@50-59,a7@left,a8@left_low,a9@no,class@no:16
#
# a1@50-59,a8@left_low,a9@no,class@no:21
#
# a1@50-59,a7@left,a8@left_low:25
#
# a1@50-59,a8@left_low,a9@no:25
#
# a1@50-59,a7@left,a8@left_low,a9@no:20
#
# a1@50-59,a6@2,a7@right,a8@left_low:2
#
# a1@50-59,a4@0-2,a6@2,a7@right,a8@left_low:2
#
# a1@50-59,a5@no,a6@2,a7@right,a8@left_low:2
#
# a1@50-59,a6@2,a7@right,a8@left_low,class@no:2
#
# a1@50-59,a6@2,a7@right,a8@left_low,a9@no:2
#
# a1@50-59,a2@ge40,a6@2,a7@right,a8@left_low:1
#
# a1@50-59,a4@0-2,a5@no,a6@2,a7@right,a8@left_low:2
#
# a1@50-59,a4@0-2,a6@2,a7@right,a8@left_low,class@no:2
#
# a1@50-59,a4@0-2,a6@2,a7@right,a8@left_low,a9@no:2
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@right,a8@left_low:1
#
# a1@50-59,a5@no,a6@2,a7@right,a8@left_low,class@no:2
#
# a1@50-59,a5@no,a6@2,a7@right,a8@left_low,a9@no:2
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@right,a8@left_low:1
#
# a1@50-59,a6@2,a7@right,a8@left_low,a9@no,class@no:2
#
# a1@50-59,a2@ge40,a6@2,a7@right,a8@left_low,class@no:1
#
# a1@50-59,a2@ge40,a6@2,a7@right,a8@left_low,a9@no:1
#
# a1@50-59,a4@0-2,a5@no,a6@2,a7@right,a8@left_low,class@no:2
#
# a1@50-59,a4@0-2,a5@no,a6@2,a7@right,a8@left_low,a9@no:2
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@right,a8@left_low:1
#
# a1@50-59,a4@0-2,a6@2,a7@right,a8@left_low,a9@no,class@no:2
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@right,a8@left_low,class@no:1
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@right,a8@left_low,a9@no:1
#
# a1@50-59,a5@no,a6@2,a7@right,a8@left_low,a9@no,class@no:2
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@right,a8@left_low,class@no:1
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@right,a8@left_low,a9@no:1
#
# a1@50-59,a2@ge40,a6@2,a7@right,a8@left_low,a9@no,class@no:1
#
# a1@50-59,a4@0-2,a5@no,a6@2,a7@right,a8@left_low,a9@no,class@no:2
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@right,a8@left_low,class@no:1
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@right,a8@left_low,a9@no:1
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@right,a8@left_low,a9@no,class@no:1
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@right,a8@left_low,a9@no,class@no:1
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@right,a8@left_low,a9@no,class@no:1
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@right:6
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@right,class@no:5
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@right:6
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@right,a9@no:6
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@right,class@no:5
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@right,a9@no,class@no:5
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@right,a9@no:6
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@right,a9@no,class@no:5
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@right:7
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@right,a9@no:7
#
# a1@50-59,a2@ge40,a6@2,a7@right,class@no:7
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@right,class@no:6
#
# a1@50-59,a2@ge40,a6@2,a7@right,a9@no,class@no:7
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@right,a9@no,class@no:6
#
# a1@50-59,a2@ge40,a6@2,a7@right,a9@no:8
#
# a1@50-59,a5@no,a6@2,a7@right,class@no:10
#
# a1@50-59,a5@no,a6@2,a7@right,a9@no:10
#
# a1@50-59,a5@no,a6@2,a7@right,a9@no,class@no:9
#
# a1@50-59,a4@0-2,a5@no,a6@2,a7@right:10
#
# a1@50-59,a4@0-2,a5@no,a6@2,a7@right,a9@no:10
#
# a1@50-59,a4@0-2,a6@2,a7@right,class@no:10
#
# a1@50-59,a4@0-2,a5@no,a6@2,a7@right,class@no:9
#
# a1@50-59,a4@0-2,a6@2,a7@right,a9@no,class@no:10
#
# a1@50-59,a4@0-2,a5@no,a6@2,a7@right,a9@no,class@no:9
#
# a1@50-59,a4@0-2,a6@2,a7@right,a9@no:11
#
# a1@50-59,a6@2,a7@right,a9@no:12
#
# a1@50-59,a6@2,a7@right,class@no:12
#
# a1@50-59,a6@2,a7@right,a9@no,class@no:11
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@left,a8@left_low:4
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@left,a8@left_low,a9@no:4
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a8@left_low,class@no:4
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@left,a8@left_low,class@no:3
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a8@left_low,a9@no,class@no:4
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@left,a8@left_low,a9@no,class@no:3
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a8@left_low,a9@no:5
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@left,a8@left_low:4
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@left,a8@left_low,a9@no:4
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@left,a8@left_low:4
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,a9@no:4
#
# a1@50-59,a2@ge40,a5@no,a6@2,a8@left_low,class@no:4
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@left,a8@left_low,class@no:3
#
# a1@50-59,a2@ge40,a5@no,a6@2,a8@left_low,a9@no,class@no:4
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a8@left_low,class@no:4
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@left,a8@left_low,a9@no,class@no:3
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,class@no:3
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a8@left_low,a9@no,class@no:4
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,a9@no,class@no:3
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a8@left_low:5
#
# a1@50-59,a2@ge40,a5@no,a6@2,a8@left_low,a9@no:5
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a8@left_low,a9@no:5
#
# a1@50-59,a2@ge40,a6@2,a8@left_low,class@no:6
#
# a1@50-59,a2@ge40,a6@2,a8@left_low,a9@no,class@no:6
#
# a1@50-59,a2@ge40,a6@2,a7@left,a8@left_low:6
#
# a1@50-59,a2@ge40,a6@2,a7@left,a8@left_low,class@no:5
#
# a1@50-59,a2@ge40,a6@2,a7@left,a8@left_low,a9@no:6
#
# a1@50-59,a2@ge40,a6@2,a7@left,a8@left_low,a9@no,class@no:5
#
# a1@50-59,a2@ge40,a6@2,a8@left_low,a9@no:7
#
# a1@50-59,a5@no,a6@2,a8@left_low,class@no:7
#
# a1@50-59,a5@no,a6@2,a8@left_low,a9@no,class@no:7
#
# a1@50-59,a5@no,a6@2,a7@left,a8@left_low:7
#
# a1@50-59,a5@no,a6@2,a7@left,a8@left_low,class@no:5
#
# a1@50-59,a5@no,a6@2,a7@left,a8@left_low,a9@no:7
#
# a1@50-59,a5@no,a6@2,a7@left,a8@left_low,a9@no,class@no:5
#
# a1@50-59,a5@no,a6@2,a8@left_low,a9@no:9
#
# a1@50-59,a4@0-2,a6@2,a8@left_low,class@no:7
#
# a1@50-59,a4@0-2,a6@2,a8@left_low,a9@no,class@no:7
#
# a1@50-59,a4@0-2,a5@no,a6@2,a8@left_low,class@no:7
#
# a1@50-59,a4@0-2,a5@no,a6@2,a8@left_low,a9@no,class@no:7
#
# a1@50-59,a4@0-2,a6@2,a7@left,a8@left_low:7
#
# a1@50-59,a4@0-2,a6@2,a7@left,a8@left_low,class@no:5
#
# a1@50-59,a4@0-2,a6@2,a7@left,a8@left_low,a9@no:7
#
# a1@50-59,a4@0-2,a5@no,a6@2,a7@left,a8@left_low:7
#
# a1@50-59,a4@0-2,a6@2,a7@left,a8@left_low,a9@no,class@no:5
#
# a1@50-59,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,class@no:5
#
# a1@50-59,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,a9@no:7
#
# a1@50-59,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,a9@no,class@no:5
#
# a1@50-59,a4@0-2,a5@no,a6@2,a8@left_low:9
#
# a1@50-59,a4@0-2,a6@2,a8@left_low,a9@no:9
#
# a1@50-59,a4@0-2,a5@no,a6@2,a8@left_low,a9@no:9
#
# a1@50-59,a6@2,a7@left,a8@left_low:12
#
# a1@50-59,a6@2,a8@left_low,a9@no:12
#
# a1@50-59,a6@2,a7@left,a8@left_low,a9@no:10
#
# a1@50-59,a6@2,a8@left_low,a9@no,class@no:10
#
# a1@50-59,a6@2,a7@left,a8@left_low,class@no:10
#
# a1@50-59,a6@2,a7@left,a8@left_low,a9@no,class@no:8
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@left:6
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@left:6
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@left,a9@no:6
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@left,class@no:5
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@left,a9@no:6
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@left,class@no:5
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@left,a9@no,class@no:5
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@left,a9@no,class@no:5
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@left,a9@no:6
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@left,class@no:6
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@left,a9@no,class@no:5
#
# a1@50-59,a2@ge40,a6@2,a7@left,class@no:8
#
# a1@50-59,a2@ge40,a6@2,a7@left,a9@no:8
#
# a1@50-59,a2@ge40,a6@2,a7@left,a9@no,class@no:7
#
# a1@50-59,a2@ge40,a5@no,a6@2:12
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2:12
#
# a1@50-59,a2@ge40,a5@no,a6@2,class@no:10
#
# a1@50-59,a2@ge40,a5@no,a6@2,a9@no:12
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,class@no:10
#
# ...
#
# a2@premeno,a4@0-2,a7@right,a8@left_low:15
#
# a2@premeno,a5@no,a7@right,a8@left_low:15
#
# a2@premeno,a4@0-2,a5@no,a7@right,a8@left_low:14
#
# a7@right,a8@left_low,a9@no,class@no:17
#
# a5@no,a7@right,a8@left_low,a9@no,class@no:16
#
# a4@0-2,a7@right,a8@left_low,a9@no,class@no:15
#
# a4@0-2,a5@no,a7@right,a8@left_low,a9@no,class@no:15
#
# a4@0-2,a7@right,a8@left_low,class@no:18
#
# a5@no,a7@right,a8@left_low,class@no:18
#
# a4@0-2,a5@no,a7@right,a8@left_low,class@no:17
#
# a7@right,a8@left_low,a9@no:23
#
# a4@0-2,a7@right,a8@left_low,a9@no:20
#
# a5@no,a7@right,a8@left_low,a9@no:21
#
# a4@0-2,a5@no,a7@right,a8@left_low,a9@no:20
#
# a4@0-2,a7@right,a8@left_low:25
#
# a4@0-2,a5@no,a7@right,a8@left_low:24
#
# a5@no,a7@right,a8@left_low:26
#
# a2@ge40,a4@0-2,a6@2,a7@left,a8@left_low,a9@no:11
#
# a2@ge40,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,a9@no:11
#
# a2@ge40,a4@0-2,a6@2,a7@left,a8@left_low,class@no:11
#
# a2@ge40,a4@0-2,a6@2,a7@left,a8@left_low,a9@no,class@no:10
#
# a2@ge40,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,class@no:11
#
# a2@ge40,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,a9@no,class@no:10
#
# a2@ge40,a4@0-2,a5@no,a6@2,a7@left,a8@left_low:12
#
# a2@ge40,a6@2,a7@left,a8@left_low,class@no:13
#
# a2@ge40,a6@2,a7@left,a8@left_low,a9@no:13
#
# a2@ge40,a6@2,a7@left,a8@left_low,a9@no,class@no:12
#
# a2@ge40,a5@no,a6@2,a7@left,a8@left_low,a9@no:11
#
# a2@ge40,a5@no,a6@2,a7@left,a8@left_low,class@no:11
#
# a2@ge40,a5@no,a6@2,a7@left,a8@left_low,a9@no,class@no:10
#
# a2@ge40,a4@0-2,a6@2,a8@left_low:16
#
# a2@ge40,a4@0-2,a6@2,a8@left_low,a9@no:15
#
# a2@ge40,a4@0-2,a5@no,a6@2,a8@left_low:16
#
# a2@ge40,a4@0-2,a5@no,a6@2,a8@left_low,a9@no:15
#
# a2@ge40,a4@0-2,a6@2,a8@left_low,class@no:14
#
# a2@ge40,a4@0-2,a6@2,a8@left_low,a9@no,class@no:13
#
# a2@ge40,a5@no,a6@2,a8@left_low,class@no:14
#
# a2@ge40,a4@0-2,a5@no,a6@2,a8@left_low,class@no:14
#
# a2@ge40,a5@no,a6@2,a8@left_low,a9@no,class@no:13
#
# a2@ge40,a4@0-2,a5@no,a6@2,a8@left_low,a9@no,class@no:13
#
# a2@ge40,a6@2,a8@left_low,a9@no,class@no:15
#
# a2@ge40,a5@no,a6@2,a8@left_low:17
#
# a2@ge40,a6@2,a8@left_low,a9@no:17
#
# a2@ge40,a5@no,a6@2,a8@left_low,a9@no:15
#
# a2@ge40,a4@0-2,a7@left,a8@left_low,class@no:17
#
# a2@ge40,a4@0-2,a5@no,a7@left,a8@left_low,class@no:17
#
# a2@ge40,a4@0-2,a7@left,a8@left_low,a9@no:17
#
# a2@ge40,a4@0-2,a7@left,a8@left_low,a9@no,class@no:16
#
# a2@ge40,a4@0-2,a5@no,a7@left,a8@left_low,a9@no:17
#
# a2@ge40,a4@0-2,a5@no,a7@left,a8@left_low,a9@no,class@no:16
#
# a2@ge40,a4@0-2,a5@no,a7@left,a8@left_low:18
#
# a2@ge40,a4@0-2,a8@left_low,class@no:25
#
# a2@ge40,a4@0-2,a8@left_low,a9@no,class@no:24
#
# a2@ge40,a4@0-2,a5@no,a8@left_low,class@no:25
#
# a2@ge40,a4@0-2,a5@no,a8@left_low,a9@no,class@no:24
#
# a2@ge40,a4@0-2,a8@left_low,a9@no:27
#
# a2@ge40,a4@0-2,a5@no,a8@left_low,a9@no:27
#
# a2@ge40,a4@0-2,a5@no,a8@left_low:28
#
# a2@ge40,a5@no,a7@left,a8@left_low,class@no:18
#
# a2@ge40,a5@no,a7@left,a8@left_low,a9@no,class@no:17
#
# a2@ge40,a7@left,a8@left_low,a9@no,class@no:20
#
# a2@ge40,a5@no,a7@left,a8@left_low:23
#
# a2@ge40,a5@no,a7@left,a8@left_low,a9@no:20
#
# a2@ge40,a7@left,a8@left_low,a9@no:24
#
# a2@ge40,a5@no,a8@left_low,class@no:26
#
# a2@ge40,a5@no,a8@left_low,a9@no,class@no:25
#
# a2@ge40,a8@left_low,a9@no,class@no:28
#
# a2@ge40,a5@no,a8@left_low:34
#
# a2@ge40,a5@no,a8@left_low,a9@no:30
#
# a2@ge40,a8@left_low,a9@no:35
#
# a2@premeno,a6@2,a7@left,a8@left_low,a9@no,class@no:7
#
# a2@premeno,a4@0-2,a6@2,a7@left,a8@left_low,a9@no,class@no:6
#
# a2@premeno,a5@no,a6@2,a7@left,a8@left_low,a9@no,class@no:6
#
# a2@premeno,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,a9@no,class@no:6
#
# a2@premeno,a5@no,a6@2,a7@left,a8@left_low,a9@no:8
#
# a2@premeno,a4@0-2,a6@2,a7@left,a8@left_low,a9@no:8
#
# a2@premeno,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,a9@no:8
#
# a2@premeno,a6@2,a7@left,a8@left_low,class@no:12
#
# a2@premeno,a4@0-2,a6@2,a7@left,a8@left_low:12
#
# a2@premeno,a4@0-2,a6@2,a7@left,a8@left_low,class@no:9
#
# a2@premeno,a5@no,a6@2,a7@left,a8@left_low:12
#
# a2@premeno,a4@0-2,a5@no,a6@2,a7@left,a8@left_low:12
#
# a2@premeno,a5@no,a6@2,a7@left,a8@left_low,class@no:9
#
# a2@premeno,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,class@no:9
#
# a2@premeno,a6@2,a8@left_low,class@no:19
#
# a2@premeno,a4@0-2,a6@2,a8@left_low,class@no:14
#
# a2@premeno,a5@no,a6@2,a8@left_low,class@no:15
#
# a2@premeno,a4@0-2,a5@no,a6@2,a8@left_low,class@no:14
#
# a2@premeno,a6@2,a8@left_low,a9@no,class@no:14
#
# a2@premeno,a4@0-2,a6@2,a8@left_low,a9@no,class@no:11
#
# a2@premeno,a5@no,a6@2,a8@left_low,a9@no,class@no:12
#
# a2@premeno,a4@0-2,a5@no,a6@2,a8@left_low,a9@no,class@no:11
#
# a2@premeno,a4@0-2,a6@2,a8@left_low,a9@no:15
#
# a2@premeno,a4@0-2,a5@no,a6@2,a8@left_low,a9@no:15
#
# a2@premeno,a5@no,a6@2,a8@left_low,a9@no:16
#
# a2@premeno,a4@0-2,a6@2,a8@left_low:20
#
# a2@premeno,a4@0-2,a5@no,a6@2,a8@left_low:20
#
# a2@premeno,a5@no,a6@2,a8@left_low:21
#
# a4@0-2,a6@2,a7@left,a8@left_low,a9@no:20
#
# a5@no,a6@2,a7@left,a8@left_low,a9@no:20
#
# a4@0-2,a5@no,a6@2,a7@left,a8@left_low,a9@no:20
#
# a6@2,a7@left,a8@left_low,a9@no,class@no:20
#
# a5@no,a6@2,a7@left,a8@left_low,a9@no,class@no:17
#
# a4@0-2,a6@2,a7@left,a8@left_low,a9@no,class@no:17
#
# a4@0-2,a5@no,a6@2,a7@left,a8@left_low,a9@no,class@no:17
#
# a4@0-2,a6@2,a7@left,a8@left_low:25
#
# a4@0-2,a5@no,a6@2,a7@left,a8@left_low:25
#
# a4@0-2,a6@2,a7@left,a8@left_low,class@no:21
#
# a4@0-2,a5@no,a6@2,a7@left,a8@left_low,class@no:21
#
# a6@2,a7@left,a8@left_low,class@no:26
#
# a5@no,a6@2,a7@left,a8@left_low:26
#
# a5@no,a6@2,a7@left,a8@left_low,class@no:21
#
# a4@0-2,a6@2,a8@left_low,class@no:29
#
# a4@0-2,a5@no,a6@2,a8@left_low,class@no:29
#
# a4@0-2,a6@2,a8@left_low,a9@no,class@no:25
#
# a4@0-2,a5@no,a6@2,a8@left_low,a9@no,class@no:25
#
# a6@2,a8@left_low,a9@no,class@no:30
#
# a5@no,a6@2,a8@left_low,class@no:30
#
# a5@no,a6@2,a8@left_low,a9@no,class@no:26
#
# a4@0-2,a6@2,a8@left_low:37
#
# a4@0-2,a5@no,a6@2,a8@left_low:37
#
# a6@2,a8@left_low,a9@no:37
#
# a4@0-2,a6@2,a8@left_low,a9@no:31
#
# a5@no,a6@2,a8@left_low,a9@no:32
#
# a4@0-2,a5@no,a6@2,a8@left_low,a9@no:31
#
# a5@no,a6@2,a8@left_low:39
#
# a2@premeno,a7@left,a8@left_low,a9@no,class@no:16
#
# a2@premeno,a5@no,a7@left,a8@left_low,a9@no,class@no:15
#
# a2@premeno,a4@0-2,a7@left,a8@left_low,a9@no,class@no:15
#
# a2@premeno,a4@0-2,a5@no,a7@left,a8@left_low,a9@no,class@no:15
#
# a2@premeno,a4@0-2,a7@left,a8@left_low,class@no:19
#
# a2@premeno,a5@no,a7@left,a8@left_low,class@no:19
#
# a2@premeno,a4@0-2,a5@no,a7@left,a8@left_low,class@no:19
#
# a2@premeno,a8@left_low,a9@no,class@no:25
#
# a2@premeno,a4@0-2,a8@left_low,a9@no,class@no:22
#
# a2@premeno,a5@no,a8@left_low,a9@no,class@no:23
#
# a2@premeno,a4@0-2,a5@no,a8@left_low,a9@no,class@no:22
#
# a2@premeno,a5@no,a8@left_low,class@no:29
#
# a2@premeno,a4@0-2,a8@left_low,class@no:29
#
# a2@premeno,a4@0-2,a5@no,a8@left_low,class@no:28
#
# a2@premeno,a7@left,a8@left_low:36
#
# a2@premeno,a5@no,a7@left,a8@left_low:26
#
# a2@premeno,a4@0-2,a7@left,a8@left_low:26
#
# a2@premeno,a4@0-2,a5@no,a7@left,a8@left_low:26
#
# a2@premeno,a7@left,a8@left_low,a9@no:24
#
# a2@premeno,a4@0-2,a7@left,a8@left_low,a9@no:20
#
# a2@premeno,a5@no,a7@left,a8@left_low,a9@no:20
#
# a2@premeno,a4@0-2,a5@no,a7@left,a8@left_low,a9@no:20
#
# a2@premeno,a4@0-2,a8@left_low,a9@no:30
#
# a2@premeno,a4@0-2,a5@no,a8@left_low,a9@no:30
#
# a2@premeno,a5@no,a8@left_low,a9@no:31
#
# a2@premeno,a4@0-2,a8@left_low:41
#
# a2@premeno,a5@no,a8@left_low:41
#
# a2@premeno,a4@0-2,a5@no,a8@left_low:40
#
# a7@left,a8@left_low,a9@no,class@no:38
#
# a5@no,a7@left,a8@left_low,a9@no,class@no:34
#
# a4@0-2,a7@left,a8@left_low,class@no:38
#
# a4@0-2,a7@left,a8@left_low,a9@no,class@no:33
#
# a4@0-2,a5@no,a7@left,a8@left_low,class@no:38
#
# a4@0-2,a5@no,a7@left,a8@left_low,a9@no,class@no:33
#
# a5@no,a7@left,a8@left_low,class@no:39
#
# a8@left_low,a9@no,class@no:55
#
# a4@0-2,a8@left_low,a9@no,class@no:48
#
# a5@no,a8@left_low,a9@no,class@no:50
#
# a4@0-2,a5@no,a8@left_low,a9@no,class@no:48
#
# a4@0-2,a8@left_low,class@no:56
#
# a4@0-2,a5@no,a8@left_low,class@no:55
#
# a5@no,a8@left_low,class@no:57
#
# a4@0-2,a7@left,a8@left_low,a9@no:40
#
# a4@0-2,a5@no,a7@left,a8@left_low,a9@no:39
#
# a4@0-2,a5@no,a7@left,a8@left_low:46
#
# a7@left,a8@left_low,a9@no:51
#
# a5@no,a7@left,a8@left_low:51
#
# a5@no,a7@left,a8@left_low,a9@no:42
#
# a4@0-2,a8@left_low,a9@no:60
#
# a4@0-2,a5@no,a8@left_low,a9@no:59
#
# a4@0-2,a5@no,a8@left_low:70
#
# a8@left_low,a9@no:74
#
# a5@no,a8@left_low,a9@no:63
#
# a5@no,a8@left_low:77
#
# a2@ge40,a5@no,a6@2,a7@right:16
#
# a2@ge40,a5@no,a6@2,a7@right,a9@no:14
#
# a2@ge40,a4@0-2,a6@2,a7@right,a9@no:14
#
# a2@ge40,a4@0-2,a5@no,a6@2,a7@right,a9@no:13
#
# a2@ge40,a4@0-2,a5@no,a6@2,a7@right:15
#
# a2@ge40,a5@no,a6@2,a7@right,class@no:12
#
# a2@ge40,a5@no,a6@2,a7@right,a9@no,class@no:10
#
# a2@ge40,a4@0-2,a5@no,a6@2,a7@right,class@no:12
#
# a2@ge40,a4@0-2,a5@no,a6@2,a7@right,a9@no,class@no:10
#
# a2@ge40,a4@0-2,a6@2,a7@right,class@no:13
#
# a2@ge40,a6@2,a7@right,a9@no,class@no:13
#
# a2@ge40,a4@0-2,a6@2,a7@right,a9@no,class@no:11
#
# a2@ge40,a6@2,a7@right,a9@no:17
#
# a2@ge40,a4@0-2,a6@2,a7@left,a9@no:16
#
# a2@ge40,a4@0-2,a6@2,a7@left,a9@no,class@no:15
#
# a2@ge40,a5@no,a6@2,a7@left,a9@no:16
#
# a2@ge40,a4@0-2,a5@no,a6@2,a7@left,a9@no:16
#
# a2@ge40,a5@no,a6@2,a7@left,a9@no,class@no:15
#
# a2@ge40,a4@0-2,a5@no,a6@2,a7@left,a9@no,class@no:15
#
# a2@ge40,a6@2,a7@left,a9@no,class@no:17
#
# a2@ge40,a5@no,a6@2,a7@left:20
#
# a2@ge40,a5@no,a6@2,a7@left,class@no:18
#
# a2@ge40,a4@0-2,a5@no,a6@2,a7@left:19
#
# a2@ge40,a4@0-2,a6@2,a7@left,class@no:19
#
# a2@ge40,a4@0-2,a5@no,a6@2,a7@left,class@no:18
#
# a2@ge40,a6@2,a7@left,class@no:21
#
# a2@ge40,a5@no,a6@2,a9@no:30
#
# a2@ge40,a4@0-2,a6@2,a9@no:30
#
# a2@ge40,a4@0-2,a5@no,a6@2,a9@no:29
#
# a2@ge40,a6@2,a9@no,class@no:30
#
# a2@ge40,a4@0-2,a6@2,a9@no,class@no:26
#
# a2@ge40,a5@no,a6@2,a9@no,class@no:25
#
# a2@ge40,a4@0-2,a5@no,a6@2,a9@no,class@no:25
#
# a2@ge40,a4@0-2,a6@2:36
#
# a2@ge40,a4@0-2,a6@2,class@no:32
#
# a2@ge40,a5@no,a6@2:36
#
# a2@ge40,a4@0-2,a5@no,a6@2:34
#
# a2@ge40,a5@no,a6@2,class@no:30
#
# a2@ge40,a4@0-2,a5@no,a6@2,class@no:30
#
# a2@ge40,a6@2,class@no:37
#
# a2@ge40,a5@no,a7@right,class@no:27
#
# a2@ge40,a4@0-2,a5@no,a7@right,class@no:27
#
# a2@ge40,a5@no,a7@right,a9@no,class@no:24
#
# a2@ge40,a4@0-2,a5@no,a7@right,a9@no,class@no:24
#
# a2@ge40,a4@0-2,a7@right,class@no:28
#
# a2@ge40,a4@0-2,a7@right,a9@no,class@no:25
#
# a2@ge40,a7@right,a9@no,class@no:29
#
# a2@ge40,a4@0-2,a7@right,a9@no:31
#
# a2@ge40,a4@0-2,a5@no,a7@right,a9@no:30
#
# a2@ge40,a4@0-2,a5@no,a7@right:35
#
# a2@ge40,a5@no,a7@right:38
#
# a2@ge40,a5@no,a7@right,a9@no:32
#
# a2@ge40,a7@right,a9@no:39
#
# a2@ge40,a4@0-2,a7@left,a9@no:33
#
# a2@ge40,a4@0-2,a7@left,a9@no,class@no:31
#
# a2@ge40,a4@0-2,a5@no,a7@left,a9@no:33
#
# a2@ge40,a4@0-2,a5@no,a7@left,a9@no,class@no:31
#
# a2@ge40,a4@0-2,a7@left,class@no:35
#
# a2@ge40,a4@0-2,a5@no,a7@left,class@no:34
#
# a2@ge40,a4@0-2,a5@no,a7@left:37
#
# a2@ge40,a7@left,class@no:42
#
# a2@ge40,a5@no,a7@left:42
#
# a2@ge40,a5@no,a7@left,class@no:35
#
# a2@ge40,a5@no,a7@left,a9@no:36
#
# a2@ge40,a7@left,a9@no,class@no:36
#
# a2@ge40,a5@no,a7@left,a9@no,class@no:32
#
# a2@ge40,a4@0-2,a9@no,class@no:56
#
# a2@ge40,a4@0-2,a5@no,a9@no,class@no:55
#
# a2@ge40,a4@0-2,a5@no,class@no:61
#
# a2@ge40,a4@0-2,a9@no:64
#
# a2@ge40,a4@0-2,a5@no,a9@no:63
#
# a2@ge40,a4@0-2,a5@no:72
#
# a2@ge40,a5@no,class@no:62
#
# a2@ge40,a5@no,a9@no,class@no:56
#
# a2@ge40,a9@no,class@no:65
#
# a2@ge40,a5@no:80
#
# a2@ge40,a5@no,a9@no:68
#
# a2@ge40,a9@no:81
#
# a2@premeno,a4@0-2,a6@2,a7@right:23
#
# a2@premeno,a4@0-2,a6@2,a7@right,a9@no:22
#
# a2@premeno,a4@0-2,a6@2,a7@right,class@no:19
#
# a2@premeno,a4@0-2,a5@no,a6@2,a7@right:23
#
# a2@premeno,a4@0-2,a6@2,a7@right,a9@no,class@no:19
#
# a2@premeno,a4@0-2,a5@no,a6@2,a7@right,a9@no:22
#
# a2@premeno,a4@0-2,a5@no,a6@2,a7@right,class@no:19
#
# a2@premeno,a4@0-2,a5@no,a6@2,a7@right,a9@no,class@no:19
#
# a2@premeno,a6@2,a7@right,a9@no,class@no:22
#
# a2@premeno,a5@no,a6@2,a7@right,a9@no,class@no:21
#
# a2@premeno,a5@no,a6@2,a7@right,a9@no:25
#
# a2@premeno,a6@2,a7@right,class@no:27
#
# a2@premeno,a5@no,a6@2,a7@right,class@no:22
#
# a2@premeno,a5@no,a6@2,a7@right:28
#
# a4@0-2,a6@2,a7@right,a9@no,class@no:30
#
# a4@0-2,a5@no,a6@2,a7@right,a9@no,class@no:29
#
# a4@0-2,a5@no,a6@2,a7@right,class@no:31
#
# a4@0-2,a6@2,a7@right,a9@no:36
#
# a4@0-2,a5@no,a6@2,a7@right,a9@no:35
#
# a4@0-2,a5@no,a6@2,a7@right:38
#
# a6@2,a7@right,a9@no:43
#
# a5@no,a6@2,a7@right,a9@no:39
#
# a5@no,a6@2,a7@right,class@no:34
#
# a5@no,a6@2,a7@right,a9@no,class@no:31
#
# a6@2,a7@right,a9@no,class@no:35
#
# a5@no,a6@2,a7@right:44
#
# a2@premeno,a6@2,a7@left,a9@no:24
#
# a2@premeno,a5@no,a6@2,a7@left,a9@no:20
#
# a2@premeno,a4@0-2,a6@2,a7@left,a9@no:21
#
# a2@premeno,a4@0-2,a5@no,a6@2,a7@left,a9@no:20
#
# a2@premeno,a6@2,a7@left,a9@no,class@no:17
#
# a2@premeno,a5@no,a6@2,a7@left,a9@no,class@no:15
#
# a2@premeno,a4@0-2,a6@2,a7@left,a9@no,class@no:16
#
# a2@premeno,a4@0-2,a5@no,a6@2,a7@left,a9@no,class@no:15
#
# a2@premeno,a5@no,a6@2,a7@left,class@no:19
#
# a2@premeno,a4@0-2,a5@no,a6@2,a7@left,class@no:19
#
# a2@premeno,a4@0-2,a6@2,a7@left,class@no:21
#
# a2@premeno,a5@no,a6@2,a7@left:25
#
# a2@premeno,a4@0-2,a5@no,a6@2,a7@left:25
#
# a2@premeno,a4@0-2,a6@2,a7@left:27
#
# a6@2,a7@left,a9@no,class@no:35
#
# a5@no,a6@2,a7@left,a9@no,class@no:31
#
# a4@0-2,a6@2,a7@left,a9@no,class@no:32
#
# a4@0-2,a5@no,a6@2,a7@left,a9@no,class@no:31
#
# a5@no,a6@2,a7@left,a9@no:37
#
# a4@0-2,a5@no,a6@2,a7@left,a9@no:37
#
# a4@0-2,a6@2,a7@left,a9@no:38
#
# a6@2,a7@left,class@no:46
#
# a4@0-2,a6@2,a7@left,class@no:41
#
# a5@no,a6@2,a7@left:46
#
# a5@no,a6@2,a7@left,class@no:38
#
# a4@0-2,a5@no,a6@2,a7@left:45
#
# a4@0-2,a5@no,a6@2,a7@left,class@no:38
#
# a4@0-2,a6@2,a7@left:48
#
# a2@premeno,a6@2,a9@no,class@no:39
#
# a2@premeno,a5@no,a6@2,a9@no,class@no:36
#
# a2@premeno,a5@no,a6@2,a9@no:45
#
# a2@premeno,a4@0-2,a6@2,a9@no,class@no:35
#
# a2@premeno,a4@0-2,a5@no,a6@2,a9@no,class@no:34
#
# a2@premeno,a4@0-2,a5@no,a6@2,class@no:38
#
# a2@premeno,a4@0-2,a6@2,a9@no:43
#
# a2@premeno,a4@0-2,a5@no,a6@2,a9@no:42
#
# a2@premeno,a4@0-2,a5@no,a6@2:48
#
# a2@premeno,a6@2,class@no:51
#
# a2@premeno,a5@no,a6@2,class@no:41
#
# a2@premeno,a5@no,a6@2:53
#
# a4@0-2,a6@2,a9@no,class@no:62
#
# a5@no,a6@2,a9@no,class@no:62
#
# a4@0-2,a5@no,a6@2,a9@no,class@no:60
#
# a4@0-2,a6@2,a9@no:74
#
# a4@0-2,a5@no,a6@2,a9@no:72
#
# a5@no,a6@2,a9@no:76
#
# a4@0-2,a6@2,class@no:73
#
# a4@0-2,a5@no,a6@2,class@no:69
#
# a4@0-2,a5@no,a6@2:83
#
# a6@2,class@no:89
#
# a5@no,a6@2,class@no:72
#
# a5@no,a6@2:90
#
# a2@premeno,a4@0-2,a7@right,class@no:35
#
# a2@premeno,a4@0-2,a5@no,a7@right,class@no:33
#
# a2@premeno,a5@no,a7@right,class@no:38
#
# a2@premeno,a7@right,a9@no,class@no:33
#
# a2@premeno,a4@0-2,a7@right,a9@no,class@no:30
#
# a2@premeno,a5@no,a7@right,a9@no,class@no:32
#
# a2@premeno,a4@0-2,a5@no,a7@right,a9@no,class@no:30
#
# a2@premeno,a4@0-2,a7@right,a9@no:40
#
# a2@premeno,a4@0-2,a5@no,a7@right,a9@no:38
#
# a2@premeno,a5@no,a7@right,a9@no:41
#
# a2@premeno,a4@0-2,a7@right:47
#
# a2@premeno,a4@0-2,a5@no,a7@right:43
#
# a2@premeno,a5@no,a7@right:51
#
# a4@0-2,a7@right,a9@no,class@no:57
#
# a4@0-2,a5@no,a7@right,a9@no,class@no:56
#
# a5@no,a7@right,a9@no,class@no:58
#
# a4@0-2,a7@right,class@no:65
#
# a4@0-2,a5@no,a7@right,class@no:62
#
# a5@no,a7@right,class@no:67
#
# a4@0-2,a7@right,a9@no:73
#
# a4@0-2,a5@no,a7@right,a9@no:70
#
# a4@0-2,a5@no,a7@right:80
#
# a7@right,a9@no:87
#
# a5@no,a7@right,a9@no:75
#
# a5@no,a7@right:91
#
# a2@premeno,a7@left,a9@no,class@no:34
#
# a2@premeno,a5@no,a7@left,a9@no,class@no:32
#
# a2@premeno,a4@0-2,a7@left,a9@no,class@no:33
#
# a2@premeno,a4@0-2,a5@no,a7@left,a9@no,class@no:32
#
# a2@premeno,a5@no,a7@left,class@no:37
#
# a2@premeno,a4@0-2,a5@no,a7@left,class@no:37
#
# a2@premeno,a4@0-2,a7@left,class@no:39
#
# a2@premeno,a7@left,a9@no:50
#
# a2@premeno,a5@no,a7@left,a9@no:44
#
# a2@premeno,a4@0-2,a7@left,a9@no:45
#
# a2@premeno,a4@0-2,a5@no,a7@left,a9@no:44
#
# a2@premeno,a5@no,a7@left:52
#
# a2@premeno,a4@0-2,a5@no,a7@left:52
#
# a2@premeno,a4@0-2,a7@left:54
#
# a5@no,a7@left,a9@no,class@no:67
#
# a4@0-2,a7@left,a9@no,class@no:67
#
# a4@0-2,a5@no,a7@left,a9@no,class@no:66
#
# a5@no,a7@left,class@no:75
#
# a4@0-2,a5@no,a7@left,class@no:74
#
# a4@0-2,a7@left,class@no:77
#
# a4@0-2,a7@left:97
#
# a7@left,a9@no:97
#
# a4@0-2,a7@left,a9@no:83
#
# a5@no,a7@left,a9@no:83
#
# a4@0-2,a5@no,a7@left,a9@no:80
#
# a4@0-2,a5@no,a7@left:92
#
# a2@premeno,a4@0-2,a9@no,class@no:63
#
# a2@premeno,a4@0-2,a5@no,a9@no,class@no:62
#
# a2@premeno,a5@no,a9@no,class@no:64
#
# a2@premeno,a4@0-2,class@no:74
#
# a2@premeno,a4@0-2,a5@no,class@no:70
#
# a2@premeno,a5@no,class@no:75
#
# a2@premeno,a4@0-2,a9@no:85
#
# a2@premeno,a5@no,a9@no:85
#
# a2@premeno,a4@0-2,a5@no,a9@no:82
#
# a2@premeno,a4@0-2:101
#
# a2@premeno,a4@0-2,a5@no:95
#
# a2@premeno,a5@no:103
#
# a4@0-2,a9@no,class@no:124
#
# a4@0-2,a5@no,a9@no,class@no:122
#
# a5@no,a9@no,class@no:125
#
# a4@0-2,class@no:142
#
# a5@no,class@no:142
#
# a4@0-2,a5@no,class@no:136
#
# a4@0-2,a9@no:156
#
# a4@0-2,a5@no,a9@no:150
#
# a4@0-2,a5@no:172
#
# a9@no:184
#
# a5@no,a9@no:158
#
# a5@no:188

# %% [markdown]
# ContrastParams

# %%
delta1, delta2, substantial_threshold = 0.1, 0.0, 0.0

# %%
class ContrastParams(object):
    '''
    classdocs
    '''

    def __init__(self, delta1, delta2, share_threshold, n_lhs_features, n_rhs_features):
        '''
        Constructor
        '''
        self.delta1 = delta1 
        self.delta2 = delta2 
    
        self.share_threshold = share_threshold
        self.n_lhs_features = n_lhs_features
        self.n_rhs_features = n_rhs_features

# %%
contrast_params = ContrastParams(delta1, delta2,
                                      substantial_threshold, 
                                      lhs_feature_count, 
                                      rhs_feature_count)

# %%
contrast_params

# %%
my_minpts,my_eps = 3, 2.0

# %%
class dbscanParams(object):
    
    def __init__(self, minpts, eps):
        self.min_pts = minpts
        self.eps = eps

# %%
dbscan_params = dbscanParams(my_minpts, my_eps)

# %%
epsilon =5e-3

# %% [markdown]
# Clustering Enginer

# %%
from sklearn.decomposition.incremental_pca import IncrementalPCA

# %%
class UnexpectednessExtractor(object):
    
    def __init__(self, X_train, freq_itemset_dict, rule_list, contrast_params, epsilon = 5e-5, eps_step = 0.1, reduced_rate = None):
        self.rule_list = rule_list
        self.freq_itemset_dict = freq_itemset_dict
        
        self.original_features = X_train
        self.sample_features = X_train
        
        self.contrast_params = contrast_params
        self.epsilon = epsilon
        self.eps_step = eps_step

        if reduced_rate is not None:
            ncomponents = int(X_train.shape[1] * reduced_rate) 
            pca = IncrementalPCA(n_components = ncomponents)
            self.sample_features = pca.fit_transform(X_train)
    def data_size(self):
        return len(self.rule_list)

    def check_inner_contrast(self, new_cluster_locations):
        group = self._collect_group_info(new_cluster_locations)
        return self.freq_itemset_dict.is_inner_contrast(group, self.contrast_params)

    def _collect_group_info(self, locations):
        lhs_features = []
        rhs_features = []
        rules = []
        
        n = self.contrast_params.n_lhs_features
        for i in locations:
            lhs_features.append(self.original_features[i][:n])
            rhs_features.append(self.original_features[i][n:])
            rules.append(self.rule_list[i])
            
        return {'lhs': np.array(lhs_features),
                'rhs': np.array(rhs_features),
                'r': rules}

    def check_outer_contrast(self, group1, group2):
        #print(len(group1), len(group2))
        if len(group1) == 0 or len(group2) == 0:
            return False
        
        g1 = self._collect_group_info(group1)
        g2 = self._collect_group_info(group2)
        
        return self.freq_itemset_dict.is_outer_contrast(g1, g2,
                                           self.contrast_params)
        
    def detect_unexpectedness(self, clustering_result):
        print('Geting conflict information...')
        
        array_Y = np.array(clustering_result)
        cluster_indices = Counter(clustering_result)
        
        print(len(clustering_result),len(cluster_indices))
        outliers = np.where(array_Y == -1)[0]
        my_unexpected_patterns = {i : [] for i in outliers}
        
        print('Finding unexpectedness....')

        outlier_group = self._collect_group_info(outliers)
        for cluster_index in cluster_indices.keys():
            if cluster_index == -1: continue 
            beliefs = np.where(array_Y == cluster_index)[0]
            belief_group = self._collect_group_info(beliefs)
            contrast_location = self.freq_itemset_dict.find_pottential_contrast_locs(outlier_group, 
                                                                             belief_group,
                                                                             self.contrast_params)
            
            if contrast_location is None:
                continue 
            
            for i in range(len(contrast_location[0])):
                x = contrast_location[0][i]
                y = contrast_location[1][i]
                
                t = self.freq_itemset_dict._complement_condition(outlier_group['r'][x], belief_group['r'][y])
                if t > self.contrast_params.share_threshold:
                    j = beliefs[y]
                    conf = self.freq_itemset_dict.getConfidence(self.rule_list[j])
                    b = cosine_similarity(np.reshape(outlier_group['lhs'][x,:], (1, -1)), 
                                          np.reshape(belief_group['lhs'][y,:], (1, -1)))[0,0]
                    my_unexpected_patterns[outliers[x]].append((self.rule_list[j].serialize(), b, t, conf))
                
        
        final_unexpected_patterns = []
        
        for i in my_unexpected_patterns.keys():
            contrast_beliefs = my_unexpected_patterns[i]
            if len(contrast_beliefs) == 0: continue
            c = self.freq_itemset_dict.getConfidence(self.rule_list[i])
            sorted_beliefs = sorted(contrast_beliefs, key=lambda x: x[1], reverse = True)
            del sorted_beliefs[3: ]
            final_unexpected_patterns.append((self.rule_list[i].serialize(), c, sorted_beliefs))
        print('Number of unexpected patterns ' + str(len(final_unexpected_patterns)) )
        return sorted(final_unexpected_patterns, key=lambda x: x[2][0][1], reverse=True)

# %%
clustering_engine = UnexpectednessExtractor(X_train, 
                                         freq_itemset_dict, 
                                         association_rules_list, 
                                         contrast_params,
                                         epsilon=epsilon,
                                         #reduced_rate=None)
                                         reduced_rate=0.5)

# %% [markdown]
# Clustering labels

# %%
from sklearn.metrics.pairwise import euclidean_distances, cosine_similarity

# %%
eps_step = 0.1

# %%
rule_list = association_rules_list

# %%
def data_size():
        return len(rule_list)

# %%
class MyRulesClustering(object):
    
    def __init__(self, dbscan_params, clustering_engine, nThreads, allowed_conflict_size = 0):
        self.dbscan_params = dbscan_params
        self.best_eps = self.dbscan_params.eps
        
        self.nthreads = nThreads
        
        self.engine = clustering_engine
        self.allowed_conflict_size = allowed_conflict_size
        
        self.Y = None
        self.visisted = None



    def intialize(self):
        m = self.engine.data_size()
        self.Y = [-1 for _ in range(m)]
        self.visisted = [False for _ in range(m)]

    def region_query(self, p):
        temp = self.engine.sample_features[p,:]
        temp = np.reshape(temp, (1, -1))
       
        distance = euclidean_distances(temp, self.engine.sample_features)
        neighbors = np.where(distance <= self.best_eps)
        return neighbors[1].tolist()


    def expand_cluster(self, p, C, neighbors):
        self.Y[p] = C
        while len(neighbors) > 0:
            other_p = neighbors.pop(0)
            if self.visisted[other_p] == False:
                self.visisted[other_p] = True
                other_neighbors = self.region_query(other_p)
                
                if (len(other_neighbors) >= self.dbscan_params.min_pts):
                    neighbors.extend(other_neighbors)
                    tmp = list(set(neighbors))
                    neighbors.clear()
                    neighbors.extend(tmp)
                    
            if self.Y[other_p] == -1:
                self.Y[other_p] = C

    def check_contrast(self, C):
        
        tmp_Y = np.array(self.Y)
        new_cluster_locations = np.where(tmp_Y == C)[0]
        if len(new_cluster_locations) <= self.allowed_conflict_size: return False
        
        if self.engine.check_inner_contrast(new_cluster_locations)==True:
            return True 
        
        cluster_indices = Counter(tmp_Y)
        for cluster in cluster_indices.keys():
            if cluster == C or cluster == -1: continue
            
            old_cluster_locations = np.where(tmp_Y == cluster)[0]
         
            if len(old_cluster_locations) <= self.allowed_conflict_size: continue
            if self.engine.check_outer_contrast(old_cluster_locations, new_cluster_locations) == True:
                return True
                
        return False  


    def run(self, eps_step):
        m = self.engine.data_size()
        print("this is m",m)
            
        self.best_eps = self.dbscan_params.eps
        while(self.best_eps  > 0):
            print('running for ' + str(self.best_eps))
            self.intialize()
            C = -1
            flag = True
            for p in range(m):
                if p % 100 == 0: print (p)
                if self.visisted[p] == True: continue
                
                self.visisted[p] = True
                neighbors = self.region_query(p)
                if len(neighbors) >= self.dbscan_params.min_pts:
                    C += 1
                    self.expand_cluster(p, C, neighbors)
                    if self.check_contrast(C) == True:
                        flag = False
                        break
                        
            if flag == True:
                print('Found a good eps: ' + str(self.best_eps)) 
                break
            
            self.best_eps -= eps_step

    def detect_unexpectedness(self, clustering_result):
        print('Geting conflict information...')
        
        array_Y = np.array(clustering_result)
        cluster_indices = Counter(clustering_result)
        
        print(len(clustering_result),len(cluster_indices))
        outliers = np.where(array_Y == -1)[0]
        my_unexpected_patterns = {i : [] for i in outliers}
        
        print('Finding unexpectedness....')

        outlier_group = self._collect_group_info(outliers)
        for cluster_index in cluster_indices.keys():
            if cluster_index == -1: continue 
            beliefs = np.where(array_Y == cluster_index)[0]
            belief_group = self._collect_group_info(beliefs)
            contrast_location = self.freq_itemset_dict.find_pottential_contrast_locs(outlier_group, 
                                                                             belief_group,
                                                                             self.contrast_params)
            
            if contrast_location is None:
                continue 
            
            for i in range(len(contrast_location[0])):
                x = contrast_location[0][i]
                y = contrast_location[1][i]
                
                t = self.freq_itemset_dict._complement_condition(outlier_group['r'][x], belief_group['r'][y])
                if t > self.contrast_params.share_threshold:
                    j = beliefs[y]
                    conf = self.freq_itemset_dict.getConfidence(self.rule_list[j])
                    b = cosine_similarity(np.reshape(outlier_group['lhs'][x,:], (1, -1)), 
                                          np.reshape(belief_group['lhs'][y,:], (1, -1)))[0,0]
                    my_unexpected_patterns[outliers[x]].append((self.rule_list[j].serialize(), b, t, conf))
                
        
        final_unexpected_patterns = []
        
        for i in my_unexpected_patterns.keys():
            contrast_beliefs = my_unexpected_patterns[i]
            if len(contrast_beliefs) == 0: continue
            c = self.freq_itemset_dict.getConfidence(self.rule_list[i])
            sorted_beliefs = sorted(contrast_beliefs, key=lambda x: x[1], reverse = True)
            del sorted_beliefs[3: ]
            final_unexpected_patterns.append((self.rule_list[i].serialize(), c, sorted_beliefs))
        print('Number of unexpected patterns ' + str(len(final_unexpected_patterns)) )
        return sorted(final_unexpected_patterns, key=lambda x: x[2][0][1], reverse=True)

# %%
from sklearn.decomposition.incremental_pca import IncrementalPCA
from sklearn.cluster import DBSCAN
from sklearn.cluster import OPTICS, cluster_optics_dbscan

# %%
def run_dbscan(dbscan_params, nthreads, data, points):
        print ('Doing clustering ....')
        print('epsilon ' + str(epsilon))
        reduced_rate =0.5
        
        ncomponents = int(data.shape[1] * reduced_rate)
        pca = IncrementalPCA(n_components = ncomponents)
        data = pca.fit_transform(data) 
        
        
        db  = OPTICS(min_samples=points,xi=.1).fit(data)
        core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
        
        labels = db.labels_
        
        #Y = noconflict_db.Y.copy()

        Y = labels
        
        n_clusters = len(set(Y))- (1 if -1 in Y else 0)
        n_noises = list(Y).count(-1)
        
       
        print('Number of clusters' + str(n_clusters))
        print('Number of noises' + str(n_noises))
    
        print("Y" , Y)
        print("Type of Y is ",type(Y))
        print("Lenght of Y is",len(Y))
        return Y

# %%
def merge_itemsets(itemset_1, itemset_2):
    merged_items = []
    merged_items.extend(itemset_1)
    merged_items.extend(itemset_2)
    merged_items = list(set(merged_items))
    merged_items = sorted(merged_items)
    
    return merged_items

# %%
from collections import Counter

# %%
cluster_labels = run_dbscan(dbscan_params, nthreads = 4, data=X_train, points=3)
# Out:
# Doing clustering ....
# epsilon 0.005
# Number of clusters254
# Number of noises1305
# Y [ -1 153 153 ... 213 240 204]
# Type of Y is  <class 'numpy.ndarray'>
# Lenght of Y is 2429

# %% [markdown]
# Computing confidence

# %%
rules_and_their_clusters = []

# %%
def compute_confidence(association_rules_list):
        freq_itemset_dict = load_frequent_itemsets_as_dict()
        
        rule_confidence_dict = {}
        for rule in association_rules_list:
            left, _, both = freq_itemset_dict.get_frequency_combo(rule)
            rule_confidence_dict[rule.serialize()] = (both/left, both)
        
        print("rule_confidence_dict",rule_confidence_dict)
        return rule_confidence_dict

# %%
confidence_support_values = compute_confidence(association_rules_list)
# Out:
# Streaming output truncated to the last 5000 lines.
#
# a1@40-49,a4@0-2,a6@2,a7@left,class@yes:3
#
# a1@40-49,a4@0-2,a6@2,a7@left,a9@no,class@yes:2
#
# a1@40-49,a2@premeno,a4@0-2,a6@2,a7@left,class@yes:3
#
# a1@40-49,a2@premeno,a4@0-2,a6@2,a7@left,a9@no,class@yes:2
#
# a1@40-49,a5@no,a6@2,a7@left,class@yes:3
#
# a1@40-49,a4@0-2,a5@no,a6@2,a7@left,class@yes:3
#
# a1@40-49,a5@no,a6@2,a7@left,a9@no,class@yes:2
#
# a1@40-49,a2@premeno,a5@no,a6@2,a7@left,class@yes:3
#
# a1@40-49,a4@0-2,a5@no,a6@2,a7@left,a9@no,class@yes:2
#
# a1@40-49,a2@premeno,a4@0-2,a5@no,a6@2,a7@left,class@yes:3
#
# a1@40-49,a2@premeno,a5@no,a6@2,a7@left,a9@no,class@yes:2
#
# a1@40-49,a2@premeno,a4@0-2,a5@no,a6@2,a7@left,a9@no,class@yes:2
#
# a1@40-49,a2@premeno,a6@2,a7@left,class@yes:5
#
# a1@40-49,a4@0-2,a6@2,class@yes:7
#
# a1@40-49,a4@0-2,a5@no,a6@2,class@yes:7
#
# a1@40-49,a2@premeno,a4@0-2,a6@2,class@yes:6
#
# a1@40-49,a2@premeno,a4@0-2,a5@no,a6@2,class@yes:6
#
# a1@40-49,a4@0-2,a6@2,a9@no,class@yes:5
#
# a1@40-49,a2@premeno,a4@0-2,a6@2,a9@no,class@yes:4
#
# a1@40-49,a4@0-2,a5@no,a6@2,a9@no,class@yes:5
#
# a1@40-49,a2@premeno,a4@0-2,a5@no,a6@2,a9@no,class@yes:4
#
# a1@40-49,a5@no,a6@2,a9@no,class@yes:6
#
# a1@40-49,a2@premeno,a6@2,a9@no,class@yes:6
#
# a1@40-49,a2@premeno,a5@no,a6@2,a9@no,class@yes:5
#
# a1@40-49,a5@no,a6@2,class@yes:8
#
# a1@40-49,a2@premeno,a5@no,a6@2,class@yes:7
#
# a1@40-49,a2@premeno,a6@2,class@yes:10
#
# a4@0-2,a6@2,a7@left,a9@no,class@yes:6
#
# a4@0-2,a5@no,a6@2,a7@left,a9@no,class@yes:6
#
# a2@premeno,a4@0-2,a6@2,a7@left,class@yes:6
#
# a2@premeno,a4@0-2,a6@2,a7@left,a9@no,class@yes:5
#
# a2@premeno,a4@0-2,a5@no,a6@2,a7@left,class@yes:6
#
# a2@premeno,a4@0-2,a5@no,a6@2,a7@left,a9@no,class@yes:5
#
# a4@0-2,a5@no,a6@2,a7@left,class@yes:7
#
# a6@2,a7@left,a9@no,class@yes:8
#
# a2@premeno,a6@2,a7@left,a9@no,class@yes:7
#
# a5@no,a6@2,a7@left,a9@no,class@yes:6
#
# a2@premeno,a5@no,a6@2,a7@left,class@yes:6
#
# a2@premeno,a5@no,a6@2,a7@left,a9@no,class@yes:5
#
# a2@premeno,a6@2,a7@left,class@yes:9
#
# a2@premeno,a4@0-2,a6@2,class@yes:10
#
# a2@premeno,a4@0-2,a6@2,a9@no,class@yes:8
#
# a2@premeno,a4@0-2,a5@no,a6@2,class@yes:10
#
# a2@premeno,a4@0-2,a5@no,a6@2,a9@no,class@yes:8
#
# a4@0-2,a6@2,a9@no,class@yes:12
#
# a4@0-2,a5@no,a6@2,a9@no,class@yes:12
#
# a4@0-2,a5@no,a6@2,class@yes:14
#
# a2@premeno,a6@2,class@yes:16
#
# a2@premeno,a5@no,a6@2,class@yes:12
#
# a2@premeno,a6@2,a9@no,class@yes:11
#
# a2@premeno,a5@no,a6@2,a9@no,class@yes:9
#
# a5@no,a6@2,a9@no,class@yes:14
#
# a5@no,a6@2,class@yes:18
#
# a1@40-49,a2@ge40,a4@0-2,class@yes:1
#
# a1@40-49,a2@ge40,a4@0-2,a9@no,class@yes:1
#
# a1@40-49,a2@ge40,a4@0-2,a7@right,class@yes:1
#
# a1@40-49,a2@ge40,a4@0-2,a5@no,class@yes:1
#
# a1@40-49,a2@ge40,a4@0-2,a7@right,a9@no,class@yes:1
#
# a1@40-49,a2@ge40,a4@0-2,a5@no,a9@no,class@yes:1
#
# a1@40-49,a2@ge40,a4@0-2,a5@no,a7@right,class@yes:1
#
# a1@40-49,a2@ge40,a4@0-2,a5@no,a7@right,a9@no,class@yes:1
#
# a1@40-49,a2@ge40,a7@right,class@yes:2
#
# a1@40-49,a2@ge40,a5@no,a7@right,class@yes:2
#
# a1@40-49,a2@ge40,a7@right,a8@left_low,class@yes:1
#
# a1@40-49,a2@ge40,a5@no,a7@right,a8@left_low,class@yes:1
#
# a1@40-49,a2@ge40,a7@right,a9@no,class@yes:1
#
# a1@40-49,a2@ge40,a5@no,a7@right,a9@no,class@yes:1
#
# a1@40-49,a2@ge40,a7@left,a9@no,class@yes:1
#
# a1@40-49,a2@ge40,a5@no,a7@left,a9@no,class@yes:1
#
# a1@40-49,a2@ge40,a8@left_low,a9@no,class@yes:1
#
# a1@40-49,a2@ge40,a7@left,a8@left_low,a9@no,class@yes:1
#
# a1@40-49,a2@ge40,a5@no,a8@left_low,a9@no,class@yes:1
#
# a1@40-49,a2@ge40,a5@no,a7@left,a8@left_low,a9@no,class@yes:1
#
# a1@40-49,a2@ge40,a5@no,a9@no,class@yes:2
#
# a1@40-49,a2@ge40,a8@left_low,class@yes:2
#
# a1@40-49,a2@ge40,a5@no,a8@left_low,class@yes:2
#
# a1@40-49,a2@ge40,a7@left,class@yes:2
#
# a1@40-49,a2@ge40,a7@left,a8@left_low,class@yes:1
#
# a1@40-49,a2@ge40,a5@no,a7@left,class@yes:1
#
# a1@40-49,a2@ge40,a5@no,a7@left,a8@left_low,class@yes:1
#
# a1@40-49,a2@ge40,a5@no,class@yes:3
#
# a1@40-49,a7@right,a8@left_low,class@yes:4
#
# a1@40-49,a5@no,a7@right,a8@left_low,class@yes:4
#
# a1@40-49,a7@right,a8@left_low,a9@no,class@yes:2
#
# a1@40-49,a4@0-2,a7@right,a8@left_low,class@yes:3
#
# a1@40-49,a2@premeno,a7@right,a8@left_low,class@yes:3
#
# a1@40-49,a5@no,a7@right,a8@left_low,a9@no,class@yes:2
#
# a1@40-49,a4@0-2,a5@no,a7@right,a8@left_low,class@yes:3
#
# a1@40-49,a2@premeno,a5@no,a7@right,a8@left_low,class@yes:3
#
# a1@40-49,a4@0-2,a7@right,a8@left_low,a9@no,class@yes:2
#
# a1@40-49,a2@premeno,a7@right,a8@left_low,a9@no,class@yes:2
#
# a1@40-49,a2@premeno,a4@0-2,a7@right,a8@left_low,class@yes:3
#
# a1@40-49,a4@0-2,a5@no,a7@right,a8@left_low,a9@no,class@yes:2
#
# a1@40-49,a2@premeno,a5@no,a7@right,a8@left_low,a9@no,class@yes:2
#
# a1@40-49,a2@premeno,a4@0-2,a5@no,a7@right,a8@left_low,class@yes:3
#
# a1@40-49,a2@premeno,a4@0-2,a7@right,a8@left_low,a9@no,class@yes:2
#
# a1@40-49,a2@premeno,a4@0-2,a5@no,a7@right,a8@left_low,a9@no,class@yes:2
#
# a1@40-49,a4@0-2,a8@left_low,class@yes:7
#
# a1@40-49,a4@0-2,a7@left,a8@left_low,class@yes:4
#
# a1@40-49,a4@0-2,a5@no,a8@left_low,class@yes:7
#
# a1@40-49,a2@premeno,a4@0-2,a8@left_low,class@yes:7
#
# a1@40-49,a4@0-2,a5@no,a7@left,a8@left_low,class@yes:4
#
# a1@40-49,a2@premeno,a4@0-2,a7@left,a8@left_low,class@yes:4
#
# a1@40-49,a2@premeno,a4@0-2,a5@no,a8@left_low,class@yes:7
#
# a1@40-49,a2@premeno,a4@0-2,a5@no,a7@left,a8@left_low,class@yes:4
#
# a1@40-49,a4@0-2,a8@left_low,a9@no,class@yes:4
#
# a1@40-49,a4@0-2,a5@no,a8@left_low,a9@no,class@yes:4
#
# a1@40-49,a4@0-2,a7@left,a8@left_low,a9@no,class@yes:2
#
# a1@40-49,a2@premeno,a4@0-2,a8@left_low,a9@no,class@yes:4
#
# a1@40-49,a4@0-2,a5@no,a7@left,a8@left_low,a9@no,class@yes:2
#
# a1@40-49,a2@premeno,a4@0-2,a5@no,a8@left_low,a9@no,class@yes:4
#
# a1@40-49,a2@premeno,a4@0-2,a7@left,a8@left_low,a9@no,class@yes:2
#
# a1@40-49,a2@premeno,a4@0-2,a5@no,a7@left,a8@left_low,a9@no,class@yes:2
#
# a1@40-49,a7@left,a8@left_low,a9@no,class@yes:5
#
# a1@40-49,a2@premeno,a7@left,a8@left_low,a9@no,class@yes:4
#
# a1@40-49,a5@no,a7@left,a8@left_low,a9@no,class@yes:3
#
# a1@40-49,a2@premeno,a5@no,a7@left,a8@left_low,a9@no,class@yes:2
#
# a1@40-49,a2@premeno,a5@no,a8@left_low,a9@no,class@yes:4
#
# a1@40-49,a2@premeno,a8@left_low,a9@no,class@yes:6
#
# a1@40-49,a5@no,a7@left,a8@left_low,class@yes:5
#
# a1@40-49,a2@premeno,a5@no,a7@left,a8@left_low,class@yes:4
#
# a1@40-49,a2@premeno,a7@left,a8@left_low,class@yes:7
#
# a1@40-49,a5@no,a8@left_low,class@yes:9
#
# a1@40-49,a2@premeno,a5@no,a8@left_low,class@yes:7
#
# a1@40-49,a2@premeno,a8@left_low,class@yes:10
#
# a1@40-49,a4@0-2,a7@right,a9@no,class@yes:7
#
# a1@40-49,a2@premeno,a4@0-2,a7@right,class@yes:7
#
# a1@40-49,a2@premeno,a4@0-2,a7@right,a9@no,class@yes:6
#
# a1@40-49,a4@0-2,a5@no,a7@right,class@yes:6
#
# a1@40-49,a5@no,a7@right,a9@no,class@yes:6
#
# a1@40-49,a4@0-2,a5@no,a7@right,a9@no,class@yes:5
#
# a1@40-49,a2@premeno,a5@no,a7@right,a9@no,class@yes:5
#
# a1@40-49,a2@premeno,a4@0-2,a5@no,a7@right,class@yes:5
#
# a1@40-49,a2@premeno,a4@0-2,a5@no,a7@right,a9@no,class@yes:4
#
# a1@40-49,a7@right,a9@no,class@yes:9
#
# a1@40-49,a2@premeno,a7@right,a9@no,class@yes:8
#
# a1@40-49,a2@premeno,a7@right,class@yes:10
#
# a1@40-49,a4@0-2,a7@left,class@yes:7
#
# a1@40-49,a4@0-2,a5@no,a7@left,class@yes:7
#
# a1@40-49,a4@0-2,a7@left,a9@no,class@yes:5
#
# a1@40-49,a2@premeno,a4@0-2,a7@left,class@yes:7
#
# a1@40-49,a4@0-2,a5@no,a7@left,a9@no,class@yes:5
#
# a1@40-49,a2@premeno,a4@0-2,a5@no,a7@left,class@yes:7
#
# a1@40-49,a2@premeno,a4@0-2,a7@left,a9@no,class@yes:5
#
# a1@40-49,a2@premeno,a4@0-2,a5@no,a7@left,a9@no,class@yes:5
#
# a1@40-49,a5@no,a7@left,a9@no,class@yes:6
#
# a1@40-49,a2@premeno,a5@no,a7@left,a9@no,class@yes:5
#
# a1@40-49,a2@premeno,a5@no,a7@left,class@yes:7
#
# a1@40-49,a7@left,a9@no,class@yes:9
#
# a1@40-49,a2@premeno,a7@left,a9@no,class@yes:8
#
# a1@40-49,a2@premeno,a7@left,class@yes:11
#
# a1@40-49,a4@0-2,a5@no,a9@no,class@yes:10
#
# a1@40-49,a2@premeno,a4@0-2,a5@no,a9@no,class@yes:9
#
# a1@40-49,a2@premeno,a4@0-2,a9@no,class@yes:11
#
# a1@40-49,a4@0-2,a5@no,class@yes:13
#
# a1@40-49,a2@premeno,a4@0-2,a5@no,class@yes:12
#
# a1@40-49,a2@premeno,a4@0-2,class@yes:14
#
# a1@40-49,a5@no,a9@no,class@yes:12
#
# a1@40-49,a2@premeno,a5@no,a9@no,class@yes:10
#
# a1@40-49,a2@premeno,a5@no,class@yes:13
#
# a1@40-49,a9@no,class@yes:18
#
# a1@40-49,a2@premeno,a9@no,class@yes:16
#
# a1@40-49,a2@premeno,class@yes:21
#
# a2@ge40,a4@0-2,a8@left_low,class@yes:3
#
# a2@ge40,a4@0-2,a8@left_low,a9@no,class@yes:3
#
# a2@ge40,a4@0-2,a5@no,a8@left_low,class@yes:3
#
# a2@ge40,a4@0-2,a7@right,a8@left_low,class@yes:2
#
# a2@ge40,a4@0-2,a5@no,a8@left_low,a9@no,class@yes:3
#
# a2@ge40,a4@0-2,a7@right,a8@left_low,a9@no,class@yes:2
#
# a2@ge40,a4@0-2,a5@no,a7@right,a8@left_low,class@yes:2
#
# a2@ge40,a4@0-2,a5@no,a7@right,a8@left_low,a9@no,class@yes:2
#
# a2@ge40,a4@0-2,a7@left,class@yes:3
#
# a2@ge40,a4@0-2,a7@left,a8@left_low,class@yes:1
#
# a2@ge40,a4@0-2,a7@left,a9@no,class@yes:2
#
# a2@ge40,a4@0-2,a5@no,a7@left,class@yes:3
#
# a2@ge40,a4@0-2,a7@left,a8@left_low,a9@no,class@yes:1
#
# a2@ge40,a4@0-2,a5@no,a7@left,a8@left_low,class@yes:1
#
# a2@ge40,a4@0-2,a5@no,a7@left,a9@no,class@yes:2
#
# a2@ge40,a4@0-2,a5@no,a7@left,a8@left_low,a9@no,class@yes:1
#
# a2@ge40,a4@0-2,a9@no,class@yes:8
#
# a2@ge40,a4@0-2,a5@no,a9@no,class@yes:8
#
# a2@ge40,a4@0-2,a7@right,a9@no,class@yes:6
#
# a2@ge40,a4@0-2,a5@no,a7@right,a9@no,class@yes:6
#
# a2@ge40,a4@0-2,a7@right,class@yes:8
#
# a2@ge40,a4@0-2,a5@no,a7@right,class@yes:8
#
# a2@ge40,a4@0-2,a5@no,class@yes:11
#
# a2@ge40,a7@right,a8@left_low,a9@no,class@yes:3
#
# a2@ge40,a5@no,a7@right,a8@left_low,class@yes:3
#
# a2@ge40,a5@no,a7@right,a8@left_low,a9@no,class@yes:2
#
# a2@ge40,a7@left,a8@left_low,a9@no,class@yes:4
#
# a2@ge40,a5@no,a7@left,a8@left_low,a9@no,class@yes:3
#
# a2@ge40,a5@no,a8@left_low,a9@no,class@yes:5
#
# a2@ge40,a7@left,a8@left_low,class@yes:8
#
# a2@ge40,a5@no,a8@left_low,class@yes:8
#
# a2@ge40,a5@no,a7@left,a8@left_low,class@yes:5
#
# a2@ge40,a7@right,a9@no,class@yes:10
#
# a2@ge40,a5@no,a7@right,a9@no,class@yes:8
#
# a2@ge40,a5@no,a7@right,class@yes:11
#
# a2@ge40,a7@left,a9@no,class@yes:6
#
# a2@ge40,a5@no,a7@left,a9@no,class@yes:4
#
# a2@ge40,a5@no,a7@left,class@yes:7
#
# a2@ge40,a9@no,class@yes:16
#
# a2@ge40,a5@no,a9@no,class@yes:12
#
# a2@ge40,a5@no,class@yes:18
#
# a2@premeno,a7@right,a8@left_low,class@yes:5
#
# a2@premeno,a7@right,a8@left_low,a9@no,class@yes:3
#
# a2@premeno,a4@0-2,a7@right,a8@left_low,class@yes:5
#
# a2@premeno,a5@no,a7@right,a8@left_low,class@yes:5
#
# a2@premeno,a4@0-2,a7@right,a8@left_low,a9@no,class@yes:3
#
# a2@premeno,a5@no,a7@right,a8@left_low,a9@no,class@yes:3
#
# a2@premeno,a4@0-2,a5@no,a7@right,a8@left_low,class@yes:5
#
# a2@premeno,a4@0-2,a5@no,a7@right,a8@left_low,a9@no,class@yes:3
#
# a7@right,a8@left_low,a9@no,class@yes:6
#
# a4@0-2,a7@right,a8@left_low,a9@no,class@yes:5
#
# a5@no,a7@right,a8@left_low,a9@no,class@yes:5
#
# a4@0-2,a5@no,a7@right,a8@left_low,a9@no,class@yes:5
#
# a4@0-2,a7@right,a8@left_low,class@yes:7
#
# a4@0-2,a5@no,a7@right,a8@left_low,class@yes:7
#
# a5@no,a7@right,a8@left_low,class@yes:8
#
# a2@premeno,a4@0-2,a5@no,a7@right,class@yes:10
#
# a2@premeno,a4@0-2,a7@right,a9@no,class@yes:10
#
# a2@premeno,a4@0-2,a5@no,a7@right,a9@no,class@yes:8
#
# a2@premeno,a7@right,a9@no,class@yes:13
#
# a2@premeno,a5@no,a7@right,class@yes:13
#
# a2@premeno,a5@no,a7@right,a9@no,class@yes:9
#
# a4@0-2,a7@right,a9@no,class@yes:16
#
# a4@0-2,a5@no,a7@right,a9@no,class@yes:14
#
# a4@0-2,a5@no,a7@right,class@yes:18
#
# a7@right,a9@no,class@yes:23
#
# a5@no,a7@right,a9@no,class@yes:17
#
# a5@no,a7@right,class@yes:24
#
# a2@premeno,a4@0-2,a7@left,a8@left_low,class@yes:7
#
# a2@premeno,a4@0-2,a5@no,a7@left,a8@left_low,class@yes:7
#
# a4@0-2,a7@left,a8@left_low,a9@no,class@yes:7
#
# a2@premeno,a4@0-2,a7@left,a8@left_low,a9@no,class@yes:5
#
# a4@0-2,a5@no,a7@left,a8@left_low,a9@no,class@yes:6
#
# a2@premeno,a4@0-2,a5@no,a7@left,a8@left_low,a9@no,class@yes:5
#
# a4@0-2,a5@no,a7@left,a8@left_low,class@yes:8
#
# a4@0-2,a8@left_low,a9@no,class@yes:12
#
# a4@0-2,a5@no,a8@left_low,a9@no,class@yes:11
#
# a2@premeno,a4@0-2,a8@left_low,class@yes:12
#
# a2@premeno,a4@0-2,a8@left_low,a9@no,class@yes:8
#
# a2@premeno,a4@0-2,a5@no,a8@left_low,class@yes:12
#
# a2@premeno,a4@0-2,a5@no,a8@left_low,a9@no,class@yes:8
#
# a4@0-2,a5@no,a8@left_low,class@yes:15
#
# a2@premeno,a5@no,a8@left_low,class@yes:12
#
# a2@premeno,a5@no,a7@left,a8@left_low,class@yes:7
#
# a2@premeno,a7@left,a8@left_low,class@yes:14
#
# a2@premeno,a7@left,a8@left_low,a9@no,class@yes:8
#
# a2@premeno,a5@no,a8@left_low,a9@no,class@yes:8
#
# a2@premeno,a5@no,a7@left,a8@left_low,a9@no,class@yes:5
#
# a5@no,a8@left_low,a9@no,class@yes:13
#
# a7@left,a8@left_low,a9@no,class@yes:13
#
# a5@no,a7@left,a8@left_low,a9@no,class@yes:8
#
# a5@no,a8@left_low,class@yes:20
#
# a5@no,a7@left,a8@left_low,class@yes:12
#
# a7@left,a8@left_low,class@yes:23
#
# a2@premeno,a5@no,a7@left,class@yes:15
#
# a2@premeno,a5@no,a7@left,a9@no,class@yes:12
#
# a5@no,a7@left,a9@no,class@yes:16
#
# a2@premeno,a7@left,class@yes:23
#
# a2@premeno,a7@left,a9@no,class@yes:16
#
# a7@left,a9@no,class@yes:24
#
# a2@premeno,a4@0-2,a7@left,class@yes:15
#
# a2@premeno,a4@0-2,a7@left,a9@no,class@yes:12
#
# a2@premeno,a4@0-2,a5@no,a7@left,class@yes:15
#
# a2@premeno,a4@0-2,a5@no,a7@left,a9@no,class@yes:12
#
# a4@0-2,a7@left,a9@no,class@yes:16
#
# a4@0-2,a5@no,a7@left,a9@no,class@yes:14
#
# a4@0-2,a5@no,a7@left,class@yes:18
#
# a2@premeno,a4@0-2,a9@no,class@yes:22
#
# a2@premeno,a4@0-2,a5@no,a9@no,class@yes:20
#
# a2@premeno,a4@0-2,a5@no,class@yes:25
#
# a4@0-2,a9@no,class@yes:32
#
# a4@0-2,a5@no,a9@no,class@yes:28
#
# a4@0-2,a5@no,class@yes:36
#
# a2@premeno,a5@no,class@yes:28
#
# a2@premeno,a5@no,a9@no,class@yes:21
#
# a2@premeno,a9@no,class@yes:29
#
# a5@no,class@yes:46
#
# a5@no,a9@no,class@yes:33
#
# a9@no,class@yes:47
#
# a1@50-59,a2@premeno,a7@left,a8@left_up:2
#
# a1@50-59,a2@premeno,a6@2,a7@left,a8@left_up:2
#
# a1@50-59,a2@premeno,a7@left,a8@left_up,a9@no:2
#
# a1@50-59,a2@premeno,a5@no,a7@left,a8@left_up:1
#
# a1@50-59,a2@premeno,a4@0-2,a7@left,a8@left_up:2
#
# a1@50-59,a2@premeno,a7@left,a8@left_up,class@no:2
#
# a1@50-59,a2@premeno,a6@2,a7@left,a8@left_up,a9@no:2
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@left,a8@left_up:1
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@left,a8@left_up:2
#
# a1@50-59,a2@premeno,a6@2,a7@left,a8@left_up,class@no:2
#
# a1@50-59,a2@premeno,a5@no,a7@left,a8@left_up,a9@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a7@left,a8@left_up,a9@no:2
#
# a1@50-59,a2@premeno,a7@left,a8@left_up,a9@no,class@no:2
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@left,a8@left_up:1
#
# a1@50-59,a2@premeno,a5@no,a7@left,a8@left_up,class@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a7@left,a8@left_up,class@no:2
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@left,a8@left_up,a9@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@left,a8@left_up,a9@no:2
#
# a1@50-59,a2@premeno,a6@2,a7@left,a8@left_up,a9@no,class@no:2
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@left,a8@left_up:1
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@left,a8@left_up,class@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@left,a8@left_up,class@no:2
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@left,a8@left_up,a9@no:1
#
# a1@50-59,a2@premeno,a5@no,a7@left,a8@left_up,a9@no,class@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a7@left,a8@left_up,a9@no,class@no:2
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@left,a8@left_up,class@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@left,a8@left_up,a9@no:1
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@left,a8@left_up,a9@no,class@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@left,a8@left_up,a9@no,class@no:2
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@left,a8@left_up,class@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@left,a8@left_up,a9@no,class@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@left,a8@left_up,a9@no,class@no:1
#
# a1@50-59,a2@premeno,a6@2,a7@right,a8@left_up:3
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@right,a8@left_up:2
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@right,a8@left_up:3
#
# a1@50-59,a2@premeno,a6@2,a7@right,a8@left_up,a9@no:2
#
# a1@50-59,a2@premeno,a6@2,a7@right,a8@left_up,class@no:3
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@right,a8@left_up:2
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@right,a8@left_up,a9@no:2
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@right,a8@left_up,class@no:2
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@right,a8@left_up,a9@no:2
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@right,a8@left_up,class@no:3
#
# a1@50-59,a2@premeno,a6@2,a7@right,a8@left_up,a9@no,class@no:2
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@right,a8@left_up,a9@no:2
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@right,a8@left_up,class@no:2
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@right,a8@left_up,a9@no,class@no:2
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@right,a8@left_up,a9@no,class@no:2
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@right,a8@left_up,a9@no,class@no:2
#
# a1@50-59,a2@premeno,a6@2,a8@left_up,a9@no:4
#
# a1@50-59,a2@premeno,a6@2,a8@left_up,a9@no,class@no:4
#
# a1@50-59,a2@premeno,a5@no,a6@2,a8@left_up:4
#
# a1@50-59,a2@premeno,a5@no,a6@2,a8@left_up,a9@no:3
#
# a1@50-59,a2@premeno,a5@no,a6@2,a8@left_up,class@no:4
#
# a1@50-59,a2@premeno,a5@no,a6@2,a8@left_up,a9@no,class@no:3
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a8@left_up:4
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a8@left_up:3
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a8@left_up,a9@no:4
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a8@left_up,class@no:4
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a8@left_up,a9@no:3
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a8@left_up,class@no:3
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a8@left_up,a9@no,class@no:4
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a8@left_up,a9@no,class@no:3
#
# a1@50-59,a2@premeno,a6@2,a8@left_up,class@no:5
#
# a1@50-59,a2@premeno,a7@right,a8@left_up,a9@no:4
#
# a1@50-59,a2@premeno,a5@no,a7@right,a8@left_up,a9@no:4
#
# a1@50-59,a2@premeno,a4@0-2,a7@right,a8@left_up:4
#
# a1@50-59,a2@premeno,a4@0-2,a7@right,a8@left_up,a9@no:4
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@right,a8@left_up:4
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@right,a8@left_up,a9@no:4
#
# a1@50-59,a2@premeno,a7@right,a8@left_up,class@no:4
#
# a1@50-59,a2@premeno,a4@0-2,a7@right,a8@left_up,class@no:3
#
# a1@50-59,a2@premeno,a7@right,a8@left_up,a9@no,class@no:3
#
# a1@50-59,a2@premeno,a5@no,a7@right,a8@left_up,class@no:4
#
# a1@50-59,a2@premeno,a4@0-2,a7@right,a8@left_up,a9@no,class@no:3
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@right,a8@left_up,class@no:3
#
# a1@50-59,a2@premeno,a5@no,a7@right,a8@left_up,a9@no,class@no:3
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@right,a8@left_up,a9@no,class@no:3
#
# a1@50-59,a2@premeno,a5@no,a7@right,a8@left_up:5
#
# a1@50-59,a2@premeno,a8@left_up,class@no:6
#
# a1@50-59,a2@premeno,a4@0-2,a8@left_up:6
#
# a1@50-59,a2@premeno,a4@0-2,a8@left_up,class@no:5
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a8@left_up:5
#
# a1@50-59,a2@premeno,a5@no,a8@left_up,class@no:5
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a8@left_up,class@no:4
#
# a1@50-59,a2@premeno,a5@no,a8@left_up,a9@no:5
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a8@left_up,a9@no:5
#
# a1@50-59,a2@premeno,a8@left_up,a9@no,class@no:5
#
# a1@50-59,a2@premeno,a5@no,a8@left_up,a9@no,class@no:4
#
# a1@50-59,a2@premeno,a4@0-2,a8@left_up,a9@no,class@no:5
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a8@left_up,a9@no,class@no:4
#
# a1@50-59,a2@premeno,a4@0-2,a8@left_up,a9@no:6
#
# a1@50-59,a2@premeno,a7@right,a8@left_low:2
#
# a1@50-59,a2@premeno,a6@2,a7@right,a8@left_low:1
#
# a1@50-59,a2@premeno,a7@right,a8@left_low,class@no:1
#
# a1@50-59,a2@premeno,a7@right,a8@left_low,a9@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a7@right,a8@left_low:2
#
# a1@50-59,a2@premeno,a5@no,a7@right,a8@left_low:2
#
# a1@50-59,a2@premeno,a6@2,a7@right,a8@left_low,class@no:1
#
# a1@50-59,a2@premeno,a6@2,a7@right,a8@left_low,a9@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@right,a8@left_low:1
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@right,a8@left_low:1
#
# a1@50-59,a2@premeno,a7@right,a8@left_low,a9@no,class@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a7@right,a8@left_low,class@no:1
#
# a1@50-59,a2@premeno,a5@no,a7@right,a8@left_low,class@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a7@right,a8@left_low,a9@no:1
#
# a1@50-59,a2@premeno,a5@no,a7@right,a8@left_low,a9@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@right,a8@left_low:2
#
# a1@50-59,a2@premeno,a6@2,a7@right,a8@left_low,a9@no,class@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@right,a8@left_low,class@no:1
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@right,a8@left_low,class@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@right,a8@left_low,a9@no:1
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@right,a8@left_low,a9@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@right,a8@left_low:1
#
# a1@50-59,a2@premeno,a4@0-2,a7@right,a8@left_low,a9@no,class@no:1
#
# a1@50-59,a2@premeno,a5@no,a7@right,a8@left_low,a9@no,class@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@right,a8@left_low,class@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@right,a8@left_low,a9@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@right,a8@left_low,a9@no,class@no:1
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@right,a8@left_low,a9@no,class@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@right,a8@left_low,class@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@right,a8@left_low,a9@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@right,a8@left_low,a9@no,class@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@right,a8@left_low,a9@no,class@no:1
#
# a1@50-59,a2@premeno,a6@2,a7@right:5
#
# a1@50-59,a2@premeno,a6@2,a7@right,class@no:5
#
# a1@50-59,a2@premeno,a6@2,a7@right,a9@no:4
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@right:4
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@right:5
#
# a1@50-59,a2@premeno,a6@2,a7@right,a9@no,class@no:4
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@right,class@no:4
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@right,class@no:5
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@right,a9@no:4
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@right,a9@no:4
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@right:4
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@right,a9@no,class@no:4
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@right,a9@no,class@no:4
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@right,class@no:4
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@right,a9@no:4
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@right,a9@no,class@no:4
#
# a1@50-59,a2@premeno,a7@right,class@no:6
#
# a1@50-59,a2@premeno,a7@right,a9@no,class@no:5
#
# a1@50-59,a2@premeno,a4@0-2,a7@right,class@no:5
#
# a1@50-59,a2@premeno,a5@no,a7@right,class@no:6
#
# a1@50-59,a2@premeno,a4@0-2,a7@right,a9@no,class@no:5
#
# a1@50-59,a2@premeno,a5@no,a7@right,a9@no,class@no:5
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@right,class@no:5
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@right,a9@no,class@no:5
#
# a1@50-59,a2@premeno,a4@0-2,a7@right:7
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@right:7
#
# a1@50-59,a2@premeno,a7@right,a9@no:7
#
# a1@50-59,a2@premeno,a4@0-2,a7@right,a9@no:6
#
# a1@50-59,a2@premeno,a5@no,a7@right,a9@no:6
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@right,a9@no:6
#
# a1@50-59,a2@premeno,a5@no,a7@right:8
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@left:4
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@left:4
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@left,class@no:2
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@left,a9@no:4
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@left,class@no:2
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@left,a9@no:4
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@left,a9@no,class@no:2
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@left,a9@no,class@no:2
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@left:5
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@left,class@no:3
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@left,a9@no:5
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@left,a9@no,class@no:3
#
# a1@50-59,a2@premeno,a6@2,a7@left,a9@no:6
#
# a1@50-59,a2@premeno,a6@2,a7@left,class@no:6
#
# a1@50-59,a2@premeno,a6@2,a7@left,a9@no,class@no:4
#
# a1@50-59,a2@premeno,a4@0-2,a6@2:9
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a9@no:9
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,class@no:7
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a9@no,class@no:7
#
# a1@50-59,a2@premeno,a5@no,a6@2,class@no:7
#
# a1@50-59,a2@premeno,a5@no,a6@2,a9@no,class@no:6
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,class@no:6
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a9@no,class@no:6
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2:8
#
# a1@50-59,a2@premeno,a5@no,a6@2,a9@no:8
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a9@no:8
#
# a1@50-59,a2@premeno,a6@2,a9@no:10
#
# a1@50-59,a2@premeno,a6@2,a9@no,class@no:8
#
# a1@50-59,a2@premeno,a6@2,class@no:11
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@left,a8@left_low:2
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@left,a8@left_low,a9@no:2
#
# a1@50-59,a2@premeno,a5@no,a6@2,a8@left_low,class@no:2
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@left,a8@left_low,class@no:1
#
# a1@50-59,a2@premeno,a5@no,a6@2,a8@left_low,a9@no,class@no:2
#
# a1@50-59,a2@premeno,a5@no,a6@2,a7@left,a8@left_low,a9@no,class@no:1
#
# a1@50-59,a2@premeno,a5@no,a6@2,a8@left_low,a9@no:3
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@left,a8@left_low:2
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@left,a8@left_low,a9@no:2
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@left,a8@left_low:2
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,a9@no:2
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a8@left_low,class@no:2
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@left,a8@left_low,class@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a8@left_low,a9@no,class@no:2
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a8@left_low,class@no:2
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a7@left,a8@left_low,a9@no,class@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,class@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a8@left_low,a9@no,class@no:2
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,a9@no,class@no:1
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a8@left_low:3
#
# a1@50-59,a2@premeno,a4@0-2,a6@2,a8@left_low,a9@no:3
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a8@left_low,a9@no:3
#
# a1@50-59,a2@premeno,a6@2,a7@left,a8@left_low,a9@no:3
#
# a1@50-59,a2@premeno,a6@2,a8@left_low,a9@no,class@no:3
#
# a1@50-59,a2@premeno,a6@2,a7@left,a8@left_low,a9@no,class@no:2
#
# a1@50-59,a2@premeno,a6@2,a8@left_low,class@no:5
#
# a1@50-59,a2@premeno,a6@2,a7@left,a8@left_low:5
#
# a1@50-59,a2@premeno,a6@2,a7@left,a8@left_low,class@no:4
#
# a1@50-59,a2@premeno,a4@0-2,a8@left_low,class@no:7
#
# a1@50-59,a2@premeno,a4@0-2,a7@left,a8@left_low:7
#
# a1@50-59,a2@premeno,a4@0-2,a7@left,a8@left_low,class@no:6
#
# a1@50-59,a2@premeno,a5@no,a8@left_low,class@no:7
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a8@left_low,class@no:7
#
# a1@50-59,a2@premeno,a5@no,a7@left,a8@left_low:7
#
# a1@50-59,a2@premeno,a5@no,a7@left,a8@left_low,class@no:6
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@left,a8@left_low:7
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@left,a8@left_low,class@no:6
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a8@left_low:9
#
# a1@50-59,a2@premeno,a5@no,a8@left_low,a9@no:8
#
# a1@50-59,a2@premeno,a4@0-2,a8@left_low,a9@no:8
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a8@left_low,a9@no:8
#
# a1@50-59,a2@premeno,a8@left_low,a9@no,class@no:8
#
# a1@50-59,a2@premeno,a4@0-2,a8@left_low,a9@no,class@no:7
#
# a1@50-59,a2@premeno,a5@no,a8@left_low,a9@no,class@no:7
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a8@left_low,a9@no,class@no:7
#
# a1@50-59,a2@premeno,a7@left,a8@left_low,a9@no,class@no:7
#
# a1@50-59,a2@premeno,a4@0-2,a7@left,a8@left_low,a9@no:7
#
# a1@50-59,a2@premeno,a4@0-2,a7@left,a8@left_low,a9@no,class@no:6
#
# a1@50-59,a2@premeno,a5@no,a7@left,a8@left_low,a9@no:7
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@left,a8@left_low,a9@no:7
#
# a1@50-59,a2@premeno,a5@no,a7@left,a8@left_low,a9@no,class@no:6
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@left,a8@left_low,a9@no,class@no:6
#
# a1@50-59,a2@premeno,a8@left_low,class@no:10
#
# a1@50-59,a2@premeno,a7@left,a8@left_low,class@no:9
#
# a1@50-59,a2@premeno,a7@left,a8@left_low:11
#
# a1@50-59,a2@premeno,a5@no,a7@left:11
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@left:11
#
# a1@50-59,a2@premeno,a5@no,a7@left,class@no:8
#
# a1@50-59,a2@premeno,a5@no,a7@left,a9@no:11
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@left,class@no:8
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@left,a9@no:11
#
# a1@50-59,a2@premeno,a5@no,a7@left,a9@no,class@no:8
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a7@left,a9@no,class@no:8
#
# a1@50-59,a2@premeno,a7@left,class@no:12
#
# a1@50-59,a2@premeno,a7@left,a9@no,class@no:10
#
# a1@50-59,a2@premeno,a4@0-2,a7@left:12
#
# a1@50-59,a2@premeno,a4@0-2,a7@left,class@no:9
#
# a1@50-59,a2@premeno,a4@0-2,a7@left,a9@no:12
#
# a1@50-59,a2@premeno,a4@0-2,a7@left,a9@no,class@no:9
#
# a1@50-59,a2@premeno,a7@left,a9@no:13
#
# a1@50-59,a2@premeno,a4@0-2,class@no:14
#
# a1@50-59,a2@premeno,a4@0-2,a9@no,class@no:14
#
# a1@50-59,a2@premeno,a5@no,class@no:14
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,class@no:13
#
# a1@50-59,a2@premeno,a5@no,a9@no,class@no:13
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a9@no,class@no:13
#
# a1@50-59,a2@premeno,a9@no,class@no:15
#
# a1@50-59,a2@premeno,a5@no:19
#
# a1@50-59,a2@premeno,a5@no,a9@no:17
#
# a1@50-59,a2@premeno,a4@0-2,a5@no:18
#
# a1@50-59,a2@premeno,a4@0-2,a9@no:18
#
# a1@50-59,a2@premeno,a4@0-2,a5@no,a9@no:17
#
# a1@50-59,a2@premeno,a9@no:20
#
# a1@50-59,a2@ge40,a5@no,a6@2,a8@left_up:3
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a8@left_up:3
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@right,a8@left_up:2
#
# a1@50-59,a2@ge40,a5@no,a6@2,a8@left_up,class@no:3
#
# a1@50-59,a2@ge40,a5@no,a6@2,a8@left_up,a9@no:3
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@right,a8@left_up:2
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a8@left_up,class@no:3
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a8@left_up,a9@no:3
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@right,a8@left_up,class@no:2
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@right,a8@left_up,a9@no:2
#
# a1@50-59,a2@ge40,a5@no,a6@2,a8@left_up,a9@no,class@no:3
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@right,a8@left_up,class@no:2
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@right,a8@left_up,a9@no:2
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a8@left_up,a9@no,class@no:3
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@right,a8@left_up,a9@no,class@no:2
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@right,a8@left_up,a9@no,class@no:2
#
# a1@50-59,a2@ge40,a6@2,a7@right,a8@left_up:4
#
# a1@50-59,a2@ge40,a6@2,a7@right,a8@left_up,class@no:4
#
# a1@50-59,a2@ge40,a6@2,a7@right,a8@left_up,a9@no:4
#
# a1@50-59,a2@ge40,a6@2,a7@right,a8@left_up,a9@no,class@no:4
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a8@left_up:4
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@right,a8@left_up:3
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a8@left_up,class@no:4
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a8@left_up,a9@no:4
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@right,a8@left_up,class@no:3
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@right,a8@left_up,a9@no:3
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a8@left_up,a9@no,class@no:4
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@right,a8@left_up,a9@no,class@no:3
#
# a1@50-59,a2@ge40,a6@2,a8@left_up,a9@no:5
#
# a1@50-59,a2@ge40,a6@2,a8@left_up,class@no:5
#
# a1@50-59,a2@ge40,a6@2,a8@left_up,a9@no,class@no:5
#
# a1@50-59,a5@no,a6@2,a7@right,a8@left_up:5
#
# a1@50-59,a5@no,a6@2,a7@right,a8@left_up,a9@no:4
#
# a1@50-59,a4@0-2,a5@no,a6@2,a7@right,a8@left_up:4
#
# a1@50-59,a5@no,a6@2,a7@right,a8@left_up,class@no:5
#
# a1@50-59,a4@0-2,a5@no,a6@2,a7@right,a8@left_up,a9@no:4
#
# a1@50-59,a5@no,a6@2,a7@right,a8@left_up,a9@no,class@no:4
#
# a1@50-59,a4@0-2,a5@no,a6@2,a7@right,a8@left_up,class@no:4
#
# a1@50-59,a4@0-2,a5@no,a6@2,a7@right,a8@left_up,a9@no,class@no:4
#
# a1@50-59,a4@0-2,a5@no,a6@2,a8@left_up:6
#
# a1@50-59,a4@0-2,a5@no,a6@2,a8@left_up,class@no:6
#
# a1@50-59,a5@no,a6@2,a8@left_up,a9@no:6
#
# a1@50-59,a4@0-2,a5@no,a6@2,a8@left_up,a9@no:6
#
# a1@50-59,a5@no,a6@2,a8@left_up,a9@no,class@no:6
#
# a1@50-59,a4@0-2,a5@no,a6@2,a8@left_up,a9@no,class@no:6
#
# a1@50-59,a5@no,a6@2,a8@left_up,class@no:7
#
# a1@50-59,a6@2,a7@right,a8@left_up:7
#
# a1@50-59,a4@0-2,a6@2,a7@right,a8@left_up:5
#
# a1@50-59,a6@2,a7@right,a8@left_up,a9@no:6
#
# a1@50-59,a6@2,a7@right,a8@left_up,class@no:7
#
# a1@50-59,a4@0-2,a6@2,a7@right,a8@left_up,a9@no:5
#
# a1@50-59,a4@0-2,a6@2,a7@right,a8@left_up,class@no:5
#
# a1@50-59,a6@2,a7@right,a8@left_up,a9@no,class@no:6
#
# a1@50-59,a4@0-2,a6@2,a7@right,a8@left_up,a9@no,class@no:5
#
# a1@50-59,a4@0-2,a6@2,a8@left_up:8
#
# a1@50-59,a4@0-2,a6@2,a8@left_up,a9@no:8
#
# a1@50-59,a4@0-2,a6@2,a8@left_up,class@no:8
#
# a1@50-59,a4@0-2,a6@2,a8@left_up,a9@no,class@no:8
#
# a1@50-59,a6@2,a8@left_up,a9@no:9
#
# a1@50-59,a6@2,a8@left_up,a9@no,class@no:9
#
# a1@50-59,a6@2,a8@left_up,class@no:10
#
# a1@50-59,a6@2,a7@left,a8@left_up:3
#
# a1@50-59,a5@no,a6@2,a7@left,a8@left_up:2
#
# a1@50-59,a6@2,a7@left,a8@left_up,a9@no:3
#
# a1@50-59,a6@2,a7@left,a8@left_up,class@no:3
#
# a1@50-59,a4@0-2,a6@2,a7@left,a8@left_up:3
#
# a1@50-59,a2@ge40,a6@2,a7@left,a8@left_up:1
#
# a1@50-59,a5@no,a6@2,a7@left,a8@left_up,a9@no:2
#
# a1@50-59,a5@no,a6@2,a7@left,a8@left_up,class@no:2
#
# a1@50-59,a4@0-2,a5@no,a6@2,a7@left,a8@left_up:2
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@left,a8@left_up:1
#
# a1@50-59,a6@2,a7@left,a8@left_up,a9@no,class@no:3
#
# a1@50-59,a4@0-2,a6@2,a7@left,a8@left_up,a9@no:3
#
# a1@50-59,a2@ge40,a6@2,a7@left,a8@left_up,a9@no:1
#
# a1@50-59,a4@0-2,a6@2,a7@left,a8@left_up,class@no:3
#
# a1@50-59,a2@ge40,a6@2,a7@left,a8@left_up,class@no:1
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@left,a8@left_up:1
#
# a1@50-59,a5@no,a6@2,a7@left,a8@left_up,a9@no,class@no:2
#
# a1@50-59,a4@0-2,a5@no,a6@2,a7@left,a8@left_up,a9@no:2
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@left,a8@left_up,a9@no:1
#
# a1@50-59,a4@0-2,a5@no,a6@2,a7@left,a8@left_up,class@no:2
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@left,a8@left_up,class@no:1
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@left,a8@left_up:1
#
# a1@50-59,a4@0-2,a6@2,a7@left,a8@left_up,a9@no,class@no:3
#
# a1@50-59,a2@ge40,a6@2,a7@left,a8@left_up,a9@no,class@no:1
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@left,a8@left_up,a9@no:1
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@left,a8@left_up,class@no:1
#
# a1@50-59,a4@0-2,a5@no,a6@2,a7@left,a8@left_up,a9@no,class@no:2
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@left,a8@left_up,a9@no,class@no:1
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@left,a8@left_up,a9@no:1
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@left,a8@left_up,class@no:1
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@left,a8@left_up,a9@no,class@no:1
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@left,a8@left_up,a9@no,class@no:1
#
# a1@50-59,a5@no,a7@left,a8@left_up:7
#
# a1@50-59,a5@no,a7@left,a8@left_up,a9@no:7
#
# a1@50-59,a5@no,a7@left,a8@left_up,class@no:7
#
# a1@50-59,a4@0-2,a5@no,a7@left,a8@left_up:7
#
# a1@50-59,a2@ge40,a5@no,a7@left,a8@left_up:6
#
# a1@50-59,a5@no,a7@left,a8@left_up,a9@no,class@no:7
#
# a1@50-59,a4@0-2,a5@no,a7@left,a8@left_up,a9@no:7
#
# a1@50-59,a2@ge40,a5@no,a7@left,a8@left_up,a9@no:6
#
# a1@50-59,a4@0-2,a5@no,a7@left,a8@left_up,class@no:7
#
# a1@50-59,a2@ge40,a5@no,a7@left,a8@left_up,class@no:6
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a7@left,a8@left_up:6
#
# a1@50-59,a4@0-2,a5@no,a7@left,a8@left_up,a9@no,class@no:7
#
# a1@50-59,a2@ge40,a5@no,a7@left,a8@left_up,a9@no,class@no:6
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a7@left,a8@left_up,a9@no:6
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a7@left,a8@left_up,class@no:6
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a7@left,a8@left_up,a9@no,class@no:6
#
# a1@50-59,a2@ge40,a7@left,a8@left_up:7
#
# a1@50-59,a2@ge40,a7@left,a8@left_up,a9@no:6
#
# a1@50-59,a2@ge40,a7@left,a8@left_up,class@no:7
#
# a1@50-59,a2@ge40,a4@0-2,a7@left,a8@left_up:6
#
# a1@50-59,a2@ge40,a7@left,a8@left_up,a9@no,class@no:6
#
# a1@50-59,a2@ge40,a4@0-2,a7@left,a8@left_up,a9@no:6
#
# a1@50-59,a2@ge40,a4@0-2,a7@left,a8@left_up,class@no:6
#
# a1@50-59,a2@ge40,a4@0-2,a7@left,a8@left_up,a9@no,class@no:6
#
# a1@50-59,a4@0-2,a7@left,a8@left_up:9
#
# a1@50-59,a7@left,a8@left_up,class@no:9
#
# a1@50-59,a4@0-2,a7@left,a8@left_up,class@no:8
#
# a1@50-59,a7@left,a8@left_up,a9@no:9
#
# a1@50-59,a7@left,a8@left_up,a9@no,class@no:8
#
# a1@50-59,a4@0-2,a7@left,a8@left_up,a9@no:9
#
# a1@50-59,a4@0-2,a7@left,a8@left_up,a9@no,class@no:8
#
# a1@50-59,a2@ge40,a4@0-2,a7@right,a8@left_up:5
#
# a1@50-59,a2@ge40,a4@0-2,a7@right,a8@left_up,class@no:5
#
# a1@50-59,a2@ge40,a4@0-2,a7@right,a8@left_up,a9@no:5
#
# a1@50-59,a2@ge40,a4@0-2,a7@right,a8@left_up,a9@no,class@no:5
#
# a1@50-59,a2@ge40,a5@no,a7@right,a8@left_up:5
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a7@right,a8@left_up:4
#
# a1@50-59,a2@ge40,a5@no,a7@right,a8@left_up,class@no:4
#
# a1@50-59,a2@ge40,a5@no,a7@right,a8@left_up,a9@no:5
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a7@right,a8@left_up,class@no:4
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a7@right,a8@left_up,a9@no:4
#
# a1@50-59,a2@ge40,a5@no,a7@right,a8@left_up,a9@no,class@no:4
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a7@right,a8@left_up,a9@no,class@no:4
#
# a1@50-59,a2@ge40,a7@right,a8@left_up,class@no:8
#
# a1@50-59,a2@ge40,a7@right,a8@left_up,a9@no,class@no:8
#
# a1@50-59,a2@ge40,a7@right,a8@left_up,a9@no:9
#
# a1@50-59,a4@0-2,a5@no,a7@right,a8@left_up:9
#
# a1@50-59,a4@0-2,a5@no,a7@right,a8@left_up,a9@no:9
#
# a1@50-59,a4@0-2,a7@right,a8@left_up,class@no:9
#
# a1@50-59,a4@0-2,a5@no,a7@right,a8@left_up,class@no:8
#
# a1@50-59,a4@0-2,a7@right,a8@left_up,a9@no,class@no:9
#
# a1@50-59,a4@0-2,a5@no,a7@right,a8@left_up,a9@no,class@no:8
#
# a1@50-59,a4@0-2,a7@right,a8@left_up,a9@no:10
#
# a1@50-59,a5@no,a7@right,a8@left_up,class@no:9
#
# a1@50-59,a5@no,a7@right,a8@left_up,a9@no,class@no:8
#
# a1@50-59,a5@no,a7@right,a8@left_up,a9@no:10
#
# a1@50-59,a7@right,a8@left_up,class@no:13
#
# a1@50-59,a7@right,a8@left_up,a9@no,class@no:12
#
# a1@50-59,a7@right,a8@left_up,a9@no:14
#
# a1@50-59,a2@ge40,a5@no,a8@left_up:11
#
# a1@50-59,a2@ge40,a5@no,a8@left_up,a9@no:11
#
# a1@50-59,a2@ge40,a5@no,a8@left_up,class@no:10
#
# a1@50-59,a2@ge40,a5@no,a8@left_up,a9@no,class@no:10
#
# a1@50-59,a2@ge40,a4@0-2,a8@left_up:11
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a8@left_up:10
#
# a1@50-59,a2@ge40,a4@0-2,a8@left_up,a9@no:11
#
# a1@50-59,a2@ge40,a4@0-2,a8@left_up,class@no:11
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a8@left_up,a9@no:10
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a8@left_up,class@no:10
#
# a1@50-59,a2@ge40,a4@0-2,a8@left_up,a9@no,class@no:11
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a8@left_up,a9@no,class@no:10
#
# a1@50-59,a2@ge40,a8@left_up,class@no:15
#
# a1@50-59,a2@ge40,a8@left_up,a9@no:15
#
# a1@50-59,a2@ge40,a8@left_up,a9@no,class@no:14
#
# a1@50-59,a4@0-2,a5@no,a8@left_up:16
#
# a1@50-59,a4@0-2,a5@no,a8@left_up,a9@no:16
#
# a1@50-59,a5@no,a8@left_up,class@no:16
#
# a1@50-59,a4@0-2,a5@no,a8@left_up,class@no:15
#
# a1@50-59,a5@no,a8@left_up,a9@no,class@no:15
#
# a1@50-59,a4@0-2,a5@no,a8@left_up,a9@no,class@no:15
#
# a1@50-59,a5@no,a8@left_up,a9@no:17
#
# a1@50-59,a4@0-2,a8@left_up:19
#
# a1@50-59,a4@0-2,a8@left_up,class@no:17
#
# a1@50-59,a4@0-2,a8@left_up,a9@no:19
#
# a1@50-59,a4@0-2,a8@left_up,a9@no,class@no:17
#
# a1@50-59,a8@left_up,class@no:22
#
# a1@50-59,a8@left_up,a9@no,class@no:20
#
# a1@50-59,a8@left_up,a9@no:23
#
# a1@50-59,a7@right,a8@left_low:6
#
# a1@50-59,a4@0-2,a7@right,a8@left_low:6
#
# a1@50-59,a5@no,a7@right,a8@left_low:6
#
# a1@50-59,a7@right,a8@left_low,class@no:5
#
# a1@50-59,a7@right,a8@left_low,a9@no:5
#
# a1@50-59,a2@ge40,a7@right,a8@left_low:4
#
# a1@50-59,a4@0-2,a5@no,a7@right,a8@left_low:6
#
# a1@50-59,a4@0-2,a7@right,a8@left_low,class@no:5
#
# a1@50-59,a4@0-2,a7@right,a8@left_low,a9@no:5
#
# a1@50-59,a2@ge40,a4@0-2,a7@right,a8@left_low:4
#
# a1@50-59,a5@no,a7@right,a8@left_low,class@no:5
#
# a1@50-59,a5@no,a7@right,a8@left_low,a9@no:5
#
# a1@50-59,a2@ge40,a5@no,a7@right,a8@left_low:4
#
# a1@50-59,a7@right,a8@left_low,a9@no,class@no:5
#
# a1@50-59,a2@ge40,a7@right,a8@left_low,class@no:4
#
# a1@50-59,a2@ge40,a7@right,a8@left_low,a9@no:4
#
# a1@50-59,a4@0-2,a5@no,a7@right,a8@left_low,class@no:5
#
# a1@50-59,a4@0-2,a5@no,a7@right,a8@left_low,a9@no:5
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a7@right,a8@left_low:4
#
# a1@50-59,a4@0-2,a7@right,a8@left_low,a9@no,class@no:5
#
# a1@50-59,a2@ge40,a4@0-2,a7@right,a8@left_low,class@no:4
#
# a1@50-59,a2@ge40,a4@0-2,a7@right,a8@left_low,a9@no:4
#
# a1@50-59,a5@no,a7@right,a8@left_low,a9@no,class@no:5
#
# a1@50-59,a2@ge40,a5@no,a7@right,a8@left_low,class@no:4
#
# a1@50-59,a2@ge40,a5@no,a7@right,a8@left_low,a9@no:4
#
# a1@50-59,a2@ge40,a7@right,a8@left_low,a9@no,class@no:4
#
# a1@50-59,a4@0-2,a5@no,a7@right,a8@left_low,a9@no,class@no:5
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a7@right,a8@left_low,class@no:4
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a7@right,a8@left_low,a9@no:4
#
# a1@50-59,a2@ge40,a4@0-2,a7@right,a8@left_low,a9@no,class@no:4
#
# a1@50-59,a2@ge40,a5@no,a7@right,a8@left_low,a9@no,class@no:4
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a7@right,a8@left_low,a9@no,class@no:4
#
# a1@50-59,a2@ge40,a4@0-2,a7@left,a8@left_low:6
#
# a1@50-59,a2@ge40,a4@0-2,a7@left,a8@left_low,class@no:5
#
# a1@50-59,a2@ge40,a4@0-2,a7@left,a8@left_low,a9@no:6
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a7@left,a8@left_low:6
#
# a1@50-59,a2@ge40,a4@0-2,a7@left,a8@left_low,a9@no,class@no:5
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a7@left,a8@left_low,class@no:5
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a7@left,a8@left_low,a9@no:6
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a7@left,a8@left_low,a9@no,class@no:5
#
# a1@50-59,a2@ge40,a4@0-2,a8@left_low,class@no:9
#
# a1@50-59,a2@ge40,a4@0-2,a8@left_low,a9@no,class@no:9
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a8@left_low,class@no:9
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a8@left_low,a9@no,class@no:9
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a8@left_low:10
#
# a1@50-59,a2@ge40,a4@0-2,a8@left_low,a9@no:10
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a8@left_low,a9@no:10
#
# a1@50-59,a2@ge40,a7@left,a8@left_low,class@no:9
#
# a1@50-59,a2@ge40,a7@left,a8@left_low,a9@no,class@no:8
#
# a1@50-59,a2@ge40,a5@no,a7@left,a8@left_low:9
#
# a1@50-59,a2@ge40,a5@no,a7@left,a8@left_low,class@no:6
#
# a1@50-59,a2@ge40,a5@no,a7@left,a8@left_low,a9@no:8
#
# a1@50-59,a2@ge40,a5@no,a7@left,a8@left_low,a9@no,class@no:6
#
# a1@50-59,a2@ge40,a7@left,a8@left_low,a9@no:10
#
# a1@50-59,a2@ge40,a5@no,a8@left_low:13
#
# a1@50-59,a2@ge40,a5@no,a8@left_low,a9@no:12
#
# a1@50-59,a2@ge40,a8@left_low,class@no:13
#
# a1@50-59,a2@ge40,a5@no,a8@left_low,class@no:10
#
# a1@50-59,a2@ge40,a8@left_low,a9@no,class@no:12
#
# a1@50-59,a2@ge40,a5@no,a8@left_low,a9@no,class@no:10
#
# a1@50-59,a2@ge40,a8@left_low,a9@no:14
#
# a1@50-59,a4@0-2,a7@left,a8@left_low:15
#
# a1@50-59,a4@0-2,a7@left,a8@left_low,class@no:12
#
# a1@50-59,a4@0-2,a7@left,a8@left_low,a9@no:15
#
# a1@50-59,a4@0-2,a5@no,a7@left,a8@left_low:14
#
# a1@50-59,a4@0-2,a7@left,a8@left_low,a9@no,class@no:12
#
# a1@50-59,a4@0-2,a5@no,a7@left,a8@left_low,class@no:12
#
# a1@50-59,a4@0-2,a5@no,a7@left,a8@left_low,a9@no:14
#
# a1@50-59,a4@0-2,a5@no,a7@left,a8@left_low,a9@no,class@no:12
#
# a1@50-59,a4@0-2,a8@left_low,class@no:17
#
# a1@50-59,a4@0-2,a8@left_low,a9@no,class@no:17
#
# a1@50-59,a4@0-2,a5@no,a8@left_low,class@no:17
#
# a1@50-59,a4@0-2,a5@no,a8@left_low,a9@no,class@no:17
#
# a1@50-59,a4@0-2,a5@no,a8@left_low:20
#
# a1@50-59,a4@0-2,a8@left_low,a9@no:20
#
# a1@50-59,a4@0-2,a5@no,a8@left_low,a9@no:19
#
# a1@50-59,a5@no,a7@left,a8@left_low:17
#
# a1@50-59,a5@no,a7@left,a8@left_low,class@no:13
#
# a1@50-59,a5@no,a7@left,a8@left_low,a9@no:16
#
# a1@50-59,a5@no,a7@left,a8@left_low,a9@no,class@no:13
#
# a1@50-59,a5@no,a8@left_low,class@no:18
#
# a1@50-59,a5@no,a8@left_low,a9@no,class@no:18
#
# a1@50-59,a5@no,a8@left_low,a9@no:21
#
# a1@50-59,a7@left,a8@left_low,class@no:19
#
# a1@50-59,a7@left,a8@left_low,a9@no,class@no:16
#
# a1@50-59,a8@left_low,a9@no,class@no:21
#
# a1@50-59,a7@left,a8@left_low:25
#
# a1@50-59,a8@left_low,a9@no:25
#
# a1@50-59,a7@left,a8@left_low,a9@no:20
#
# a1@50-59,a6@2,a7@right,a8@left_low:2
#
# a1@50-59,a4@0-2,a6@2,a7@right,a8@left_low:2
#
# a1@50-59,a5@no,a6@2,a7@right,a8@left_low:2
#
# a1@50-59,a6@2,a7@right,a8@left_low,class@no:2
#
# a1@50-59,a6@2,a7@right,a8@left_low,a9@no:2
#
# a1@50-59,a2@ge40,a6@2,a7@right,a8@left_low:1
#
# a1@50-59,a4@0-2,a5@no,a6@2,a7@right,a8@left_low:2
#
# a1@50-59,a4@0-2,a6@2,a7@right,a8@left_low,class@no:2
#
# a1@50-59,a4@0-2,a6@2,a7@right,a8@left_low,a9@no:2
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@right,a8@left_low:1
#
# a1@50-59,a5@no,a6@2,a7@right,a8@left_low,class@no:2
#
# a1@50-59,a5@no,a6@2,a7@right,a8@left_low,a9@no:2
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@right,a8@left_low:1
#
# a1@50-59,a6@2,a7@right,a8@left_low,a9@no,class@no:2
#
# a1@50-59,a2@ge40,a6@2,a7@right,a8@left_low,class@no:1
#
# a1@50-59,a2@ge40,a6@2,a7@right,a8@left_low,a9@no:1
#
# a1@50-59,a4@0-2,a5@no,a6@2,a7@right,a8@left_low,class@no:2
#
# a1@50-59,a4@0-2,a5@no,a6@2,a7@right,a8@left_low,a9@no:2
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@right,a8@left_low:1
#
# a1@50-59,a4@0-2,a6@2,a7@right,a8@left_low,a9@no,class@no:2
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@right,a8@left_low,class@no:1
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@right,a8@left_low,a9@no:1
#
# a1@50-59,a5@no,a6@2,a7@right,a8@left_low,a9@no,class@no:2
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@right,a8@left_low,class@no:1
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@right,a8@left_low,a9@no:1
#
# a1@50-59,a2@ge40,a6@2,a7@right,a8@left_low,a9@no,class@no:1
#
# a1@50-59,a4@0-2,a5@no,a6@2,a7@right,a8@left_low,a9@no,class@no:2
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@right,a8@left_low,class@no:1
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@right,a8@left_low,a9@no:1
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@right,a8@left_low,a9@no,class@no:1
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@right,a8@left_low,a9@no,class@no:1
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@right,a8@left_low,a9@no,class@no:1
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@right:6
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@right,class@no:5
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@right:6
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@right,a9@no:6
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@right,class@no:5
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@right,a9@no,class@no:5
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@right,a9@no:6
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@right,a9@no,class@no:5
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@right:7
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@right,a9@no:7
#
# a1@50-59,a2@ge40,a6@2,a7@right,class@no:7
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@right,class@no:6
#
# a1@50-59,a2@ge40,a6@2,a7@right,a9@no,class@no:7
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@right,a9@no,class@no:6
#
# a1@50-59,a2@ge40,a6@2,a7@right,a9@no:8
#
# a1@50-59,a5@no,a6@2,a7@right,class@no:10
#
# a1@50-59,a5@no,a6@2,a7@right,a9@no:10
#
# a1@50-59,a5@no,a6@2,a7@right,a9@no,class@no:9
#
# a1@50-59,a4@0-2,a5@no,a6@2,a7@right:10
#
# a1@50-59,a4@0-2,a5@no,a6@2,a7@right,a9@no:10
#
# a1@50-59,a4@0-2,a6@2,a7@right,class@no:10
#
# a1@50-59,a4@0-2,a5@no,a6@2,a7@right,class@no:9
#
# a1@50-59,a4@0-2,a6@2,a7@right,a9@no,class@no:10
#
# a1@50-59,a4@0-2,a5@no,a6@2,a7@right,a9@no,class@no:9
#
# a1@50-59,a4@0-2,a6@2,a7@right,a9@no:11
#
# a1@50-59,a6@2,a7@right,a9@no:12
#
# a1@50-59,a6@2,a7@right,class@no:12
#
# a1@50-59,a6@2,a7@right,a9@no,class@no:11
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@left,a8@left_low:4
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@left,a8@left_low,a9@no:4
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a8@left_low,class@no:4
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@left,a8@left_low,class@no:3
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a8@left_low,a9@no,class@no:4
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@left,a8@left_low,a9@no,class@no:3
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a8@left_low,a9@no:5
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@left,a8@left_low:4
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@left,a8@left_low,a9@no:4
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@left,a8@left_low:4
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,a9@no:4
#
# a1@50-59,a2@ge40,a5@no,a6@2,a8@left_low,class@no:4
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@left,a8@left_low,class@no:3
#
# a1@50-59,a2@ge40,a5@no,a6@2,a8@left_low,a9@no,class@no:4
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a8@left_low,class@no:4
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@left,a8@left_low,a9@no,class@no:3
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,class@no:3
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a8@left_low,a9@no,class@no:4
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,a9@no,class@no:3
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a8@left_low:5
#
# a1@50-59,a2@ge40,a5@no,a6@2,a8@left_low,a9@no:5
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a8@left_low,a9@no:5
#
# a1@50-59,a2@ge40,a6@2,a8@left_low,class@no:6
#
# a1@50-59,a2@ge40,a6@2,a8@left_low,a9@no,class@no:6
#
# a1@50-59,a2@ge40,a6@2,a7@left,a8@left_low:6
#
# a1@50-59,a2@ge40,a6@2,a7@left,a8@left_low,class@no:5
#
# a1@50-59,a2@ge40,a6@2,a7@left,a8@left_low,a9@no:6
#
# a1@50-59,a2@ge40,a6@2,a7@left,a8@left_low,a9@no,class@no:5
#
# a1@50-59,a2@ge40,a6@2,a8@left_low,a9@no:7
#
# a1@50-59,a5@no,a6@2,a8@left_low,class@no:7
#
# a1@50-59,a5@no,a6@2,a8@left_low,a9@no,class@no:7
#
# a1@50-59,a5@no,a6@2,a7@left,a8@left_low:7
#
# a1@50-59,a5@no,a6@2,a7@left,a8@left_low,class@no:5
#
# a1@50-59,a5@no,a6@2,a7@left,a8@left_low,a9@no:7
#
# a1@50-59,a5@no,a6@2,a7@left,a8@left_low,a9@no,class@no:5
#
# a1@50-59,a5@no,a6@2,a8@left_low,a9@no:9
#
# a1@50-59,a4@0-2,a6@2,a8@left_low,class@no:7
#
# a1@50-59,a4@0-2,a6@2,a8@left_low,a9@no,class@no:7
#
# a1@50-59,a4@0-2,a5@no,a6@2,a8@left_low,class@no:7
#
# a1@50-59,a4@0-2,a5@no,a6@2,a8@left_low,a9@no,class@no:7
#
# a1@50-59,a4@0-2,a6@2,a7@left,a8@left_low:7
#
# a1@50-59,a4@0-2,a6@2,a7@left,a8@left_low,class@no:5
#
# a1@50-59,a4@0-2,a6@2,a7@left,a8@left_low,a9@no:7
#
# a1@50-59,a4@0-2,a5@no,a6@2,a7@left,a8@left_low:7
#
# a1@50-59,a4@0-2,a6@2,a7@left,a8@left_low,a9@no,class@no:5
#
# a1@50-59,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,class@no:5
#
# a1@50-59,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,a9@no:7
#
# a1@50-59,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,a9@no,class@no:5
#
# a1@50-59,a4@0-2,a5@no,a6@2,a8@left_low:9
#
# a1@50-59,a4@0-2,a6@2,a8@left_low,a9@no:9
#
# a1@50-59,a4@0-2,a5@no,a6@2,a8@left_low,a9@no:9
#
# a1@50-59,a6@2,a7@left,a8@left_low:12
#
# a1@50-59,a6@2,a8@left_low,a9@no:12
#
# a1@50-59,a6@2,a7@left,a8@left_low,a9@no:10
#
# a1@50-59,a6@2,a8@left_low,a9@no,class@no:10
#
# a1@50-59,a6@2,a7@left,a8@left_low,class@no:10
#
# a1@50-59,a6@2,a7@left,a8@left_low,a9@no,class@no:8
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@left:6
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@left:6
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@left,a9@no:6
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@left,class@no:5
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@left,a9@no:6
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@left,class@no:5
#
# a1@50-59,a2@ge40,a5@no,a6@2,a7@left,a9@no,class@no:5
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@left,a9@no,class@no:5
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@left,a9@no:6
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@left,class@no:6
#
# a1@50-59,a2@ge40,a4@0-2,a6@2,a7@left,a9@no,class@no:5
#
# a1@50-59,a2@ge40,a6@2,a7@left,class@no:8
#
# a1@50-59,a2@ge40,a6@2,a7@left,a9@no:8
#
# a1@50-59,a2@ge40,a6@2,a7@left,a9@no,class@no:7
#
# a1@50-59,a2@ge40,a5@no,a6@2:12
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2:12
#
# a1@50-59,a2@ge40,a5@no,a6@2,class@no:10
#
# a1@50-59,a2@ge40,a5@no,a6@2,a9@no:12
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,class@no:10
#
# a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a9@no:12
#
# ...
#
# a2@premeno,a5@no,a6@2,a8@left_low,class@no:15
#
# a2@premeno,a4@0-2,a5@no,a6@2,a8@left_low,class@no:14
#
# a2@premeno,a6@2,a8@left_low,a9@no,class@no:14
#
# a2@premeno,a4@0-2,a6@2,a8@left_low,a9@no,class@no:11
#
# a2@premeno,a5@no,a6@2,a8@left_low,a9@no,class@no:12
#
# a2@premeno,a4@0-2,a5@no,a6@2,a8@left_low,a9@no,class@no:11
#
# a2@premeno,a4@0-2,a6@2,a8@left_low,a9@no:15
#
# a2@premeno,a4@0-2,a5@no,a6@2,a8@left_low,a9@no:15
#
# a2@premeno,a5@no,a6@2,a8@left_low,a9@no:16
#
# a2@premeno,a4@0-2,a6@2,a8@left_low:20
#
# a2@premeno,a4@0-2,a5@no,a6@2,a8@left_low:20
#
# a2@premeno,a5@no,a6@2,a8@left_low:21
#
# a4@0-2,a6@2,a7@left,a8@left_low,a9@no:20
#
# a5@no,a6@2,a7@left,a8@left_low,a9@no:20
#
# a4@0-2,a5@no,a6@2,a7@left,a8@left_low,a9@no:20
#
# a6@2,a7@left,a8@left_low,a9@no,class@no:20
#
# a5@no,a6@2,a7@left,a8@left_low,a9@no,class@no:17
#
# a4@0-2,a6@2,a7@left,a8@left_low,a9@no,class@no:17
#
# a4@0-2,a5@no,a6@2,a7@left,a8@left_low,a9@no,class@no:17
#
# a4@0-2,a6@2,a7@left,a8@left_low:25
#
# a4@0-2,a5@no,a6@2,a7@left,a8@left_low:25
#
# a4@0-2,a6@2,a7@left,a8@left_low,class@no:21
#
# a4@0-2,a5@no,a6@2,a7@left,a8@left_low,class@no:21
#
# a6@2,a7@left,a8@left_low,class@no:26
#
# a5@no,a6@2,a7@left,a8@left_low:26
#
# a5@no,a6@2,a7@left,a8@left_low,class@no:21
#
# a4@0-2,a6@2,a8@left_low,class@no:29
#
# a4@0-2,a5@no,a6@2,a8@left_low,class@no:29
#
# a4@0-2,a6@2,a8@left_low,a9@no,class@no:25
#
# a4@0-2,a5@no,a6@2,a8@left_low,a9@no,class@no:25
#
# a6@2,a8@left_low,a9@no,class@no:30
#
# a5@no,a6@2,a8@left_low,class@no:30
#
# a5@no,a6@2,a8@left_low,a9@no,class@no:26
#
# a4@0-2,a6@2,a8@left_low:37
#
# a4@0-2,a5@no,a6@2,a8@left_low:37
#
# a6@2,a8@left_low,a9@no:37
#
# a4@0-2,a6@2,a8@left_low,a9@no:31
#
# a5@no,a6@2,a8@left_low,a9@no:32
#
# a4@0-2,a5@no,a6@2,a8@left_low,a9@no:31
#
# a5@no,a6@2,a8@left_low:39
#
# a2@premeno,a7@left,a8@left_low,a9@no,class@no:16
#
# a2@premeno,a5@no,a7@left,a8@left_low,a9@no,class@no:15
#
# a2@premeno,a4@0-2,a7@left,a8@left_low,a9@no,class@no:15
#
# a2@premeno,a4@0-2,a5@no,a7@left,a8@left_low,a9@no,class@no:15
#
# a2@premeno,a4@0-2,a7@left,a8@left_low,class@no:19
#
# a2@premeno,a5@no,a7@left,a8@left_low,class@no:19
#
# a2@premeno,a4@0-2,a5@no,a7@left,a8@left_low,class@no:19
#
# a2@premeno,a8@left_low,a9@no,class@no:25
#
# a2@premeno,a4@0-2,a8@left_low,a9@no,class@no:22
#
# a2@premeno,a5@no,a8@left_low,a9@no,class@no:23
#
# a2@premeno,a4@0-2,a5@no,a8@left_low,a9@no,class@no:22
#
# a2@premeno,a5@no,a8@left_low,class@no:29
#
# a2@premeno,a4@0-2,a8@left_low,class@no:29
#
# a2@premeno,a4@0-2,a5@no,a8@left_low,class@no:28
#
# a2@premeno,a7@left,a8@left_low:36
#
# a2@premeno,a5@no,a7@left,a8@left_low:26
#
# a2@premeno,a4@0-2,a7@left,a8@left_low:26
#
# a2@premeno,a4@0-2,a5@no,a7@left,a8@left_low:26
#
# a2@premeno,a7@left,a8@left_low,a9@no:24
#
# a2@premeno,a4@0-2,a7@left,a8@left_low,a9@no:20
#
# a2@premeno,a5@no,a7@left,a8@left_low,a9@no:20
#
# a2@premeno,a4@0-2,a5@no,a7@left,a8@left_low,a9@no:20
#
# a2@premeno,a4@0-2,a8@left_low,a9@no:30
#
# a2@premeno,a4@0-2,a5@no,a8@left_low,a9@no:30
#
# a2@premeno,a5@no,a8@left_low,a9@no:31
#
# a2@premeno,a4@0-2,a8@left_low:41
#
# a2@premeno,a5@no,a8@left_low:41
#
# a2@premeno,a4@0-2,a5@no,a8@left_low:40
#
# a7@left,a8@left_low,a9@no,class@no:38
#
# a5@no,a7@left,a8@left_low,a9@no,class@no:34
#
# a4@0-2,a7@left,a8@left_low,class@no:38
#
# a4@0-2,a7@left,a8@left_low,a9@no,class@no:33
#
# a4@0-2,a5@no,a7@left,a8@left_low,class@no:38
#
# a4@0-2,a5@no,a7@left,a8@left_low,a9@no,class@no:33
#
# a5@no,a7@left,a8@left_low,class@no:39
#
# a8@left_low,a9@no,class@no:55
#
# a4@0-2,a8@left_low,a9@no,class@no:48
#
# a5@no,a8@left_low,a9@no,class@no:50
#
# a4@0-2,a5@no,a8@left_low,a9@no,class@no:48
#
# a4@0-2,a8@left_low,class@no:56
#
# a4@0-2,a5@no,a8@left_low,class@no:55
#
# a5@no,a8@left_low,class@no:57
#
# a4@0-2,a7@left,a8@left_low,a9@no:40
#
# a4@0-2,a5@no,a7@left,a8@left_low,a9@no:39
#
# a4@0-2,a5@no,a7@left,a8@left_low:46
#
# a7@left,a8@left_low,a9@no:51
#
# a5@no,a7@left,a8@left_low:51
#
# a5@no,a7@left,a8@left_low,a9@no:42
#
# a4@0-2,a8@left_low,a9@no:60
#
# a4@0-2,a5@no,a8@left_low,a9@no:59
#
# a4@0-2,a5@no,a8@left_low:70
#
# a8@left_low,a9@no:74
#
# a5@no,a8@left_low,a9@no:63
#
# a5@no,a8@left_low:77
#
# a2@ge40,a5@no,a6@2,a7@right:16
#
# a2@ge40,a5@no,a6@2,a7@right,a9@no:14
#
# a2@ge40,a4@0-2,a6@2,a7@right,a9@no:14
#
# a2@ge40,a4@0-2,a5@no,a6@2,a7@right,a9@no:13
#
# a2@ge40,a4@0-2,a5@no,a6@2,a7@right:15
#
# a2@ge40,a5@no,a6@2,a7@right,class@no:12
#
# a2@ge40,a5@no,a6@2,a7@right,a9@no,class@no:10
#
# a2@ge40,a4@0-2,a5@no,a6@2,a7@right,class@no:12
#
# a2@ge40,a4@0-2,a5@no,a6@2,a7@right,a9@no,class@no:10
#
# a2@ge40,a4@0-2,a6@2,a7@right,class@no:13
#
# a2@ge40,a6@2,a7@right,a9@no,class@no:13
#
# a2@ge40,a4@0-2,a6@2,a7@right,a9@no,class@no:11
#
# a2@ge40,a6@2,a7@right,a9@no:17
#
# a2@ge40,a4@0-2,a6@2,a7@left,a9@no:16
#
# a2@ge40,a4@0-2,a6@2,a7@left,a9@no,class@no:15
#
# a2@ge40,a5@no,a6@2,a7@left,a9@no:16
#
# a2@ge40,a4@0-2,a5@no,a6@2,a7@left,a9@no:16
#
# a2@ge40,a5@no,a6@2,a7@left,a9@no,class@no:15
#
# a2@ge40,a4@0-2,a5@no,a6@2,a7@left,a9@no,class@no:15
#
# a2@ge40,a6@2,a7@left,a9@no,class@no:17
#
# a2@ge40,a5@no,a6@2,a7@left:20
#
# a2@ge40,a5@no,a6@2,a7@left,class@no:18
#
# a2@ge40,a4@0-2,a5@no,a6@2,a7@left:19
#
# a2@ge40,a4@0-2,a6@2,a7@left,class@no:19
#
# a2@ge40,a4@0-2,a5@no,a6@2,a7@left,class@no:18
#
# a2@ge40,a6@2,a7@left,class@no:21
#
# a2@ge40,a5@no,a6@2,a9@no:30
#
# a2@ge40,a4@0-2,a6@2,a9@no:30
#
# a2@ge40,a4@0-2,a5@no,a6@2,a9@no:29
#
# a2@ge40,a6@2,a9@no,class@no:30
#
# a2@ge40,a4@0-2,a6@2,a9@no,class@no:26
#
# a2@ge40,a5@no,a6@2,a9@no,class@no:25
#
# a2@ge40,a4@0-2,a5@no,a6@2,a9@no,class@no:25
#
# a2@ge40,a4@0-2,a6@2:36
#
# a2@ge40,a4@0-2,a6@2,class@no:32
#
# a2@ge40,a5@no,a6@2:36
#
# a2@ge40,a4@0-2,a5@no,a6@2:34
#
# a2@ge40,a5@no,a6@2,class@no:30
#
# a2@ge40,a4@0-2,a5@no,a6@2,class@no:30
#
# a2@ge40,a6@2,class@no:37
#
# a2@ge40,a5@no,a7@right,class@no:27
#
# a2@ge40,a4@0-2,a5@no,a7@right,class@no:27
#
# a2@ge40,a5@no,a7@right,a9@no,class@no:24
#
# a2@ge40,a4@0-2,a5@no,a7@right,a9@no,class@no:24
#
# a2@ge40,a4@0-2,a7@right,class@no:28
#
# a2@ge40,a4@0-2,a7@right,a9@no,class@no:25
#
# a2@ge40,a7@right,a9@no,class@no:29
#
# a2@ge40,a4@0-2,a7@right,a9@no:31
#
# a2@ge40,a4@0-2,a5@no,a7@right,a9@no:30
#
# a2@ge40,a4@0-2,a5@no,a7@right:35
#
# a2@ge40,a5@no,a7@right:38
#
# a2@ge40,a5@no,a7@right,a9@no:32
#
# a2@ge40,a7@right,a9@no:39
#
# a2@ge40,a4@0-2,a7@left,a9@no:33
#
# a2@ge40,a4@0-2,a7@left,a9@no,class@no:31
#
# a2@ge40,a4@0-2,a5@no,a7@left,a9@no:33
#
# a2@ge40,a4@0-2,a5@no,a7@left,a9@no,class@no:31
#
# a2@ge40,a4@0-2,a7@left,class@no:35
#
# a2@ge40,a4@0-2,a5@no,a7@left,class@no:34
#
# a2@ge40,a4@0-2,a5@no,a7@left:37
#
# a2@ge40,a7@left,class@no:42
#
# a2@ge40,a5@no,a7@left:42
#
# a2@ge40,a5@no,a7@left,class@no:35
#
# a2@ge40,a5@no,a7@left,a9@no:36
#
# a2@ge40,a7@left,a9@no,class@no:36
#
# a2@ge40,a5@no,a7@left,a9@no,class@no:32
#
# a2@ge40,a4@0-2,a9@no,class@no:56
#
# a2@ge40,a4@0-2,a5@no,a9@no,class@no:55
#
# a2@ge40,a4@0-2,a5@no,class@no:61
#
# a2@ge40,a4@0-2,a9@no:64
#
# a2@ge40,a4@0-2,a5@no,a9@no:63
#
# a2@ge40,a4@0-2,a5@no:72
#
# a2@ge40,a5@no,class@no:62
#
# a2@ge40,a5@no,a9@no,class@no:56
#
# a2@ge40,a9@no,class@no:65
#
# a2@ge40,a5@no:80
#
# a2@ge40,a5@no,a9@no:68
#
# a2@ge40,a9@no:81
#
# a2@premeno,a4@0-2,a6@2,a7@right:23
#
# a2@premeno,a4@0-2,a6@2,a7@right,a9@no:22
#
# a2@premeno,a4@0-2,a6@2,a7@right,class@no:19
#
# a2@premeno,a4@0-2,a5@no,a6@2,a7@right:23
#
# a2@premeno,a4@0-2,a6@2,a7@right,a9@no,class@no:19
#
# a2@premeno,a4@0-2,a5@no,a6@2,a7@right,a9@no:22
#
# a2@premeno,a4@0-2,a5@no,a6@2,a7@right,class@no:19
#
# a2@premeno,a4@0-2,a5@no,a6@2,a7@right,a9@no,class@no:19
#
# a2@premeno,a6@2,a7@right,a9@no,class@no:22
#
# a2@premeno,a5@no,a6@2,a7@right,a9@no,class@no:21
#
# a2@premeno,a5@no,a6@2,a7@right,a9@no:25
#
# a2@premeno,a6@2,a7@right,class@no:27
#
# a2@premeno,a5@no,a6@2,a7@right,class@no:22
#
# a2@premeno,a5@no,a6@2,a7@right:28
#
# a4@0-2,a6@2,a7@right,a9@no,class@no:30
#
# a4@0-2,a5@no,a6@2,a7@right,a9@no,class@no:29
#
# a4@0-2,a5@no,a6@2,a7@right,class@no:31
#
# a4@0-2,a6@2,a7@right,a9@no:36
#
# a4@0-2,a5@no,a6@2,a7@right,a9@no:35
#
# a4@0-2,a5@no,a6@2,a7@right:38
#
# a6@2,a7@right,a9@no:43
#
# a5@no,a6@2,a7@right,a9@no:39
#
# a5@no,a6@2,a7@right,class@no:34
#
# a5@no,a6@2,a7@right,a9@no,class@no:31
#
# a6@2,a7@right,a9@no,class@no:35
#
# a5@no,a6@2,a7@right:44
#
# a2@premeno,a6@2,a7@left,a9@no:24
#
# a2@premeno,a5@no,a6@2,a7@left,a9@no:20
#
# a2@premeno,a4@0-2,a6@2,a7@left,a9@no:21
#
# a2@premeno,a4@0-2,a5@no,a6@2,a7@left,a9@no:20
#
# a2@premeno,a6@2,a7@left,a9@no,class@no:17
#
# a2@premeno,a5@no,a6@2,a7@left,a9@no,class@no:15
#
# a2@premeno,a4@0-2,a6@2,a7@left,a9@no,class@no:16
#
# a2@premeno,a4@0-2,a5@no,a6@2,a7@left,a9@no,class@no:15
#
# a2@premeno,a5@no,a6@2,a7@left,class@no:19
#
# a2@premeno,a4@0-2,a5@no,a6@2,a7@left,class@no:19
#
# a2@premeno,a4@0-2,a6@2,a7@left,class@no:21
#
# a2@premeno,a5@no,a6@2,a7@left:25
#
# a2@premeno,a4@0-2,a5@no,a6@2,a7@left:25
#
# a2@premeno,a4@0-2,a6@2,a7@left:27
#
# a6@2,a7@left,a9@no,class@no:35
#
# a5@no,a6@2,a7@left,a9@no,class@no:31
#
# a4@0-2,a6@2,a7@left,a9@no,class@no:32
#
# a4@0-2,a5@no,a6@2,a7@left,a9@no,class@no:31
#
# a5@no,a6@2,a7@left,a9@no:37
#
# a4@0-2,a5@no,a6@2,a7@left,a9@no:37
#
# a4@0-2,a6@2,a7@left,a9@no:38
#
# a6@2,a7@left,class@no:46
#
# a4@0-2,a6@2,a7@left,class@no:41
#
# a5@no,a6@2,a7@left:46
#
# a5@no,a6@2,a7@left,class@no:38
#
# a4@0-2,a5@no,a6@2,a7@left:45
#
# a4@0-2,a5@no,a6@2,a7@left,class@no:38
#
# a4@0-2,a6@2,a7@left:48
#
# a2@premeno,a6@2,a9@no,class@no:39
#
# a2@premeno,a5@no,a6@2,a9@no,class@no:36
#
# a2@premeno,a5@no,a6@2,a9@no:45
#
# a2@premeno,a4@0-2,a6@2,a9@no,class@no:35
#
# a2@premeno,a4@0-2,a5@no,a6@2,a9@no,class@no:34
#
# a2@premeno,a4@0-2,a5@no,a6@2,class@no:38
#
# a2@premeno,a4@0-2,a6@2,a9@no:43
#
# a2@premeno,a4@0-2,a5@no,a6@2,a9@no:42
#
# a2@premeno,a4@0-2,a5@no,a6@2:48
#
# a2@premeno,a6@2,class@no:51
#
# a2@premeno,a5@no,a6@2,class@no:41
#
# a2@premeno,a5@no,a6@2:53
#
# a4@0-2,a6@2,a9@no,class@no:62
#
# a5@no,a6@2,a9@no,class@no:62
#
# a4@0-2,a5@no,a6@2,a9@no,class@no:60
#
# a4@0-2,a6@2,a9@no:74
#
# a4@0-2,a5@no,a6@2,a9@no:72
#
# a5@no,a6@2,a9@no:76
#
# a4@0-2,a6@2,class@no:73
#
# a4@0-2,a5@no,a6@2,class@no:69
#
# a4@0-2,a5@no,a6@2:83
#
# a6@2,class@no:89
#
# a5@no,a6@2,class@no:72
#
# a5@no,a6@2:90
#
# a2@premeno,a4@0-2,a7@right,class@no:35
#
# a2@premeno,a4@0-2,a5@no,a7@right,class@no:33
#
# a2@premeno,a5@no,a7@right,class@no:38
#
# a2@premeno,a7@right,a9@no,class@no:33
#
# a2@premeno,a4@0-2,a7@right,a9@no,class@no:30
#
# a2@premeno,a5@no,a7@right,a9@no,class@no:32
#
# a2@premeno,a4@0-2,a5@no,a7@right,a9@no,class@no:30
#
# a2@premeno,a4@0-2,a7@right,a9@no:40
#
# a2@premeno,a4@0-2,a5@no,a7@right,a9@no:38
#
# a2@premeno,a5@no,a7@right,a9@no:41
#
# a2@premeno,a4@0-2,a7@right:47
#
# a2@premeno,a4@0-2,a5@no,a7@right:43
#
# a2@premeno,a5@no,a7@right:51
#
# a4@0-2,a7@right,a9@no,class@no:57
#
# a4@0-2,a5@no,a7@right,a9@no,class@no:56
#
# a5@no,a7@right,a9@no,class@no:58
#
# a4@0-2,a7@right,class@no:65
#
# a4@0-2,a5@no,a7@right,class@no:62
#
# a5@no,a7@right,class@no:67
#
# a4@0-2,a7@right,a9@no:73
#
# a4@0-2,a5@no,a7@right,a9@no:70
#
# a4@0-2,a5@no,a7@right:80
#
# a7@right,a9@no:87
#
# a5@no,a7@right,a9@no:75
#
# a5@no,a7@right:91
#
# a2@premeno,a7@left,a9@no,class@no:34
#
# a2@premeno,a5@no,a7@left,a9@no,class@no:32
#
# a2@premeno,a4@0-2,a7@left,a9@no,class@no:33
#
# a2@premeno,a4@0-2,a5@no,a7@left,a9@no,class@no:32
#
# a2@premeno,a5@no,a7@left,class@no:37
#
# a2@premeno,a4@0-2,a5@no,a7@left,class@no:37
#
# a2@premeno,a4@0-2,a7@left,class@no:39
#
# a2@premeno,a7@left,a9@no:50
#
# a2@premeno,a5@no,a7@left,a9@no:44
#
# a2@premeno,a4@0-2,a7@left,a9@no:45
#
# a2@premeno,a4@0-2,a5@no,a7@left,a9@no:44
#
# a2@premeno,a5@no,a7@left:52
#
# a2@premeno,a4@0-2,a5@no,a7@left:52
#
# a2@premeno,a4@0-2,a7@left:54
#
# a5@no,a7@left,a9@no,class@no:67
#
# a4@0-2,a7@left,a9@no,class@no:67
#
# a4@0-2,a5@no,a7@left,a9@no,class@no:66
#
# a5@no,a7@left,class@no:75
#
# a4@0-2,a5@no,a7@left,class@no:74
#
# a4@0-2,a7@left,class@no:77
#
# a4@0-2,a7@left:97
#
# a7@left,a9@no:97
#
# a4@0-2,a7@left,a9@no:83
#
# a5@no,a7@left,a9@no:83
#
# a4@0-2,a5@no,a7@left,a9@no:80
#
# a4@0-2,a5@no,a7@left:92
#
# a2@premeno,a4@0-2,a9@no,class@no:63
#
# a2@premeno,a4@0-2,a5@no,a9@no,class@no:62
#
# a2@premeno,a5@no,a9@no,class@no:64
#
# a2@premeno,a4@0-2,class@no:74
#
# a2@premeno,a4@0-2,a5@no,class@no:70
#
# a2@premeno,a5@no,class@no:75
#
# a2@premeno,a4@0-2,a9@no:85
#
# a2@premeno,a5@no,a9@no:85
#
# a2@premeno,a4@0-2,a5@no,a9@no:82
#
# a2@premeno,a4@0-2:101
#
# a2@premeno,a4@0-2,a5@no:95
#
# a2@premeno,a5@no:103
#
# a4@0-2,a9@no,class@no:124
#
# a4@0-2,a5@no,a9@no,class@no:122
#
# a5@no,a9@no,class@no:125
#
# a4@0-2,class@no:142
#
# a5@no,class@no:142
#
# a4@0-2,a5@no,class@no:136
#
# a4@0-2,a9@no:156
#
# a4@0-2,a5@no,a9@no:150
#
# a4@0-2,a5@no:172
#
# a9@no:184
#
# a5@no,a9@no:158
#
# a5@no:188
#
# rule_confidence_dict {'a1@40-49,a2@premeno,a3@15-19,a5@no,a6@3,a7@right>class@no': (1.0, 1), 'a2@premeno,a3@15-19,a5@no,a6@3,a7@right,a9@yes>class@no': (1.0, 1), 'a1@40-49,a2@premeno,a3@15-19,a5@no,a6@3,a7@right,a9@yes>class@no': (1.0, 1), 'a1@40-49,a2@premeno,a5@no,a6@3,a7@right,a8@right_low,a9@yes>class@no': (1.0, 1), 'a1@40-49,a2@premeno,a3@15-19,a5@no,a6@3,a7@right,a8@right_low,a9@yes>class@no': (1.0, 1), 'a1@40-49,a2@premeno,a3@15-19,a4@12-14,a5@no,a6@3,a7@right,a8@right_low,a9@yes>class@no': (1.0, 1), 'a1@70-79,a2@ge40,a4@0-2,a5@no,a6@1,a9@no>class@no': (1.0, 1), 'a2@ge40,a3@40-44,a4@0-2,a5@no,a6@1,a7@right,a9@no>class@no': (1.0, 1), 'a2@ge40,a3@40-44,a4@0-2,a5@no,a6@1,a7@right,a8@right_up,a9@no>class@no': (1.0, 1), 'a1@70-79,a2@ge40,a3@40-44,a4@0-2,a5@no,a6@1,a7@right,a8@right_up,a9@no>class@no': (1.0, 1), 'a1@70-79,a2@ge40,a4@0-2,a5@no,a7@left,a9@no>class@no': (1.0, 1), 'a2@ge40,a3@10-14,a4@0-2,a5@no,a6@2,a7@left,a8@central,a9@no>class@no': (1.0, 1), 'a1@70-79,a2@ge40,a3@10-14,a4@0-2,a5@no,a6@2,a7@left,a8@central,a9@no>class@no': (1.0, 1), 'a1@70-79,a2@ge40,a4@0-2,a5@no,a9@no>class@no': (1.0, 2), 'a1@50-59,a2@ge40,a3@5-9,a4@0-2,a5@no,a6@2,a7@right,a8@right_up,a9@no>class@no': (1.0, 1), 'a2@premeno,a3@5-9,a4@0-2,a5@no,a6@2,a7@left>class@no': (1.0, 1), 'a2@premeno,a3@5-9,a4@0-2,a5@no,a6@2,a7@left,a9@no>class@no': (1.0, 1), 'a1@30-39,a2@premeno,a3@5-9,a4@0-2,a5@no,a6@2,a7@left,a8@right_low,a9@no>class@no': (1.0, 1), 'a1@40-49,a2@premeno,a3@5-9,a4@0-2,a5@no,a6@1,a7@left,a8@left_low,a9@yes>class@no': (1.0, 1), 'a3@5-9,a4@0-2,a5@no,a6@2,a9@no>class@no': (1.0, 2), 'a2@premeno,a3@5-9,a4@0-2,a5@no,a7@left>class@no': (1.0, 2), 'a3@5-9,a4@0-2,a5@no>class@no': (1.0, 3), 'a3@45-49,a4@0-2,a5@no,a7@left,a9@yes>class@no': (1.0, 1), 'a1@40-49,a2@premeno,a3@45-49,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,a9@yes>class@no': (1.0, 1), 'a1@60-69,a2@ge40,a3@45-49,a7@left>class@no': (1.0, 1), 'a2@ge40,a6@3,a7@left,a8@central,a9@no>class@no': (1.0, 1), 'a1@60-69,a2@ge40,a5@yes,a6@3,a7@left,a8@central,a9@no>class@no': (1.0, 1), 'a1@60-69,a2@ge40,a4@6-8,a5@yes,a6@3,a7@left,a8@central,a9@no>class@no': (1.0, 1), 'a1@60-69,a2@ge40,a3@45-49,a4@6-8,a5@yes,a6@3,a7@left,a8@central,a9@no>class@no': (1.0, 1), 'a1@40-49,a2@premeno,a3@0-4,a4@0-2,a5@no,a6@2,a7@right,a9@no>class@no': (1.0, 1), 'a1@40-49,a2@premeno,a3@0-4,a4@0-2,a5@no,a6@2,a7@right,a8@right_low,a9@no>class@no': (1.0, 1), 'a1@40-49,a2@premeno,a3@0-4,a4@0-2,a5@no,a7@left,a8@central,a9@no>class@no': (1.0, 1), 'a1@40-49,a2@premeno,a4@0-2,a5@no,a6@3,a7@left,a8@central,a9@no>class@no': (1.0, 1), 'a1@40-49,a2@premeno,a3@0-4,a4@0-2,a5@no,a6@3,a7@left,a8@central,a9@no>class@no': (1.0, 1), 'a1@50-59,a2@ge40,a3@0-4,a4@0-2,a5@no,a7@right,a8@central,a9@no>class@no': (1.0, 1), 'a1@50-59,a2@ge40,a3@0-4,a4@0-2,a5@no,a6@1,a7@right,a8@central,a9@no>class@no': (1.0, 1), 'a1@40-49,a2@premeno,a3@0-4,a4@0-2,a5@no,a9@no>class@no': (1.0, 2), 'a1@50-59,a2@ge40,a3@0-4,a4@0-2,a5@no,a6@2,a8@central,a9@no>class@no': (1.0, 1), 'a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@left,a8@central,a9@no>class@no': (1.0, 1), 'a1@50-59,a2@ge40,a3@0-4,a4@0-2,a5@no,a6@2,a7@left,a8@central,a9@no>class@no': (1.0, 1), 'a3@0-4,a4@0-2,a5@no,a7@left,a8@central,a9@no>class@no': (1.0, 2), 'a1@50-59,a2@ge40,a3@0-4,a4@0-2,a5@no,a8@central,a9@no>class@no': (1.0, 2), 'a3@0-4,a4@0-2,a5@no,a8@central,a9@no>class@no': (0.8, 4), 'a1@50-59,a2@ge40,a3@50-54,a4@0-2,a5@no,a6@1,a7@right,a8@right_up,a9@no>class@no': (1.0, 1), 'a2@ge40,a3@50-54,a4@0-2,a5@no,a6@2,a9@no>class@no': (1.0, 1), 'a1@60-69,a2@ge40,a3@50-54,a4@0-2,a5@no,a6@2,a9@no>class@no': (1.0, 1), 'a1@60-69,a2@ge40,a3@50-54,a4@0-2,a5@no,a6@2,a8@left_low,a9@no>class@no': (1.0, 1), 'a1@60-69,a2@ge40,a3@50-54,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,a9@no>class@no': (1.0, 1), 'a3@50-54,a4@0-2,a5@no,a6@2,a9@no>class@no': (1.0, 2), 'a3@50-54,a4@0-2,a5@no,a6@2,a8@left_low,a9@no>class@no': (1.0, 2), 'a3@50-54,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,a9@no>class@no': (1.0, 2), 'a1@40-49,a2@premeno,a3@50-54,a4@0-2,a5@no,a ...

# %% [markdown]
# Saving to file

# %%
print('Saving clusters to the output file ....')
for i in range(len(cluster_labels)):
  rule_key = association_rules_list[i].serialize()
  rules_and_their_clusters.append((rule_key, cluster_labels[i], 
                                         confidence_support_values[rule_key]))
# Out:
# Saving clusters to the output file ....

# %%
rules_and_their_clusters = sorted(rules_and_their_clusters, key=lambda x: x[1])

# %%
rules_and_their_clusters
# Out:
# [('a1@40-49,a2@premeno,a3@15-19,a5@no,a6@3,a7@right>class@no', -1, (1.0, 1)),
#  ('a1@70-79,a2@ge40,a4@0-2,a5@no,a6@1,a9@no>class@no', -1, (1.0, 1)),
#  ('a2@ge40,a3@40-44,a4@0-2,a5@no,a6@1,a7@right,a9@no>class@no', -1, (1.0, 1)),
#  ('a2@ge40,a3@40-44,a4@0-2,a5@no,a6@1,a7@right,a8@right_up,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@70-79,a2@ge40,a3@40-44,a4@0-2,a5@no,a6@1,a7@right,a8@right_up,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a2@ge40,a3@10-14,a4@0-2,a5@no,a6@2,a7@left,a8@central,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@70-79,a2@ge40,a3@10-14,a4@0-2,a5@no,a6@2,a7@left,a8@central,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a2@premeno,a3@5-9,a4@0-2,a5@no,a6@2,a7@left>class@no', -1, (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@5-9,a4@0-2,a5@no,a6@1,a7@left,a8@left_low,a9@yes>class@no',
#   -1,
#   (1.0, 1)),
#  ('a2@premeno,a3@5-9,a4@0-2,a5@no,a7@left>class@no', -1, (1.0, 2)),
#  ('a3@5-9,a4@0-2,a5@no>class@no', -1, (1.0, 3)),
#  ('a2@ge40,a6@3,a7@left,a8@central,a9@no>class@no', -1, (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@0-4,a4@0-2,a5@no,a6@2,a7@right,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@0-4,a4@0-2,a5@no,a6@2,a7@right,a8@right_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@ge40,a3@0-4,a4@0-2,a5@no,a7@right,a8@central,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@ge40,a3@0-4,a4@0-2,a5@no,a6@1,a7@right,a8@central,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@ge40,a3@0-4,a4@0-2,a5@no,a6@2,a8@central,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@ge40,a3@0-4,a4@0-2,a5@no,a8@central,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a3@0-4,a4@0-2,a5@no,a8@central,a9@no>class@no', -1, (0.8, 4)),
#  ('a3@50-54,a4@0-2,a5@no,a6@2,a8@left_low,a9@no>class@no', -1, (1.0, 2)),
#  ('a3@50-54,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@40-49,a2@premeno,a3@50-54,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@ge40,a4@15-17,a6@3,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@ge40,a3@35-39,a4@15-17,a6@3,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@ge40,a4@15-17,a5@yes,a7@right>class@no', -1, (1.0, 1)),
#  ('a1@40-49,a2@ge40,a4@15-17,a5@yes,a7@right,a8@left_up>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@ge40,a3@40-44,a6@2,a7@right,a8@left_up>class@no', -1, (1.0, 1)),
#  ('a1@40-49,a3@40-44,a5@yes,a6@2,a7@right,a8@left_up,a9@yes>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@ge40,a4@15-17,a6@3,a9@no>class@no', -1, (1.0, 2)),
#  ('a1@60-69,a4@0-2,a5@no,a6@1,a8@right_up,a9@no>class@no', -1, (1.0, 1)),
#  ('a1@50-59,a2@lt40,a4@0-2,a5@no,a7@left,a9@no>class@no', -1, (1.0, 1)),
#  ('a1@50-59,a2@lt40,a3@15-19,a4@0-2,a5@no,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@lt40,a3@15-19,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@30-39,a4@0-2,a5@no,a6@3,a7@right,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a2@lt40,a4@0-2,a5@no,a6@1,a7@left,a9@no>class@no', -1, (1.0, 2)),
#  ('a1@60-69,a2@lt40,a4@0-2,a5@no,a6@1,a7@left,a9@no>class@no', -1, (1.0, 2)),
#  ('a2@lt40,a4@0-2,a5@no,a6@1,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@60-69,a3@30-34,a4@0-2,a5@no,a6@1,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@60-69,a2@lt40,a3@30-34,a4@0-2,a5@no,a6@1,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a2@lt40,a3@30-34,a4@0-2,a5@no,a9@no>class@no', -1, (1.0, 2)),
#  ('a2@lt40,a3@15-19,a4@0-2,a5@no,a9@no>class@no', -1, (1.0, 2)),
#  ('a2@lt40,a4@0-2,a5@no,a8@left_up,a9@no>class@no', -1, (1.0, 2)),
#  ('a3@30-34,a4@0-2,a5@no,a6@3,a7@right,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a2@lt40,a4@0-2,a5@no,a6@3,a7@right,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a2@lt40,a4@0-2,a5@no,a7@left,a8@left_low,a9@no>class@no', -1, (1.0, 2)),
#  ('a1@50-59,a2@lt40,a4@0-2,a5@no,a9@no>class@no', -1, (1.0, 2)),
#  ('a2@lt40,a4@0-2,a5@no,a9@no>class@no', -1, (1.0, 5)),
#  ('a2@lt40,a4@0-2,a5@no,a7@left,a9@no>class@no', -1, (1.0, 3)),
#  ('a1@40-49,a2@premeno,a3@35-39,a5@yes,a6@2,a7@right,a8@right_up>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@35-39,a5@yes,a6@2,a7@right,a8@right_up,a9@yes>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@35-39,a4@9-11,a5@yes,a6@2,a7@right,a8@right_up,a9@yes>class@no',
#   -1,
#   (1.0, 1)),
#  ('a2@premeno,a4@9-11,a5@yes,a6@2,a7@right,a9@yes>class@no', -1, (1.0, 2)),
#  ('a1@40-49,a2@premeno,a3@35-39,a5@yes,a6@2,a7@right>class@no', -1, (1.0, 2)),
#  ('a1@40-49,a2@premeno,a6@2,a7@right,a8@left_up,a9@yes>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@35-39,a5@yes,a6@2,a7@right,a8@left_up>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@35-39,a5@yes,a6@2,a7@right,a9@yes>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@40-49,a2@premeno,a3@35-39,a5@yes,a6@2,a7@right,a8@left_up,a9@yes>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@35-39,a4@9-11,a5@yes,a6@2,a7@right,a9@yes>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@40-49,a2@premeno,a3@35-39,a4@9-11,a5@yes,a6@2,a7@right,a8@left_up,a9@yes>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@ge40,a3@30-34,a6@3,a7@left,a8@left_low,a9@yes>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@25-29,a4@0-2,a6@2,a7@left,a8@right_low>class@no',
#   -1,
#   (1.0, 1)),
#  ('a2@ge40,a3@25-29,a5@?,a6@1,a8@left_low,a9@yes>class@no', -1, (1.0, 1)),
#  ('a3@25-29,a4@3-5,a7@right,a8@left_low,a9@yes>class@no', -1, (1.0, 1)),
#  ('a3@25-29,a5@?,a9@yes>class@no', -1, (1.0, 2)),
#  ('a1@50-59,a2@ge40,a3@30-34,a4@9-11,a5@?,a6@3,a7@left,a9@yes>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@50-59,a2@ge40,a3@30-34,a4@9-11,a5@?,a6@3,a7@left,a8@left_low,a9@yes>class@no',
#   -1,
#   (1.0, 1)),
#  ('a3@30-34,a4@6-8,a5@yes,a6@2,a7@right,a9@no>class@no', -1, (1.0, 1)),
#  ('a1@60-69,a2@ge40,a3@30-34,a4@6-8,a5@yes,a9@no>class@no', -1, (1.0, 1)),
#  ('a2@premeno,a3@25-29,a5@yes,a8@left_up,a9@yes>class@no', -1, (1.0, 1)),
#  ('a2@premeno,a3@25-29,a5@yes,a6@2,a8@left_up,a9@yes>class@no', -1, (1.0, 1)),
#  ('a1@30-39,a2@premeno,a3@25-29,a5@yes,a6@2,a9@yes>class@no', -1, (1.0, 1)),
#  ('a1@30-39,a2@premeno,a3@25-29,a5@yes,a6@2,a7@right,a9@yes>class@no',
#   -1,
#   (1.0, 1)),
#  ('a2@ge40,a3@30-34,a5@yes,a6@2,a8@left_low,a9@no>class@no', -1, (1.0, 1)),
#  ('a2@ge40,a3@30-34,a5@yes,a6@2,a9@no>class@no', -1, (1.0, 2)),
#  ('a2@ge40,a3@30-34,a4@6-8,a5@yes,a6@2,a9@no>class@no', -1, (1.0, 2)),
#  ('a4@6-8,a5@yes,a6@2>class@no', -1, (1.0, 3)),
#  ('a4@6-8,a5@yes,a6@2,a7@right>class@no', -1, (1.0, 2)),
#  ('a2@premeno,a3@40-44,a4@0-2,a5@no,a6@2,a7@left,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a2@premeno,a3@40-44,a4@0-2,a5@no,a6@2,a7@left,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a2@ge40,a3@40-44,a6@2,a7@left,a8@left_low,a9@no>class@no', -1, (1.0, 2)),
#  ('a1@50-59,a2@ge40,a3@40-44,a6@2,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a3@40-44,a4@0-2,a5@no,a6@2,a7@left,a9@no>class@no', -1, (1.0, 2)),
#  ('a3@40-44,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a3@40-44,a4@0-2,a5@no,a6@2,a7@left,a9@no>class@no', -1, (1.0, 2)),
#  ('a2@ge40,a3@40-44,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@ge40,a3@40-44,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@30-39,a2@premeno,a3@40-44,a4@0-2,a5@no,a6@2,a7@right,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@30-39,a2@premeno,a3@40-44,a4@0-2,a5@no,a7@right,a8@right_up,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@30-39,a2@premeno,a3@40-44,a4@0-2,a5@no,a6@2,a7@right,a8@right_up,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a2@premeno,a4@3-5,a5@no,a7@right,a8@right_up,a9@yes>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@30-39,a2@premeno,a3@40-44,a4@3-5,a5@no,a7@right,a9@yes>class@no',
#   -1,
#   (1.0, 1)),
#  ('a3@40-44,a4@0-2,a5@no,a7@right,a8@right_up,a9@no>class@no', -1, (1.0, 2)),
#  ('a1@30-39,a2@premeno,a3@40-44,a5@no,a7@right>class@no', -1, (1.0, 2)),
#  ('a1@30-39,a2@premeno,a5@no,a7@right,a8@right_up>class@no', -1, (1.0, 2)),
#  ('a1@30-39,a2@premeno,a3@40-44,a5@no,a7@right,a8@right_up>class@no',
#   -1,
#   (1.0, 2)),
#  ('a3@40-44,a5@no,a7@right,a8@right_up>class@no', -1, (1.0, 3)),
#  ('a1@40-49,a2@premeno,a3@40-44,a4@3-5,a5@yes,a7@right,a8@left_up,a9@yes>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@40-44,a4@3-5,a5@yes,a6@3,a7@right,a8@left_up,a9@yes>class@no',
#   -1,
#   (1.0, 1)),
#  ('a2@premeno,a4@3-5,a5@no,a6@3,a7@right,a8@right_up>class@no', -1, (1.0, 1)),
#  ('a2@premeno,a3@40-44,a7@right,a9@yes>class@no', -1, (1.0, 2)),
#  ('a2@premeno,a3@40-44,a4@3-5,a7@right,a9@yes>class@no', -1, (1.0, 2)),
#  ('a1@40-49,a2@premeno,a3@40-44,a4@0-2,a5@no,a7@right,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a3@40-44,a4@0-2,a5@no,a6@1,a7@right,a9@no>class@no', -1, (1.0, 2)),
#  ('a1@40-49,a2@premeno,a3@40-44,a4@0-2,a5@no,a6@1,a7@right,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a2@premeno,a3@40-44,a4@0-2,a5@no,a6@2,a7@left,a8@left_low>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@30-39,a2@premeno,a3@40-44,a4@0-2,a5@no,a6@2>class@no', -1, (1.0, 2)),
#  ('a2@ge40,a3@40-44,a5@yes,a6@2>class@no', -1, (1.0, 2)),
#  ('a1@30-39,a2@premeno,a3@40-44,a6@2,a9@yes>class@no', -1, (1.0, 1)),
#  ('a1@30-39,a2@premeno,a3@40-44,a5@no,a6@2,a9@yes>class@no', -1, (1.0, 1)),
#  ('a1@40-49,a3@40-44,a5@yes,a7@right,a8@left_up,a9@yes>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@30-39,a2@premeno,a3@40-44,a5@no,a9@yes>class@no', -1, (1.0, 2)),
#  ('a2@premeno,a3@40-44,a9@yes>class@no', -1, (1.0, 3)),
#  ('a3@40-44,a7@right,a9@yes>class@no', -1, (1.0, 3)),
#  ('a2@premeno,a3@40-44,a4@0-2,a5@no,a6@2,a7@right,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@40-44,a4@0-2,a5@no,a6@2,a7@right,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@40-44,a4@0-2,a5@no,a7@right,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a2@premeno,a3@40-44,a4@0-2,a5@no,a6@2,a7@left>class@no', -1, (1.0, 2)),
#  ('a3@40-44,a6@2,a7@left,a8@left_low>class@no', -1, (1.0, 3)),
#  ('a3@40-44,a4@0-2,a5@no,a6@2,a7@left,a8@left_low>class@no', -1, (1.0, 2)),
#  ('a3@40-44,a4@0-2,a5@no,a6@2,a7@left>class@no', -1, (1.0, 3)),
#  ('a2@premeno,a3@40-44,a4@0-2,a5@no,a6@2,a8@left_low>class@no', -1, (1.0, 2)),
#  ('a2@premeno,a3@40-44,a4@0-2,a5@no,a6@2>class@no', -1, (1.0, 4)),
#  ('a2@premeno,a3@40-44,a4@0-2,a5@no,a6@2,a9@no>class@no', -1, (1.0, 3)),
#  ('a2@premeno,a3@40-44,a4@0-2,a5@no,a6@2,a7@right,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a3@40-44,a4@0-2,a5@no,a6@2,a9@no>class@no', -1, (0.8, 4)),
#  ('a2@premeno,a3@40-44,a5@no,a7@right>class@no', -1, (1.0, 4)),
#  ('a2@premeno,a3@40-44,a4@0-2,a5@no,a7@right,a9@no>class@no', -1, (1.0, 3)),
#  ('a3@40-44,a5@no,a7@right,a9@no>class@no', -1, (0.8, 4)),
#  ('a3@40-44,a4@0-2,a5@no,a7@right,a9@no>class@no', -1, (0.8, 4)),
#  ('a1@40-49,a2@premeno,a3@35-39,a6@2,a7@right,a8@right_up,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@35-39,a4@0-2,a5@no,a6@2,a7@right,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@35-39,a4@0-2,a5@no,a6@2,a7@right,a8@right_up,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a5@yes,a6@3,a8@left_low,a9@yes>class@no', -1, (1.0, 1)),
#  ('a1@40-49,a2@premeno,a4@0-2,a5@yes,a6@3,a7@right,a8@left_low,a9@yes>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@35-39,a4@0-2,a5@yes,a6@3,a7@right,a8@left_low,a9@yes>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@35-39,a5@yes,a7@right,a8@left_up>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@40-49,a2@premeno,a3@35-39,a5@yes,a7@right,a8@left_up,a9@yes>class@no',
#   -1,
#   (1.0, 2)),
#  ('a2@premeno,a3@35-39,a5@yes,a7@right>class@no', -1, (0.8, 4)),
#  ('a1@40-49,a2@premeno,a3@35-39,a5@yes,a7@right>class@no', -1, (1.0, 4)),
#  ('a1@40-49,a2@premeno,a3@35-39,a5@yes,a7@right,a9@yes>class@no',
#   -1,
#   (1.0, 4)),
#  ('a3@35-39,a4@0-2,a6@3,a8@left_up>class@no', -1, (1.0, 2)),
#  ('a1@50-59,a3@35-39,a4@0-2,a5@no,a8@left_up,a9@no>class@no', -1, (1.0, 3)),
#  ('a1@50-59,a2@premeno,a3@35-39,a4@0-2,a5@no,a7@right,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a3@35-39,a4@0-2,a8@left_up>class@no', -1, (0.8, 4)),
#  ('a1@50-59,a3@35-39,a4@0-2,a5@no,a6@2,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@50-59,a2@premeno,a3@35-39,a4@0-2,a5@no,a6@2,a7@right,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a2@premeno,a3@35-39,a4@0-2,a5@no,a6@2,a7@right,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@50-59,a2@ge40,a3@35-39,a4@0-2,a5@no,a7@left,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@50-59,a2@ge40,a3@35-39,a5@no,a6@3,a7@left,a9@no>class@no', -1, (1.0, 3)),
#  ('a1@50-59,a2@ge40,a3@35-39,a4@0-2,a5@no,a6@3,a7@left,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@50-59,a2@ge40,a4@0-2,a5@no,a6@3,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a2@premeno,a3@35-39,a4@0-2,a7@right>class@no', -1, (0.8, 4)),
#  ('a2@premeno,a3@25-29,a4@0-2,a5@no,a6@2,a7@right,a8@central,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@25-29,a4@0-2,a5@no,a6@2,a7@right,a8@central,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@ge40,a3@15-19,a4@0-2,a5@no,a6@1,a7@right,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@ge40,a3@15-19,a4@0-2,a5@no,a6@1,a7@right,a8@central,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@ge40,a4@0-2,a5@yes,a6@2,a7@left,a8@central>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@ge40,a3@15-19,a4@0-2,a8@central>class@no', -1, (1.0, 2)),
#  ('a1@30-39,a2@premeno,a4@0-2,a5@no,a6@1,a7@left,a8@central,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@30-39,a2@premeno,a3@25-29,a4@0-2,a5@no,a6@1,a7@left,a8@central,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a2@premeno,a3@25-29,a4@0-2,a5@no,a8@central,a9@no>class@no', -1, (1.0, 2)),
#  ('a1@50-59,a2@ge40,a6@2,a7@left,a9@yes>class@no', -1, (1.0, 1)),
#  ('a1@50-59,a2@ge40,a5@yes,a6@2,a7@left,a9@yes>class@no', -1, (1.0, 1)),
#  ('a4@0-2,a5@no,a6@3,a7@left,a8@central,a9@no>class@no', -1, (1.0, 2)),
#  ('a6@3,a7@left,a8@central,a9@no>class@no', -1, (1.0, 3)),
#  ('a1@50-59,a2@premeno,a4@0-2,a5@no,a7@left,a8@central,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@premeno,a3@30-34,a4@0-2,a5@no,a6@1,a7@left,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a3@30-34,a4@0-2,a5@no,a6@1,a7@left,a8@central,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@premeno,a3@30-34,a4@0-2,a5@no,a6@1,a7@left,a8@central,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@ge40,a3@30-34,a4@0-2,a5@no,a6@1,a7@right,a8@central,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a3@30-34,a4@0-2,a5@no,a6@1,a8@central,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a2@premeno,a4@0-2,a5@no,a6@1,a7@left,a8@central,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@50-59,a2@ge40,a4@0-2,a5@no,a6@1,a7@right,a8@central,a9@no>class@no',
#   -1,
#   (1.0, 3)),
#  ('a4@0-2,a5@no,a6@1,a8@central,a9@no>class@no', -1, (1.0, 5)),
#  ('a1@50-59,a4@0-2,a5@no,a6@1,a8@central,a9@no>class@no', -1, (1.0, 4)),
#  ('a1@50-59,a4@0-2,a5@no,a7@left,a8@central,a9@no>class@no', -1, (1.0, 2)),
#  ('a1@50-59,a2@ge40,a4@0-2,a6@2,a7@left,a8@central>class@no', -1, (1.0, 2)),
#  ('a1@50-59,a4@0-2,a7@left,a8@central>class@no', -1, (1.0, 3)),
#  ('a1@50-59,a2@ge40,a4@0-2,a5@no,a8@central,a9@no>class@no', -1, (0.8, 4)),
#  ('a2@ge40,a4@0-2,a7@left,a8@central>class@no', -1, (1.0, 3)),
#  ('a2@ge40,a4@0-2,a6@2,a7@left,a8@central>class@no', -1, (1.0, 3)),
#  ('a2@ge40,a4@0-2,a7@left,a8@central,a9@no>class@no', -1, (1.0, 2)),
#  ('a2@ge40,a4@0-2,a5@no,a7@left,a8@central,a9@no>class@no', -1, (1.0, 2)),
#  ('a2@ge40,a7@left,a8@central,a9@no>class@no', -1, (1.0, 3)),
#  ('a1@40-49,a2@premeno,a3@10-14,a4@0-2,a5@no,a6@1,a7@right,a8@right_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@30-39,a2@premeno,a3@10-14,a4@0-2,a5@no,a6@2,a7@left,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@30-39,a2@premeno,a3@10-14,a4@0-2,a5@no,a6@2,a7@left,a8@right_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a2@premeno,a3@10-14,a4@0-2,a5@no,a8@right_low,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a2@ge40,a3@15-19,a4@0-2,a5@no,a6@1,a7@left,a9@no>class@no', -1, (1.0, 1)),
#  ('a2@ge40,a4@0-2,a5@no,a6@1,a7@left,a8@right_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a3@15-19,a5@no,a8@right_low>class@no', -1, (1.0, 2)),
#  ('a1@60-69,a2@ge40,a3@15-19,a4@0-2,a5@no,a6@1,a7@left,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@60-69,a2@ge40,a3@15-19,a4@0-2,a5@no,a6@1,a7@left,a8@right_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@30-39,a2@premeno,a3@20-24,a4@0-2,a5@no,a6@2,a7@left,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@20-24,a4@0-2,a5@no,a6@1,a7@left,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@20-24,a4@0-2,a5@no,a6@1,a7@left,a8@right_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@20-24,a4@0-2,a5@no,a7@left,a8@right_low,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a2@premeno,a3@20-24,a4@0-2,a5@no,a7@left,a8@right_low,a9@no>class@no',
#   -1,
#   (1.0, 3)),
#  ('a1@50-59,a2@premeno,a3@25-29,a5@no,a6@2,a7@right,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a2@premeno,a3@25-29,a4@0-2,a5@no,a6@2,a8@right_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@premeno,a3@25-29,a4@0-2,a5@no,a6@2,a7@right,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a2@premeno,a3@25-29,a4@0-2,a5@no,a6@2,a7@right,a8@right_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@premeno,a3@25-29,a4@0-2,a5@no,a6@2,a7@right,a8@right_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@30-34,a4@0-2,a5@no,a6@2,a7@right,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@30-34,a4@0-2,a5@no,a6@2,a7@right,a8@right_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@30-34,a4@0-2,a5@no,a6@2,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@40-49,a2@premeno,a3@30-34,a4@0-2,a5@no,a6@2,a7@left,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@30-34,a4@0-2,a5@no,a6@2,a8@right_low,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@40-49,a2@premeno,a3@30-34,a4@0-2,a5@no,a6@2,a7@left,a8@right_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a4@0-2,a5@no,a6@1,a7@right,a8@right_low,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@40-49,a2@premeno,a3@25-29,a4@0-2,a5@no,a7@left,a8@right_low>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@25-29,a4@0-2,a5@no,a7@left,a8@right_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@25-29,a4@0-2,a5@no,a6@1,a7@left,a8@right_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@25-29,a4@0-2,a5@no,a6@1,a7@right,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@25-29,a4@0-2,a5@no,a7@right,a8@right_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@25-29,a4@0-2,a5@no,a6@1,a7@right,a8@right_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@25-29,a4@0-2,a5@no,a6@1,a8@right_low,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a4@0-2,a5@no,a6@1,a7@left,a8@right_low,a9@no>class@no', -1, (1.0, 3)),
#  ('a1@40-49,a2@premeno,a4@0-2,a5@no,a6@1,a7@left,a8@right_low,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a4@0-2,a5@no,a6@1,a8@right_low,a9@no>class@no', -1, (1.0, 5)),
#  ('a1@40-49,a2@premeno,a4@0-2,a5@no,a6@1,a8@right_low,a9@no>class@no',
#   -1,
#   (1.0, 4)),
#  ('a1@40-49,a2@premeno,a8@right_low,a9@yes>class@no', -1, (1.0, 2)),
#  ('a2@premeno,a3@25-29,a4@0-2,a5@no,a7@right,a8@right_low,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a2@premeno,a4@0-2,a5@no,a6@2,a7@right,a8@right_low,a9@no>class@no',
#   -1,
#   (1.0, 3)),
#  ('a1@40-49,a2@premeno,a4@0-2,a5@no,a6@2,a7@right,a8@right_low,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a2@premeno,a5@no,a7@right,a8@right_low>class@no', -1, (1.0, 6)),
#  ('a1@40-49,a2@premeno,a4@0-2,a5@no,a7@right,a8@right_low,a9@no>class@no',
#   -1,
#   (1.0, 4)),
#  ('a2@premeno,a3@25-29,a4@0-2,a6@2,a8@right_low>class@no', -1, (1.0, 2)),
#  ('a1@40-49,a2@premeno,a3@25-29,a4@0-2,a7@left,a8@right_low>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@40-49,a2@premeno,a4@0-2,a6@2,a7@left,a8@right_low>class@no',
#   -1,
#   (1.0, 3)),
#  ('a1@40-49,a2@premeno,a4@0-2,a6@2,a8@right_low>class@no', -1, (1.0, 5)),
#  ('a1@40-49,a2@premeno,a4@0-2,a5@no,a6@2,a8@right_low,a9@no>class@no',
#   -1,
#   (1.0, 4)),
#  ('a2@premeno,a4@0-2,a6@2,a8@right_low>class@no', -1, (1.0, 9)),
#  ('a2@premeno,a4@0-2,a5@no,a6@2,a8@right_low,a9@no>class@no', -1, (1.0, 8)),
#  ('a1@40-49,a2@premeno,a4@0-2,a5@no,a7@left,a8@right_low,a9@no>class@no',
#   -1,
#   (1.0, 4)),
#  ('a1@40-49,a2@premeno,a8@right_low>class@no', -1, (1.0, 10)),
#  ('a1@40-49,a2@premeno,a4@0-2,a5@no,a8@right_low>class@no', -1, (1.0, 8)),
#  ('a1@40-49,a2@premeno,a4@0-2,a5@no,a8@right_low,a9@no>class@no',
#   -1,
#   (1.0, 8)),
#  ('a4@0-2,a5@no,a7@left,a8@right_low,a9@no>class@no', -1, (1.0, 8)),
#  ('a2@premeno,a4@0-2,a5@no,a7@left,a8@right_low,a9@no>class@no', -1, (1.0, 7)),
#  ('a4@0-2,a5@no,a8@right_low>class@no', -1, (0.9285714285714286, 13)),
#  ('a2@premeno,a4@0-2,a5@no,a8@right_low,a9@no>class@no', -1, (1.0, 12)),
#  ('a2@premeno,a3@10-14,a4@0-2,a5@no,a6@1,a7@right,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@30-39,a2@premeno,a3@10-14,a4@0-2,a5@no,a6@1,a7@right,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a2@ge40,a3@10-14,a4@0-2,a5@no,a6@2,a8@left_up>class@no', -1, (1.0, 1)),
#  ('a2@ge40,a3@10-14,a4@0-2,a5@no,a6@2,a7@right,a8@left_up>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@60-69,a2@ge40,a3@10-14,a4@0-2,a5@no,a6@2,a7@right,a8@left_up>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@60-69,a2@ge40,a3@10-14,a4@0-2,a5@no,a6@2,a8@left_up,a9@yes>class@no',
#   -1,
#   (1.0, 1)),
#  ('a3@10-14,a4@0-2,a5@no,a6@2,a9@yes>class@no', -1, (1.0, 2)),
#  ('a1@50-59,a3@10-14,a4@0-2,a5@no,a7@right,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a2@premeno,a3@10-14,a4@0-2,a5@no,a6@1,a7@left,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a2@premeno,a3@10-14,a4@0-2,a5@no,a6@1,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@premeno,a3@10-14,a4@0-2,a5@no,a6@2,a7@right,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@premeno,a3@10-14,a4@0-2,a5@no,a9@no>class@no', -1, (1.0, 2)),
#  ('a1@50-59,a2@ge40,a3@10-14,a4@0-2,a5@no,a6@1,a7@left,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a3@10-14,a4@0-2,a5@no,a6@1,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@50-59,a2@ge40,a4@0-2,a5@no,a6@1,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@ge40,a3@10-14,a4@0-2,a5@no,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@50-59,a2@ge40,a3@10-14,a4@0-2,a5@no,a6@1,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a3@10-14,a4@0-2,a5@no,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 3)),
#  ('a1@50-59,a2@ge40,a3@10-14,a4@0-2,a5@no,a9@no>class@no', -1, (1.0, 4)),
#  ('a1@50-59,a3@10-14,a4@0-2,a5@no,a6@1,a9@no>class@no', -1, (1.0, 4)),
#  ('a1@50-59,a2@ge40,a3@10-14,a4@0-2,a5@no,a6@1,a9@no>class@no', -1, (1.0, 3)),
#  ('a1@50-59,a3@10-14,a4@0-2,a5@no,a6@1,a7@left,a9@no>class@no', -1, (1.0, 3)),
#  ('a1@50-59,a2@ge40,a3@10-14,a4@0-2,a5@no,a7@left,a9@no>class@no',
#   -1,
#   (1.0, 3)),
#  ('a1@50-59,a2@ge40,a3@10-14,a4@0-2,a5@no,a6@1,a7@left,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@50-59,a3@10-14,a4@0-2,a5@no,a7@left,a9@no>class@no', -1, (1.0, 4)),
#  ('a1@50-59,a3@10-14,a4@0-2,a5@no,a9@no>class@no', -1, (1.0, 6)),
#  ('a2@premeno,a3@10-14,a4@0-2,a5@no,a6@2,a7@left,a8@left_low>class@no',
#   -1,
#   (1.0, 2)),
#  ('a2@premeno,a3@10-14,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@10-14,a4@0-2,a5@no,a6@2,a7@left,a8@left_low>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@40-49,a2@premeno,a3@10-14,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a2@premeno,a3@10-14,a4@0-2,a5@no,a6@2,a7@right,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@10-14,a4@0-2,a5@no,a6@2,a7@right,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@10-14,a4@0-2,a5@no,a6@1,a7@right,a9@no>class@no',
#   -1,
#   (1.0, 3)),
#  ('a2@premeno,a3@10-14,a4@0-2,a5@no,a6@1,a7@right,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@40-49,a2@premeno,a3@10-14,a4@0-2,a5@no,a6@1,a7@right,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@40-49,a2@premeno,a3@10-14,a4@0-2,a5@no,a7@right,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 3)),
#  ('a1@40-49,a2@premeno,a3@10-14,a4@0-2,a5@no,a6@2,a7@right,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@10-14,a4@0-2,a5@no,a6@2>class@no', -1, (1.0, 4)),
#  ('a1@40-49,a2@premeno,a3@10-14,a4@0-2,a5@no,a6@2,a9@no>class@no',
#   -1,
#   (1.0, 3)),
#  ('a1@40-49,a2@premeno,a3@10-14,a4@0-2,a5@no,a6@2,a7@right,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@40-49,a2@premeno,a3@10-14,a4@0-2,a5@no,a7@right,a9@no>class@no',
#   -1,
#   (1.0, 5)),
#  ('a1@60-69,a2@ge40,a3@10-14,a4@0-2,a5@no,a6@2>class@no', -1, (1.0, 2)),
#  ('a1@60-69,a2@ge40,a3@10-14,a4@0-2,a5@no,a6@1,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@60-69,a2@ge40,a3@10-14,a4@0-2,a5@no,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@60-69,a2@ge40,a3@10-14,a4@0-2,a5@no,a6@1,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@60-69,a2@ge40,a3@10-14,a4@0-2,a5@no,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 3)),
#  ('a1@60-69,a2@ge40,a3@10-14,a4@0-2,a5@no,a6@1,a7@left,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@60-69,a3@10-14,a4@0-2,a5@no,a6@1,a9@no>class@no', -1, (1.0, 5)),
#  ('a1@60-69,a3@10-14,a4@0-2,a5@no,a6@1,a7@left,a9@no>class@no', -1, (1.0, 4)),
#  ('a1@60-69,a2@ge40,a3@10-14,a4@0-2,a5@no,a6@1,a9@no>class@no', -1, (1.0, 4)),
#  ('a1@60-69,a2@ge40,a3@10-14,a4@0-2,a5@no,a6@1,a7@left,a9@no>class@no',
#   -1,
#   (1.0, 3)),
#  ('a1@60-69,a3@10-14,a4@0-2,a5@no,a9@no>class@no', -1, (1.0, 6)),
#  ('a1@60-69,a2@ge40,a3@10-14,a4@0-2,a5@no>class@no', -1, (1.0, 6)),
#  ('a1@60-69,a2@ge40,a3@10-14,a4@0-2,a5@no,a7@left,a9@no>class@no',
#   -1,
#   (1.0, 4)),
#  ('a2@ge40,a3@10-14,a4@0-2,a5@no,a6@1,a7@left,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 3)),
#  ('a3@10-14,a4@0-2,a5@no,a6@1,a8@left_up,a9@no>class@no', -1, (1.0, 6)),
#  ('a3@10-14,a4@0-2,a5@no,a8@left_up>class@no', -1, (1.0, 9)),
#  ('a3@10-14,a4@0-2,a5@no,a8@left_up,a9@no>class@no', -1, (1.0, 8)),
#  ('a2@ge40,a3@10-14,a4@0-2,a5@no,a6@1,a7@right,a9@no>class@no', -1, (1.0, 2)),
#  ('a2@premeno,a3@10-14,a4@0-2,a5@no,a7@right,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a2@premeno,a3@10-14,a4@0-2,a5@no,a6@2,a7@right,a9@no>class@no',
#   -1,
#   (1.0, 3)),
#  ('a2@premeno,a3@10-14,a4@0-2,a5@no,a6@2,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a2@premeno,a3@10-14,a4@0-2,a5@no,a6@2,a7@right,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a3@10-14,a4@0-2,a5@no,a6@2,a8@left_up>class@no', -1, (1.0, 3)),
#  ('a3@10-14,a4@0-2,a5@no,a6@2,a7@right,a8@left_up>class@no', -1, (1.0, 3)),
#  ('a3@10-14,a4@0-2,a5@no,a6@2,a7@right>class@no', -1, (1.0, 4)),
#  ('a2@premeno,a3@10-14,a4@0-2,a5@no,a7@right,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 4)),
#  ('a3@10-14,a4@0-2,a5@no,a6@1,a7@right,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 3)),
#  ('a2@premeno,a3@10-14,a4@0-2,a5@no,a6@1,a9@no>class@no', -1, (1.0, 5)),
#  ('a2@premeno,a3@10-14,a4@0-2,a5@no,a6@1,a7@right,a9@no>class@no',
#   -1,
#   (1.0, 4)),
#  ('a3@10-14,a4@0-2,a5@no,a6@1,a7@right,a9@no>class@no', -1, (1.0, 6)),
#  ('a2@premeno,a3@10-14,a4@0-2,a5@no,a7@right,a9@no>class@no', -1, (1.0, 7)),
#  ('a3@10-14,a4@0-2,a5@no,a7@right>class@no', -1, (1.0, 10)),
#  ('a3@10-14,a4@0-2,a5@no,a7@right,a9@no>class@no', -1, (1.0, 9)),
#  ('a2@premeno,a3@10-14,a4@0-2,a5@no,a7@left,a8@left_low>class@no',
#   -1,
#   (1.0, 3)),
#  ('a2@premeno,a3@10-14,a4@0-2,a5@no,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a2@premeno,a3@10-14,a4@0-2,a5@no,a8@left_low>class@no', -1, (1.0, 5)),
#  ('a2@premeno,a3@10-14,a4@0-2,a5@no,a8@left_low,a9@no>class@no', -1, (1.0, 4)),
#  ('a2@ge40,a3@10-14,a4@0-2,a5@no,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 4)),
#  ('a2@premeno,a3@10-14,a4@0-2,a5@no,a6@1,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a2@ge40,a3@10-14,a4@0-2,a5@no,a6@1,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 3)),
#  ('a3@10-14,a4@0-2,a5@no,a6@1,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 3)),
#  ('a2@ge40,a3@10-14,a4@0-2,a5@no,a6@1,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a3@10-14,a4@0-2,a5@no,a6@1,a8@left_low,a9@no>class@no', -1, (1.0, 5)),
#  ('a3@10-14,a4@0-2,a5@no,a7@left,a8@left_low,a9@no>class@no', -1, (1.0, 6)),
#  ('a3@10-14,a4@0-2,a5@no,a8@left_low>class@no', -1, (1.0, 10)),
#  ('a3@10-14,a4@0-2,a5@no,a8@left_low,a9@no>class@no', -1, (1.0, 9)),
#  ('a2@ge40,a3@10-14,a4@0-2,a5@no,a6@2>class@no', -1, (1.0, 4)),
#  ('a2@ge40,a3@10-14,a4@0-2,a5@no,a6@2,a7@left,a9@no>class@no', -1, (1.0, 3)),
#  ('a3@10-14,a4@0-2,a5@no,a6@2,a8@left_low>class@no', -1, (1.0, 5)),
#  ('a3@10-14,a4@0-2,a5@no,a6@2,a7@left,a8@left_low>class@no', -1, (1.0, 4)),
#  ('a3@10-14,a4@0-2,a5@no,a6@2,a8@left_low,a9@no>class@no', -1, (1.0, 4)),
#  ('a3@10-14,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 3)),
#  ('a2@premeno,a3@10-14,a4@0-2,a5@no,a6@2,a9@no>class@no', -1, (1.0, 5)),
#  ('a2@premeno,a3@10-14,a4@0-2,a5@no,a6@2,a7@left>class@no', -1, (1.0, 3)),
#  ('a2@premeno,a3@10-14,a4@0-2,a5@no,a6@2,a7@left,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a3@10-14,a4@0-2,a5@no,a6@2,a7@left>class@no', -1, (1.0, 6)),
#  ('a3@10-14,a4@0-2,a5@no,a6@2,a7@left,a9@no>class@no', -1, (1.0, 5)),
#  ('a3@10-14,a4@0-2,a5@no,a6@2>class@no', -1, (1.0, 10)),
#  ('a3@10-14,a4@0-2,a5@no,a6@2,a9@no>class@no', -1, (1.0, 8)),
#  ('a2@premeno,a3@10-14,a4@0-2,a5@no,a7@left>class@no', -1, (1.0, 4)),
#  ('a2@premeno,a3@10-14,a4@0-2,a5@no,a7@left,a9@no>class@no', -1, (1.0, 3)),
#  ('a2@ge40,a3@10-14,a4@0-2,a5@no,a6@1,a9@no>class@no', -1, (1.0, 7)),
#  ('a2@ge40,a3@10-14,a4@0-2,a5@no,a6@1,a7@left,a9@no>class@no', -1, (1.0, 5)),
#  ('a2@ge40,a3@10-14,a4@0-2,a5@no,a9@no>class@no', -1, (1.0, 10)),
#  ('a2@ge40,a3@10-14,a4@0-2,a5@no,a7@left,a9@no>class@no', -1, (1.0, 8)),
#  ('a2@ge40,a3@10-14,a4@0-2,a5@no>class@no', -1, (1.0, 11)),
#  ('a3@10-14,a4@0-2,a5@no,a6@1,a9@no>class@no', -1, (1.0, 13)),
#  ('a3@10-14,a4@0-2,a5@no,a6@1,a7@left,a9@no>class@no', -1, (1.0, 7)),
#  ('a3@10-14,a4@0-2,a5@no,a7@left,a9@no>class@no', -1, (1.0, 12)),
#  ('a3@10-14,a4@0-2,a5@no>class@no', -1, (1.0, 23)),
#  ('a3@10-14,a4@0-2,a5@no,a9@no>class@no', -1, (1.0, 21)),
#  ('a1@50-59,a2@ge40,a3@15-19,a4@0-2,a5@no,a6@2,a7@right,a8@right_up,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a4@0-2,a5@no,a6@1,a7@right,a8@right_up,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@20-24,a4@0-2,a5@no,a6@1,a7@right,a8@right_up,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@20-24,a4@0-2,a5@no,a7@right,a8@right_up,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@50-59,a2@ge40,a4@0-2,a5@no,a6@3,a8@right_up,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@ge40,a3@25-29,a4@0-2,a5@no,a6@3,a7@left,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@ge40,a4@0-2,a5@no,a6@3,a7@left,a8@right_up,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@ge40,a3@25-29,a4@0-2,a5@no,a6@3,a7@left,a8@right_up,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a3@30-34,a4@0-2,a5@no,a6@1,a8@right_up,a9@no>class@no', -1, (1.0, 2)),
#  ('a1@50-59,a2@ge40,a3@30-34,a4@0-2,a5@no,a7@right,a8@right_up,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@ge40,a3@30-34,a4@0-2,a5@no,a6@1,a7@right,a8@right_up,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a4@0-2,a5@no,a6@1,a8@right_up,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a4@0-2,a5@no,a6@1,a7@right,a8@right_up,a9@no>class@no', -1, (1.0, 4)),
#  ('a4@0-2,a5@no,a6@1,a8@right_up,a9@no>class@no', -1, (1.0, 6)),
#  ('a4@0-2,a5@no,a6@1,a7@left,a8@right_up,a9@no>class@no', -1, (1.0, 2)),
#  ('a1@40-49,a2@premeno,a3@30-34,a4@0-2,a5@no,a7@left,a8@right_up,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@30-34,a4@0-2,a5@no,a6@1,a7@left,a8@right_up,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a2@ge40,a3@30-34,a7@right,a8@right_up,a9@no>class@no', -1, (1.0, 2)),
#  ('a1@40-49,a2@premeno,a4@0-2,a5@no,a7@right,a8@right_up,a9@no>class@no',
#   -1,
#   (0.8, 4)),
#  ('a2@premeno,a4@0-2,a5@no,a7@right,a8@right_up,a9@no>class@no',
#   -1,
#   (0.8333333333333334, 5)),
#  ('a1@40-49,a2@premeno,a6@2,a7@right,a8@right_up,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a5@no,a6@2,a7@right,a8@right_up,a9@no>class@no',
#   -1,
#   (0.8333333333333334, 5)),
#  ('a4@0-2,a5@no,a6@2,a7@right,a8@right_up,a9@no>class@no', -1, (1.0, 5)),
#  ('a2@premeno,a5@no,a7@right,a8@right_up>class@no',
#   -1,
#   (0.8571428571428571, 6)),
#  ('a4@0-2,a5@no,a7@right,a8@right_up,a9@no>class@no',
#   -1,
#   (0.9090909090909091, 10)),
#  ('a1@40-49,a2@premeno,a3@15-19,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@30-39,a2@premeno,a4@0-2,a5@no,a6@1,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@30-39,a2@premeno,a3@15-19,a4@0-2,a5@no,a6@1,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a2@ge40,a3@15-19,a4@0-2,a5@no,a9@yes>class@no', -1, (1.0, 2)),
#  ('a2@ge40,a3@15-19,a4@0-2,a5@no,a7@left,a9@yes>class@no', -1, (1.0, 1)),
#  ('a1@60-69,a2@ge40,a3@15-19,a4@0-2,a5@no,a8@left_up,a9@yes>class@no',
#   -1,
#   (1.0, 2)),
#  ('a2@ge40,a3@15-19,a4@0-2,a7@left,a9@yes>class@no', -1, (1.0, 2)),
#  ('a1@60-69,a2@ge40,a4@0-2,a5@no,a6@2,a7@left,a8@left_up,a9@yes>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@60-69,a2@ge40,a3@15-19,a4@0-2,a5@no,a6@2,a7@left,a8@left_up,a9@yes>class@no',
#   -1,
#   (1.0, 1)),
#  ('a3@15-19,a5@no,a9@yes>class@no', -1, (1.0, 3)),
#  ('a2@ge40,a3@15-19,a4@0-2,a9@yes>class@no', -1, (1.0, 3)),
#  ('a3@15-19,a4@0-2,a5@no,a6@3,a7@right,a8@left_up,a9@yes>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@60-69,a2@ge40,a3@15-19,a4@0-2,a5@no,a6@3,a7@right,a8@left_up,a9@yes>class@no',
#   -1,
#   (1.0, 1)),
#  ('a3@15-19,a5@no,a6@3,a7@right,a9@yes>class@no', -1, (1.0, 2)),
#  ('a3@15-19,a5@no,a6@3,a7@right>class@no', -1, (1.0, 3)),
#  ('a1@60-69,a2@ge40,a3@15-19,a4@0-2,a5@no,a7@right,a8@left_up>class@no',
#   -1,
#   (1.0, 3)),
#  ('a1@60-69,a2@ge40,a3@15-19,a4@0-2,a5@no,a6@2,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@60-69,a2@ge40,a3@15-19,a4@0-2,a5@no,a6@2,a7@right,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@60-69,a2@ge40,a3@15-19,a4@0-2,a5@no,a6@2,a8@left_up>class@no',
#   -1,
#   (1.0, 3)),
#  ('a3@15-19,a4@0-2,a5@no,a8@left_up>class@no', -1, (0.8333333333333334, 5)),
#  ('a3@15-19,a4@0-2,a5@no,a7@right,a8@left_up>class@no', -1, (1.0, 4)),
#  ('a3@15-19,a4@0-2,a5@no,a7@right,a8@left_up,a9@no>class@no', -1, (1.0, 3)),
#  ('a1@50-59,a3@15-19,a4@0-2,a5@no,a6@1,a9@no>class@no', -1, (1.0, 2)),
#  ('a2@ge40,a3@15-19,a4@0-2,a5@no,a6@1,a9@no>class@no', -1, (1.0, 2)),
#  ('a3@15-19,a4@0-2,a5@no,a6@1,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 3)),
#  ('a2@premeno,a3@15-19,a4@0-2,a5@no,a6@1,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 3)),
#  ('a3@15-19,a4@0-2,a5@no,a6@1,a9@no>class@no', -1, (0.8333333333333334, 5)),
#  ('a3@15-19,a4@0-2,a5@no,a6@1,a7@left,a9@no>class@no', -1, (1.0, 4)),
#  ('a1@60-69,a2@ge40,a3@15-19,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@60-69,a2@ge40,a3@15-19,a4@0-2,a5@no,a7@right>class@no', -1, (1.0, 4)),
#  ('a1@60-69,a2@ge40,a3@15-19,a4@0-2,a5@no,a6@2,a7@right,a9@no>class@no',
#   -1,
#   (1.0, 3)),
#  ('a2@ge40,a3@15-19,a4@0-2,a5@no,a7@left,a9@no>class@no', -1, (1.0, 3)),
#  ('a1@60-69,a2@ge40,a3@15-19,a4@0-2,a5@no,a7@left,a9@no>class@no',
#   -1,
#   (1.0, 3)),
#  ('a2@ge40,a3@15-19,a4@0-2,a7@left>class@no', -1, (1.0, 5)),
#  ('a2@ge40,a3@15-19,a4@0-2,a5@no,a7@left>class@no', -1, (1.0, 4)),
#  ('a1@60-69,a2@ge40,a3@15-19,a4@0-2,a5@no,a7@left>class@no', -1, (1.0, 4)),
#  ('a1@60-69,a2@ge40,a3@15-19,a4@0-2,a5@no,a6@2,a9@no>class@no', -1, (1.0, 5)),
#  ('a1@60-69,a2@ge40,a3@15-19,a4@0-2,a5@no>class@no', -1, (1.0, 8)),
#  ('a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@right,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a2@premeno,a3@15-19,a4@0-2,a5@no,a6@2,a7@right,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@premeno,a3@15-19,a4@0-2,a5@no,a6@2,a7@right,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a3@15-19,a4@0-2,a5@no,a7@right,a9@no>class@no', -1, (1.0, 4)),
#  ('a1@50-59,a4@0-2,a5@no,a6@2,a7@right,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@50-59,a3@15-19,a4@0-2,a5@no,a6@2,a7@right,a9@no>class@no', -1, (1.0, 3)),
#  ('a1@50-59,a3@15-19,a4@0-2,a5@no,a6@2,a7@right,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@50-59,a2@ge40,a3@15-19,a4@0-2,a6@2,a7@right>class@no', -1, (1.0, 2)),
#  ('a1@50-59,a2@ge40,a3@15-19,a4@0-2,a5@no,a7@right,a9@no>class@no',
#   -1,
#   (1.0, 3)),
#  ('a1@50-59,a2@ge40,a3@15-19,a4@0-2,a5@no,a6@2,a7@right,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@50-59,a2@ge40,a3@15-19,a4@0-2,a6@2>class@no', -1, (1.0, 3)),
#  ('a1@50-59,a3@15-19,a4@0-2,a5@no,a9@no>class@no',
#   -1,
#   (0.8571428571428571, 6)),
#  ('a3@15-19,a4@0-2,a5@no,a6@2,a7@right,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 3)),
#  ('a2@ge40,a3@15-19,a4@0-2,a5@no,a7@right,a9@no>class@no', -1, (1.0, 6)),
#  ('a2@ge40,a3@15-19,a4@0-2,a5@no,a6@2,a7@right,a9@no>class@no', -1, (1.0, 5)),
#  ('a3@15-19,a4@0-2,a5@no,a7@right,a9@no>class@no',
#   -1,
#   (0.8888888888888888, 8)),
#  ('a2@premeno,a3@15-19,a4@0-2,a5@no,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (0.8, 4)),
#  ('a2@ge40,a3@15-19,a4@0-2,a5@no,a9@no>class@no', -1, (1.0, 9)),
#  ('a2@ge40,a3@15-19,a4@0-2,a5@no,a6@2,a9@no>class@no', -1, (1.0, 7)),
#  ('a3@15-19,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (0.8, 4)),
#  ('a3@15-19,a4@0-2,a5@no,a6@2,a8@left_low,a9@no>class@no', -1, (0.875, 7)),
#  ('a3@15-19,a4@0-2,a5@no,a6@2,a9@no>class@no', -1, (0.8333333333333334, 10)),
#  ('a3@15-19,a4@0-2,a5@no,a8@left_low,a9@no>class@no',
#   -1,
#   (0.8333333333333334, 10)),
#  ('a3@15-19,a4@0-2,a5@no,a7@left,a8@left_low,a9@no>class@no', -1, (0.875, 7)),
#  ('a3@15-19,a4@0-2,a5@no,a9@no>class@no', -1, (0.8421052631578947, 16)),
#  ('a1@30-39,a2@premeno,a4@0-2,a5@no,a6@2,a7@right,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@30-39,a2@premeno,a3@25-29,a4@0-2,a5@no,a6@2,a7@right,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@30-39,a2@premeno,a3@25-29,a6@2,a7@right>class@no', -1, (1.0, 2)),
#  ('a1@30-39,a2@premeno,a3@25-29,a6@2>class@no', -1, (1.0, 3)),
#  ('a1@30-39,a2@premeno,a3@25-29,a6@2,a7@left,a8@left_low>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@30-39,a2@premeno,a4@0-2,a5@no,a6@2,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@30-39,a2@premeno,a3@25-29,a4@0-2,a5@no,a6@2,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@30-39,a2@premeno,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@30-39,a2@premeno,a3@25-29,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@30-39,a2@premeno,a3@25-29,a4@0-2,a5@no,a7@left,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@30-39,a2@premeno,a3@25-29,a4@0-2,a5@no,a9@no>class@no', -1, (1.0, 3)),
#  ('a1@30-39,a2@premeno,a3@25-29>class@no', -1, (0.8, 4)),
#  ('a2@premeno,a3@20-24,a5@yes,a6@2,a7@right,a8@left_up>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@30-39,a2@premeno,a4@0-2,a5@no,a6@2,a8@left_low>class@no', -1, (1.0, 3)),
#  ('a1@30-39,a2@premeno,a4@0-2,a5@no,a6@2,a7@left,a8@left_low>class@no',
#   -1,
#   (1.0, 2)),
#  ('a2@premeno,a3@20-24,a4@3-5,a5@yes,a6@2,a7@right,a8@left_up>class@no',
#   -1,
#   (1.0, 1)),
#  ('a4@3-5,a5@yes,a6@2,a7@right,a8@left_up,a9@yes>class@no', -1, (1.0, 1)),
#  ('a2@ge40,a4@3-5,a5@yes,a6@3,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a3@25-29,a4@3-5,a5@yes,a7@right>class@no', -1, (1.0, 1)),
#  ('a1@50-59,a2@ge40,a3@25-29,a4@3-5,a5@yes,a6@3,a7@right>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@premeno,a4@3-5,a6@2,a7@right>class@no', -1, (1.0, 1)),
#  ('a1@50-59,a3@25-29,a4@3-5,a7@right,a9@yes>class@no', -1, (1.0, 1)),
#  ('a1@50-59,a3@25-29,a4@3-5,a7@right>class@no', -1, (1.0, 2)),
#  ('a1@50-59,a3@25-29,a4@3-5,a7@right,a8@left_up>class@no', -1, (1.0, 2)),
#  ('a1@50-59,a4@3-5,a5@yes,a6@3,a7@right,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a4@3-5,a5@no,a6@2,a7@right,a8@left_up>class@no', -1, (1.0, 1)),
#  ('a1@50-59,a2@premeno,a3@25-29,a5@no,a6@2,a7@right,a8@left_up>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@premeno,a4@3-5,a5@no,a6@2,a7@right,a8@left_up>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@premeno,a5@no,a6@2,a9@yes>class@no', -1, (1.0, 1)),
#  ('a2@premeno,a3@25-29,a5@no,a6@2,a7@right,a9@yes>class@no', -1, (1.0, 1)),
#  ('a2@premeno,a3@25-29,a5@no,a6@2,a7@right,a8@left_up,a9@yes>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@premeno,a3@25-29,a4@3-5,a5@no,a6@2,a7@right,a8@left_up,a9@yes>class@no',
#   -1,
#   (1.0, 1)),
#  ('a3@25-29,a4@3-5,a7@right,a9@yes>class@no', -1, (1.0, 2)),
#  ('a1@50-59,a4@3-5,a5@yes,a6@2,a7@right,a8@left_up>class@no', -1, (1.0, 1)),
#  ('a1@50-59,a4@3-5,a6@2,a7@right,a8@left_up,a9@no>class@no', -1, (1.0, 1)),
#  ('a1@50-59,a4@3-5,a5@yes,a6@2,a7@right,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a3@20-24,a4@3-5,a5@yes,a6@2,a7@right,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@ge40,a3@20-24,a4@3-5,a5@yes,a6@2,a7@right,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a4@3-5,a5@yes,a7@right,a8@left_up,a9@no>class@no', -1, (1.0, 2)),
#  ('a2@premeno,a3@20-24,a4@3-5,a6@2,a7@right,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a2@premeno,a3@20-24,a4@3-5,a6@2,a7@right,a8@left_up>class@no',
#   -1,
#   (1.0, 2)),
#  ('a4@3-5,a5@yes,a6@2,a7@right,a8@left_up>class@no', -1, (1.0, 2)),
#  ('a3@20-24,a4@3-5,a5@yes,a6@2,a7@right,a8@left_up>class@no', -1, (1.0, 2)),
#  ('a3@20-24,a4@3-5,a6@2,a7@right,a8@left_up>class@no', -1, (1.0, 3)),
#  ('a2@premeno,a4@3-5,a6@2,a7@right,a8@left_up,a9@yes>class@no', -1, (1.0, 2)),
#  ('a4@3-5,a5@yes,a6@3,a7@right,a8@left_up>class@no', -1, (1.0, 2)),
#  ('a4@3-5,a5@yes,a7@right,a8@left_up>class@no', -1, (1.0, 4)),
#  ('a1@50-59,a4@3-5,a6@2,a7@right>class@no', -1, (1.0, 2)),
#  ('a1@50-59,a4@3-5,a6@2,a7@right,a8@left_up>class@no', -1, (1.0, 2)),
#  ('a4@3-5,a6@2,a7@right,a8@left_up>class@no', -1, (0.8, 4)),
#  ('a2@premeno,a3@30-34,a7@right,a8@left_low,a9@no>class@no', -1, (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@30-34,a7@right,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a2@premeno,a3@30-34,a5@yes,a6@2,a8@left_low,a9@no>class@no', -1, (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@30-34,a5@yes,a6@2,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a2@premeno,a5@yes,a7@right,a8@left_low,a9@no>class@no', -1, (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@30-34,a6@2,a7@right,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a2@premeno,a5@yes,a6@2,a7@right,a9@no>class@no', -1, (1.0, 1)),
#  ('a1@40-49,a2@premeno,a5@yes,a6@2,a7@right,a9@no>class@no', -1, (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@30-34,a5@yes,a6@2,a7@right,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a2@premeno,a4@3-5,a6@2,a7@right,a8@left_low,a9@no>class@no', -1, (1.0, 2)),
#  ('a1@40-49,a2@premeno,a4@3-5,a6@2,a7@right,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a2@premeno,a3@20-24,a4@3-5,a6@2,a7@right,a9@no>class@no', -1, (1.0, 2)),
#  ('a2@premeno,a3@20-24,a4@3-5,a6@2,a7@right,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@20-24,a5@no,a6@2,a7@right,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a2@premeno,a3@30-34,a6@2,a7@left,a8@left_low>class@no', -1, (1.0, 1)),
#  ('a2@premeno,a3@30-34,a5@yes,a6@2,a7@left,a8@left_low>class@no',
#   -1,
#   (1.0, 1)),
#  ('a2@premeno,a3@30-34,a5@yes,a6@2,a8@left_low>class@no', -1, (1.0, 2)),
#  ('a2@premeno,a3@30-34,a4@3-5,a5@yes,a6@2,a8@left_low>class@no', -1, (1.0, 2)),
#  ('a3@30-34,a4@3-5,a5@yes,a7@left,a8@left_low>class@no', -1, (1.0, 2)),
#  ('a3@30-34,a4@3-5,a5@yes,a8@left_low,a9@no>class@no', -1, (1.0, 2)),
#  ('a1@50-59,a2@premeno,a3@30-34,a6@2,a7@left,a8@left_low,a9@yes>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@premeno,a3@20-24,a5@yes,a6@2,a9@no>class@no', -1, (1.0, 1)),
#  ('a1@50-59,a2@premeno,a3@20-24,a6@2,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@premeno,a6@2,a7@left,a9@yes>class@no', -1, (1.0, 2)),
#  ('a1@50-59,a2@premeno,a6@2,a7@left,a8@left_low,a9@yes>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@50-59,a2@premeno,a4@3-5,a6@2>class@no', -1, (1.0, 4)),
#  ('a1@50-59,a4@3-5,a5@yes,a9@no>class@no', -1, (0.8, 4)),
#  ('a1@50-59,a4@3-5,a5@yes,a6@2>class@no', -1, (1.0, 5)),
#  ('a2@ge40,a4@3-5,a5@yes,a7@left,a8@left_low,a9@no>class@no', -1, (1.0, 2)),
#  ('a1@60-69,a2@ge40,a3@20-24,a4@0-2,a5@no,a6@2,a9@no>class@no', -1, (1.0, 2)),
#  ('a1@60-69,a2@ge40,a3@20-24,a4@0-2,a5@no,a6@2,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a2@ge40,a3@20-24,a4@0-2,a5@no,a6@2,a7@left,a9@no>class@no', -1, (1.0, 1)),
#  ('a1@60-69,a2@ge40,a3@20-24,a4@0-2,a5@no,a6@2,a7@left,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@60-69,a2@ge40,a3@20-24,a4@0-2,a5@no,a6@2,a7@right,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@ge40,a3@20-24,a4@0-2,a5@no,a7@right,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a3@20-24,a4@0-2,a5@no,a6@1,a7@right,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@ge40,a3@20-24,a4@0-2,a5@no,a6@1,a7@right,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a2@ge40,a3@20-24,a4@0-2,a5@no,a6@1,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a3@20-24,a4@0-2,a5@no,a6@1,a7@right,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@40-49,a2@premeno,a3@20-24,a4@0-2,a5@no,a6@1,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a4@0-2,a5@no,a6@1,a7@right,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@20-24,a4@0-2,a5@no,a6@1,a7@right,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@20-24,a4@0-2,a5@no,a6@1,a7@right,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a3@20-24,a4@0-2,a5@no,a6@1,a7@right,a9@no>class@no', -1, (1.0, 3)),
#  ('a1@40-49,a2@premeno,a3@20-24,a4@0-2,a5@no,a6@1,a9@no>class@no',
#   -1,
#   (1.0, 3)),
#  ('a1@50-59,a3@20-24,a4@0-2,a5@no,a8@left_low,a9@no>class@no', -1, (1.0, 2)),
#  ('a1@50-59,a3@20-24,a4@0-2,a5@no,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a3@20-24,a4@0-2,a5@no,a6@1,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@50-59,a2@premeno,a3@20-24,a4@0-2,a5@no,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a2@premeno,a3@20-24,a4@0-2,a5@no,a6@1,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@premeno,a3@20-24,a4@0-2,a5@no,a6@1,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a2@premeno,a3@20-24,a4@0-2,a5@no,a6@1,a7@left,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a2@premeno,a3@20-24,a4@0-2,a5@no,a6@1,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a2@premeno,a3@20-24,a4@0-2,a5@no,a6@1,a9@no>class@no', -1, (1.0, 4)),
#  ('a3@20-24,a4@0-2,a5@no,a6@1,a8@left_low,a9@no>class@no', -1, (1.0, 4)),
#  ('a3@20-24,a4@0-2,a5@no,a6@1,a7@left,a9@no>class@no', -1, (1.0, 3)),
#  ('a3@20-24,a4@0-2,a5@no,a6@1,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a3@20-24,a4@0-2,a5@no,a6@1,a9@no>class@no', -1, (1.0, 6)),
#  ('a5@yes,a6@2,a7@right,a8@left_up,a9@no>class@no', -1, (1.0, 2)),
#  ('a2@ge40,a5@yes,a6@2,a7@right,a8@left_up,a9@no>class@no', -1, (1.0, 2)),
#  ('a1@50-59,a2@ge40,a5@yes,a6@2,a7@right,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@50-59,a2@ge40,a3@20-24,a5@yes,a6@2,a7@right,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a3@20-24,a5@yes,a6@2,a7@right,a8@left_up>class@no', -1, (1.0, 3)),
#  ('a1@40-49,a2@ge40,a3@20-24,a4@0-2,a5@no,a6@3,a8@left_low>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a4@0-2,a5@no,a6@3,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@ge40,a4@0-2,a5@no,a6@3,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a2@ge40,a3@20-24,a4@0-2,a5@no,a6@3,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@ge40,a3@20-24,a4@0-2,a5@no,a6@3,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a4@0-2,a5@no,a6@3,a8@left_low>class@no', -1, (1.0, 2)),
#  ('a1@40-49,a3@20-24,a4@0-2,a5@no,a6@3,a8@left_low>class@no', -1, (1.0, 2)),
#  ('a1@50-59,a2@ge40,a4@0-2,a5@no,a6@3,a7@right,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@ge40,a3@20-24,a4@0-2,a5@no,a7@left,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a3@20-24,a4@0-2,a5@no,a6@3,a7@left,a9@no>class@no', -1, (1.0, 4)),
#  ('a2@ge40,a3@20-24,a4@0-2,a5@no,a6@3,a9@no>class@no', -1, (0.8, 4)),
#  ('a2@ge40,a3@20-24,a4@0-2,a5@no,a6@3,a7@left,a9@no>class@no', -1, (1.0, 3)),
#  ('a1@50-59,a2@premeno,a3@20-24,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@50-59,a2@ge40,a3@20-24,a4@0-2,a5@no,a6@2,a7@right,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@ge40,a3@20-24,a6@2,a7@right,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 3)),
#  ('a1@50-59,a2@ge40,a3@20-24,a4@0-2,a6@2,a7@right,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@50-59,a3@20-24,a4@0-2,a5@no,a7@left,a9@no>class@no', -1, (1.0, 3)),
#  ('a1@50-59,a2@ge40,a3@20-24,a4@0-2,a7@right,a9@no>class@no', -1, (0.8, 4)),
#  ('a1@50-59,a2@ge40,a3@20-24,a4@0-2,a9@no>class@no',
#   -1,
#   (0.8571428571428571, 6)),
#  ('a1@50-59,a2@ge40,a3@20-24,a4@0-2,a5@no,a9@no>class@no',
#   -1,
#   (0.8333333333333334, 5)),
# ...
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a3@30-34,a4@0-2,a5@no,a7@left,a8@left_up>class@no', -1, (1.0, 2)),
#  ('a2@premeno,a3@30-34,a4@0-2,a5@no,a6@3,a7@left,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@30-34,a4@0-2,a5@no,a6@3,a7@left,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a3@30-34,a4@0-2,a5@no,a8@left_up>class@no', -1, (1.0, 3)),
#  ('a1@40-49,a2@premeno,a3@30-34,a4@0-2,a5@no,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@50-59,a2@ge40,a3@30-34,a4@0-2,a5@no,a6@3,a7@right,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@ge40,a4@0-2,a5@no,a6@3,a7@right,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@ge40,a3@30-34,a4@0-2,a5@no,a6@3,a7@right,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@ge40,a3@30-34,a4@0-2,a5@no,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@50-59,a2@ge40,a3@30-34,a4@0-2,a5@no,a7@right,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a3@30-34,a7@right,a8@left_low,a9@no>class@no', -1, (1.0, 3)),
#  ('a1@50-59,a2@premeno,a4@0-2,a5@no,a6@3,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@premeno,a3@30-34,a4@0-2,a5@no,a6@3,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 1)),
#  ('a2@premeno,a3@30-34,a8@left_low,a9@no>class@no', -1, (0.8, 4)),
#  ('a1@50-59,a3@30-34,a4@0-2,a5@no,a8@left_low,a9@no>class@no', -1, (1.0, 3)),
#  ('a1@50-59,a2@ge40,a3@30-34,a8@left_low>class@no', -1, (0.8, 4)),
#  ('a2@ge40,a3@30-34,a4@0-2,a5@no,a8@left_low>class@no', -1, (1.0, 5)),
#  ('a2@ge40,a3@30-34,a4@0-2,a5@no,a8@left_low,a9@no>class@no', -1, (1.0, 4)),
#  ('a3@30-34,a4@0-2,a5@no,a7@left,a8@left_low>class@no', -1, (0.875, 7)),
#  ('a3@30-34,a4@0-2,a5@no,a7@left,a8@left_low,a9@no>class@no', -1, (1.0, 6)),
#  ('a1@50-59,a3@30-34,a4@0-2,a5@no,a8@left_up,a9@no>class@no', -1, (1.0, 2)),
#  ('a3@30-34,a4@0-2,a5@no,a6@3,a8@left_up,a9@no>class@no', -1, (1.0, 2)),
#  ('a2@ge40,a3@30-34,a4@0-2,a5@no,a7@left,a8@left_up>class@no', -1, (1.0, 4)),
#  ('a2@ge40,a3@30-34,a4@0-2,a5@no,a7@left,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 3)),
#  ('a3@30-34,a4@0-2,a5@no,a7@left,a8@left_up>class@no',
#   -1,
#   (0.8571428571428571, 6)),
#  ('a3@30-34,a4@0-2,a5@no,a7@left,a8@left_up,a9@no>class@no',
#   -1,
#   (0.8333333333333334, 5)),
#  ('a3@30-34,a4@0-2,a5@no,a8@left_up,a9@no>class@no', -1, (0.8, 8)),
#  ('a1@50-59,a2@ge40,a3@30-34,a4@0-2,a5@no,a7@right,a9@no>class@no',
#   -1,
#   (1.0, 4)),
#  ('a1@50-59,a3@30-34,a4@0-2,a5@no,a9@no>class@no', -1, (0.8, 8)),
#  ('a2@ge40,a3@30-34,a4@0-2,a5@no,a7@right,a9@no>class@no',
#   -1,
#   (0.8333333333333334, 5)),
#  ('a2@ge40,a3@30-34,a4@0-2,a5@no,a7@left,a9@no>class@no',
#   -1,
#   (0.8333333333333334, 5)),
#  ('a2@ge40,a3@30-34,a4@0-2,a5@no,a7@left>class@no', -1, (0.875, 7)),
#  ('a3@30-34,a4@0-2,a5@no,a7@left>class@no', -1, (0.8, 16)),
#  ('a3@30-34,a4@0-2,a5@no,a7@left,a9@no>class@no',
#   -1,
#   (0.8235294117647058, 14)),
#  ('a4@0-2,a5@no,a6@2,a7@left,a8@left_up,a9@yes>class@no', -1, (1.0, 3)),
#  ('a2@ge40,a4@0-2,a5@no,a7@left,a8@left_up,a9@yes>class@no', -1, (1.0, 2)),
#  ('a2@ge40,a4@0-2,a5@no,a6@2,a7@left,a8@left_up,a9@yes>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@40-49,a2@premeno,a6@3,a7@right,a8@left_up,a9@yes>class@no',
#   -1,
#   (1.0, 3)),
#  ('a1@40-49,a2@premeno,a7@right,a8@left_up,a9@yes>class@no', -1, (1.0, 4)),
#  ('a4@0-2,a5@no,a6@2,a8@left_up,a9@yes>class@no', -1, (1.0, 5)),
#  ('a2@ge40,a4@0-2,a5@no,a6@2,a8@left_up,a9@yes>class@no', -1, (1.0, 4)),
#  ('a6@2,a7@right,a8@left_up,a9@yes>class@no', -1, (0.875, 7)),
#  ('a2@premeno,a6@2,a7@right,a8@left_up,a9@yes>class@no', -1, (0.8, 4)),
#  ('a1@40-49,a2@premeno,a6@3,a7@right,a9@yes>class@no', -1, (1.0, 6)),
#  ('a1@40-49,a2@premeno,a7@right,a9@yes>class@no', -1, (0.8181818181818182, 9)),
#  ('a4@0-2,a5@no,a6@2,a9@yes>class@no', -1, (0.8181818181818182, 9)),
#  ('a1@50-59,a2@ge40,a4@0-2,a5@no,a6@1,a7@left,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a2@ge40,a4@0-2,a5@no,a6@1,a7@left,a8@left_up,a9@no>class@no', -1, (1.0, 5)),
#  ('a1@40-49,a2@premeno,a4@0-2,a5@no,a6@1,a7@right,a8@left_up,a9@no>class@no',
#   -1,
#   (0.8, 4)),
#  ('a1@40-49,a2@premeno,a4@0-2,a5@no,a6@1,a7@right,a8@left_low>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@40-49,a2@premeno,a4@0-2,a5@no,a6@1,a7@left,a9@no>class@no',
#   -1,
#   (0.8, 4)),
#  ('a1@40-49,a2@premeno,a4@0-2,a5@no,a6@1,a7@right,a9@no>class@no',
#   -1,
#   (0.8888888888888888, 8)),
#  ('a1@50-59,a4@0-2,a5@no,a6@1,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 5)),
#  ('a1@50-59,a2@premeno,a4@0-2,a5@no,a6@1,a9@no>class@no',
#   -1,
#   (0.8571428571428571, 6)),
#  ('a1@50-59,a2@ge40,a4@0-2,a5@no,a6@1,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 3)),
#  ('a1@50-59,a4@0-2,a5@no,a6@1,a8@left_low,a9@no>class@no', -1, (1.0, 7)),
#  ('a1@50-59,a2@ge40,a4@0-2,a5@no,a6@1,a7@right,a9@no>class@no', -1, (1.0, 8)),
#  ('a1@50-59,a4@0-2,a5@no,a6@1,a7@left,a9@no>class@no', -1, (1.0, 8)),
#  ('a1@50-59,a2@ge40,a4@0-2,a5@no,a6@1,a7@left,a9@no>class@no', -1, (1.0, 3)),
#  ('a1@50-59,a2@ge40,a4@0-2,a5@no,a6@1,a9@no>class@no', -1, (1.0, 11)),
#  ('a1@50-59,a4@0-2,a5@no,a6@1,a9@no>class@no', -1, (0.9444444444444444, 17)),
#  ('a2@ge40,a6@1,a7@right,a8@left_low>class@no', -1, (1.0, 4)),
#  ('a2@ge40,a4@0-2,a5@no,a6@1,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 3)),
#  ('a2@ge40,a4@0-2,a5@no,a6@1,a8@left_low,a9@no>class@no', -1, (1.0, 6)),
#  ('a2@ge40,a4@0-2,a5@no,a6@1,a7@left,a9@no>class@no', -1, (1.0, 9)),
#  ('a2@ge40,a4@0-2,a5@no,a6@1,a7@right>class@no', -1, (0.9166666666666666, 11)),
#  ('a2@ge40,a4@0-2,a5@no,a6@1,a7@right,a9@no>class@no', -1, (1.0, 11)),
#  ('a2@ge40,a4@0-2,a5@no,a6@1,a9@no>class@no', -1, (1.0, 20)),
#  ('a2@premeno,a4@0-2,a5@no,a6@1,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (0.875, 7)),
#  ('a2@premeno,a4@0-2,a5@no,a6@1,a8@left_low,a9@no>class@no',
#   -1,
#   (0.8181818181818182, 9)),
#  ('a4@0-2,a5@no,a6@1,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (0.9166666666666666, 11)),
#  ('a4@0-2,a5@no,a6@1,a8@left_low,a9@no>class@no',
#   -1,
#   (0.8888888888888888, 16)),
#  ('a4@0-2,a5@no,a6@1,a7@right,a9@no>class@no', -1, (0.84, 21)),
#  ('a2@premeno,a4@0-2,a5@no,a6@1,a7@left,a9@no>class@no',
#   -1,
#   (0.8571428571428571, 12)),
#  ('a4@0-2,a5@no,a6@1,a7@left,a9@no>class@no', -1, (0.92, 23)),
#  ('a4@0-2,a5@no,a6@1,a9@no>class@no', -1, (0.88, 44)),
#  ('a2@ge40,a6@3,a7@left,a8@left_up,a9@no>class@no', -1, (1.0, 3)),
#  ('a4@0-2,a5@no,a6@3,a7@left,a8@left_up,a9@no>class@no', -1, (0.8, 4)),
#  ('a1@50-59,a2@ge40,a6@3,a8@left_up>class@no', -1, (0.875, 7)),
#  ('a1@50-59,a6@3,a8@left_up,a9@no>class@no', -1, (0.875, 7)),
#  ('a1@50-59,a2@ge40,a6@3,a8@left_up,a9@no>class@no',
#   -1,
#   (0.8571428571428571, 6)),
#  ('a1@50-59,a2@ge40,a4@0-2,a5@no,a6@3,a7@right,a9@no>class@no', -1, (1.0, 2)),
#  ('a1@50-59,a2@ge40,a4@0-2,a5@no,a6@3,a7@left,a9@no>class@no',
#   -1,
#   (0.8333333333333334, 5)),
#  ('a1@50-59,a2@ge40,a4@0-2,a5@no,a6@3,a9@no>class@no', -1, (0.875, 7)),
#  ('a1@50-59,a4@0-2,a5@no,a6@3,a9@no>class@no', -1, (0.8181818181818182, 9)),
#  ('a2@ge40,a4@0-2,a5@no,a6@3,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (1.0, 3)),
#  ('a2@ge40,a4@0-2,a5@no,a6@3,a7@left,a9@no>class@no', -1, (0.875, 7)),
#  ('a1@50-59,a2@premeno,a5@no,a6@2,a7@right,a8@left_up>class@no', -1, (1.0, 3)),
#  ('a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@right,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@50-59,a2@premeno,a5@no,a6@2,a8@left_up>class@no', -1, (1.0, 4)),
#  ('a1@50-59,a2@premeno,a4@0-2,a6@2,a8@left_up,a9@no>class@no', -1, (1.0, 4)),
#  ('a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 3)),
#  ('a1@50-59,a2@premeno,a5@no,a7@right,a8@left_up>class@no', -1, (0.8, 4)),
#  ('a1@50-59,a2@premeno,a4@0-2,a5@no,a8@left_up,a9@no>class@no', -1, (0.8, 4)),
#  ('a1@50-59,a2@premeno,a4@0-2,a8@left_up,a9@no>class@no',
#   -1,
#   (0.8333333333333334, 5)),
#  ('a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@right,a9@no>class@no',
#   -1,
#   (1.0, 4)),
#  ('a1@50-59,a2@premeno,a4@0-2,a5@no,a7@right,a9@no>class@no',
#   -1,
#   (0.8333333333333334, 5)),
#  ('a1@50-59,a2@premeno,a6@2,a9@no>class@no', -1, (0.8, 8)),
#  ('a1@50-59,a2@ge40,a6@2,a8@left_up,a9@no>class@no', -1, (1.0, 5)),
#  ('a1@50-59,a2@ge40,a6@2,a7@right,a8@left_up,a9@no>class@no', -1, (1.0, 4)),
#  ('a1@50-59,a4@0-2,a6@2,a7@right,a8@left_up,a9@no>class@no', -1, (1.0, 5)),
#  ('a1@50-59,a4@0-2,a5@no,a6@2,a7@right,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 4)),
#  ('a1@50-59,a4@0-2,a5@no,a6@2,a8@left_up,a9@no>class@no', -1, (1.0, 6)),
#  ('a1@50-59,a6@2,a8@left_up,a9@no>class@no', -1, (1.0, 9)),
#  ('a1@50-59,a4@0-2,a6@2,a8@left_up,a9@no>class@no', -1, (1.0, 8)),
#  ('a1@50-59,a4@0-2,a6@2,a7@left,a8@left_up,a9@no>class@no', -1, (1.0, 3)),
#  ('a1@50-59,a4@0-2,a5@no,a6@2,a7@left,a8@left_up,a9@no>class@no',
#   -1,
#   (1.0, 2)),
#  ('a1@50-59,a2@ge40,a7@right,a8@left_up,a9@no>class@no',
#   -1,
#   (0.8888888888888888, 8)),
#  ('a1@50-59,a5@no,a7@right,a8@left_up,a9@no>class@no', -1, (0.8, 8)),
#  ('a1@50-59,a4@0-2,a5@no,a7@right,a8@left_up,a9@no>class@no',
#   -1,
#   (0.8888888888888888, 8)),
#  ('a1@50-59,a7@right,a8@left_up,a9@no>class@no', -1, (0.8571428571428571, 12)),
#  ('a1@50-59,a2@ge40,a8@left_up,a9@no>class@no', -1, (0.9333333333333333, 14)),
#  ('a1@50-59,a8@left_up,a9@no>class@no', -1, (0.8695652173913043, 20)),
#  ('a1@50-59,a2@ge40,a8@left_low,a9@no>class@no', -1, (0.8571428571428571, 12)),
#  ('a1@50-59,a7@left,a8@left_low,a9@no>class@no', -1, (0.8, 16)),
#  ('a1@50-59,a2@ge40,a4@0-2,a6@2,a7@right,a9@no>class@no',
#   -1,
#   (0.8571428571428571, 6)),
#  ('a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@right,a9@no>class@no',
#   -1,
#   (0.8333333333333334, 5)),
#  ('a1@50-59,a2@ge40,a6@2,a7@right,a9@no>class@no', -1, (0.875, 7)),
#  ('a1@50-59,a6@2,a7@right,a9@no>class@no', -1, (0.9166666666666666, 11)),
#  ('a1@50-59,a4@0-2,a5@no,a6@2,a7@right,a9@no>class@no', -1, (0.9, 9)),
#  ('a1@50-59,a2@ge40,a6@2,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (0.8333333333333334, 5)),
#  ('a1@50-59,a6@2,a7@left,a8@left_low>class@no', -1, (0.8333333333333334, 10)),
#  ('a1@50-59,a2@ge40,a6@2,a7@left,a9@no>class@no', -1, (0.875, 7)),
#  ('a1@50-59,a2@ge40,a6@2,a9@no>class@no', -1, (0.875, 14)),
#  ('a1@50-59,a2@ge40,a4@0-2,a5@no,a7@right,a9@no>class@no', -1, (0.9375, 15)),
#  ('a1@50-59,a2@ge40,a7@right,a9@no>class@no', -1, (0.8636363636363636, 19)),
#  ('a1@50-59,a5@no,a7@right,a9@no>class@no', -1, (0.875, 21)),
#  ('a1@50-59,a4@0-2,a5@no,a7@right,a9@no>class@no',
#   -1,
#   (0.9130434782608695, 21)),
#  ('a1@50-59,a7@right,a9@no>class@no', -1, (0.8333333333333334, 25)),
#  ('a1@50-59,a2@ge40,a7@left,a9@no>class@no', -1, (0.8, 16)),
#  ('a1@50-59,a4@0-2,a5@no,a7@left,a9@no>class@no',
#   -1,
#   (0.8148148148148148, 22)),
#  ('a1@50-59,a2@ge40,a9@no>class@no', -1, (0.8333333333333334, 35)),
#  ('a1@50-59,a4@0-2,a5@no,a9@no>class@no', -1, (0.86, 43)),
#  ('a1@40-49,a2@premeno,a5@no,a6@2,a8@left_up>class@no', -1, (0.8, 8)),
#  ('a1@40-49,a4@0-2,a5@no,a6@2,a8@left_up>class@no', -1, (0.8, 8)),
#  ('a1@40-49,a2@premeno,a4@0-2,a5@no,a6@2,a8@left_up>class@no', -1, (0.875, 7)),
#  ('a1@40-49,a2@premeno,a4@0-2,a5@no,a6@2,a8@left_up,a9@no>class@no',
#   -1,
#   (0.8571428571428571, 6)),
#  ('a1@40-49,a2@premeno,a5@no,a7@right,a8@left_up,a9@no>class@no',
#   -1,
#   (0.8181818181818182, 9)),
#  ('a1@40-49,a2@premeno,a4@0-2,a5@no,a8@left_up>class@no', -1, (0.8125, 13)),
#  ('a1@40-49,a2@premeno,a4@0-2,a5@no,a7@right,a8@left_up,a9@no>class@no',
#   -1,
#   (0.8888888888888888, 8)),
#  ('a4@0-2,a5@no,a6@2,a7@left,a8@left_up>class@no',
#   -1,
#   (0.8333333333333334, 10)),
#  ('a2@ge40,a4@0-2,a6@2,a8@left_up>class@no', -1, (0.9285714285714286, 13)),
#  ('a2@ge40,a4@0-2,a5@no,a6@2,a8@left_up>class@no',
#   -1,
#   (0.9230769230769231, 12)),
#  ('a2@ge40,a7@right,a8@left_up,a9@no>class@no', -1, (0.8, 12)),
#  ('a2@premeno,a5@no,a6@2,a7@right,a8@left_up>class@no', -1, (0.8, 8)),
#  ('a2@premeno,a4@0-2,a5@no,a6@2,a8@left_up,a9@no>class@no',
#   -1,
#   (0.8333333333333334, 10)),
#  ('a4@0-2,a5@no,a6@2,a7@right,a8@left_up>class@no',
#   -1,
#   (0.9285714285714286, 13)),
#  ('a5@no,a6@2,a7@right,a8@left_up,a9@no>class@no',
#   -1,
#   (0.8571428571428571, 12)),
#  ('a4@0-2,a5@no,a6@2,a7@right,a8@left_up,a9@no>class@no',
#   -1,
#   (0.9166666666666666, 11)),
#  ('a5@no,a6@2,a7@right,a8@left_up>class@no', -1, (0.8333333333333334, 15)),
#  ('a4@0-2,a5@no,a6@2,a8@left_up,a9@no>class@no', -1, (0.8571428571428571, 18)),
#  ('a4@0-2,a5@no,a6@2,a8@left_up>class@no', -1, (0.8846153846153846, 23)),
#  ('a5@no,a6@2,a8@left_up>class@no', -1, (0.8333333333333334, 25)),
#  ('a4@0-2,a5@no,a7@right,a8@left_up,a9@no>class@no',
#   -1,
#   (0.8076923076923077, 21)),
#  ('a4@0-2,a5@no,a8@left_up,a9@no>class@no', -1, (0.8043478260869565, 37)),
#  ('a4@0-2,a5@no,a8@left_up>class@no', -1, (0.8, 44)),
#  ('a1@40-49,a2@ge40,a4@0-2,a5@no,a6@2,a7@left>class@no', -1, (1.0, 2)),
#  ('a1@40-49,a2@premeno,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (0.8, 4)),
#  ('a1@40-49,a2@premeno,a4@0-2,a5@no,a7@right,a9@no>class@no', -1, (0.84, 21)),
#  ('a1@40-49,a2@premeno,a4@0-2,a5@no,a7@right>class@no',
#   -1,
#   (0.8275862068965517, 24)),
#  ('a4@0-2,a5@no,a6@2,a7@left,a8@left_low>class@no', -1, (0.84, 21)),
#  ('a4@0-2,a5@no,a6@2,a7@left,a8@left_low,a9@no>class@no', -1, (0.85, 17)),
#  ('a5@no,a6@2,a7@left,a8@left_low>class@no', -1, (0.8076923076923077, 21)),
#  ('a4@0-2,a5@no,a6@2,a8@left_low,a9@no>class@no',
#   -1,
#   (0.8064516129032258, 25)),
#  ('a4@0-2,a5@no,a7@left,a8@left_low,a9@no>class@no',
#   -1,
#   (0.8461538461538461, 33)),
#  ('a4@0-2,a5@no,a8@left_low,a9@no>class@no', -1, (0.8135593220338984, 48)),
#  ('a2@ge40,a4@0-2,a5@no,a6@2,a7@left>class@no', -1, (0.9473684210526315, 18)),
#  ('a2@ge40,a4@0-2,a5@no,a7@right,a9@no>class@no', -1, (0.8, 24)),
#  ('a4@0-2,a5@no,a6@2,a7@right,a9@no>class@no', -1, (0.8285714285714286, 29)),
#  ('a6@2,a7@right,a9@no>class@no', -1, (0.813953488372093, 35)),
#  ('a4@0-2,a5@no,a6@2,a7@left,a9@no>class@no', -1, (0.8378378378378378, 31)),
#  ('a4@0-2,a5@no,a6@2,a7@left>class@no', -1, (0.8444444444444444, 38)),
#  ('a5@no,a6@2>class@no', -1, (0.8, 72)),
#  ('a4@0-2,a5@no,a6@2>class@no', -1, (0.8313253012048193, 69)),
#  ('a4@0-2,a5@no,a7@right,a9@no>class@no', -1, (0.8, 56)),
#  ('a4@0-2,a5@no,a7@left,a9@no>class@no', -1, (0.825, 66)),
#  ('a4@0-2,a5@no,a9@no>class@no', -1, (0.8133333333333334, 122)),
#  ('a2@ge40,a3@20-24,a5@yes,a8@left_low>class@yes', -1, (1.0, 1)),
#  ('a2@ge40,a3@20-24,a5@yes,a7@left,a8@left_low>class@yes', -1, (1.0, 1)),
#  ('a2@ge40,a3@20-24,a5@yes,a6@3,a7@left,a8@left_low>class@yes', -1, (1.0, 1)),
#  ('a2@ge40,a3@20-24,a6@3,a7@left,a8@left_low,a9@yes>class@yes', -1, (1.0, 1)),
#  ('a1@60-69,a2@ge40,a6@3,a7@left,a8@left_low,a9@yes>class@yes', -1, (1.0, 1)),
#  ('a1@60-69,a2@ge40,a3@20-24,a6@3,a7@left,a8@left_low,a9@yes>class@yes',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@ge40,a6@3,a7@left,a9@yes>class@yes', -1, (1.0, 1)),
#  ('a1@40-49,a5@yes,a6@3,a7@left,a9@yes>class@yes', -1, (1.0, 1)),
#  ('a2@ge40,a3@15-19,a7@left,a8@left_low,a9@yes>class@yes', -1, (1.0, 1)),
#  ('a2@ge40,a3@15-19,a6@1,a7@left,a8@left_low>class@yes', -1, (1.0, 1)),
#  ('a1@60-69,a2@ge40,a4@0-2,a5@no,a6@3,a7@right,a8@left_up,a9@no>class@yes',
#   -1,
#   (1.0, 1)),
#  ('a1@60-69,a2@ge40,a3@50-54,a4@0-2,a5@no,a6@3,a7@right,a8@left_up,a9@no>class@yes',
#   -1,
#   (1.0, 1)),
#  ('a2@premeno,a3@30-34,a5@yes,a6@3,a7@left,a9@no>class@yes', -1, (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@30-34,a5@yes,a6@3,a7@left,a9@no>class@yes',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@30-34,a5@yes,a6@3,a7@left,a8@left_low,a9@no>class@yes',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@30-34,a4@15-17,a5@yes,a6@3,a7@left,a8@left_low,a9@no>class@yes',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@15-19,a5@yes,a6@3,a7@left,a8@left_low,a9@no>class@yes',
#   -1,
#   (1.0, 1)),
#  ('a1@40-49,a2@premeno,a3@15-19,a4@15-17,a5@yes,a6@3,a7@left,a8@left_low,a9@no>class@yes',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@premeno,a6@3,a7@right,a9@no>class@yes', -1, (1.0, 1)),
#  ('a1@50-59,a2@premeno,a6@3,a7@right,a8@right_up,a9@no>class@yes',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@premeno,a5@yes,a6@3,a7@right,a8@right_up,a9@no>class@yes',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@premeno,a3@35-39,a5@yes,a6@3,a7@right,a8@right_up,a9@no>class@yes',
#   -1,
#   (1.0, 1)),
#  ('a1@50-59,a2@premeno,a3@35-39,a4@15-17,a5@yes,a6@3,a7@right,a8@right_up,a9@no>class@yes',
#   -1,
#   (1.0, 1)),
#  ('a2@premeno,a5@yes,a6@3,a7@left,a9@no>class@yes', -1, (1.0, 2)),
#  ...]

# %%
with open('rules_with_clusters.txt', 'w') as f:
  f.write("\n".join(str(v) for v in rules_and_their_clusters))

# %% [markdown]
# Finding Unexpected rules

# %%
print('Finding unexpected patterns ....')
# Out:
# Finding unexpected patterns ....

# %%
unexpected_rules = clustering_engine.detect_unexpectedness(cluster_labels)
# Out:
# Geting conflict information...
# 2429 255
# Finding unexpectedness....
# Number of unexpected patterns 325

# %%
with open('unexpected_rules.txt', 'w') as f:
  f.write("\n".join(str(v) for v in unexpected_rules))

# %%
#with json format

# %%
#IO helper

# %%
import json
import numpy as np

class IOHelper:

    @staticmethod
    def write_file_in_lines(file_name, data, header = None):
        with open(file_name, "w") as text_file:
            if header is not None:
                text_file.write(header)
                text_file.write('\n')
            for transaction in data:
                text_file.write(transaction)
                text_file.write('\n')
    
    @staticmethod        
    def read_file_in_lines(inputfile, has_header = False):
        data = []
        with open(inputfile, "r") as text_file:
            file_iter = iter(text_file)
            if has_header == True:
                next(file_iter)
            
            for line in file_iter:
                data.append(line.strip())
        return data
    
    @staticmethod
    def read_ranking_file(input_file):
        patterns = []
        ranking = []
        k = 0
        with open(input_file, "r") as text_file:
            for line in text_file:
                subStrings = line.split(';')
                rule_key = subStrings[0].strip()
                patterns.append(rule_key)
                ranking.append([])
                for v in subStrings[1:]:
                    r = int(v)
                    ranking[k].append(r)
                
                k += 1
                if k % 1000 == 0: print(str(k))
        return patterns, np.array(ranking)
    
    @staticmethod 
    def save_as_json_format(file_name, o):
        with open (file_name, 'w') as text_file:
            json.dump(o, text_file)
            
    @staticmethod 
    def save_as_json_format_in_line(file_name, o):
        with open (file_name, 'w') as text_file:
            #json.dump(o, text_file)
            for item in o:
                line = json.dumps(item)
                text_file.write(line)
                text_file.write('\n')
            
    @staticmethod        
    def load_json_object(file_name):
        with open(file_name, 'r') as text_file:
            o = json.load(text_file)
            return o
    
    @staticmethod    
    def write_matrix(file_name, matrix):
        with open(file_name, "w") as text_file:
            for line in matrix:
                text_file.write(','.join(str(x) for x in line.tolist()))
                text_file.write('\n')
    
    @staticmethod
    def write_list_of_tuples(file_name, tuples_list):
        with open(file_name, 'w') as writer:
            for rule in tuples_list:
                writer.write(str(rule))
                writer.write('\n')

# %%
IOHelper.save_as_json_format('unexpected_rule_file_json', unexpected_rules)

# %% [markdown]
# Plotting in 3D

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

#from sklearn.decomposition.kernel_pca import KernelPCA
from sklearn.decomposition.incremental_pca import IncrementalPCA

# %%
def load_feature_vectors(input_file):
    features = []
    association_rules = []
    
    with open(input_file, 'r') as feature_reader:
        feature_reader.readline()
        feature_reader.readline()
        for line in feature_reader:
            rule_text, f_vector = json.loads(line.strip())
            association_rules.append(rule_text)
            features.append(f_vector)
    return np.array(features), association_rules

# %%
def load_clusters(input_file):
    
    number_of_cluster = -1
    clusters_dict = {}
    with open(input_file, 'r') as clusters_reader:
        for line in clusters_reader:
            sub_strings = line.split('\'')
            rule_text = sub_strings[1].strip('(\' ')
            temp = sub_strings[2].split(',')
            
            cluster_id = int(temp[1])
            clusters_dict[rule_text] = cluster_id
            
            if cluster_id > number_of_cluster: number_of_cluster = cluster_id
    return clusters_dict, cluster_id + 1

# %%
import colorsys

def get_N_HexCol(N=5):

    HSV_tuples = [(x * 1.0 / N, 1, 1) for x in range(N)]
    hex_out = []
    for rgb in HSV_tuples:
        rgb = map(lambda x: int(x * 255), colorsys.hsv_to_rgb(*rgb))
        hex_out.append('#%02x%02x%02x' % tuple(rgb))
    #print(hex_out)
    return hex_out

# %%
X, association_rules = load_feature_vectors("/content/miner.tmp.non_redundant_rules")

# %%
m = 2
print('dimensional reduce: ' + str(m))
    
pca = IncrementalPCA(n_components = X.shape[1]//m)
new_X = pca.fit_transform(X)
clusters, number_of_clusters = load_clusters("/content/rules_with_clusters.txt")
print (number_of_clusters)
    
unique_colors = get_N_HexCol(number_of_clusters + 1)
Y = []
for rule in association_rules:
  cluster_id = clusters[rule]
  Y.append(unique_colors[cluster_id + 1])
# Out:
# dimensional reduce: 2
# 254

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.text2D(0.5, 0.95, 'Optics3D', transform=ax.transAxes)
ax.scatter(new_X[:,0], new_X[:,1], new_X[:,2], c = Y, alpha = 0.9, s = 5)
plt.show()

# %% [markdown]
# More Plotting

# %%
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
import numpy as np

# %%
reduced_rate =0.5
        
ncomponents = int(X_train.shape[1] * reduced_rate)
pca = IncrementalPCA(n_components = ncomponents)
data = pca.fit_transform(X_train) 
        
        
db  = OPTICS(min_samples=20).fit(data)
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
        
labels = db.labels_
Y = labels
n_clusters = len(set(Y))- (1 if -1 in Y else 0)
n_noises = list(Y).count(-1)
print('Number of clusters' + str(n_clusters))
print('Number of noises' + str(n_noises))
# Out:
# Number of clusters1
# Number of noises688

# %%
plt.figure(figsize=(20, 14))
G = gridspec.GridSpec(2, 3)
ax2 = plt.subplot(G[1, 0])

# OPTICS
colors = ['g.', 'r.', 'b.', 'y.', 'c.']
for klass, color in zip(range(0, 5), colors):
    Xk = X_train[db.labels_ == klass]
    ax2.plot(Xk[:, 0], Xk[:, 1], color, alpha=0.3)
ax2.plot(X_train[db.labels_ == -1, 0], X_train[db.labels_ == -1, 1], 'k+', alpha=0.1)
ax2.set_title('Automatic Clustering\nOPTICS')
# Out:
# Text(0.5, 1.0, 'Automatic Clustering\nOPTICS')

# %%
from sklearn.metrics.ranking import roc_curve, auc
from sklearn.metrics.classification import f1_score
from sklearn.svm.classes import SVC
from sklearn.ensemble.forest import RandomForestClassifier

# %%
class AssociationRule:
    def __init__(self, left, right):
        self.left_items = left
        self.right_items = right
        self.scores = []
        
    def length(self):
        return len(self.left_items) + len(self.right_items)
     
    def score(self, index):
        return self.scores[index]
    
    def lhs_string(self):
        return itemset_2_string(self.left_items)
        
    def rhs_string(self):
        return itemset_2_string(self.right_items)
    
    def serialize(self):
        left_key = self.lhs_string()
        right_key = self.rhs_string()
        return left_key + ">" + right_key
    
    @staticmethod        
    def string_2_rule(s):
        subStrings = s.split(">")
        left = string_2_itemset(subStrings[0].strip())
        right = string_2_itemset(subStrings[1].strip())
        #print("AssociationRule(left, right",AssociationRule(left, right))
        return AssociationRule(left, right)

    def append_score(self, score):
        self.scores.append(score)
        
    def get_itemset(self):
        itemset = []
        itemset.extend(self.left_items)
        itemset.extend(self.right_items)
        itemset.sort()
        return itemset
        
        
    def rule_itemset_2_string(self):
        itemset = self.get_itemset()
        return itemset_2_string(itemset)
    
    def compute_basic_probs(self,frequent_itemsets, nTransactions):  
        
        left = frequent_itemsets[self.lhs_string()]
        right = frequent_itemsets[self.rhs_string()]
        
        both = frequent_itemsets[self.rule_itemset_2_string()]
        
        vector = {}
        
        ''' 1. P(A)'''
        p_A = left/nTransactions
        vector['A'] = p_A
        
        ''' 2. P(B)'''
        p_B = right/nTransactions
        vector['B'] = p_B
        
        ''' 3. P(~A)'''
        p_not_A = 1 - p_A
        vector['~A'] = p_not_A
        
        ''' 4. P(~B)'''
        p_not_B = 1 - p_B
        vector['~B'] = p_not_B
        
        ''' 5. P(AB) '''
        p_A_and_B = both/nTransactions
        vector['AB'] = p_A_and_B
        
        ''' 6. P(~AB)'''
        p_not_A_and_B = (right - both)/nTransactions
        vector['~AB'] = p_not_A_and_B
        
        ''' 7. P(A~B)'''
        p_A_and_not_B = (left - both)/nTransactions
        vector['A~B'] = p_A_and_not_B
        
        ''' 8. P(~A~B)'''
        p_not_A_and_not_B = 1 - (left + right - both)/nTransactions
        vector['~A~B'] = p_not_A_and_not_B 
        
        '''
        9. P(A|B)
        '''
        p_A_if_B = p_A_and_B / p_B
        vector['A|B'] = p_A_if_B
        
        '''
        10. P(~A|~B)
        '''
        p_not_A_if_not_B = p_not_A_and_not_B / p_not_B
        vector['~A|~B'] = p_not_A_if_not_B
        
        '''
        11. P(A|~B)
        '''
        p_A_if_not_B = p_A_and_not_B/p_not_B
        vector['A|~B'] = p_A_if_not_B
        
        '''
        12. p(~A|B)
        '''
        p_not_A_if_B = p_not_A_and_B / p_B
        vector['~A|B'] = p_not_A_if_B
        
        '''
        13. P(B|A)
        '''
        p_B_if_A = p_A_and_B / p_A
        vector['B|A'] = p_B_if_A
        
        '''
        14. P(~B|~A)
        '''
        p_not_B_if_not_A = p_not_A_and_not_B / p_not_A
        vector['~B|~A'] = p_not_B_if_not_A
        
        '''
        15. P(B|~A)
        '''
        p_B_if_not_A = p_not_A_and_B/p_not_A
        vector['B|~A'] = p_B_if_not_A
        
        '''
        16. p(~B|A)
        '''
        p_not_B_if_A = p_A_and_not_B / p_A
        vector['~B|A'] = p_not_B_if_A
        
        return vector
    
    def is_redundant_(self, bits, k, itemset, freq_itemset_dict): 
        '''
        Run out of items --> create rule and check format criterion
        '''
        if k >= len(itemset):
            items_1 = []
            items_2 = []
            for index in range(len(bits)):
                if bits[index] == True:
                    items_1.append(itemset[index])
                else:
                    items_2.append(itemset[index])
            for item in items_2:
                rule = AssociationRule(items_1, [item])
                confidence = freq_itemset_dict.getConfidence(rule)
                if confidence == 1: return True
            return False 
      
        value_domain = [True, False]
        for value in value_domain:
            bits[k] = value
            checker = self.is_redundant_(bits, k+1, itemset, freq_itemset_dict)
            if checker == True: return True
            bits[k] = True    
        return False
    
    '''
    Expand an item-set with equivalent items.
    '''
    def is_redundant(self, freq_itemset_dict):
        bits = [True for _ in self.left_items]
        checker = self.is_redundant_(bits, 0, self.left_items, freq_itemset_dict)
        if checker == True: return True
        
        bits =  [True for _ in self.right_items]
        return self.is_redundant_(bits, 0, self.right_items, freq_itemset_dict)
    
    '''
    Check if an item-set is satisfied condition of the rule. 
    '''
    def satisfy_rule(self, itemset, is_lhs = True):
        condition = self.left_items
        if is_lhs == False: condition = self.right_items
        if len(condition) > len(itemset) or len(itemset) == 0:
            return False
        for item in condition:
            if item not in itemset:
                return False
        return True

# %%
'''
Created on 14 Feb 2018

@author: danhbuithi
'''

class RelationArray2D(object):
    '''
    classdocs
    '''

    def __init__(self, item_dict, relation_values):
        '''
        Constructor
        '''
        self.item_dict = item_dict
        self.relation_matrix = relation_values
        
        
    def get_value(self, item1, item2):
        i = self.item_dict[item1]
        j = self.item_dict[item2]
        return self.relation_matrix[i, j]
    
    def get_items(self):
        return self.item_dict.keys()
        
    def get_index(self, item):
        return self.item_dict[item]
    
class RelationArray1D(object):
    '''
    classdocs
    '''

    def __init__(self, item_dict, values):
        '''
        Constructor
        '''
        self.item_dict = item_dict
        self.values = values
        
        
    def get_value_at(self, index):
        return self.values[index]
    
    def get_items(self):
        return self.item_dict.keys()
        
    def get_value(self, item):
        return self.item_dict[item]

# %%
# Transaction databases, each transaction is a set of items
import numpy as np
from scipy import sparse
from scipy import stats


class DataSet:
    def __init__(self):
        self.current = 0
        self.train_data = []
        self.data_labels = []
        
    
    def __iter__(self):
        return iter(self.train_data)
                
    def size(self):
        return len(self.train_data)
    
    def get_transaction(self, index):
        return self.train_data[index]
    
    def clear(self):
        self.train_data.clear()
        
    def add_transaction(self, t):
        return self.train_data.append(t) 
        
    '''
    Load data set from a file. The input file must be formated in CSV (comma separated)
    class_index is used in the case of data-set with labels. 
    '''
    def load(self, file_path, class_index = -1, has_header = False):
        self.train_data = []
        if class_index != -1: self.data_labels = []
        
        with open(file_path, "r") as text_in_file:
            if has_header == True:
                text_in_file.readline()
                
            for line in text_in_file:
                #print("dataset script line", line)
                transaction = [x.strip() for x in line.split(',')]
                transaction = list(filter(None, transaction))
                #print("datset script transaction" , transaction)
                
                if (class_index != -1):
                    self.data_labels.append(transaction[class_index])
                    del transaction[class_index]
                
                self.train_data.append(list(set(transaction)))
        print("Loading done")
    '''
    Return number of classes in data (if have).
    '''            
    def number_of_classes(self):
        if self.data_labels == None: return 0
        return len(set(self.data_labels))

    def convert_data_labels(self, inlier_name):
        Y_train = np.zeros(len(self.data_labels))
        for i in range(Y_train.shape[0]):
            if self.data_labels[i] == inlier_name:
                Y_train[i] = 1
            else: 
                Y_train[i] = -1
        return Y_train

    def convert_2_binary_format_with(self, items_dict, classes_dict = None):
        n_items = len(items_dict)
        X_train = np.zeros((self.size(), n_items))
        
        k = 0
        for transaction in self.train_data:
            for item in transaction:
                if item not in items_dict: 
                    print('not in features...')
                    continue
                i = items_dict[item]
                X_train[k, i] = 1.0
            k += 1
            
        Y_train = []
        if classes_dict is not None:
            for label in self.data_labels:
                if label not in classes_dict:
                    print('not in classes')
                    Y_train.append(-1)
                else:
                    Y_train.append(classes_dict[label]) 
        return X_train, np.array(Y_train)        
    
    def get_items_dict_(self):
        attr_dict = {}
        #check existing data
        for transaction in self.train_data:
            for index in range (len(transaction)):
                item_name = transaction[index]
                if item_name not in attr_dict:
                    attr_dict[item_name] = True
        return attr_dict
    
    def get_class_list_(self):
        # Sort items and classes in alphabet order.
        return sorted(set(self.data_labels))
        
        

    '''
    Convert transaction data into binary format
    '''
    def convert_2_binary_format(self):
        
        attr_dict = self.get_items_dict_()
        print("convert_2_binary_format attr_dict", attr_dict)
        """
        {'a6@3': True, 'a7@left': True, 'a9@no': True, 'a3@30-34': True, 'a1@30-39': True, 'class@no': True, 'a5@no': True, 'a4@0-2': True, 'a2@premeno': True, 'a8@left_low': True, 'a8@right_up': True, 'a3@20-24': True, 'a7@right': True, 'a1@40-49': True, 'a6@2': True, 'a8@left_up': True, 'a2@ge40': True, 'a1@60-69': True, 'a3@15-19': True, 'a8@right_low': True, 'a3@0-4': True, 'a3@25-29': True, 'a1@50-59': True, 'a3@50-54': True, 'a8@central': True, 'a6@1': True, 'a3@10-14': True, 'a2@lt40': True, 'a3@40-44': True, 'a3@35-39': True, 'a1@70-79': True, 'a3@5-9': True, 'a9@yes': True, 'a5@yes': True, 'a4@6-8': True, 'a4@9-11': True, 'a4@3-5': True, 'a3@45-49': True, 'a5@?': True, 'a4@15-17': True, 'a4@12-14': True, 'class@yes': True, 'a8@?': True, 'a4@24-26': True}
        
        
        """
         
        # Sort items and classes in alphabet order.
        classes_list = sorted(set(self.data_labels))
        items_list = sorted(attr_dict.keys())
        
        classes_dict = {classes_list[i] : i for i in range(len(classes_list))}
        attr_dict = {items_list[i] : i for i in range(len(items_list))}
        
        #Generate binary matrix (X_train) and array of labels(Y_train)
        X_train, Y_train = self.convert_2_binary_format_with(attr_dict, classes_dict)
                
        return RelationArray2D(attr_dict, sparse.csr_matrix(X_train)), RelationArray1D(classes_dict, np.array(Y_train))
        
    @staticmethod
    def write_relation_matrix_(matrix):
        with open('item_relation.csv', 'w') as file_writer:
            item_names = sorted(matrix.item_dict.keys())
            file_writer.write('o0o,')
            file_writer.write(','.join(item_names))
            file_writer.write('\n')
            for i in range(len(item_names)):
                file_writer.write(item_names[i] + ',')
                file_writer.write(','.join(str(x) for x in matrix.relation_matrix[i].tolist()))
                file_writer.write('\n')
                
                
   
    '''
    This method estimates relationship among items. There're two kinds of relationship
    - Correlation:including negative correlation (<= -0.3) and positive correlation (>= 0.3)
    - Cover: threshold 1.0, including cover (2) and covered (-2) 
    '''
    def items_relationship(self):
        
        print ('Computing item relation matrix...')
        
        X_train, _ = self.convert_2_binary_format()
        
        print("X_train",X_train)
    
        correlation_matrix, p_values = stats.spearmanr(X_train.relation_matrix.todense(), axis = 0)
        
        zeros_mask = (p_values <= 0.05).astype(int)
        small_mask = (np.abs(correlation_matrix) >= 0.1).astype(int)
        
        relation_matrix = correlation_matrix * small_mask * zeros_mask
        
        a = RelationArray2D(X_train.item_dict, relation_matrix)
        DataSet.write_relation_matrix_(a)
        
        return a

# %%
train_data_set = DataSet()

# %%
train_data_set.load("/content/breast_train_transactions.txt", 0, has_header = False)
# Out:
# Loading done

# %%
X_train, Y_train = train_data_set.convert_2_binary_format()
# Out:
# convert_2_binary_format attr_dict {'a3@30-34': True, 'a4@0-2': True, 'a6@3': True, 'a7@left': True, 'a1@30-39': True, 'a5@no': True, 'a2@premeno': True, 'a8@left_low': True, 'a9@no': True, 'a6@2': True, 'a3@20-24': True, 'a7@right': True, 'a8@right_up': True, 'a1@40-49': True, 'a1@60-69': True, 'a2@ge40': True, 'a3@15-19': True, 'a8@left_up': True, 'a3@0-4': True, 'a8@right_low': True, 'a1@50-59': True, 'a3@25-29': True, 'a3@50-54': True, 'a8@central': True, 'a3@10-14': True, 'a2@lt40': True, 'a6@1': True, 'a3@40-44': True, 'a3@35-39': True, 'a1@70-79': True, 'a3@5-9': True, 'a5@yes': True, 'a4@6-8': True, 'a9@yes': True, 'a4@9-11': True, 'a4@3-5': True, 'a3@45-49': True, 'a5@?': True, 'a4@15-17': True, 'a4@12-14': True, 'a8@?': True, 'a4@24-26': True}

# %%
test_data_set = DataSet()
test_data_set.load("/content/breast_test_transactions.txt", 0, has_header = False)
Xtest, Ytest = test_data_set.convert_2_binary_format_with(X_train.item_dict, Y_train.item_dict)
Ytest = Ytest.flatten()
# Out:
# Loading done
# not in features...

# %%
class_count = train_data_set.number_of_classes()

# %%
import json
import numpy as np

class IOHelper:

    @staticmethod
    def write_file_in_lines(file_name, data, header = None):
        with open(file_name, "w") as text_file:
            if header is not None:
                text_file.write(header)
                text_file.write('\n')
            for transaction in data:
                text_file.write(transaction)
                text_file.write('\n')
    
    @staticmethod        
    def read_file_in_lines(inputfile, has_header = False):
        data = []
        with open(inputfile, "r") as text_file:
            file_iter = iter(text_file)
            if has_header == True:
                next(file_iter)
            
            for line in file_iter:
                data.append(line.strip())
        return data
    
    @staticmethod
    def read_ranking_file(input_file):
        patterns = []
        ranking = []
        k = 0
        with open(input_file, "r") as text_file:
            for line in text_file:
                subStrings = line.split(';')
                rule_key = subStrings[0].strip()
                patterns.append(rule_key)
                ranking.append([])
                for v in subStrings[1:]:
                    r = int(v)
                    ranking[k].append(r)
                
                k += 1
                if k % 1000 == 0: print(str(k))
        return patterns, np.array(ranking)
    
    @staticmethod 
    def save_as_json_format(file_name, o):
        with open (file_name, 'w') as text_file:
            json.dump(o, text_file)
            
    @staticmethod 
    def save_as_json_format_in_line(file_name, o):
        with open (file_name, 'w') as text_file:
            #json.dump(o, text_file)
            for item in o:
                line = json.dumps(item)
                text_file.write(line)
                text_file.write('\n')
            
    @staticmethod        
    def load_json_object(file_name):
        with open(file_name, 'r') as text_file:
            o = json.load(text_file)
            return o
    
    @staticmethod    
    def write_matrix(file_name, matrix):
        with open(file_name, "w") as text_file:
            for line in matrix:
                text_file.write(','.join(str(x) for x in line.tolist()))
                text_file.write('\n')
    
    @staticmethod
    def write_list_of_tuples(file_name, tuples_list):
        with open(file_name, 'w') as writer:
            for rule in tuples_list:
                writer.write(str(rule))
                writer.write('\n')

# %%
unexpected_rules = IOHelper.load_json_object("/content/unexpected_rule_file_json")

# %%
unexpected_rules
# Out:
# [['a1@50-59,a2@ge40,a4@0-2,a5@no,a6@3,a7@left,a9@no>class@no',
#   0.8333333333333334,
#   [['a1@50-59,a2@ge40,a3@30-34,a4@0-2,a5@no,a6@3,a7@left,a9@no>class@yes',
#     0.9720244168575001,
#     1.0,
#     1.0],
#    ['a1@50-59,a2@ge40,a3@30-34,a5@no,a6@3,a7@left,a9@no>class@yes',
#     0.9620316820077568,
#     0.5,
#     1.0],
#    ['a1@50-59,a2@ge40,a3@30-34,a4@0-2,a5@no,a6@3,a7@left,a8@?,a9@no>class@yes',
#     0.946437332472341,
#     1.0,
#     1.0]]],
#  ['a2@premeno,a4@0-2,a5@no,a6@1,a7@left,a8@left_low,a9@no>class@no',
#   0.875,
#   [['a2@premeno,a3@40-44,a4@0-2,a5@no,a6@1,a7@left,a8@left_low,a9@no>class@yes',
#     0.957956970372433,
#     1.0,
#     1.0],
#    ['a1@40-49,a2@premeno,a3@40-44,a4@0-2,a5@no,a6@1,a7@left,a8@left_low,a9@no>class@yes',
#     0.9497376721731239,
#     1.0,
#     1.0],
#    ['a2@premeno,a3@40-44,a4@0-2,a5@no,a6@1,a7@left,a9@no>class@yes',
#     0.9193087112345576,
#     0.5,
#     1.0]]],
#  ['a1@40-49,a2@premeno,a3@30-34,a4@0-2,a5@no,a7@right,a8@left_up,a9@no>class@no',
#   1.0,
#   [['a2@premeno,a3@30-34,a5@no,a7@right,a8@left_up>class@yes',
#     0.954055617590429,
#     1.0,
#     0.8]]],
#  ['a2@premeno,a4@0-2,a5@no,a6@1,a7@left,a9@no>class@no',
#   0.8571428571428571,
#   [['a2@premeno,a3@40-44,a4@0-2,a5@no,a6@1,a7@left,a9@no>class@yes',
#     0.9524145541916337,
#     1.0,
#     1.0],
#    ['a2@premeno,a3@40-44,a4@0-2,a5@no,a6@1,a7@left,a8@left_low,a9@no>class@yes',
#     0.9242232312756008,
#     1.0,
#     1.0],
#    ['a1@40-49,a2@premeno,a3@40-44,a4@0-2,a5@no,a6@1,a7@left,a8@left_low,a9@no>class@yes',
#     0.9184494224985799,
#     1.0,
#     1.0]]],
#  ['a2@ge40,a4@0-2,a5@no,a6@3,a7@left,a9@no>class@no',
#   0.875,
#   [['a1@50-59,a2@ge40,a3@30-34,a4@0-2,a5@no,a6@3,a7@left,a9@no>class@yes',
#     0.9521331356064251,
#     1.0,
#     1.0],
#    ['a1@50-59,a2@ge40,a3@30-34,a5@no,a6@3,a7@left,a9@no>class@yes',
#     0.9399245145673196,
#     0.5,
#     1.0],
#    ['a1@50-59,a2@ge40,a3@30-34,a4@0-2,a5@no,a6@3,a7@left,a8@?,a9@no>class@yes',
#     0.92743176179467,
#     1.0,
#     1.0]]],
#  ['a2@premeno,a5@yes,a6@2,a7@right,a9@yes>class@no',
#   0.8,
#   [['a1@40-49,a2@premeno,a3@20-24,a5@yes,a6@2,a7@right,a9@yes>class@yes',
#     0.9504943555827796,
#     1.0,
#     1.0],
#    ['a1@40-49,a2@premeno,a4@3-5,a5@yes,a6@2,a7@right,a8@right_up,a9@yes>class@yes',
#     0.9461276466529668,
#     1.0,
#     1.0],
#    ['a1@40-49,a2@premeno,a3@20-24,a4@3-5,a5@yes,a6@2,a7@right,a9@yes>class@yes',
#     0.9414096133272978,
#     1.0,
#     1.0]]],
#  ['a1@40-49,a2@premeno,a4@0-2,a5@no,a6@1,a7@left,a9@no>class@no',
#   0.8,
#   [['a2@premeno,a3@40-44,a4@0-2,a5@no,a6@1,a7@left,a9@no>class@yes',
#     0.9410231045301586,
#     0.5,
#     1.0],
#    ['a1@40-49,a2@premeno,a3@40-44,a4@0-2,a5@no,a6@1,a7@left,a8@left_low,a9@no>class@yes',
#     0.9295300943715217,
#     1.0,
#     1.0],
#    ['a2@premeno,a3@40-44,a4@0-2,a5@no,a6@1,a7@left,a8@left_low,a9@no>class@yes',
#     0.9138833127646078,
#     1.0,
#     1.0]]],
#  ['a1@50-59,a2@ge40,a3@35-39,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,a9@no>class@yes',
#   1.0,
#   [['a2@ge40,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,a9@no>class@no',
#     0.9404446166868735,
#     1.0,
#     0.9090909090909091],
#    ['a1@50-59,a2@ge40,a4@0-2,a6@2,a7@left,a9@no>class@no',
#     0.9391059899264894,
#     1.0,
#     0.8333333333333334],
#    ['a2@ge40,a5@no,a6@2,a7@left,a8@left_low,a9@no>class@no',
#     0.9344605245320957,
#     1.0,
#     0.9090909090909091]]],
#  ['a2@ge40,a4@0-2,a5@no,a7@right,a9@no>class@no',
#   0.8,
#   [['a1@60-69,a2@ge40,a3@50-54,a4@0-2,a5@no,a7@right,a9@no>class@yes',
#     0.9378000129057211,
#     1.0,
#     1.0],
#    ['a1@60-69,a2@ge40,a3@50-54,a4@0-2,a5@no,a7@right,a8@left_up,a9@no>class@yes',
#     0.9043149473693669,
#     1.0,
#     1.0],
#    ['a1@60-69,a2@ge40,a3@30-34,a4@0-2,a5@no,a6@3,a7@right,a9@no>class@yes',
#     0.8169896672560366,
#     1.0,
#     1.0]]],
#  ['a1@40-49,a2@premeno,a3@30-34,a5@no,a6@2,a7@right,a8@left_up,a9@no>class@yes',
#   1.0,
#   [['a1@40-49,a2@premeno,a5@no,a6@2,a7@right,a8@left_up,a9@no>class@no',
#     0.9353126414808138,
#     1.0,
#     0.8333333333333334],
#    ['a2@premeno,a5@no,a6@2,a7@right,a8@left_up,a9@no>class@no',
#     0.9251819422041795,
#     1.0,
#     0.875],
#    ['a1@40-49,a2@premeno,a5@no,a6@2,a7@right,a9@no>class@no',
#     0.8962709270055578,
#     1.0,
#     0.8235294117647058]]],
#  ['a1@40-49,a2@premeno,a3@35-39,a4@0-2,a5@no,a7@right,a8@left_up,a9@no>class@yes',
#   1.0,
#   [['a1@40-49,a2@premeno,a4@0-2,a7@right,a8@left_up>class@no',
#     0.9322000708388536,
#     1.0,
#     0.8333333333333334],
#    ['a1@40-49,a2@premeno,a4@0-2,a5@no,a7@right,a8@left_up>class@no',
#     0.9250465189167291,
#     1.0,
#     0.9],
#    ['a1@40-49,a2@premeno,a5@no,a7@right,a8@left_up>class@no',
#     0.9104169608777269,
#     1.0,
#     0.8333333333333334]]],
#  ['a1@60-69,a2@ge40,a4@0-2,a5@no,a6@3,a7@right,a8@left_up,a9@no>class@yes',
#   1.0,
#   [['a2@ge40,a4@0-2,a5@no,a6@3,a8@left_up,a9@no>class@no',
#     0.9309243395840119,
#     1.0,
#     0.8],
#    ['a1@60-69,a2@ge40,a4@0-2,a5@no,a7@right,a8@left_up,a9@no>class@no',
#     0.9033367721137868,
#     1.0,
#     0.8],
#    ['a2@ge40,a4@0-2,a5@no,a7@right,a8@left_up,a9@no>class@no',
#     0.875181154747906,
#     1.0,
#     0.8]]],
#  ['a1@40-49,a2@premeno,a3@25-29,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,a9@yes>class@yes',
#   1.0,
#   [['a2@premeno,a4@0-2,a5@no,a6@2,a7@left,a9@yes>class@no',
#     0.9290731992337636,
#     1.0,
#     0.8],
#    ['a4@0-2,a5@no,a6@2,a7@left,a9@yes>class@no',
#     0.8151468999124795,
#     1.0,
#     0.875]]],
#  ['a1@50-59,a2@ge40,a5@yes,a6@3,a7@right,a8@right_up,a9@no>class@yes',
#   1.0,
#   [['a1@50-59,a2@ge40,a5@yes,a7@right,a9@no>class@no',
#     0.9282698913769887,
#     1.0,
#     0.8]]],
#  ['a1@40-49,a2@premeno,a3@30-34,a4@0-2,a5@no,a6@1,a7@right,a8@left_up,a9@no>class@no',
#   1.0,
#   [['a2@premeno,a3@30-34,a5@no,a7@right,a8@left_up>class@yes',
#     0.9270549944671137,
#     1.0,
#     0.8]]],
#  ['a1@50-59,a3@20-24,a4@0-2,a6@1,a7@left,a8@left_up,a9@no>class@yes',
#   1.0,
#   [['a1@50-59,a4@0-2,a7@left,a8@left_up,a9@no>class@no',
#     0.923964940374962,
#     1.0,
#     0.8888888888888888],
#    ['a1@50-59,a4@0-2,a8@left_up,a9@no>class@no',
#     0.7835696476243621,
#     1.0,
#     0.8947368421052632]]],
#  ['a2@premeno,a4@0-2,a5@no,a6@1,a8@left_low,a9@no>class@no',
#   0.8181818181818182,
#   [['a2@premeno,a3@40-44,a4@0-2,a5@no,a6@1,a7@left,a8@left_low,a9@no>class@yes',
#     0.9215561170972373,
#     1.0,
#     1.0],
#    ['a1@40-49,a2@premeno,a3@40-44,a4@0-2,a5@no,a6@1,a7@left,a8@left_low,a9@no>class@yes',
#     0.915871824030679,
#     1.0,
#     1.0],
#    ['a2@premeno,a3@40-44,a4@0-2,a5@no,a6@1,a7@left,a9@no>class@yes',
#     0.8745530192617659,
#     0.5,
#     1.0]]],
#  ['a1@60-69,a2@ge40,a3@20-24,a4@0-2,a5@no,a6@3,a8@left_low,a9@no>class@yes',
#   1.0,
#   [['a2@ge40,a4@0-2,a5@no,a6@3,a8@left_low,a9@no>class@no',
#     0.9204916306817541,
#     1.0,
#     0.8333333333333334],
#    ['a1@60-69,a2@ge40,a4@0-2,a5@no,a8@left_low,a9@no>class@no',
#     0.8508391484486307,
#     1.0,
#     0.8666666666666667],
#    ['a2@ge40,a5@no,a8@left_low,a9@no>class@no',
#     0.8212700122367277,
#     1.0,
#     0.8333333333333334]]],
#  ['a1@50-59,a2@premeno,a3@15-19,a4@0-2,a5@no,a6@2,a7@left,a8@left_low,a9@no>class@yes',
#   1.0,
#   [['a1@50-59,a2@premeno,a4@0-2,a5@no,a7@left,a8@left_low,a9@no>class@no',
#     0.9194782097204323,
#     1.0,
#     0.8571428571428571],
#    ['a1@50-59,a2@premeno,a6@2,a7@left,a8@left_low>class@no',
#     0.7751426119187024,
#     1.0,
#     0.8],
#    ['a2@premeno,a4@0-2,a5@no,a6@2,a9@no>class@no',
#     0.7583140012245503,
#     1.0,
#     0.8095238095238095]]],
#  ['a1@50-59,a2@ge40,a4@3-5,a5@yes,a6@3,a7@right,a8@right_up,a9@no>class@yes',
#   1.0,
#   [['a1@50-59,a2@ge40,a5@yes,a7@right,a9@no>class@no',
#     0.9194364112651503,
#     1.0,
#     0.8]]],
#  ['a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a7@right,a8@central,a9@no>class@yes',
#   1.0,
#   [['a2@ge40,a4@0-2,a5@no,a6@2,a7@right>class@no',
#     0.917234206734367,
#     1.0,
#     0.8],
#    ['a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a9@no>class@no',
#     0.8750997578832334,
#     1.0,
#     0.8333333333333334],
#    ['a2@ge40,a4@0-2,a5@no,a6@2,a9@no>class@no',
#     0.8726144696731096,
#     1.0,
#     0.8620689655172413]]],
#  ['a2@premeno,a5@no,a6@2,a7@right,a8@left_up>class@no',
#   0.8,
#   [['a1@30-39,a2@premeno,a5@no,a7@right,a8@left_up>class@yes',
#     0.91164649721225,
#     0.3333333333333333,
#     1.0],
#    ['a1@40-49,a2@premeno,a3@30-34,a4@3-5,a5@no,a6@2,a7@right,a8@left_up,a9@no>class@yes',
#     0.8268248955003468,
#     1.0,
#     1.0],
#    ['a2@premeno,a3@30-34,a5@no,a7@right,a8@left_up>class@yes',
#     0.8191340389965526,
#     0.4,
#     0.8]]],
#  ['a1@60-69,a2@ge40,a3@50-54,a4@0-2,a5@no,a6@3,a7@right,a8@left_up,a9@no>class@yes',
#   1.0,
#   [['a2@ge40,a4@0-2,a5@no,a6@3,a8@left_up,a9@no>class@no',
#     0.9063506860353143,
#     1.0,
#     0.8],
#    ['a1@60-69,a2@ge40,a4@0-2,a5@no,a7@right,a8@left_up,a9@no>class@no',
#     0.8812833901693362,
#     1.0,
#     0.8],
#    ['a2@ge40,a4@0-2,a5@no,a7@right,a8@left_up,a9@no>class@no',
#     0.8523022486298568,
#     1.0,
#     0.8]]],
#  ['a1@40-49,a2@premeno,a3@35-39,a4@0-2,a5@no,a6@1,a7@right,a8@left_up,a9@no>class@yes',
#   1.0,
#   [['a1@40-49,a2@premeno,a4@0-2,a7@right,a8@left_up>class@no',
#     0.9055233416382467,
#     1.0,
#     0.8333333333333334],
#    ['a1@40-49,a2@premeno,a4@0-2,a5@no,a7@right,a8@left_up>class@no',
#     0.8981228445662821,
#     1.0,
#     0.9],
#    ['a1@40-49,a2@premeno,a5@no,a7@right,a8@left_up>class@no',
#     0.880247498019044,
#     1.0,
#     0.8333333333333334]]],
#  ['a1@40-49,a2@ge40,a4@0-2,a5@no,a6@2,a7@right,a8@left_up,a9@no>class@yes',
#   1.0,
#   [['a2@ge40,a4@0-2,a5@no,a6@2,a7@right,a8@left_up,a9@no>class@no',
#     0.9020977276877588,
#     1.0,
#     0.8333333333333334],
#    ['a2@ge40,a4@0-2,a6@2,a7@right,a8@left_up,a9@no>class@no',
#     0.8940917531473922,
#     1.0,
#     0.8571428571428571],
#    ['a2@ge40,a4@0-2,a5@no,a6@2,a7@right,a8@left_up>class@no',
#     0.8704910192664729,
#     1.0,
#     0.875]]],
#  ['a2@ge40,a3@40-44,a4@0-2,a5@no,a6@2,a7@right,a8@left_low,a9@no>class@yes',
#   1.0,
#   [['a2@ge40,a4@0-2,a5@no,a7@right,a8@left_low,a9@no>class@no',
#     0.9013221996650791,
#     1.0,
#     0.8],
#    ['a2@ge40,a4@0-2,a5@no,a6@2,a8@left_low,a9@no>class@no',
#     0.8381686858421772,
#     1.0,
#     0.8666666666666667],
#    ['a2@ge40,a4@0-2,a5@no,a6@2,a7@right>class@no',
#     0.8371493613862595,
#     1.0,
#     0.8]]],
#  ['a1@50-59,a2@ge40,a4@0-2,a5@no,a6@3,a9@no>class@no',
#   0.875,
#   [['a1@50-59,a2@ge40,a3@30-34,a4@0-2,a5@no,a6@3,a7@left,a9@no>class@yes',
#     0.8990135746088976,
#     1.0,
#     1.0],
#    ['a1@50-59,a2@ge40,a3@30-34,a5@no,a6@3,a7@left,a9@no>class@yes',
#     0.8827673836039304,
#     0.5,
#     1.0],
#    ['a1@50-59,a2@ge40,a3@30-34,a4@0-2,a5@no,a6@3,a7@left,a8@?,a9@no>class@yes',
#     0.876396235692656,
#     1.0,
#     1.0]]],
#  ['a2@premeno,a5@yes,a6@2,a7@right>class@no',
#   0.8333333333333334,
#   [['a1@40-49,a2@premeno,a3@20-24,a5@yes,a6@2,a7@right,a9@yes>class@yes',
#     0.8989861350424588,
#     1.0,
#     1.0],
#    ['a1@40-49,a2@premeno,a4@3-5,a5@yes,a6@2,a7@right,a8@right_up,a9@yes>class@yes',
#     0.8983243854520969,
#     1.0,
#     1.0],
#    ['a1@40-49,a2@premeno,a3@20-24,a4@3-5,a5@yes,a6@2,a7@right,a9@yes>class@yes',
#     0.893442188409586,
#     1.0,
#     1.0]]],
#  ['a1@40-49,a2@premeno,a5@yes,a7@right,a9@yes>class@no',
#   0.8333333333333334,
#   [['a1@40-49,a2@premeno,a3@20-24,a5@yes,a6@2,a7@right,a9@yes>class@yes',
#     0.8980706830284334,
#     1.0,
#     1.0],
#    ['a1@40-49,a2@premeno,a4@3-5,a5@yes,a6@2,a7@right,a8@right_up,a9@yes>class@yes',
#     0.8953082449120109,
#     1.0,
#     1.0],
#    ['a1@40-49,a2@premeno,a3@20-24,a4@3-5,a5@yes,a6@2,a7@right,a9@yes>class@yes',
#     0.8911097641224563,
#     1.0,
#     1.0]]],
#  ['a2@premeno,a3@15-19,a4@0-2,a7@right,a8@left_up,a9@no>class@yes',
#   1.0,
#   [['a1@40-49,a2@premeno,a4@0-2,a7@right,a8@left_up>class@no',
#     0.8933341538251623,
#     1.0,
#     0.8333333333333334]]],
#  ['a1@50-59,a2@ge40,a3@20-24,a4@3-5,a5@yes,a6@3,a7@right,a8@right_up,a9@no>class@yes',
#   1.0,
#   [['a1@50-59,a2@ge40,a5@yes,a7@right,a9@no>class@no',
#     0.89297660741065,
#     1.0,
#     0.8]]],
#  ['a2@premeno,a3@30-34,a8@left_low,a9@no>class@no',
#   0.8,
#   [['a1@40-49,a2@premeno,a3@30-34,a6@3,a7@left,a8@left_low,a9@no>class@yes',
#     0.8922638954591461,
#     1.0,
#     1.0],
#    ['a1@40-49,a3@30-34,a6@3,a7@left,a8@left_low,a9@no>class@yes',
#     0.8260621094436092,
#     0.5,
#     1.0],
#    ['a1@40-49,a2@premeno,a5@yes,a6@3,a7@left,a8@left_low,a9@no>class@yes',
#     0.6338614056722593,
#     0.5,
#     1.0]]],
#  ['a2@ge40,a3@30-34,a4@0-2,a5@no,a7@left,a9@no>class@no',
#   0.8333333333333334,
#   [['a1@50-59,a2@ge40,a3@30-34,a4@0-2,a5@no,a6@3,a7@left,a9@no>class@yes',
#     0.8916597511239768,
#     1.0,
#     1.0],
#    ['a1@50-59,a2@ge40,a3@30-34,a5@no,a6@3,a7@left,a9@no>class@yes',
#     0.877157082765752,
#     0.5,
#     1.0],
#    ['a1@50-59,a2@ge40,a3@30-34,a4@0-2,a5@no,a6@3,a7@left,a8@?,a9@no>class@yes',
#     0.8703245845445062,
#     1.0,
#     1.0]]],
#  ['a1@40-49,a2@premeno,a3@30-34,a4@0-2,a5@no,a8@left_up,a9@no>class@no',
#   1.0,
#   [['a2@premeno,a3@30-34,a5@no,a7@right,a8@left_up>class@yes',
#     0.8899634896596557,
#     0.5,
#     0.8]]],
#  ['a2@premeno,a3@30-34,a5@no,a6@2,a7@right,a8@left_up>class@yes',
#   1.0,
#   [['a2@premeno,a5@no,a6@2,a7@right,a8@left_up,a9@no>class@no',
#     0.8892917345518068,
#     0.5,
#     0.875],
#    ['a1@40-49,a2@premeno,a5@no,a6@2,a7@right,a8@left_up,a9@no>class@no',
#     0.8840273434999697,
#     0.5,
#     0.8333333333333334],
#    ['a1@40-49,a2@premeno,a5@no,a7@right,a8@left_up>class@no',
#     0.8508584472451834,
#     0.5,
#     0.8333333333333334]]],
#  ['a2@ge40,a4@3-5,a5@yes,a6@3,a7@right,a8@right_up,a9@no>class@yes',
#   1.0,
#   [['a1@50-59,a2@ge40,a5@yes,a7@right,a9@no>class@no',
#     0.8891082417106043,
#     1.0,
#     0.8]]],
#  ['a1@50-59,a2@ge40,a3@20-24,a4@0-2,a5@no,a6@2,a7@right,a8@central,a9@no>class@yes',
#   1.0,
#   [['a2@ge40,a4@0-2,a5@no,a6@2,a7@right>class@no',
#     0.8876169163907413,
#     1.0,
#     0.8],
#    ['a1@50-59,a2@ge40,a4@0-2,a5@no,a6@2,a9@no>class@no',
#     0.8473886687623025,
#     1.0,
#     0.8333333333333334],
#    ['a2@ge40,a4@0-2,a5@no,a6@2,a9@no>class@no',
#     0.8451198277302144,
#     1.0,
#     0.8620689655172413]]],
#  ['a2@premeno,a3@15-19,a4@0-2,a5@no,a6@2,a8@left_up,a9@no>class@yes',
#   1.0,
#   [['a2@premeno,a4@0-2,a5@no,a6@2,a9@no>class@no',
#     0.8864881686878834,
#     1.0,
#     0.8095238095238095],
#    ['a1@40-49,a2@premeno,a4@0-2,a5@no,a6@2,a9@no>class@no',
#     0.8636769829383367,
#     1.0,
#     0.8333333333333334],
#    ['a4@0-2,a5@no,a6@2,a9@no>class@no',
#     0.7903191519593898,
#     1.0,
#     0.8333333333333334]]],
#  ['a2@ge40,a3@30-34,a4@0-2,a5@no,a7@right,a9@no>class@no',
#   0.8333333333333334,
#   [['a1@60-69,a2@ge40,a3@30-34,a4@0-2,a5@no,a6@3,a7@right,a9@no>class@yes',
#     0.8850801111330671,
#     1.0,
#     1.0],
#    ['a2@ge40,a3@30-34,a4@0-2,a5@no,a6@3,a7@right,a8@central,a9@no>class@yes',
#     0.8774502779712346,
#     1.0,
#     1.0],
#    ['a1@60-69,a2@ge40,a3@30-34,a4@0-2,a5@no,a6@3,a7@right,a8@central,a9@no>class@yes',
#     0.8578428012081248,
#     1.0,
#     1.0]]],
#  ['a2@premeno,a5@yes,a7@right,a9@yes>class@no',
#   0.875,
#   [['a1@40-49,a2@premeno,a4@3-5,a5@yes,a6@2,a7@right,a8@right_up,a9@yes>class@yes',
#     0.8837409227172313,
#     1.0,
#     1.0],
#    ['a1@40-49,a2@premeno,a3@20-24,a5@yes,a6@2,a7@right,a9@yes>class@yes',
#     0.8754037405129317,
#     1.0,
#     1.0],
#    ['a1@40-49,a2@premeno,a3@20-24,a4@3-5,a5@yes,a6@2,a7@right,a9@yes>class@yes',
#     0.8700409842893203,
#     1.0,
#     1.0]]],
#  ['a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a8@right_up,a9@no>class@yes',
#   1.0,
#   [['a2@premeno,a4@0-2,a5@no,a6@2,a9@no>class@no',
#     0.8829682895429911,
#     1.0,
#     0.8095238095238095],
#    ['a4@0-2,a5@no,a6@2,a9@no>class@no',
#     0.8297903343095221,
#     1.0,
#     0.8333333333333334],
#    ['a1@50-59,a4@0-2,a5@no,a6@2,a9@no>class@no',
#     0.7402567864757006,
#     1.0,
#     0.8095238095238095]]],
#  ['a1@60-69,a2@ge40,a3@40-44,a4@0-2,a5@no,a6@2,a7@right,a8@left_low,a9@no>class@yes',
#   1.0,
#   [['a2@ge40,a4@0-2,a5@no,a7@right,a8@left_low,a9@no>class@no',
#     0.88129185164656,
#     1.0,
#     0.8],
#    ['a1@60-69,a2@ge40,a4@0-2,a5@no,a6@2,a7@right>class@no',
#     0.8471861070860303,
#     1.0,
#     0.875],
#    ['a1@60-69,a2@ge40,a4@0-2,a5@no,a6@2,a8@left_low,a9@no>class@no',
#     0.8469434948149581,
#     1.0,
#     0.8888888888888888]]],
#  ['a2@ge40,a3@40-44,a7@right,a8@left_low,a9@no>class@yes',
#   1.0,
#   [['a2@ge40,a4@0-2,a5@no,a7@right,a8@left_low,a9@no>class@no',
#     0.8773532269701322,
#     0.5,
#     0.8],
#    ['a2@ge40,a5@no,a8@left_low,a9@no>class@no',
#     0.7031220154060162,
#     0.5,
#     0.8333333333333334],
#    ['a2@ge40,a4@0-2,a5@no,a8@left_low,a9@no>class@no',
#     0.6873448716679363,
#     0.5,
#     0.8888888888888888]]],
#  ['a2@ge40,a4@3-5,a5@no,a9@no>class@yes',
#   1.0,
#   [['a2@ge40,a5@no,a9@no>class@no',
#     0.8767242778104306,
#     1.0,
#     0.8235294117647058],
#    ['a1@50-59,a2@ge40,a5@no,a9@no>class@no',
#     0.8473345377156225,
#     0.5,
#     0.8529411764705882],
#    ['a2@ge40,a3@25-29,a5@no,a9@no>class@no',
#     0.7942222289354527,
#     0.25,
#     0.875]]],
#  ['a1@50-59,a2@ge40,a6@3,a8@left_up,a9@no>class@no',
#   0.8571428571428571,
#   [['a1@50-59,a2@ge40,a3@30-34,a5@no,a6@3,a7@right,a8@left_up,a9@no>class@yes',
#     0.8765083272559158,
#     1.0,
#     1.0],
#    ['a2@ge40,a3@30-34,a5@no,a6@3,a7@right,a8@left_up,a9@no>class@yes',
#     0.8402413910149745,
#     1.0,
#     1.0],
#    ['a1@50-59,a2@ge40,a4@3-5,a5@no,a6@3,a7@right,a9@no>class@yes',
#     0.7821613495462738,
#     1.0,
#     1.0]]],
#  ['a2@premeno,a3@15-19,a4@0-2,a5@no,a6@1,a7@right,a8@left_low,a9@no>class@yes',
#   1.0,
#   [['a4@0-2,a5@no,a6@1,a7@right,a8@left_low,a9@no>class@no',
#     0.8764736504214765,
#     1.0,
#     0.8333333333333334],
#    ['a4@0-2,a5@no,a6@1,a7@right,a8@left_low>class@no',
#     0.8537124933399232,
#     1.0,
#     0.8571428571428571]]],
#  ['a1@40-49,a2@premeno,a5@no,a7@right,a8@left_up,a9@no>class@no',
#   0.8181818181818182,
#   [['a2@premeno,a3@30-34,a5@no,a7@right,a8@left_up>class@yes',
#     0.8742349889151637,
#     0.4,
#     0.8],
#    ['a2@premeno,a3@30-34,a4@3-5,a5@no,a7@right,a8@left_up,a9@no>class@yes',
#     0.8465041202997419,
#     1.0,
#     1.0],
#    ['a1@40-49,a2@premeno,a3@30-34,a4@3-5,a5@no,a6@2,a7@right,a8@left_up,a9@no>class@yes',
#     0.8263558739860584,
#     1.0,
#     1.0]]],
#  ['a1@40-49,a2@ge40,a3@20-24,a4@0-2,a5@no,a6@2,a7@right,a8@left_up,a9@no>class@yes',
#   1.0,
#   [['a2@ge40,a4@0-2,a5@no,a6@2,a7@right,a8@left_up,a9@no>class@no',
#     0.8733764952363793,
#     1.0,
#     0.8333333333333334],
#    ['a2@ge40,a4@0-2,a6@2,a7@right,a8@left_up,a9@no>class@no',
#     0.865801102117932,
#     1.0,
#     0.8571428571428571],
#    ['a2@ge40,a4@0-2,a5@no,a6@2,a7@right,a8@left_up>class@no',
#     0.8431052574541912,
#     1.0,
#     0.875]]],
#  ['a3@30-34,a4@3-5,a5@yes,a7@left,a8@left_low>class@no',
#   1.0,
#   [['a5@yes,a6@3,a7@left,a8@left_low>class@yes',
#     0.8727834205196355,
#     0.5,
#     0.875],
#    ['a5@yes,a6@3,a7@left>class@yes',
#     0.8218717886678234,
#     0.5,
#     0.8461538461538461],
#    ['a3@30-34,a5@yes,a6@3,a9@no>class@yes', 0.5014101135804361, 0.5, 0.8]]],
#  ['a1@40-49,a3@30-34,a4@0-2,a5@no,a8@left_up>class@no',
#   1.0,
#   [['a2@premeno,a3@30-34,a5@no,a7@right,a8@left_up>class@yes',
#     0.8723495439331027,
#     0.3333333333333333,
#     0.8]]],
#  ['a2@ge40,a4@0-2,a5@no,a6@1,a7@right>class@no',
#   0.9166666666666666,
#   [['a1@60-69,a2@ge40,a5@no,a7@right,a8@right_up>class@yes',
#     0.8707823555472487,
#     0.5,
#     1.0],
#    ['a2@ge40,a4@0-2,a5@no,a6@1,a7@right,a9@yes>class@yes',
#     0.811983650490698,
#     1.0,
#     1.0],
#    ['a1@60-69,a2@ge40,a4@0-2,a5@no,a6@1,a7@right,a9@yes>class@yes',
#     0.7931403843887195,
#     1.0,
#     1.0]]],
#  ['a2@ge40,a7@right,a8@left_up,a9@no>class@no',
#   0.8,
#   [['a1@60-69,a2@ge40,a3@50-54,a4@0-2,a5@no,a7@right,a8@left_up,a9@no>class@yes',
#     0.8707407704289246,
#     1.0,
#     1.0],
#    ['a2@ge40,a3@30-34,a5@no,a6@3,a7@right,a8@left_up,a9@no>class@yes',
#     0.8121250893820134,
#     1.0,
#     1.0],
#    ['a1@60-69,a2@ge40,a3@50-54,a4@0-2,a5@no,a7@right,a9@no>class@yes',
#     0.8046162410774903,
#     1.0,
#     1.0]]],
#  ['a4@0-2,a5@no,a7@right,a8@left_up,a9@no>class@no',
#   0.8076923076923077,
#   [['a1@30-39,a2@premeno,a4@0-2,a5@no,a7@right,a8@left_up,a9@no>class@yes',
#     0.868518734397536,
#     1.0,
#     1.0],
#    ['a1@30-39,a2@premeno,a4@0-2,a5@no,a6@1,a7@right,a8@left_up,a9@no>class@yes',
#     0.8465929932743841,
#     1.0,
#     1.0],
#    ['a1@30-39,a2@premeno,a4@0-2,a5@no,a7@right,a8@left_up>class@yes',
#     0.8126731242594764,
#     1.0,
#     1.0]]],
#  ['a2@ge40,a3@25-29,a5@no,a6@2,a8@right_up,a9@no>class@yes',
#   1.0,
#   [['a2@ge40,a3@25-29,a5@no,a9@no>class@no', 0.8682455944412684, 1.0, 0.875],
#    ['a2@ge40,a5@no,a9@no>class@no',
#     0.7897173279804351,
#     1.0,
#     0.8235294117647058]]],
#  ['a1@40-49,a2@premeno,a4@0-2,a5@no,a7@right,a8@left_up,a9@no>class@no',
#   0.8888888888888888,
#   [['a2@premeno,a3@30-34,a5@no,a7@right,a8@left_up>class@yes',
#     0.8674114633236115,
#     0.2,
#     0.8]]],
#  ['a2@ge40,a3@20-24,a4@0-2,a5@no,a6@3,a9@no>class@no',
#   0.8,
#   [['a2@ge40,a3@20-24,a4@0-2,a5@no,a6@3,a7@right,a8@left_low,a9@no>class@yes',
#     0.8673593846135849,
#     1.0,
#     1.0],
#    ['a1@60-69,a2@ge40,a3@20-24,a4@0-2,a5@no,a6@3,a7@right,a8@left_low,a9@no>class@yes',
#     0.8506900735031006,
#     1.0,
#     1.0],
#    ['a2@ge40,a3@20-24,a5@no,a6@3,a7@right,a8@left_low>class@yes',
#     0.7912412425994966,
#     0.5,
#     1.0]]],
#  ['a1@50-59,a2@ge40,a3@30-34,a4@3-5,a5@no,a6@3,a7@right,a8@left_up,a9@no>class@yes',
#   1.0,
#   [['a1@50-59,a2@ge40,a5@no,a6@3,a8@left_up,a9@no>class@no',
#     0.8640526760511241,
#     1.0,
#     0.8],
#    ['a1@50-59,a2@ge40,a5@no,a9@no>class@no',
#     0.6490120487143038,
#     1.0,
#     0.8529411764705882],
#    ['a2@ge40,a5@no,a9@no>class@no',
#     0.6402619961164537,
#     1.0,
#     0.8235294117647058]]],
#  ['a2@ge40,a4@3-5,a5@no,a7@left,a8@left_low>class@yes',
#   1.0,
#   [['a2@ge40,a5@no,a7@left,a8@left_low,a9@no>class@no',
#     0.8620385022246398,
#     0.6666666666666666,
#     0.85],
#    ['a1@60-69,a2@ge40,a5@no,a7@left>class@no',
#     0.8185320081080344,
#     0.3333333333333333,
#     0.8947368421052632],
#    ['a2@ge40,a5@no,a7@left,a9@no>class@no',
#     0.812919215167459,
#     0.6666666666666666,
#     0.8888888888888888]]],
#  ['a2@ge40,a3@30-34,a4@0-2,a5@no,a7@left>class@no',
#   0.875,
#   [['a1@50-59,a2@ge40,a3@30-34,a4@0-2,a5@no,a6@3,a7@left,a9@no>class@yes',
#     0.8604284942569348,
#     1.0,
#     1.0],
#    ['a1@50-59,a2@ge40,a3@30-34,a5@no,a6@3,a7@left,a9@no>class@yes',
#     0.8414091238380417,
#     0.5,
#     1.0],
#    ['a1@50-59,a2@ge40,a3@30-34,a4@0-2,a5@no,a6@3,a7@left,a8@?,a9@no>class@yes',
#     0.8407466873324705,
#     1.0,
#     1.0]]],
#  ['a1@30-39,a2@premeno,a3@15-19,a4@0-2,a5@no,a6@1,a7@right,a8@left_low,a9@no>class@yes',
#   1.0,
#   [['a4@0-2,a5@no,a6@1,a7@right,a8@left_low,a9@no>class@no',
#     0.8549806071880575,
#     1.0,
#     0.8333333333333334],
#    ['a4@0-2,a5@no,a6@1,a7@right,a8@left_low>class@no',
#     0.8332354789222064,
#     1.0,
#     0.8571428571428571]]],
#  ['a1@40-49,a2@premeno,a4@0-2,a6@3,a7@right,a8@left_up,a9@no>class@yes',
#   1.0,
#   [['a1@40-49,a2@premeno,a4@0-2,a7@right,a8@left_up>class@no',
#     0.8549582980059217,
#     1.0,
#     0.8333333333333334]]],
#  ['a1@60-69,a2@ge40,a3@40-44,a7@right,a8@left_low,a9@no>class@yes',
#   1.0,
#   [['a2@ge40,a4@0-2,a5@no,a7@right,a8@left_low,a9@no>class@no',
#     0.8541907440437144,
#     0.5,
#     0.8],
#    ['a1@60-69,a2@ge40,a4@0-2,a5@no,a8@left_low,a9@no>class@no',
#     0.7161910525710324,
#     0.5,
#     0.8666666666666667],
#    ['a1@60-69,a2@ge40,a4@0-2,a5@no,a9@no>class@no',
#     0.6946492421916989,
#     0.5,
#     0.8518518518518519]]],
#  ['a2@premeno,a4@0-2,a5@no,a6@2,a8@left_up,a9@no>class@no',
#   0.8333333333333334,
#   [['a2@premeno,a3@15-19,a4@0-2,a5@no,a6@2,a7@left,a8@left_up,a9@no>class@yes',
#     0.8539029737722449,
#     1.0,
#     1.0],
#    ['a1@40-49,a2@premeno,a3@15-19,a4@0-2,a5@no,a6@2,a7@left,a8@left_up,a9@no>class@yes',
#     0.8519842101920466,
#     1.0,
#     1.0],
#    ['a1@40-49,a2@premeno,a3@15-19,a4@0-2,a5@no,a7@left,a8@left_up,a9@no>class@yes',
#     0.7799106309649682,
#     1.0,
#     1.0]]],
#  ['a2@ge40,a3@30-34,a6@2,a7@left>class@no',
#   0.8333333333333334,
#   [['a2@ge40,a3@30-34,a4@3-5,a5@yes,a6@2,a7@left>class@yes',
#     0.852230607390246,
#     1.0,
#     1.0],
#    ['a1@60-69,a2@ge40,a3@30-34,a5@yes,a6@2,a7@left,a8@central>class@yes',
#     0.8171817193676189,
#     1.0,
#     1.0],
#    ['a2@ge40,a3@30-34,a5@yes,a6@2,a7@left,a9@yes>class@yes',
#     0.8028447807622956,
#     1.0,
#     1.0]]],
#  ['a4@0-2,a5@no,a6@1,a7@left,a8@left_low,a9@no>class@no',
#   0.9166666666666666,
#   [['a2@premeno,a3@40-44,a4@0-2,a5@no,a6@1,a7@left,a8@left_low,a9@no>class@yes',
#     0.851887187932029,
#     1.0,
#     1.0],
#    ['a1@40-49,a2@premeno,a3@40-44,a4@0-2,a5@no,a6@1,a7@left,a8@left_low,a9@no>class@yes',
#     0.8178132361648704,
#     1.0,
#     1.0],
#    ['a2@premeno,a3@40-44,a4@0-2,a5@no,a6@1,a7@left,a9@no>class@yes',
#     0.7982133493635352,
#     0.5,
#     1.0]]],
#  ['a1@50-59,a2@ge40,a7@left,a9@no>class@no',
#   0.8,
#   [['a1@50-59,a2@ge40,a3@30-34,a6@3,a7@left,a9@no>class@yes',
#     0.8518426771308812,
#     1.0,
#     1.0],
#    ['a1@50-59,a2@ge40,a3@30-34,a5@no,a6@3,a7@left,a9@no>class@yes',
#     0.8223615433471269,
#     1.0,
#     1.0],
#    ['a1@50-59,a2@ge40,a3@30-34,a4@0-2,a5@no,a6@3,a7@left,a9@no>class@yes',
#     0.813701768759644,
#     1.0,
#     1.0]]],
#  ['a1@40-49,a2@premeno,a4@0-2,a5@no,a6@1,a7@right,a8@left_up,a9@no>class@no',
#   0.8,
#   [['a2@premeno,a3@30-34,a5@no,a7@right,a8@left_up>class@yes',
#     0.8496932714153518,
#     0.2,
#     0.8]]],
#  ['a4@0-2,a5@no,a6@2,a7@left,a8@left_up>class@no',
#   0.8333333333333334,
#   [['a2@premeno,a3@15-19,a4@0-2,a5@no,a6@2,a7@left,a8@left_up,a9@no>class@yes',
#     0.8495897276552298,
#     1.0,
#     1.0],
#    ['a1@40-49,a2@premeno,a3@15-19,a4@0-2,a5@no,a6@2,a7@left,a8@left_up,a9@no>class@yes',
#     0.8210888498706695,
#     1.0,
#     1.0],
#    ['a1@40-49,a2@premeno,a3@15-19,a4@0-2,a5@no,a7@left,a8@left_up,a9@no>class@yes',
#     0.7331958895237922,
#     1.0,
#     1.0]]],
#  ['a1@60-69,a2@ge40,a4@0-2,a5@no>class@no',
#   0.8,
#   [['a1@60-69,a2@ge40,a3@50-54,a4@0-2,a5@no,a7@right,a9@no>class@yes',
#     0.8492631068548441,
#     1.0,
#     1.0],
#    ['a1@60-69,a2@ge40,a5@no,a7@right,a8@right_up>class@yes',
#     0.814178372611573,
#     0.5,
#     1.0],
#    ['a1@60-69,a2@ge40,a3@50-54,a4@0-2,a5@no,a7@right,a8@left_up,a9@no>class@yes',
#     0.8076964520882689,
#     1.0,
#     1.0]]],
#  ['a1@40-49,a2@premeno,a4@0-2,a5@no,a6@2,a8@left_up,a9@no>class@no',
#   0.8571428571428571,
#   [['a1@40-49,a2@premeno,a3@15-19,a4@0-2,a5@no,a6@2,a7@left,a8@left_up,a9@no>class@yes',
#     0.8486327325961281,
#     1.0,
#     1.0],
#    ['a2@premeno,a3@15-19,a4@0-2,a5@no,a6@2,a7@left,a8@left_up,a9@no>class@yes',
#     0.8315760897667224,
#     1.0,
#     1.0],
#    ['a1@40-49,a2@premeno,a3@15-19,a4@0-2,a5@no,a7@left,a8@left_up,a9@no>class@yes',
#     0.7804932633511961,
#     1.0,
#     1.0]]],
#  ['a1@40-49,a2@premeno,a7@right,a9@yes>class@no',
#   0.8181818181818182,
#   [['a1@40-49,a2@premeno,a3@20-24,a5@yes,a6@2,a7@right,a9@yes>class@yes',
#     0.848512028324102,
#     1.0,
#     1.0],
#    ['a1@40-49,a2@premeno,a4@3-5,a5@yes,a6@2,a7@right,a8@right_up,a9@yes>class@yes',
#     0.8398237451305793,
#     1.0,
#     1.0],
#    ['a1@40-49,a2@premeno,a3@20-24,a4@3-5,a5@yes,a6@2,a7@right,a9@yes>class@yes',
#     0.8350800770001792,
#     1.0,
#     1.0]]],
#  ['a1@50-59,a4@3-5,a5@yes,a9@no>class@no',
#   0.8,
#   [['a4@3-5,a5@yes,a8@right_up,a9@no>class@yes', 0.8454264663335099, 0.5, 1.0],
#    ['a1@50-59,a2@ge40,a3@20-24,a4@3-5,a5@yes,a6@3,a7@right,a9@no>class@yes',
#     0.7847562261359418,
#     1.0,
#     1.0],
#    ['a4@3-5,a5@yes,a7@right,a8@right_up,a9@no>class@yes',
#     0.7513891709089401,
#     1.0,
#     1.0]]],
#  ['a1@40-49,a2@premeno,a3@15-19,a4@0-2,a8@left_up,a9@no>class@yes',
#   1.0,
#   [['a1@40-49,a2@premeno,a4@0-2,a7@right,a8@left_up>class@no',
#     0.8434572885476243,
#     0.5,
#     0.8333333333333334],
#    ['a1@40-49,a2@premeno,a4@0-2,a5@no,a6@2,a9@no>class@no',
#     0.7896558430011785,
#     0.5,
#     0.8333333333333334],
#    ['a2@premeno,a4@0-2,a5@no,a6@2,a9@no>class@no',
#     0.7830786819648872,
#     0.5,
#     0.8095238095238095]]],
#  ['a3@30-34,a4@0-2,a5@no,a6@1,a7@right,a9@no>class@no',
#   0.8333333333333334,
#   [['a1@30-39,a2@premeno,a3@30-34,a4@0-2,a5@no,a6@1,a7@right,a8@left_up,a9@no>class@yes',
#     0.8423500388576137,
#     1.0,
#     1.0],
#    ['a1@30-39,a2@premeno,a3@30-34,a4@0-2,a5@no,a7@right,a8@left_up,a9@no>class@yes',
#     0.7949900309887866,
#     1.0,
#     1.0],
#    ['a1@30-39,a2@premeno,a4@0-2,a5@no,a6@1,a7@right,a8@left_up,a9@no>class@yes',
#     0.7598788450168558,
#     1.0,
#     1.0]]],
#  ['a4@0-2,a5@no,a6@1,a7@left,a9@no>class@no',
#   0.92,
#   [['a2@premeno,a3@40-44,a4@0-2,a5@no,a6@1,a7@left,a9@no>class@yes',
#     0.8393949729177499,
#     1.0,
#     1.0],
#    ['a2@premeno,a3@40-44,a4@0-2,a5@no,a6@1,a7@left,a8@left_low,a9@no>class@yes',
#     0.8195786421678634,
#     1.0,
#     1.0],
#    ['a1@40-49,a2@premeno,a3@40-44,a4@0-2,a5@no,a6@1,a7@left,a8@left_low,a9@no>class@yes',
#     0.7862583618340828,
#     1.0,
#     1.0]]],
#  ['a3@25-29,a5@no,a6@2,a8@right_up,a9@no>class@yes',
#   1.0,
#   [['a4@0-2,a5@no,a6@2,a9@no>class@no',
#     0.838237540946642,
#     0.5,
#     0.8333333333333334],
#    ['a2@premeno,a4@0-2,a5@no,a6@2,a9@no>class@no',
#     0.7712339378207606,
#     0.5,
#     0.8095238095238095],
#    ['a1@50-59,a4@0-2,a5@no,a6@2,a9@no>class@no',
#     0.7633690516116158,
#     0.5,
#     0.8095238095238095]]],
#  ['a4@0-2,a5@no,a6@1,a7@right,a9@no>class@no',
#   0.84,
#   [['a1@30-39,a2@premeno,a4@0-2,a5@no,a6@1,a7@right,a8@left_up,a9@no>class@yes',
#     0.8364813419340641,
#     1.0,
#     1.0],
#    ['a1@30-39,a2@premeno,a3@30-34,a4@0-2,a5@no,a6@1,a7@right,a8@left_up,a9@no>class@yes',
#     0.7931798470843543,
#     1.0,
#     1.0],
#    ['a1@30-39,a2@premeno,a4@0-2,a5@no,a7@right,a8@left_up,a9@no>class@yes',
#     0.7773556944975898,
#     1.0,
#     1.0]]],
#  ['a1@50-59,a5@yes,a6@3,a7@right,a8@right_up,a9@no>class@yes',
#   1.0,
#   [['a1@50-59,a2@ge40,a5@yes,a7@right,a9@no>class@no',
#     0.834896869539279,
#     0.5,
#     0.8]]],
#  ['a1@40-49,a2@premeno,a4@0-2,a5@no,a7@right>class@no',
#   0.8275862068965517,
#   [['a2@premeno,a3@30-34,a5@no,a7@right,a8@left_up>class@yes',
#     0.8347768054007706,
#     0.2,
#     0.8],
#    ['a1@40-49,a2@premeno,a4@0-2,a5@no,a6@2,a7@right,a8@left_low,a9@yes>class@yes',
#     0.6657536307262508,
#     1.0,
#     1.0],
#    ['a1@40-49,a2@premeno,a3@50-54,a4@0-2,a5@no,a6@2,a7@right,a8@left_low,a9@yes>class@yes',
#     0.6508801223765321,
#     1.0,
#     1.0]]],
#  ['a2@ge40,a4@3-5,a5@no,a8@left_low>class@yes',
#   1.0,
#   [['a2@ge40,a5@no,a8@left_low,a9@no>class@no',
#     0.8328823067688048,
#     0.5,
#     0.8333333333333334],
#    ['a1@50-59,a2@ge40,a5@no,a8@left_low,a9@no>class@no',
#     0.8142307214609585,
#     0.25,
#     0.8333333333333334],
#    ['a2@ge40,a5@no,a7@left,a8@left_low,a9@no>class@no',
#     0.8041022078383925,
#     0.5,
#     0.85]]],
#  ['a2@premeno,a4@0-2,a6@3,a7@right,a8@left_up,a9@no>class@yes',
#   1.0,
#   [['a1@40-49,a2@premeno,a4@0-2,a7@right,a8@left_up>class@no',
#     0.832333183532693,
#     1.0,
#     0.8333333333333334]]],
#  ['a1@30-39,a2@premeno,a4@0-2,a5@no,a6@1,a8@left_up,a9@no>class@yes',
#   1.0,
#   [['a2@premeno,a3@30-34,a4@0-2,a5@no,a6@1,a9@no>class@no',
#     0.8317453968380067,
#     0.5,
#     0.8],
#    ['a4@0-2,a5@no,a7@left,a8@left_up,a9@no>class@no',
#     0.669563157351506,
#     0.5,
#     0.8]]],
#  ['a2@ge40,a4@3-5,a6@3,a7@right>class@yes',
#   0.8,
#   [['a2@ge40,a5@yes,a7@right,a8@left_up>class@no',
#     0.8298482039724037,
#     0.2,
#     1.0],
#    ['a1@50-59,a2@ge40,a4@3-5,a5@yes,a6@3,a7@right,a8@left_up,a9@no>class@no',
#     0.791998746918713,
#     1.0,
#     1.0],
#    ['a2@ge40,a5@yes,a6@3,a7@right,a8@left_up,a9@no>class@no',
#     0.7677842378337989,
#     0.5,
#     1.0]]],
#  ['a2@ge40,a4@0-2,a5@no,a8@left_up,a9@yes>class@no',
#   0.8333333333333334,
#   [['a2@ge40,a3@30-34,a4@0-2,a5@no,a6@3,a8@left_up,a9@yes>class@yes',
#     0.828663138847997,
#     1.0,
#     1.0],
#    ['a2@ge40,a3@30-34,a5@no,a6@3,a8@left_up,a9@yes>class@yes',
#     0.8089426854358434,
#     1.0,
#     1.0],
#    ['a2@ge40,a3@30-34,a4@0-2,a5@no,a6@3,a7@right,a8@left_up,a9@yes>class@yes',
#     0.8018934240888999,
#     1.0,
#     1.0]]],
#  ['a1@60-69,a2@ge40,a3@20-24,a5@no,a6@2,a7@left,a8@left_low>class@yes',
#   1.0,
#   [['a1@60-69,a2@ge40,a5@no,a7@left>class@no',
#     0.8283926347067812,
#     1.0,
#     0.8947368421052632]]],
#  ['a1@60-69,a2@ge40,a3@30-34,a5@yes,a7@left,a8@central>class@yes',
#   1.0,
#   [['a1@60-69,a2@ge40,a3@30-34,a7@left>class@no',
#     0.8274427346728318,
#     1.0,
#     0.8571428571428571]]],
#  ['a3@30-34,a4@0-2,a5@no,a6@1,a8@left_up,a9@no>class@no',
#   0.8,
#   [['a1@30-39,a2@premeno,a3@30-34,a4@0-2,a5@no,a6@1,a7@right,a8@left_up,a9@no>class@yes',
#     0.8273013657988659,
#     1.0,
#     1.0],
#    ['a1@30-39,a2@premeno,a3@30-34,a4@0-2,a5@no,a7@right,a8@left_up,a9@no>class@yes',
#     0.7768218042934603,
#     1.0,
#     1.0],
#    ['a1@30-39,a2@premeno,a4@0-2,a5@no,a6@1,a7@right,a8@left_up,a9@no>class@yes',
#     0.7408070726994563,
#     1.0,
#     1.0]]],
#  ['a1@40-49,a2@premeno,a4@0-2,a5@no,a8@left_up>class@no',
#   0.8125,
#   [['a2@premeno,a3@30-34,a5@no,a7@right,a8@left_up>class@yes',
#     0.8259329654406515,
#     0.2,
#     0.8],
#    ['a1@40-49,a2@premeno,a3@15-19,a4@0-2,a5@no,a7@left,a8@left_up,a9@no>class@yes',
#     0.7963655955688766,
#     1.0,
#     1.0],
#    ['a1@40-49,a2@premeno,a3@15-19,a4@0-2,a5@no,a6@2,a7@left,a8@left_up,a9@no>class@yes',
#     0.7560122393820348,
#     1.0,
#     1.0]]],
#  ['a1@50-59,a2@ge40,a7@right,a8@left_up,a9@no>class@no',
#   0.8888888888888888,
#   [['a1@50-59,a2@ge40,a3@30-34,a5@no,a6@3,a7@right,a8@left_up,a9@no>class@yes',
#     0.8258970934530313,
#     1.0,
#     1.0],
#    ['a2@ge40,a3@30-34,a5@no,a6@3,a7@right,a8@left_up,a9@no>class@yes',
#     0.7890739923494327,
#     1.0,
#     1.0],
#    ['a1@50-59,a2@ge40,a4@3-5,a5@no,a6@3,a7@right,a9@no>class@yes',
#     0.7532196406163187,
#     1.0,
#     1.0]]],
#  ['a1@50-59,a2@lt40,a3@20-24,a4@0-2,a5@?,a6@1,a7@left,a8@left_up,a9@no>class@yes',
#   1.0,
#   [['a1@50-59,a4@0-2,a7@left,a8@left_up,a9@no>class@no',
#     0.8252806493682472,
#     1.0,
#     0.8888888888888888],
#    ['a1@50-59,a4@0-2,a8@left_up,a9@no>class@no',
#     0.6916231209657887,
#     1.0,
#     0.8947368421052632]]],
#  ['a1@50-59,a4@0-2,a5@no,a6@3,a9@no>class@no',
#   0.8181818181818182,
#   [['a1@50-59,a2@ge40,a3@30-34,a4@0-2,a5@no,a6@3,a7@left,a9@no>class@yes',
#     0.8238974376766385,
#     1.0,
#     1.0],
#    ['a1@50-59,a2@ge40,a3@30-34,a4@0-2,a5@no,a6@3,a7@left,a8@?,a9@no>class@yes',
#     0.8044469773252452,
#     1.0,
#     1.0],
#    ['a1@50-59,a2@ge40,a3@30-34,a5@no,a6@3,a7@left,a9@no>class@yes',
#     0.8004721825011666,
#     0.5,
#     1.0]]],
#  ['a2@premeno,a3@15-19,a4@0-2,a8@left_up,a9@no>class@yes',
#   1.0,
#   [['a1@40-49,a2@premeno,a4@0-2,a7@right,a8@left_up>class@no',
#     0.8231588909286874,
#     0.5,
#     0.8333333333333334],
#    ['a2@premeno,a4@0-2,a5@no,a6@2,a9@no>class@no',
#     0.7859508150783062,
#     0.5,
#     0.8095238095238095],
#    ['a1@40-49,a2@premeno,a4@0-2,a5@no,a6@2,a9@no>class@no',
#     0.7691356011806995,
#     0.5,
#     0.8333333333333334]]],
#  ['a4@0-2,a5@no,a7@right,a9@no>class@no',
#   0.8,
#   [['a1@30-39,a2@premeno,a4@0-2,a5@no,a7@right,a8@left_up,a9@no>class@yes',
#     0.8222031364670433,
#     1.0,
#     1.0],
#    ['a1@30-39,a2@premeno,a4@0-2,a5@no,a6@1,a7@right,a8@left_up,a9@no>class@yes',
#     0.80363064978091,
#     1.0,
#     1.0],
#    ['a1@60-69,a2@ge40,a3@50-54,a4@0-2,a5@no,a7@right,a9@no>class@yes',
#     0.7700474504343202,
#     1.0,
#     1.0]]],
#  ['a3@30-34,a4@3-5,a5@yes,a8@left_low,a9@no>class@no',
#   1.0,
#   [['a3@30-34,a5@yes,a6@3,a9@no>class@yes', 0.81836703341902, 0.5, 0.8],
#    ['a5@yes,a6@3,a7@left,a8@left_low>class@yes',
#     0.6032477957693826,
#     0.5,
#     0.875],
#    ['a5@yes,a6@3,a7@left>class@yes',
#     0.5273052736212567,
#     0.5,
#     0.8461538461538461]]],
#  ['a1@40-49,a2@premeno,a4@0-2,a5@no,a6@2,a8@left_up>class@no',
#   0.875,
#   [['a1@40-49,a2@premeno,a3@15-19,a4@0-2,a5@no,a6@2,a7@left,a8@left_up,a9@no>class@yes',
#     0.8175543040546772,
#     1.0,
#     1.0],
#    ['a2@premeno,a3@15-19,a4@0-2,a5@no,a6@2,a7@left,a8@left_up,a9@no>class@yes',
#     0.796401370385499,
#     1.0,
#     1.0],
#    ['a1@40-49,a2@premeno,a3@15-19,a4@0-2,a5@no,a7@left,a8@left_up,a9@no>class@yes',
#     0.7394873312618983,
#     1.0,
#     1.0]]],
#  ['a1@50-59,a2@premeno,a4@0-2,a5@no,a6@3,a7@right,a8@left_low,a9@yes>class@yes',
#   1.0,
#   [['a2@premeno,a4@0-2,a6@3,a7@right,a9@yes>class@no',
#     0.816100460434744,
#     1.0,
#     0.8]]],
#  ['a4@0-2,a5@no,a7@left,a8@left_low,a9@no>class@no',
#   0.8461538461538461,
#   [['a2@premeno,a3@40-44,a4@0-2,a5@no,a6@1,a7@left,a8@left_low,a9@no>class@yes',
#     0.8159858908267638,
#     1.0,
#     1.0],
#    ['a1@40-49,a2@premeno,a3@40-44,a4@0-2,a5@no,a6@1,a7@left,a8@left_low,a9@no>class@yes',
#     0.7823491336530689,
#     1.0,
#     1.0],
#    ['a2@premeno,a3@40-44,a4@0-2,a5@no,a6@1,a7@left,a9@no>class@yes',
#     0.7542914906403048,
#     0.5,
#     1.0]]],
#  ['a4@0-2,a5@no,a6@1,a8@left_low,a9@no>class@no',
#   0.8888888888888888,
#   [['a2@premeno,a3@40-44,a4@0-2,a5@no,a6@1,a7@left,a8@left_low,a9@no>class@yes',
#     0.8141418328468971,
#     1.0,
#     1.0],
#    ['a1@40-49,a2@premeno,a3@40-44,a4@0-2,a5@no,a6@1,a7@left,a8@left_low,a9@no>class@yes',
#     0.7824080543775358,
#     1.0,
#     1.0],
#    ['a2@premeno,a3@40-44,a4@0-2,a5@no,a6@1,a7@left,a9@no>class@yes',
#     0.7492576529797202,
#     0.5,
#     1.0]]],
#  ['a3@30-34,a4@0-2,a5@no,a8@left_up,a9@no>class@no',
#   0.8,
#   [['a1@30-39,a2@premeno,a3@30-34,a4@0-2,a5@no,a7@right,a8@left_up,a9@no>class@yes',
#     0.8139842535239807,
#     1.0,
#     1.0],
#    ['a1@30-39,a2@premeno,a3@30-34,a4@0-2,a5@no,a6@1,a7@right,a8@left_up,a9@no>class@yes',
#     0.7984422632961938,
#     1.0,
#     1.0],
#    ['a1@30-39,a2@premeno,a3@30-34,a5@no,a8@left_up>class@yes',
#     0.7424804297153241,
#     0.6,
#     0.8]]],
#  ['a1@50-59,a2@ge40,a3@30-34,a6@3,a7@left,a8@left_low,a9@yes>class@no',
#   1.0,
#   [['a6@3,a7@left,a8@left_low,a9@yes>class@yes',
#     0.812472494496459,
#     1.0,
#     0.8333333333333334]]],
#  ['a3@25-29,a5@no,a7@left,a8@left_low,a9@yes>class@yes',
#   1.0,
#   [['a4@0-2,a5@no,a6@2,a7@left,a9@yes>class@no',
#     0.8123016031325135,
#     0.5,
#     0.875],
#    ['a2@premeno,a4@0-2,a5@no,a6@2,a7@left,a9@yes>class@no',
#     0.7442305786153044,
#     0.5,
#     0.8],
#    ['a2@ge40,a3@25-29,a5@no,a8@left_low>class@no',
#     0.5538385472580983,
#     0.5,
#     0.8333333333333334]]],
#  ['a1@40-49,a2@premeno,a3@15-19,a4@0-2,a6@3,a7@right,a8@left_up,a9@no>class@yes',
#   1.0,
#   [['a1@40-49,a2@premeno,a4@0-2,a7@right,a8@left_up>class@no',
#     0.8122076520944119,
#     1.0,
#     0.8333333333333334]]],
#  ['a1@50-59,a2@premeno,a4@0-2,a5@no,a6@2,a7@left,a8@right_up,a9@no>class@yes',
#   1.0,
#   [['a2@premeno,a4@0-2,a5@no,a6@2,a9@no>class@no',
#     0.8109164555995323,
#     1.0,
#     0.8095238095238095],
#    ['a4@0-2,a5@no,a6@2,a9@no>class@no',
#     0.7606982837228097,
#     1.0,
#     0.8333333333333334],
#    ['a1@50-59,a4@0-2,a5@no,a6@2,a9@no>class@no',
#     0.7029322242336001,
#     1.0,
#     0.8095238095238095]]],
#  ['a2@premeno,a4@3-5,a5@yes,a6@2,a7@right,a8@right_up>class@yes',
#   1.0,
#   [['a2@premeno,a6@2,a7@right,a8@right_up>class@no',
#     0.8102228903306097,
#     1.0,
#     0.8]]],
#  ['a1@40-49,a2@premeno,a4@3-5,a5@yes,a6@2,a7@right,a8@right_up>class@yes',
#   1.0,
#   [['a2@premeno,a6@2,a7@right,a8@right_up>class@no',
#     0.8101064486222584,
#     1.0,
#     0.8]]],
#  ['a2@ge40,a3@25-29,a7@right,a9@no>class@no',
#   0.8333333333333334,
#   [['a2@ge40,a3@25-29,a4@3-5,a5@no,a6@2,a7@right,a9@no>class@yes',
#     0.8097010256845449,
#     1.0,
#     1.0],
#    ['a1@60-69,a2@ge40,a3@25-29,a4@3-5,a5@no,a6@2,a7@right,a9@no>class@yes',
#     0.7904221478163739,
#     1.0,
#     1.0],
#    ['a2@ge40,a3@25-29,a4@3-5,a5@no,a6@2,a7@right,a8@right_up,a9@no>class@yes',
#     0.7847141681418282,
#     1.0,
#     1.0]]],
#  ['a1@40-49,a2@premeno,a4@0-2,a5@no,a7@right,a9@no>class@no',
#   0.84,
#   [['a2@premeno,a3@30-34,a5@no,a7@right,a8@left_up>class@yes',
#     0.8089668178121555,
#     0.2,
#     0.8]]],
#  ['a1@30-39,a2@premeno,a4@0-2,a5@no,a8@left_up>class@yes',
#   0.8,
#   [['a1@30-39,a2@premeno,a4@0-2,a5@no,a6@2,a9@no>class@no',
#     0.8075289647087901,
#     0.4,
#     0.8],
#    ['a2@premeno,a4@0-2,a5@no,a6@2,a9@no>class@no',
#     0.7736613835599793,
#     0.4,
#     0.8095238095238095],
#    ['a2@premeno,a3@30-34,a4@0-2,a5@no,a6@1,a9@no>class@no',
#     0.7256196458005294,
#     0.2,
#     0.8]]],
#  ['a1@60-69,a2@ge40,a3@30-34,a5@yes,a7@left,a9@yes>class@yes',
#   1.0,
#   [['a1@60-69,a2@ge40,a3@30-34,a7@left>class@no',
#     0.8070664380154435,
#     1.0,
#     0.8571428571428571]]],
#  ['a1@40-49,a2@premeno,a5@yes,a9@no>class@yes',
#   0.8571428571428571,
#   [['a1@40-49,a2@premeno,a5@yes,a6@2,a7@right,a8@left_low,a9@no>class@no',
#     0.8069005629496669,
#     1.0,
#     1.0],
#    ['a2@premeno,a4@3-5,a5@yes,a6@2,a7@right,a8@left_low,a9@no>class@no',
#     0.7784151425089679,
#     1.0,
#     1.0],
#    ['a2@premeno,a5@yes,a6@2,a7@right,a8@left_low,a9@no>class@no',
#     0.7775774010607541,
#     1.0,
#     1.0]]],
#  ['a1@50-59,a6@3,a8@left_up,a9@no>class@no',
#   0.875,
#   [['a1@50-59,a2@ge40,a3@30-34,a5@no,a6@3,a7@right,a8@left_up,a9@no>class@yes',
#     0.8041028008987362,
#     1.0,
#     1.0],
#    ['a2@ge40,a3@30-34,a5@no,a6@3,a7@right,a8@left_up,a9@no>class@yes',
#     0.7571664003209465,
#     1.0,
#     1.0],
#    ['a3@30-34,a4@3-5,a5@no,a6@3,a7@right,a8@left_up,a9@no>class@yes',
#     0.6999872236791884,
#     1.0,
#     1.0]]],
#  ['a4@0-2,a5@no,a8@left_up,a9@no>class@no',
#   0.8043478260869565,
#   [['a1@30-39,a2@premeno,a4@0-2,a5@no,a7@right,a8@left_up,a9@no>class@yes',
#     0.8039333272329925,
#     1.0,
#     1.0],
#    ['a1@30-39,a2@premeno,a4@0-2,a5@no,a6@1,a7@right,a8@left_up,a9@no>class@yes',
#     0.7868941941166998,
#     1.0,
#     1.0],
#    ['a1@30-39,a2@premeno,a3@30-34,a4@0-2,a5@no,a7@right,a8@left_up,a9@no>class@yes',
#     0.7500299617548397,
#     1.0,
#     1.0]]],
#  ['a1@30-39,a2@premeno,a6@3,a9@yes>class@yes',
#   0.8,
#   [['a2@premeno,a3@40-44,a4@3-5,a6@3,a7@right,a9@yes>class@no',
#     0.8025480797247632,
#     0.5,
#     1.0],
#    ['a1@30-39,a2@premeno,a4@3-5,a5@no,a6@3,a7@right,a8@right_up,a9@yes>class@no',
#     0.6189451609678904,
#     1.0,
#     1.0],
#    ['a1@30-39,a2@premeno,a3@40-44,a4@3-5,a5@no,a6@3,a7@right,a8@right_up,a9@yes>class@no',
#     0.6040024270079073,
#     1.0,
#     1.0]]],
#  ['a1@40-49,a2@premeno,a5@no,a6@2,a8@left_up>class@no',
#   0.8,
#   [['a1@40-49,a2@premeno,a3@15-19,a4@0-2,a5@no,a6@2,a7@left,a8@left_up,a9@no>class@yes',
#     0.8009137743074393,
#     1.0,
#     1.0],
#    ['a1@40-49,a2@premeno,a3@30-34,a4@3-5,a5@no,a6@2,a7@right,a8@left_up,a9@no>class@yes',
#     0.7878292763469547,
#     1.0,
#     1.0],
#    ['a2@premeno,a3@15-19,a4@0-2,a5@no,a6@2,a7@left,a8@left_up,a9@no>class@yes',
#     0.777076435106643,
#     1.0,
#     1.0]]],
#  ['a4@0-2,a5@no,a7@left,a9@no>class@no',
#   0.825,
#   [['a2@premeno,a3@40-44,a4@0-2,a5@no,a6@1,a7@left,a9@no>class@yes',
#     0.7991924361725905,
#     1.0,
#     1.0],
#    ['a2@premeno,a3@40-44,a4@0-2,a5@no,a6@1,a7@left,a8@left_low,a9@no>class@yes',
#     0.7828004921672331,
#     1.0,
#     1.0],
#    ['a1@40-49,a2@premeno,a3@40-44,a4@0-2,a5@no,a6@1,a7@left,a8@left_low,a9@no>class@yes',
#     0.7498331832338464,
#     1.0,
#     1.0]]],
#  ['a1@50-59,a2@premeno,a4@0-2,a5@no,a8@right_up,a9@no>class@yes',
#   1.0,
#   [['a2@premeno,a4@0-2,a5@no,a6@2,a9@no>class@no',
#     0.7989434035733858,
#     0.5,
#     0.8095238095238095],
#    ['a4@0-2,a5@no,a6@2,a9@no>class@no',
#     0.7196731582610054,
#     0.5,
#     0.8333333333333334],
#    ['a2@premeno,a3@30-34,a4@0-2,a5@no,a7@left,a9@no>class@no',
#     0.6525506843563191,
#     0.5,
#     0.8]]],
#  ['a4@0-2,a5@no,a6@2,a9@yes>class@no',
#   0.8181818181818182,
#   [['a3@50-54,a4@0-2,a5@no,a6@2,a7@right,a8@left_low,a9@yes>class@yes',
#     0.7971036445740591,
#     1.0,
#     1.0],
#    ['a2@premeno,a4@0-2,a5@no,a6@2,a7@right,a8@left_low,a9@yes>class@yes',
#     0.7650309342357274,
#     1.0,
#     1.0],
#    ['a1@40-49,a2@premeno,a4@0-2,a5@no,a6@2,a7@right,a8@left_low,a9@yes>class@yes',
#     0.7473007603909957,
#     1.0,
#     1.0]]],
#  ['a2@ge40,a4@3-5,a5@no,a7@right,a9@no>class@yes',
#   1.0,
#   [['a2@ge40,a5@no,a9@no>class@no',
#     0.7965341103674409,
#     1.0,
#     0.8235294117647058],
#    ['a1@50-59,a2@ge40,a5@no,a9@no>class@no',
#     0.7469476120471741,
#     0.5,
#     0.8529411764705882],
#    ['a2@ge40,a3@25-29,a5@no,a9@no>class@no', 0.7218910246622287, 0.5, 0.875]]],
#  ['a1@40-49,a2@premeno,a3@30-34,a5@yes,a9@no>class@yes',
#   0.8,
#   [['a1@40-49,a2@premeno,a3@30-34,a5@yes,a6@2,a7@right,a8@left_low,a9@no>class@no',
#     0.796040447654593,
#     1.0,
#     1.0],
#    ['a1@40-49,a2@premeno,a3@30-34,a4@3-5,a5@yes,a6@2,a7@right,a8@left_low,a9@no>class@no',
#     0.7943116028363876,
#     1.0,
#     1.0],
#    ['a2@premeno,a3@30-34,a4@3-5,a5@yes,a6@2,a7@right,a8@left_low,a9@no>class@no',
#     0.7702013632616991,
#     1.0,
#     1.0]]],
#  ['a1@50-59,a2@premeno,a3@30-34,a4@0-2,a5@no,a6@3,a7@left,a8@right_up,a9@no>class@yes',
#   1.0,
#   [['a2@premeno,a3@30-34,a4@0-2,a5@no,a7@left,a9@no>class@no',
#     0.7941220159964245,
#     1.0,
#     0.8]]],
#  ['a1@50-59,a2@ge40,a7@right,a9@no>class@no',
#   0.8636363636363636,
#   [['a1@50-59,a2@ge40,a4@3-5,a5@no,a6@3,a7@right,a9@no>class@yes',
#     0.7934727595654105,
#     1.0,
#     1.0],
#    ['a1@50-59,a2@ge40,a3@30-34,a5@no,a6@3,a7@right,a8@left_up,a9@no>class@yes',
#     0.7829216872451363,
#     1.0,
#     1.0],
#    ['a1@50-59,a2@ge40,a3@30-34,a4@3-5,a5@no,a6@3,a7@right,a9@no>class@yes',
#     0.7542338746088166,
#     1.0,
#     1.0]]],
#  ['a1@50-59,a2@premeno,a4@0-2,a5@no,a7@left,a8@right_up,a9@no>class@yes',
#   1.0,
#   [['a2@premeno,a3@30-34,a4@0-2,a5@no,a7@left,a9@no>class@no',
#     0.7924567212612054,
#     0.5,
#     0.8],
#    ['a2@premeno,a4@0-2,a5@no,a6@2,a9@no>class@no',
#     0.7255207781469536,
#     0.5,
#     0.8095238095238095],
#    ['a4@0-2,a5@no,a6@2,a9@no>class@no',
#     0.6516380837300275,
#     0.5,
#     0.8333333333333334]]],
#  ['a5@no,a6@2,a7@right,a8@right_up,a9@no>class@no',
#   0.8333333333333334,
#   [['a2@ge40,a4@3-5,a5@no,a6@2,a7@right,a8@right_up,a9@no>class@yes',
#     0.7919819332316983,
#     1.0,
#     1.0],
#    ['a2@ge40,a3@25-29,a4@3-5,a5@no,a6@2,a7@right,a8@right_up,a9@no>class@yes',
#     0.7457676930444032,
#     1.0,
#     1.0],
#    ['a2@ge40,a4@3-5,a5@no,a6@2,a7@right,a9@no>class@yes',
#     0.7373846499965814,
#     1.0,
#     1.0]]],
#  ['a1@50-59,a2@ge40,a8@left_up,a9@no>class@no',
#   0.9333333333333333,
#   [['a1@50-59,a2@ge40,a3@30-34,a5@no,a6@3,a7@right,a8@left_up,a9@no>class@yes',
#     0.791497915831653,
#     1.0,
#     1.0],
#    ['a2@ge40,a3@30-34,a5@no,a6@3,a7@right,a8@left_up,a9@no>class@yes',
#     0.7461411345942425,
#     1.0,
#     1.0],
#    ['a1@50-59,a2@ge40,a4@3-5,a5@no,a6@3,a7@right,a9@no>class@yes',
#     0.6890074036523177,
#     1.0,
#     1.0]]],
#  ['a1@40-49,a2@premeno,a4@0-2,a5@no,a6@1,a7@right,a9@no>class@no',
#   0.8888888888888888,
#   [['a2@premeno,a3@30-34,a5@no,a7@right,a8@left_up>class@yes',
#     0.7912816646540002,
#     0.2,
#     0.8]]],
#  ['a1@50-59,a5@no,a7@right,a8@left_up,a9@no>class@no',
#   0.8,
#   [['a1@50-59,a2@ge40,a3@30-34,a5@no,a6@3,a7@right,a8@left_up,a9@no>class@yes',
#     0.79105323844037,
#     1.0,
#     1.0],
#    ['a3@30-34,a4@3-5,a5@no,a7@right,a8@left_up,a9@no>class@yes',
#     0.7713305562894942,
#     0.5,
#     1.0],
#    ['a2@ge40,a3@30-34,a5@no,a6@3,a7@right,a8@left_up,a9@no>class@yes',
#     0.7543795226165868,
#     1.0,
#     1.0]]],
#  ['a2@premeno,a3@15-19,a4@0-2,a6@3,a7@right,a8@left_up,a9@no>class@yes',
#   1.0,
#   [['a1@40-49,a2@premeno,a4@0-2,a7@right,a8@left_up>class@no',
#     0.7897479000503189,
#     1.0,
#     0.8333333333333334]]],
#  ['a2@ge40,a3@20-24,a5@no,a6@2,a7@left,a8@left_low>class@yes',
#   1.0,
#   [['a1@60-69,a2@ge40,a5@no,a7@left>class@no',
#     0.7887365849734466,
#     1.0,
#     0.8947368421052632]]],
#  ['a2@premeno,a3@20-24,a6@2,a7@right>class@no',
#   0.8571428571428571,
#   [['a1@40-49,a2@premeno,a3@20-24,a5@yes,a6@2,a7@right,a9@yes>class@yes',
#     0.7886303696809194,
#     1.0,
#     1.0],
#    ['a1@40-49,a2@premeno,a3@20-24,a4@3-5,a5@yes,a6@2,a7@right,a9@yes>class@yes',
#     0.77430562883454,
#     1.0,
#     1.0],
#    ['a1@40-49,a2@premeno,a3@20-24,a4@3-5,a5@yes,a6@2,a7@right,a8@right_up,a9@yes>class@yes',
#     0.7532349957034497,
#     1.0,
#     1.0]]],
#  ['a1@50-59,a2@premeno,a3@25-29,a4@0-2,a5@no,a6@3,a7@right,a8@left_low,a9@yes>class@yes',
#   1.0,
#   [['a2@premeno,a4@0-2,a6@3,a7@right,a9@yes>class@no',
#     0.7885072497040728,
#     1.0,
#     0.8]]],
#  ['a1@50-59,a2@premeno,a3@25-29,a4@0-2,a5@no,a6@2,a7@left,a8@right_up,a9@no>class@yes',
#   1.0,
#   [['a2@premeno,a4@0-2,a5@no,a6@2,a9@no>class@no',
#     0.7875048348930509,
#     1.0,
#     0.8095238095238095],
#    ['a4@0-2,a5@no,a6@2,a9@no>class@no',
#     0.7196642780338172,
#     1.0,
#     0.8333333333333334],
#    ['a1@50-59,a4@0-2,a5@no,a6@2,a9@no>class@no',
#     0.6653220172970538,
#     1.0,
#     0.8095238095238095]]],
#  ['a1@30-39,a2@premeno,a5@no,a8@left_up>class@yes',
#   0.8571428571428571,
#   [['a1@30-39,a2@premeno,a4@0-2,a5@no,a6@2,a9@no>class@no',
#     0.7872888160495684,
#     0.2857142857142857,
#     0.8],
#    ['a2@premeno,a4@0-2,a5@no,a6@2,a9@no>class@no',
#     0.7482978361926723,
#     0.2857142857142857,
#     0.8095238095238095],
# ...
#     0.41152438077769654,
#     0.75,
#     0.8235294117647058],
#    ['a2@ge40,a5@no,a7@left,a9@no>class@no',
#     0.3894036066957051,
#     0.5,
#     0.8888888888888888]]],
#  ['a2@premeno,a3@25-29,a7@right,a9@yes>class@no',
#   0.8,
#   [['a1@50-59,a2@premeno,a3@25-29,a6@3,a8@left_low,a9@yes>class@yes',
#     0.5343165858749552,
#     0.5,
#     1.0],
#    ['a1@50-59,a2@premeno,a6@3,a8@left_low,a9@yes>class@yes',
#     0.4479401942715881,
#     0.5,
#     1.0],
#    ['a1@50-59,a2@premeno,a3@25-29,a4@0-2,a5@no,a6@3,a9@yes>class@yes',
#     0.43809717458283803,
#     1.0,
#     1.0]]],
#  ['a4@6-8,a5@yes,a6@3,a8@left_up>class@yes',
#   1.0,
#   [['a2@ge40,a6@3,a7@left,a8@left_up>class@no',
#     0.5334523864801931,
#     0.5,
#     0.8]]],
#  ['a4@3-5,a5@yes,a6@3,a8@left_low,a9@yes>class@yes',
#   1.0,
#   [['a1@50-59,a3@25-29,a5@yes>class@no', 0.5333298143191674, 0.5, 0.8],
#    ['a1@50-59,a2@premeno,a7@left,a8@left_low>class@no',
#     0.16503490491920803,
#     0.5,
#     0.8181818181818182]]],
#  ['a1@40-49,a2@premeno,a3@20-24,a4@3-5,a5@yes,a7@right,a9@yes>class@yes',
#   1.0,
#   [['a2@premeno,a6@2,a7@right,a8@right_up>class@no',
#     0.5284120216758177,
#     1.0,
#     0.8]]],
#  ['a2@ge40,a3@20-24,a4@3-5,a5@no,a8@left_low,a9@yes>class@yes',
#   1.0,
#   [['a1@60-69,a2@ge40,a5@no,a7@left>class@no',
#     0.5257737592822628,
#     0.5,
#     0.8947368421052632]]],
#  ['a1@60-69,a2@ge40,a3@25-29,a4@0-2,a5@no,a6@3,a9@yes>class@yes',
#   1.0,
#   [['a1@60-69,a2@ge40,a4@0-2,a5@no,a7@left>class@no',
#     0.5203568155880332,
#     1.0,
#     0.9444444444444444],
#    ['a1@60-69,a2@ge40,a5@no,a7@left>class@no',
#     0.5140120555008637,
#     1.0,
#     0.8947368421052632],
#    ['a2@ge40,a4@0-2,a5@no,a7@left>class@no',
#     0.47364332082954,
#     1.0,
#     0.918918918918919]]],
#  ['a2@ge40,a5@no,a6@3,a9@yes>class@yes',
#   0.8,
#   [['a2@ge40,a3@30-34,a4@0-2,a5@no,a8@left_up>class@no',
#     0.519431034805373,
#     0.2,
#     0.8333333333333334],
#    ['a2@ge40,a3@15-19,a4@0-2,a5@no>class@no', 0.5157997949364087, 0.2, 1.0],
#    ['a2@ge40,a4@0-2,a5@no,a8@left_up>class@no',
#     0.510714768595956,
#     0.4,
#     0.8888888888888888]]],
#  ['a3@30-34,a5@no,a6@3,a8@left_up,a9@yes>class@yes',
#   1.0,
#   [['a2@ge40,a3@30-34,a4@0-2,a5@no,a8@left_up>class@no',
#     0.5123563537042426,
#     0.5,
#     0.8333333333333334],
#    ['a2@ge40,a4@0-2,a5@no,a8@left_up>class@no',
#     0.3858340138510006,
#     0.5,
#     0.8888888888888888],
#    ['a1@60-69,a2@ge40,a4@0-2,a5@no,a8@left_up>class@no',
#     0.38388654033189185,
#     0.5,
#     0.8666666666666667]]],
#  ['a1@30-39,a2@premeno,a3@25-29>class@no',
#   0.8,
#   [['a1@30-39,a2@premeno,a3@25-29,a4@3-5,a5@yes,a6@3,a7@left,a8@left_low,a9@yes>class@yes',
#     0.5121188092835587,
#     1.0,
#     1.0],
#    ['a1@30-39,a2@premeno,a6@3,a7@left,a9@yes>class@yes',
#     0.5059446374062521,
#     0.3333333333333333,
#     1.0],
#    ['a1@30-39,a2@premeno,a5@yes,a7@left,a8@left_low>class@yes',
#     0.4885311875010662,
#     0.3333333333333333,
#     1.0]]],
#  ['a2@premeno,a3@15-19,a6@3,a7@right,a8@left_up>class@yes',
#   1.0,
#   [['a1@40-49,a2@premeno,a4@0-2,a7@right,a8@left_up>class@no',
#     0.5117749197409178,
#     1.0,
#     0.8333333333333334]]],
#  ['a1@40-49,a2@premeno,a3@15-19,a6@3,a9@no>class@yes',
#   1.0,
#   [['a1@40-49,a2@premeno,a4@0-2,a7@right,a8@left_up>class@no',
#     0.5031046975622929,
#     0.5,
#     0.8333333333333334]]],
#  ['a3@20-24,a5@no,a7@left,a8@left_low,a9@yes>class@yes',
#   1.0,
#   [['a1@60-69,a2@ge40,a5@no,a7@left>class@no',
#     0.5017802952900701,
#     1.0,
#     0.8947368421052632]]],
#  ['a3@25-29,a6@3,a7@left>class@yes',
#   0.875,
#   [['a1@50-59,a3@25-29,a5@yes>class@no', 0.501496832340876, 0.2, 0.8],
#    ['a1@50-59,a2@premeno,a7@left,a8@left_low>class@no',
#     0.392301001743652,
#     0.125,
#     0.8181818181818182],
#    ['a2@ge40,a3@25-29,a4@0-2,a5@no,a7@left,a9@no>class@no',
#     0.20221486399946756,
#     0.25,
#     1.0]]],
#  ['a3@30-34,a5@no,a6@3,a7@right,a8@left_up,a9@yes>class@yes',
#   1.0,
#   [['a2@ge40,a3@30-34,a4@0-2,a5@no,a8@left_up>class@no',
#     0.4980462214712517,
#     0.5,
#     0.8333333333333334],
#    ['a2@ge40,a4@0-2,a5@no,a8@left_up>class@no',
#     0.3848445423111415,
#     0.5,
#     0.8888888888888888],
#    ['a1@60-69,a2@ge40,a4@0-2,a5@no,a8@left_up>class@no',
#     0.38162941351240715,
#     0.5,
#     0.8666666666666667]]],
#  ['a4@6-8,a5@yes,a6@3,a8@left_up,a9@yes>class@yes',
#   1.0,
#   [['a2@ge40,a6@3,a7@left,a8@left_up>class@no',
#     0.4954393935614926,
#     1.0,
#     0.8]]],
#  ['a1@50-59,a3@25-29,a5@no,a6@3,a9@yes>class@yes',
#   1.0,
#   [['a2@premeno,a4@0-2,a6@3,a7@right,a9@yes>class@no',
#     0.4945510657265597,
#     0.5,
#     0.8],
#    ['a2@ge40,a3@25-29,a5@no,a8@left_low>class@no',
#     0.44106201268125167,
#     0.5,
#     0.8333333333333334]]],
#  ['a1@50-59,a2@premeno,a3@25-29,a6@3,a9@yes>class@yes',
#   1.0,
#   [['a2@premeno,a4@0-2,a6@3,a7@right,a9@yes>class@no',
#     0.48897219207552767,
#     0.5,
#     0.8],
#    ['a1@50-59,a3@25-29,a5@yes>class@no', 0.4856461441828311, 0.5, 0.8],
#    ['a1@50-59,a2@premeno,a7@left,a8@left_low>class@no',
#     0.41442873310064904,
#     0.5,
#     0.8181818181818182]]],
#  ['a3@25-29,a6@3,a7@left,a9@yes>class@yes',
#   1.0,
#   [['a1@50-59,a3@25-29,a5@yes>class@no', 0.4873112714316555, 0.2, 0.8],
#    ['a1@50-59,a2@premeno,a7@left,a8@left_low>class@no',
#     0.25979356729466335,
#     0.2,
#     0.8181818181818182]]],
#  ['a1@40-49,a3@30-34,a4@3-5,a5@no,a6@3,a7@left,a8@left_low,a9@no>class@yes',
#   1.0,
#   [['a2@ge40,a5@no,a7@left,a8@left_low,a9@no>class@no',
#     0.48154856174928606,
#     1.0,
#     0.85],
#    ['a2@ge40,a5@no,a7@left,a9@no>class@no',
#     0.4224628593354798,
#     1.0,
#     0.8888888888888888],
#    ['a2@ge40,a5@no,a8@left_low,a9@no>class@no',
#     0.3874889971414926,
#     1.0,
#     0.8333333333333334]]],
#  ['a3@25-29,a6@3,a8@left_low,a9@yes>class@yes',
#   1.0,
#   [['a1@50-59,a3@25-29,a5@yes>class@no', 0.480766698521961, 0.25, 0.8],
#    ['a1@50-59,a2@premeno,a7@left,a8@left_low>class@no',
#     0.23484132382801026,
#     0.25,
#     0.8181818181818182],
#    ['a2@premeno,a4@0-2,a6@3,a7@right,a9@yes>class@no',
#     0.20889638273248345,
#     0.25,
#     0.8]]],
#  ['a1@40-49,a3@20-24,a4@3-5,a7@right,a9@yes>class@yes',
#   1.0,
#   [['a2@premeno,a6@2,a7@right,a8@right_up>class@no',
#     0.4760225624629753,
#     0.5,
#     0.8]]],
#  ['a2@premeno,a3@25-29,a6@3,a8@left_low,a9@yes>class@yes',
#   1.0,
#   [['a1@50-59,a2@premeno,a7@left,a8@left_low>class@no',
#     0.4759596239631899,
#     0.3333333333333333,
#     0.8181818181818182],
#    ['a2@premeno,a4@0-2,a6@3,a7@right,a9@yes>class@no',
#     0.41520321051310616,
#     0.3333333333333333,
#     0.8],
#    ['a1@50-59,a3@25-29,a5@yes>class@no',
#     0.30939162041210233,
#     0.3333333333333333,
#     0.8]]],
#  ['a1@60-69,a2@ge40,a3@20-24,a6@3,a8@left_low>class@yes',
#   1.0,
#   [['a2@ge40,a4@0-2,a5@no,a6@3,a8@left_low,a9@no>class@no',
#     0.45880197582817767,
#     0.5,
#     0.8333333333333334],
#    ['a1@60-69,a2@ge40,a4@0-2,a5@no,a8@left_low,a9@no>class@no',
#     0.35085682506179316,
#     0.5,
#     0.8666666666666667],
#    ['a2@ge40,a5@no,a8@left_low,a9@no>class@no',
#     0.3254321614800073,
#     0.5,
#     0.8333333333333334]]],
#  ['a3@25-29,a6@3,a7@left,a8@left_low,a9@yes>class@yes',
#   1.0,
#   [['a1@50-59,a3@25-29,a5@yes>class@no',
#     0.4567430434920602,
#     0.3333333333333333,
#     0.8],
#    ['a1@50-59,a2@premeno,a7@left,a8@left_low>class@no',
#     0.3712351277748312,
#     0.3333333333333333,
#     0.8181818181818182],
#    ['a2@ge40,a3@25-29,a5@no,a8@left_low>class@no',
#     0.1227892919555158,
#     0.3333333333333333,
#     0.8333333333333334]]],
#  ['a1@50-59,a2@premeno,a6@3,a8@right_up,a9@no>class@yes',
#   1.0,
#   [['a2@premeno,a3@30-34,a4@0-2,a5@no,a7@left,a9@no>class@no',
#     0.45642524903210346,
#     0.5,
#     0.8]]],
#  ['a1@40-49,a3@30-34,a4@3-5,a5@no,a8@left_low,a9@no>class@yes',
#   1.0,
#   [['a2@ge40,a5@no,a7@left,a8@left_low,a9@no>class@no',
#     0.4557480897564223,
#     1.0,
#     0.85],
#    ['a2@ge40,a5@no,a8@left_low,a9@no>class@no',
#     0.44212399326897284,
#     1.0,
#     0.8333333333333334],
#    ['a2@ge40,a5@no,a7@left,a9@no>class@no',
#     0.38227651596488976,
#     1.0,
#     0.8888888888888888]]],
#  ['a1@60-69,a2@ge40,a4@3-5,a6@2>class@yes',
#   1.0,
#   [['a1@60-69,a2@ge40,a3@30-34,a7@left>class@no',
#     0.44958183535987833,
#     0.3333333333333333,
#     0.8571428571428571],
#    ['a1@60-69,a2@ge40,a5@no,a7@left>class@no',
#     0.19144630641534283,
#     0.3333333333333333,
#     0.8947368421052632]]],
#  ['a4@3-5,a6@2,a7@right,a8@left_up>class@no',
#   0.8,
#   [['a1@40-49,a2@premeno,a3@30-34,a4@3-5,a5@no,a6@2,a7@right,a8@left_up,a9@no>class@yes',
#     0.4474080572474963,
#     1.0,
#     1.0],
#    ['a3@30-34,a4@3-5,a5@no,a7@right,a8@left_up>class@yes',
#     0.3629650402996079,
#     0.3333333333333333,
#     1.0],
#    ['a2@premeno,a3@30-34,a4@3-5,a5@no,a6@2,a7@right,a9@no>class@yes',
#     0.3540597066809228,
#     1.0,
#     1.0]]],
#  ['a2@premeno,a3@15-19,a6@3,a9@no>class@yes',
#   1.0,
#   [['a1@40-49,a2@premeno,a4@0-2,a7@right,a8@left_up>class@no',
#     0.4467360040511161,
#     0.5,
#     0.8333333333333334]]],
#  ['a1@60-69,a2@ge40,a3@30-34,a6@3,a7@left,a8@left_low,a9@no>class@no',
#   1.0,
#   [['a3@30-34,a5@yes,a6@3,a9@no>class@yes', 0.44424935758833967, 0.5, 0.8],
#    ['a5@yes,a6@3,a7@left,a8@left_low>class@yes',
#     0.4222091179358708,
#     0.5,
#     0.875],
#    ['a5@yes,a6@3,a7@left>class@yes',
#     0.34529609951190154,
#     0.5,
#     0.8461538461538461]]],
#  ['a2@premeno,a3@30-34,a5@no,a9@yes>class@yes',
#   1.0,
#   [['a3@30-34,a4@0-2,a5@no,a8@left_low>class@no',
#     0.44115036492979676,
#     0.3333333333333333,
#     0.9]]],
#  ['a3@20-24,a5@no,a6@2,a7@left,a8@left_low,a9@yes>class@yes',
#   1.0,
#   [['a1@60-69,a2@ge40,a5@no,a7@left>class@no',
#     0.43728036163498085,
#     1.0,
#     0.8947368421052632]]],
#  ['a2@ge40,a6@3,a7@left,a8@right_low>class@yes',
#   1.0,
#   [['a1@60-69,a2@ge40,a5@no,a7@left>class@no',
#     0.43231614144427183,
#     0.25,
#     0.8947368421052632],
#    ['a2@ge40,a4@0-2,a5@no,a7@left>class@no',
#     0.38089204952944133,
#     0.25,
#     0.918918918918919],
#    ['a1@60-69,a2@ge40,a4@0-2,a5@no,a7@left>class@no',
#     0.3799615518666576,
#     0.25,
#     0.9444444444444444]]],
#  ['a1@60-69,a2@ge40,a3@20-24,a7@left,a8@left_low,a9@yes>class@yes',
#   1.0,
#   [['a1@60-69,a2@ge40,a5@no,a7@left>class@no',
#     0.4085945855917782,
#     0.5,
#     0.8947368421052632]]],
#  ['a3@20-24,a8@left_low,a9@yes>class@yes',
#   0.8,
#   [['a1@40-49,a2@premeno,a3@20-24,a4@0-2,a5@no,a6@3,a7@right,a8@left_low,a9@yes>class@no',
#     0.3862594556218477,
#     1.0,
#     1.0],
#    ['a1@40-49,a2@premeno,a4@0-2,a6@3,a7@right,a8@left_low,a9@yes>class@no',
#     0.31526177983824616,
#     0.5,
#     1.0],
#    ['a1@40-49,a2@premeno,a6@3,a7@right,a8@left_low>class@no',
#     0.287265364353976,
#     0.5,
#     1.0]]],
#  ['a4@0-2,a5@no,a8@right_low>class@no',
#   0.9285714285714286,
#   [['a2@ge40,a3@25-29,a4@0-2,a5@no,a6@3,a7@left,a8@right_low,a9@yes>class@yes',
#     0.37583580113378057,
#     1.0,
#     1.0],
#    ['a1@60-69,a2@ge40,a3@25-29,a4@0-2,a5@no,a6@3,a7@left,a8@right_low,a9@yes>class@yes',
#     0.36581335621255856,
#     1.0,
#     1.0],
#    ['a3@25-29,a4@0-2,a5@no,a6@3,a7@left,a9@yes>class@yes',
#     0.3615472380543755,
#     1.0,
#     1.0]]],
#  ['a1@40-49,a2@premeno,a3@15-19,a4@0-2,a5@yes,a6@3,a9@no>class@yes',
#   1.0,
#   [['a1@40-49,a2@premeno,a4@0-2,a7@right,a8@left_up>class@no',
#     0.3695357252469795,
#     1.0,
#     0.8333333333333334]]],
#  ['a2@ge40,a3@20-24,a7@left,a8@left_low,a9@yes>class@yes',
#   1.0,
#   [['a1@60-69,a2@ge40,a5@no,a7@left>class@no',
#     0.3520263243334917,
#     0.5,
#     0.8947368421052632]]],
#  ['a1@60-69,a2@ge40,a3@30-34,a6@3,a8@central>class@yes',
#   1.0,
#   [['a1@60-69,a2@ge40,a3@30-34,a4@0-2,a5@no,a9@no>class@no',
#     0.3398413881168241,
#     1.0,
#     0.8333333333333334],
#    ['a2@ge40,a3@30-34,a4@0-2,a5@no,a9@no>class@no',
#     0.2694733375732023,
#     1.0,
#     0.8333333333333334],
#    ['a1@60-69,a3@30-34,a4@0-2,a5@no,a9@no>class@no',
#     0.24610901637190005,
#     1.0,
#     0.8571428571428571]]],
#  ['a1@40-49,a2@premeno,a5@yes,a6@3,a7@right,a9@no>class@yes',
#   1.0,
#   [['a1@40-49,a2@premeno,a4@0-2,a7@right,a8@left_up>class@no',
#     0.3388809278334983,
#     0.3333333333333333,
#     0.8333333333333334]]],
#  ['a1@60-69,a3@30-34,a7@left,a8@left_low,a9@no>class@no',
#   1.0,
#   [['a3@30-34,a5@yes,a6@3,a9@no>class@yes', 0.33407282900804647, 0.25, 0.8],
#    ['a5@yes,a6@3,a7@left,a8@left_low>class@yes',
#     0.3086813222220197,
#     0.25,
#     0.875],
#    ['a5@yes,a6@3,a7@left>class@yes',
#     0.20317011663560275,
#     0.25,
#     0.8461538461538461]]],
#  ['a6@3,a7@left,a8@central,a9@no>class@no',
#   1.0,
#   [['a5@yes,a6@3,a7@left>class@yes',
#     0.3241970863224713,
#     0.3333333333333333,
#     0.8461538461538461]]],
#  ['a1@60-69,a2@ge40,a3@30-34,a7@left,a8@left_low,a9@no>class@no',
#   1.0,
#   [['a3@30-34,a5@yes,a6@3,a9@no>class@yes',
#     0.31954210788724646,
#     0.3333333333333333,
#     0.8],
#    ['a5@yes,a6@3,a7@left,a8@left_low>class@yes',
#     0.2996912581395655,
#     0.3333333333333333,
#     0.875],
#    ['a5@yes,a6@3,a7@left>class@yes',
#     0.20318432621272137,
#     0.3333333333333333,
#     0.8461538461538461]]],
#  ['a2@ge40,a6@3,a7@left,a8@central,a9@no>class@no',
#   1.0,
#   [['a5@yes,a6@3,a7@left>class@yes',
#     0.31184122160703354,
#     1.0,
#     0.8461538461538461]]],
#  ['a1@40-49,a3@25-29,a6@3,a7@left>class@yes',
#   1.0,
#   [['a2@premeno,a3@25-29,a8@left_up>class@no',
#     0.3065673226481044,
#     0.3333333333333333,
#     0.8]]],
#  ['a1@40-49,a4@3-5,a5@no,a6@3,a8@left_low>class@yes',
#   1.0,
#   [['a2@ge40,a5@no,a7@left,a8@left_low,a9@no>class@no',
#     0.302229789322372,
#     0.5,
#     0.85],
#    ['a2@ge40,a5@no,a8@left_low,a9@no>class@no',
#     0.28440750764296097,
#     0.5,
#     0.8333333333333334],
#    ['a2@ge40,a5@no,a7@left,a9@no>class@no',
#     0.20983925527912478,
#     0.5,
#     0.8888888888888888]]],
#  ['a2@premeno,a5@yes,a6@3,a7@right,a9@no>class@yes',
#   1.0,
#   [['a1@40-49,a2@premeno,a4@0-2,a7@right,a8@left_up>class@no',
#     0.2955681872363019,
#     0.25,
#     0.8333333333333334]]],
#  ['a2@ge40,a6@3,a7@left,a8@right_low,a9@yes>class@yes',
#   1.0,
#   [['a1@60-69,a2@ge40,a5@no,a7@left>class@no',
#     0.2844518627401354,
#     0.3333333333333333,
#     0.8947368421052632],
#    ['a1@60-69,a2@ge40,a4@0-2,a5@no,a7@left>class@no',
#     0.22233126163148256,
#     0.3333333333333333,
#     0.9444444444444444],
#    ['a2@ge40,a4@0-2,a5@no,a7@left>class@no',
#     0.2173693381208649,
#     0.3333333333333333,
#     0.918918918918919]]],
#  ['a1@40-49,a3@20-24,a4@3-5,a9@yes>class@yes',
#   1.0,
#   [['a2@premeno,a6@2,a7@right,a8@right_up>class@no',
#     0.2664207743326192,
#     0.3333333333333333,
#     0.8]]],
#  ['a2@ge40,a3@25-29,a6@3,a7@left,a8@right_low,a9@yes>class@yes',
#   1.0,
#   [['a1@60-69,a2@ge40,a5@no,a7@left>class@no',
#     0.25203438443243714,
#     0.5,
#     0.8947368421052632],
#    ['a1@60-69,a2@ge40,a4@0-2,a5@no,a7@left>class@no',
#     0.20349102772427563,
#     0.5,
#     0.9444444444444444],
#    ['a2@ge40,a4@0-2,a5@no,a7@left>class@no',
#     0.19872494402046775,
#     0.5,
#     0.918918918918919]]],
#  ['a1@40-49,a3@30-34,a4@3-5,a7@left,a8@left_low,a9@no>class@yes',
#   1.0,
#   [['a2@ge40,a5@no,a7@left,a8@left_low,a9@no>class@no',
#     0.2305895567857947,
#     1.0,
#     0.85],
#    ['a2@ge40,a5@no,a7@left,a9@no>class@no',
#     0.1423791163720009,
#     1.0,
#     0.8888888888888888]]],
#  ['a2@ge40,a3@20-24,a8@left_low,a9@yes>class@yes',
#   1.0,
#   [['a1@60-69,a2@ge40,a5@no,a7@left>class@no',
#     0.22100877682795386,
#     0.3333333333333333,
#     0.8947368421052632]]],
#  ['a2@ge40,a3@25-29,a4@3-5,a6@2,a7@right>class@yes',
#   1.0,
#   [['a2@ge40,a3@25-29,a5@no,a9@no>class@no',
#     0.20517386799737125,
#     1.0,
#     0.875]]],
#  ['a1@40-49,a2@premeno,a3@15-19,a5@yes,a6@3,a9@no>class@yes',
#   1.0,
#   [['a1@40-49,a2@premeno,a4@0-2,a7@right,a8@left_up>class@no',
#     0.1422170336607515,
#     0.5,
#     0.8333333333333334]]],
#  ['a1@40-49,a3@30-34,a4@3-5,a7@left,a9@no>class@yes',
#   1.0,
#   [['a2@ge40,a5@no,a7@left,a8@left_low,a9@no>class@no',
#     0.14009858788675916,
#     0.5,
#     0.85],
#    ['a2@ge40,a5@no,a7@left,a9@no>class@no',
#     0.11981339553724704,
#     0.5,
#     0.8888888888888888]]],
#  ['a2@premeno,a3@20-24,a6@2,a9@no>class@no',
#   0.8333333333333334,
#   [['a1@30-39,a2@premeno,a5@yes,a7@left,a8@left_low>class@yes',
#     0.13638038631691082,
#     0.3333333333333333,
#     1.0],
#    ['a1@30-39,a2@premeno,a4@3-5,a5@yes,a7@left,a8@left_low>class@yes',
#     0.13553204914652303,
#     0.5,
#     1.0]]]]

# %%
def filter_association_rules(unexpected_rules, delta_1 = 0):
    rules = []
    for x in unexpected_rules:
        if x[2][0][1] > delta_1: 
            rules.append(AssociationRule.string_2_rule(x[0]))
    return rules

# %%
def string_2_itemset(key):
    if key == '':
        return []
    else: 
        return key.split(',')

def itemset_2_string(itemset):
    return ",".join(itemset)

def merge_itemsets(itemset_1, itemset_2):
    merged_items = []
    merged_items.extend(itemset_1)
    merged_items.extend(itemset_2)
    merged_items = list(set(merged_items))
    merged_items = sorted(merged_items)
    
    return merged_items

def get_full_path(prefix, file_name):
    if prefix == '': return file_name
    return prefix + '//' + file_name

# %%
refined_unexpected_rules = filter_association_rules(unexpected_rules)

# %%
print('svm testing...')
svc_model = SVC(kernel = 'poly', degree=3, coef0 = 0.1, random_state = 1)
svc_model.fit(X_train.relation_matrix, Y_train.values.flatten())
# Out:
# svm testing...
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.1,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='poly',
#     max_iter=-1, probability=False, random_state=1, shrinking=True, tol=0.001,
#     verbose=False)

# %%
def refine_with_unexpectedness(data_set, classes_dict, preY, Ytrue, unexpected_rules):
    
    print('Refine with unexpected rules...')
    y_pred = np.copy(preY)
    for i in range(data_set.size()):
        x = data_set.get_transaction(i)
        for r in unexpected_rules:
            if r.satisfy_rule(x, is_lhs = True):
                label = r.right_items[0]
                y_pred[i] = classes_dict[label]
    print(f1_score(Ytrue, y_pred, average=None))
    if (data_set.number_of_classes() <= 2):
        fpr, tpr, _ = roc_curve(Ytrue, y_pred.flatten())
        print(auc(fpr, tpr))

# %% [markdown]
# SVM

# %%
svc_y_pred = svc_model.predict(Xtest)
print(f1_score(Ytest, svc_y_pred, average=None))
if (class_count <= 2):
  fpr, tpr, _ = roc_curve(Ytest, svc_y_pred.flatten())    
  print(auc(fpr, tpr))
# Out:
# [0.91428571 0.72727273]
# 0.7857142857142857

# %%
refine_with_unexpectedness(test_data_set, Y_train.item_dict, svc_y_pred, Ytest, refined_unexpected_rules)
# Out:
# Refine with unexpected rules...
# [0.90909091 0.76923077]
# 0.8258928571428572

# %% [markdown]
# Random Forest

# %%
print('Random forest testing...')
rf_model = RandomForestClassifier(n_estimators=20, random_state=1)
rf_model.fit(X_train.relation_matrix, Y_train.values.flatten())
    
rf_y_pred = rf_model.predict(Xtest)
print(f1_score(Ytest, rf_y_pred, average=None))
if (class_count <= 2):
  fpr, tpr, _ = roc_curve(Ytest, rf_y_pred.flatten())
  print(auc(fpr, tpr))
    
refine_with_unexpectedness(test_data_set, Y_train.item_dict, rf_y_pred, Ytest, refined_unexpected_rules)
# Out:
# Random forest testing...
# [0.88571429 0.63636364]
# 0.734375
# Refine with unexpected rules...
# [0.90909091 0.76923077]
# 0.8258928571428572
