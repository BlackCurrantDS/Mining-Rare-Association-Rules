# %% [markdown]
# <a href="https://colab.research.google.com/github/BlackCurrantDS/DBSE_Project/blob/main/Part2_Rules_to_Feature_Vectors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook takes the association rules generated and results the feature vector of each rule. Also this generated co-relation matrix.
#
# Input-
#
# input transaction file
# Association rules files(the multiple temprory ones to make it run in parallel)
#
# How to run:
#
# If Using in google colab
#
# Step1 :
#
# Load train file - /content/credit_train_transactions.txt
# Load rule files, to make it faster it process it in paraleel, please make sure each file has suffix 0,1,2 etc, eg-miner.tmp.rules.0
#
# Step 2:
#
# Change file name in cell 21
#
# Note: it prints the feature vectors and takes time, you can comment that.
#
# Step 3:
#
# Run all
#
# IF Using in jyputer notebook
#
# Change the path to desired folder where input file is kept and where output files should be generated in cell 14 and 18 and 21
#
# Output-
#
# This generates file item_relation.csv and miner.tmp.non_redundant_rules

# %% [markdown]
# RuleFormatter

# %%
class RuleFormatter(object):
    
    @staticmethod
    def mydefaultLeft(item):
        return True
    
    @staticmethod
    def mydefaultRight(item):
        return True
    
    @staticmethod
    def mydefault(rule):
        #return True
        return len(rule.right_items) == 1#<= 2
    
    
    @staticmethod
    def massLeft(item):
        return item.isdigit()
    
    @staticmethod
    def massRight(item):
        return not item.isdigit()
    
    @staticmethod
    def mass(rule):
        return rule.lhs_string().isdigit() and (not rule.rhs_string().isdigit())
    
    @staticmethod
    def rna(rule):
        condition = (len(rule.right_items) == 1)
        condition &= ('rna_' in rule.rhs_string())
        condition &=  ('rna_' not in rule.lhs_string())
        return condition
    
    @staticmethod
    def tcrLeft(item):
        return item != 'CD4' and item != 'CD8'
    
    @staticmethod
    def tcrRight(item):
        return item == 'CD4' or item == 'CD8'    
    
    @staticmethod
    def tcr(rule):
        left_key = rule.lhs_string()
        right_key = rule.rhs_string()
        return ('CD4' not in left_key) and ('CD8' not in left_key) and (right_key == 'CD4' or right_key == 'CD8')
    
    @staticmethod
    def ank3Left(item):
        return item != 'CASE' and item != 'HEALTHY'
    
    @staticmethod
    def ank3Right(item):
        return item == 'CASE' or item == 'HEALTHY'
        
    @staticmethod
    def ank3(rule):
        left_key = rule.lhs_string()
        right_key = rule.rhs_string()
        return ('CASE' not in left_key) and ('HEALTHY' not in left_key) and (right_key == 'CASE' or right_key == 'HEALTHY')
    
    @staticmethod
    def spectLeft(item):
        return 'class@' not in item
    
    @staticmethod
    def spectRight(item):
        return 'class@' in item
        
    @staticmethod
    def spect(rule):
        flag = True
        for item in rule.right_items:
            if 'class@' not in item:
                flag = False
                break
        left_key = rule.lhs_string()
        return ('class@' not in left_key) and flag == True
    
    @staticmethod
    def kddLeft(item):
        return ('c_' in item) == False
    
    @staticmethod
    def kddRight(item):
        return 'c_' in item
        
    @staticmethod
    def kdd(rule):
        left_key = rule.lhs_string()
        right_key = rule.rhs_string()
        return ('c_' not in left_key) and (len(rule.right_items) == 1 and 'c_' in right_key)
    
    @staticmethod
    def tcrmLeft(item):
        return True
    
    @staticmethod
    def tcrmRight(item):
        return True
        
    @staticmethod
    def tcrm(rule):
        a_count1 = 0
        b_count1 = 0
        for item in rule.left_items:
            if 'b_' in item:
                b_count1 += 1
            if 'a_' in item:
                a_count1 += 1
        if a_count1 > 0 and b_count1 > 0: return False
        
        a_count2 = 0
        b_count2 = 0
        for item in rule.right_items:
            if 'b_' in item:
                b_count2 += 1
            if 'a_' in item:
                a_count2 += 1
        if a_count2 > 0 and b_count2 > 0: return False
        
        return (a_count1 > 0 and b_count2 > 0) or (b_count1 > 0 and a_count2 > 0)
    
    @staticmethod
    def ppiLeft(item):
        return True
    
    @staticmethod
    def ppiRight(item):
        return True
        
    @staticmethod
    def ppi(rule):
        a_count1 = 0
        b_count1 = 0
        for item in rule.left_items:
            if 'h@' in item:
                b_count1 += 1
            if 'v@' in item:
                a_count1 += 1
        if a_count1 > 0 and b_count1 > 0: return False
        
        a_count2 = 0
        b_count2 = 0
        for item in rule.right_items:
            if 'h@' in item:
                b_count2 += 1
            if 'v@' in item:
                a_count2 += 1
        if a_count2 > 0 and b_count2 > 0: return False
        
        return (a_count1 > 0 and b_count2 > 0) or (b_count1 > 0 and a_count2 > 0)
    
    
    @staticmethod
    def spliceLeft(item):
        return item != 'EI' and item != 'IE' and item != 'N@'
    
    @staticmethod
    def spliceRight(item):
        return item == 'D_0' or item == 'D_1' or item == 'N@'
        
    @staticmethod
    def splice(rule):
        left_key = rule.lhs_string()
        right_key = rule.rhs_string()
        return ('EI' not in left_key) and ('IE' not in left_key) and ('N@' not in left_key) and (right_key == 'EI' or right_key == 'IE' or right_key == 'N@')

# %% [markdown]
# Argument tuple

# %%
class ContrastParams(object):
    '''
    classdocs
    '''

    def __init__(self, delta1, delta2, share_threshold, n_lhs_features, n_rhs_features):
        '''
        Constructor
        '''
        self.delta1 = delta1 
        self.delta2 = delta2 
    
        self.share_threshold = share_threshold
        self.n_lhs_features = n_lhs_features
        self.n_rhs_features = n_rhs_features
        
class ARMParams(object):
    '''
    classdocs
    '''

    def __init__(self, minsup, minconf, itemset_max_size=-1):
        '''
        Constructor
        '''
        self.min_sup = minsup 
        self.min_conf = minconf
        self.itemset_max_size = itemset_max_size
        
class dbscanParams(object):
    
    def __init__(self, minpts, eps):
        self.min_pts = minpts
        self.eps = eps
        
class ARMFiles(object):
    '''
    classdocs
    '''

    def __init__(self, default_folder = '/content/'):
        '''
        Constructor
        '''
        self.temp_folder = default_folder
        
        self.itemset_tmp_file = self.temp_folder + 'miner.tmp.itemsets'
        self.rules_tmp_file = self.temp_folder + 'miner.tmp.rules'
        self.best_rules_file = self.temp_folder + 'miner.best_tmp.rules'
        
        self.interestingness_tmp_file = self.temp_folder +'miner.tmp.interestingness'
        self.probabilities_tmp_file = self.temp_folder +'miner.tmp.probabilities'
        
        self.feature_tmp_file = self.temp_folder +'miner.tmp.features'
        self.non_redundant_rule_tmp_file = self.temp_folder +'miner.tmp.non_redundant_rules'
        self.non_redundant_rule_feature_tmp_file = self.temp_folder + 'miner.tmp.non_redundant_rules.features'
        self.relation_tmp_file = self.temp_folder + 'relation_matrix.csv'
        
    def get_rule_file(self, i):
        return self.rules_tmp_file + '.' + str(i)

# %% [markdown]
# RuleMining helper

# %%
def string_2_itemset(key):
    if key == '':
        return []
    else: 
        return key.split(',')

def itemset_2_string(itemset):
    return ",".join(itemset)

def merge_itemsets(itemset_1, itemset_2):
    merged_items = []
    merged_items.extend(itemset_1)
    merged_items.extend(itemset_2)
    merged_items = list(set(merged_items))
    merged_items = sorted(merged_items)
    
    return merged_items

def get_full_path(prefix, file_name):
    if prefix == '': return file_name
    return prefix + '//' + file_name

# %% [markdown]
# Association Rule

# %%
class AssociationRule:
    def __init__(self, left, right):
        self.left_items = left
        self.right_items = right
        self.scores = []
        
    def length(self):
        return len(self.left_items) + len(self.right_items)
     
    def score(self, index):
        return self.scores[index]
    
    def lhs_string(self):
        return itemset_2_string(self.left_items)
        
    def rhs_string(self):
        return itemset_2_string(self.right_items)
    
    def serialize(self):
        left_key = self.lhs_string()
        right_key = self.rhs_string()
        return left_key + ">" + right_key
    
    @staticmethod        
    def string_2_rule(s):
        subStrings = s.split(">")
        left = string_2_itemset(subStrings[0].strip())
        right = string_2_itemset(subStrings[1].strip())
        return AssociationRule(left, right)

    def append_score(self, score):
        self.scores.append(score)
        
    def get_itemset(self):
        itemset = []
        itemset.extend(self.left_items)
        itemset.extend(self.right_items)
        itemset.sort()
        return itemset
        
        
    def rule_itemset_2_string(self):
        itemset = self.get_itemset()
        return itemset_2_string(itemset)
    
    def compute_basic_probs(self,frequent_itemsets, nTransactions):  
        
        left = frequent_itemsets[self.lhs_string()]
        right = frequent_itemsets[self.rhs_string()]
        
        both = frequent_itemsets[self.rule_itemset_2_string()]
        
        vector = {}
        
        ''' 1. P(A)'''
        p_A = left/nTransactions
        vector['A'] = p_A
        
        ''' 2. P(B)'''
        p_B = right/nTransactions
        vector['B'] = p_B
        
        ''' 3. P(~A)'''
        p_not_A = 1 - p_A
        vector['~A'] = p_not_A
        
        ''' 4. P(~B)'''
        p_not_B = 1 - p_B
        vector['~B'] = p_not_B
        
        ''' 5. P(AB) '''
        p_A_and_B = both/nTransactions
        vector['AB'] = p_A_and_B
        
        ''' 6. P(~AB)'''
        p_not_A_and_B = (right - both)/nTransactions
        vector['~AB'] = p_not_A_and_B
        
        ''' 7. P(A~B)'''
        p_A_and_not_B = (left - both)/nTransactions
        vector['A~B'] = p_A_and_not_B
        
        ''' 8. P(~A~B)'''
        p_not_A_and_not_B = 1 - (left + right - both)/nTransactions
        vector['~A~B'] = p_not_A_and_not_B 
        
        '''
        9. P(A|B)
        '''
        p_A_if_B = p_A_and_B / p_B
        vector['A|B'] = p_A_if_B
        
        '''
        10. P(~A|~B)
        '''
        p_not_A_if_not_B = p_not_A_and_not_B / p_not_B
        vector['~A|~B'] = p_not_A_if_not_B
        
        '''
        11. P(A|~B)
        '''
        p_A_if_not_B = p_A_and_not_B/p_not_B
        vector['A|~B'] = p_A_if_not_B
        
        '''
        12. p(~A|B)
        '''
        p_not_A_if_B = p_not_A_and_B / p_B
        vector['~A|B'] = p_not_A_if_B
        
        '''
        13. P(B|A)
        '''
        p_B_if_A = p_A_and_B / p_A
        vector['B|A'] = p_B_if_A
        
        '''
        14. P(~B|~A)
        '''
        p_not_B_if_not_A = p_not_A_and_not_B / p_not_A
        vector['~B|~A'] = p_not_B_if_not_A
        
        '''
        15. P(B|~A)
        '''
        p_B_if_not_A = p_not_A_and_B/p_not_A
        vector['B|~A'] = p_B_if_not_A
        
        '''
        16. p(~B|A)
        '''
        p_not_B_if_A = p_A_and_not_B / p_A
        vector['~B|A'] = p_not_B_if_A
        
        return vector
    
    def is_redundant_(self, bits, k, itemset, freq_itemset_dict): 
        '''
        Run out of items --> create rule and check format criterion
        '''
        if k >= len(itemset):
            items_1 = []
            items_2 = []
            for index in range(len(bits)):
                if bits[index] == True:
                    items_1.append(itemset[index])
                else:
                    items_2.append(itemset[index])
            for item in items_2:
                rule = AssociationRule(items_1, [item])
                confidence = freq_itemset_dict.getConfidence(rule)
                if confidence == 1: return True
            return False 
      
        value_domain = [True, False]
        for value in value_domain:
            bits[k] = value
            checker = self.is_redundant_(bits, k+1, itemset, freq_itemset_dict)
            if checker == True: return True
            bits[k] = True    
        return False
    
    '''
    Expand an item-set with equivalent items.
    '''
    def is_redundant(self, freq_itemset_dict):
        bits = [True for _ in self.left_items]
        checker = self.is_redundant_(bits, 0, self.left_items, freq_itemset_dict)
        if checker == True: return True
        
        bits =  [True for _ in self.right_items]
        return self.is_redundant_(bits, 0, self.right_items, freq_itemset_dict)
    
    '''
    Check if an item-set is satisfied condition of the rule. 
    '''
    def satisfy_rule(self, itemset, is_lhs = True):
        condition = self.left_items
        if is_lhs == False: condition = self.right_items
        if len(condition) > len(itemset) or len(itemset) == 0:
            return False
        for item in condition:
            if item not in itemset:
                return False
        return True

# %% [markdown]
# Getting realtion matrix

# %%
class RelationArray2D(object):
    '''
    classdocs
    '''

    def __init__(self, item_dict, relation_values):
        '''
        Constructor
        '''
        self.item_dict = item_dict
        self.relation_matrix = relation_values
        
        
    def get_value(self, item1, item2):
        i = self.item_dict[item1]
        j = self.item_dict[item2]
        return self.relation_matrix[i, j]
    
    def get_items(self):
        return self.item_dict.keys()
        
    def get_index(self, item):
        return self.item_dict[item]
    
class RelationArray1D(object):
    '''
    classdocs
    '''

    def __init__(self, item_dict, values):
        '''
        Constructor
        '''
        self.item_dict = item_dict
        self.values = values
        
        
    def get_value_at(self, index):
        return self.values[index]
    
    def get_items(self):
        return self.item_dict.keys()
        
    def get_value(self, item):
        return self.item_dict[item]

# %%
# Transaction databases, each transaction is a set of items
import numpy as np
from scipy import sparse
from scipy import stats
#from common.RelationArray import RelationArray2D
#from common.RelationArray import RelationArray1D

class DataSet:
    def __init__(self):
        self.current = 0
        self.train_data = []
        self.data_labels = []
        
    
    def __iter__(self):
        return iter(self.train_data)
                
    def size(self):
        return len(self.train_data)
    
    def get_transaction(self, index):
        return self.train_data[index]
    
    def clear(self):
        self.train_data.clear()
        
    def add_transaction(self, t):
        return self.train_data.append(t) 
        
    '''
    Load data set from a file. The input file must be formated in CSV (comma separated)
    class_index is used in the case of data-set with labels. 
    '''
    def load(self, file_path, class_index = -1, has_header = False):
        self.train_data = []
        if class_index != -1: self.data_labels = []
        
        with open(file_path, "r") as text_in_file:
            if has_header == True:
                text_in_file.readline()
                
            for line in text_in_file:
                #print("dataset script line", line)
                transaction = [x.strip() for x in line.split(',')]
                transaction = list(filter(None, transaction))
                #print("datset script transaction" , transaction)
                
                if (class_index != -1):
                    self.data_labels.append(transaction[class_index])
                    del transaction[class_index]
                
                self.train_data.append(list(set(transaction)))
            print("loading done")

    '''
    Return number of classes in data (if have).
    '''            
    def number_of_classes(self):
        if self.data_labels == None: return 0
        return len(set(self.data_labels))

    def convert_data_labels(self, inlier_name):
        Y_train = np.zeros(len(self.data_labels))
        for i in range(Y_train.shape[0]):
            if self.data_labels[i] == inlier_name:
                Y_train[i] = 1
            else: 
                Y_train[i] = -1
        return Y_train

    def convert_2_binary_format_with(self, items_dict, classes_dict = None):
        n_items = len(items_dict)
        X_train = np.zeros((self.size(), n_items))
        
        k = 0
        for transaction in self.train_data:
            for item in transaction:
                if item not in items_dict: 
                    print('not in features...')
                    continue
                i = items_dict[item]
                X_train[k, i] = 1.0
            k += 1
            
        Y_train = []
        if classes_dict is not None:
            for label in self.data_labels:
                if label not in classes_dict:
                    print('not in classes')
                    Y_train.append(-1)
                else:
                    Y_train.append(classes_dict[label]) 
        return X_train, np.array(Y_train)        
    
    def get_items_dict_(self):
        attr_dict = {}
        #check existing data
        for transaction in self.train_data:
            #print("get_items_dict_ transactions",transaction)
            for index in range (len(transaction)):
                item_name = transaction[index]
                if item_name not in attr_dict:
                    attr_dict[item_name] = True
        return attr_dict
    
    def get_class_list_(self):
        # Sort items and classes in alphabet order.
        return sorted(set(self.data_labels))
        
        

    '''
    Convert transaction data into binary format
    '''
    def convert_2_binary_format(self):
        
        attr_dict = self.get_items_dict_()
        print("convert_2_binary_format attr_dict", attr_dict)
      
         
        # Sort items and classes in alphabet order.
        classes_list = sorted(set(self.data_labels))
        print("classes_list", classes_list)
        items_list = sorted(attr_dict.keys())
        
        classes_dict = {classes_list[i] : i for i in range(len(classes_list))}
        print("classes_dict",classes_dict)
        attr_dict = {items_list[i] : i for i in range(len(items_list))}
        print("attr_dict",attr_dict)
        
        #Generate binary matrix (X_train) and array of labels(Y_train)
        X_train, Y_train = self.convert_2_binary_format_with(attr_dict, classes_dict)
                
        return RelationArray2D(attr_dict, sparse.csr_matrix(X_train)), RelationArray1D(classes_dict, np.array(Y_train))
        
    @staticmethod
    def write_relation_matrix_(matrix):
        with open('/content/item_relation.csv', 'w') as file_writer:
            item_names = sorted(matrix.item_dict.keys())
            print("item_names in static method",item_names)
            file_writer.write('o0o,')
            file_writer.write(','.join(item_names))
            file_writer.write('\n')
            for i in range(len(item_names)):
                print("in static method i ",i)
                file_writer.write(item_names[i] + ',')
                print(matrix.relation_matrix[i])
                file_writer.write(','.join(str(x) for x in matrix.relation_matrix[i].tolist()))
                file_writer.write('\n')
                
                
   
    '''
    This method estimates relationship among items. There're two kinds of relationship
    - Correlation:including negative correlation (<= -0.3) and positive correlation (>= 0.3)
    - Cover: threshold 1.0, including cover (2) and covered (-2) 
    '''
    def items_relationship(self):
        
        print ('Computing item relation matrix...')
        
        X_train, _ = self.convert_2_binary_format()
        
        print("X_train",X_train)
    
        correlation_matrix, p_values = stats.spearmanr(X_train.relation_matrix.todense(), axis = 0)

        print(correlation_matrix)
        
        #zeros_mask = (p_values <= 0.05).astype(int)
        #small_mask = (np.abs(correlation_matrix) >= 0.1).astype(int)
        
        #relation_matrix = correlation_matrix * small_mask * zeros_mask
        relation_matrix = correlation_matrix
        print(X_train.item_dict)
        print(relation_matrix)
        a = RelationArray2D(X_train.item_dict, relation_matrix)
        print(type(a))
        print("items_relationship a", a)
        DataSet.write_relation_matrix_(a)
        
        return a

# %% [markdown]
# Rule Miner

# %%
#from rules_mining.Apriori import Apriori
#from rules_mining.Generator import Generator
#from rules_mining.ItemsetDictionary import ItemsetDictionary

#from rules_mining.ItemsetFormatter import ItemsetFormatter
#from rules_mining.RuleFormatter import RuleFormatter
#from rules_mining.AssociationRule import AssociationRule

#from objective_measures.Interestingness import ObjectiveMeasure as om
#from rules_mining.RulesCollection import RulesDictionary

import json
import numpy as np
#from common.ArgumentTuple import ARMFiles

class RuleMiner(object):    
    '''
    This class is used to generate_itemsets_and_rules and store a Naive Belief System 
    by using the most confident association rules
    '''

    def __init__(self, filter_name, train_data_set):
        
        self.nthreads = 2
        self.files_info = ARMFiles('/content/')
        
        self.filter_name = filter_name
        self.data_set = train_data_set #taking input the dataset
        print("self.data_set is none or not", self.data_set)
        self.relation_matrix = None 
        if self.data_set is not None:
            print("Not none")
            self.relation_matrix = self.data_set.items_relationship() #calling
            print(self.data_set.items_relationship()) 
            print(type(self.relation_matrix))
            print("realation matrix",self.relation_matrix )
        
        
    '''
    Load generated frequent itemsets from file. 
    This method must be called after generate_frequent_itemsets is called
    '''
    def load_frequent_itemsets_as_dict(self):
        freq_itemset_dict = ItemsetDictionary(0)
        freq_itemset_dict.load_from_file(self.files_info.itemset_tmp_file)
        return freq_itemset_dict
    
    '''
    Load generated association rules from file. 
    This method must be called after generate_association_rules is called
    '''
    def load_rules_as_dict(self):
        rules_dict = RulesDictionary()
        
        for i in range(self.nthreads):
            rules_dict.load_from_file(self.files_info.get_rule_file(i))
                
        return rules_dict

        
    '''
    Generate frequent itemsets from data-set
    '''
    def generate_frequent_itemsets(self, arm_params):
        
        print ('generating frequent item-sets...')
        apriori = Apriori(self.data_set)
        apriori.generate_frequent_itemsets_vw(arm_params.min_sup * self.data_set.size(), 
                                              self.nthreads, 
                                              arm_params.itemset_max_size, 
                                              self.files_info.itemset_tmp_file)
        
    '''
    Generate association rules from data-set. 
    This method must be called after generate_frequent_itemsets(...) is called
    '''
    def generate_association_rules(self, arm_params):
        freq_itemsets_dict = self.load_frequent_itemsets_as_dict()
        
        print ('generating rules ....')
        itemset_formatter = getattr(ItemsetFormatter, self.filter_name)
        rule_formatter = getattr(RuleFormatter, self.filter_name)
        rule_generator = Generator(freq_itemsets_dict, 
                                   arm_params.min_conf, 
                                   itemset_formatter, 
                                   rule_formatter, 
                                   self.nthreads)
        rule_generator.execute(self.files_info.rules_tmp_file)
        
    '''
    Generate association rules and select K patterns with highest confidence.
    '''    
    def generate_itemsets_and_rules(self, arm_params):
        self.generate_frequent_itemsets(arm_params)
        self.generate_association_rules(arm_params)
        self.extract_features_4_all_rules()
         
    '''
    Compute confidence for all association rules generated from data-set
    '''
    def compute_confidence(self, association_rules_list):
        freq_itemset_dict = self.load_frequent_itemsets_as_dict()
        
        rule_confidence_dict = {}
        for rule in association_rules_list:
            left, _, both = freq_itemset_dict.get_frequency_combo(rule)
            rule_confidence_dict[rule.serialize()] = (both/left, both)
        return rule_confidence_dict

    '''
    Compute values of 31 interestingness measures for all association rules generated from data-set
    '''
    def compute_interestingness(self, output_file):
        print ('computing correlation among interestingness measures...')
        #measures = [om.confidence, om.lift]
        
        measures = [om.confidence, om.coverage, om.prevalence, om.recall, om.specificity, 
                    om.accuracy, om.lift, om.leverage, om.change_of_support, om.relative_risk, 
                    om.jaccard, om.certainty_factor, om.odd_ratio, om.yuleQ, om.yuleY, 
                    om.klosgen, om.conviction, om.weighting_dependancy, 
                    om.collective_strength, om.laplace_correction, om.jmeasure, 
                    om.one_way_support, om.two_way_support, om.two_ways_support_variation, 
                    om.linear_correlation_coefficient, om.piatetsky_shapiro, om.loevinger,
                    om.information_gain, om.sebag_schoenauner, om.least_contradiction, 
                    om.odd_multiplier, om.counter_example_rate, om.zhang]
        
        print('loading frequent item-sets....')
        freq_itemsets_dict =  self.load_frequent_itemsets_as_dict()
        association_rules = self.load_association_rules()
        
        print ('computing interestingness for all rules ....')
        
        with open(output_file, 'w') as write_file:
            total = freq_itemsets_dict.ntransactions
            for rule in association_rules:
                left, right, both = freq_itemsets_dict.get_frequency_combo(rule)
                interestingness = []
                for index in range(len(measures)):
                    value = measures[index](left, right, both, total)
                    interestingness.append(value)
                write_file.write(rule.serialize() + ';')            
                write_file.write(';'.join([str(x) for x in interestingness]))
                write_file.write('\n')
                
    '''
    Determine collection of features for LHS and RHS of rules.
    This method returns two dictionaries for LHS and RHS respectively. 
    Each entry of the dictionaries are (the name of item : its index in feature vector)
    ''' 
    def _get_feature_names(self):
        
        left_features = []
        right_features = []
        
        left_filter = getattr(RuleFormatter, self.filter_name + 'Left')
        print("_get_feature_names left_filter ",left_filter) #this gives memory location
        right_filter = getattr(RuleFormatter, self.filter_name + 'Right')
        print("_get_feature_names right_filter",right_filter) #this gives memory location
        for item in self.relation_matrix.get_items():
            #print("_get_feature_names item ",item) #gives item one by one a1@30-39
            #print("_get_feature_names left_filter(item)",left_filter(item))
            if left_filter(item):
                left_features.append(item) #true or false
            if right_filter(item):
                right_features.append(item) 
        print("_get_feature_names",sorted(left_features)) #list of all the items wihtout class lables
        print("_get_feature_names",sorted(right_features))   #list of items with class labels  
        return sorted(left_features), sorted(right_features)
    
    '''
    Extract feature for an item-set.
    '''
    def _extract_features_4_itemset(self, itemset, feature_names):
        n = len(feature_names)
        f_vector = [0 for _ in range(n)]
        for item in itemset:
            print("_extract_features_4_itemset",item)
            for i in range(n):
                print("_extract_features_4_itemset i ", i)
                a = self.relation_matrix.get_value(item, feature_names[i])
                print("_extract_features_4_itemset a", a)
                if (abs(f_vector[i]) < abs(a)):
                    f_vector[i] = a
      
        return np.array(f_vector) 
    '''
    Extract feature vectors for all rules 
    '''
    def extract_features_4_all_rules(self):
        left_features, right_features  = self._get_feature_names()
        left_count = len(left_features)
        right_count = len(right_features)
        
        print('Write number of features for LHS and RHS')
        features_writer = open(self.files_info.non_redundant_rule_tmp_file, 'w')
        features_writer.write(str(left_count))
        features_writer.write('\n')
        features_writer.write(str(right_count))
        features_writer.write('\n')
        
        print('Starting extraction...')
        for i in range(self.nthreads):
            input_file = self.files_info.get_rule_file(i)
            
            with open(input_file, 'r') as rules_reader:
                for line in rules_reader:
                    print("line",line) #for each rule a3@0-4>class@no
                    rule = AssociationRule.string_2_rule(line.strip())
                    print("string to rule",rule) #memory location from class
                    a = self._extract_features_4_itemset(rule.left_items, left_features)
                    print("a",a) 
                    b = self._extract_features_4_itemset(rule.right_items, right_features)
                    print("b",b)
                    f_vector = np.concatenate((a, b))
                    print("f_vector",f_vector)
                    '''
                    Write a feature vector to file
                    '''               
                    features_writer.write(json.dumps((rule.serialize(),f_vector.tolist())))
                    features_writer.write('\n')
        features_writer.close()
        
    '''
    Load feature vectors for all non-redundant rules
    '''
    def load_feature_vectors(self):
        data = []
        lengths = []
        
        with open(self.files_info.non_redundant_rule_tmp_file, 'r') as feature_reader:
            print('Loading number of LHS and RHS features...')
            lhs_count = int(feature_reader.readline())
            rhs_count = int(feature_reader.readline())
            print('Loading feature vectors... ')
            for line in feature_reader:
                rule_text, f_vector = json.loads(line.strip())
                rule = AssociationRule.string_2_rule(rule_text.strip())
                lengths.append(rule.length())
                data.append(f_vector)
                
                
        return np.array(data), lengths, lhs_count, rhs_count
        
    '''
    Load non-redundant rules from a file.
    '''
    def load_association_rules(self):
        association_rules_list = []
        with open(self.files_info.non_redundant_rule_tmp_file, 'r') as rules_reader:
            rules_reader.readline()
            rules_reader.readline()
            
            for line in rules_reader:
                rule_text, _ = json.loads(line.strip())
                association_rules_list.append(AssociationRule.string_2_rule(rule_text.strip()))
        return association_rules_list
        
    '''
    Load non-redundant rules and their feature vectors from a file
    '''
    def load_rules_and_features(self):
        rules_and_their_features = {}
        with open(self.files_info.non_redundant_rule_tmp_file, 'r') as feature_reader:
            lhs_count = int(feature_reader.readline())
            rhs_count = int(feature_reader.readline())
            
            for line in feature_reader:
                rule_text, f_vector = json.loads(line.strip())
                rules_and_their_features[rule_text] = f_vector
        return rules_and_their_features, lhs_count, rhs_count

# %%
train_data_set = DataSet()

# %%
train_data_set.load("/content/credit_train_transactions.txt")
# Out:
# loading done

# %%
ruleminer = RuleMiner('spect',train_data_set)
# Out:
# self.data_set is none or not <__main__.DataSet object at 0x7f721c8bf940>
# Not none
# Computing item relation matrix...
# convert_2_binary_format attr_dict {'a2@less_7': True, 'a12@g': True, 'a13@less_500': True, 'class@yes': True, 'a1@30_47': True, 'a3@u': True, 'a5@w': True, 'a0@b': True, 'a8@t': True, 'a14@less_25k': True, 'a4@g': True, 'a9@t': True, 'a11@f': True, 'a6@v': True, 'a10@less_17': True, 'a7@less_7': True, 'a1@47_64': True, 'a0@a': True, 'a6@h': True, 'a5@q': True, 'a1@less_30': True, 'a9@f': True, 'a11@t': True, 'a12@s': True, 'a5@m': True, 'a5@r': True, 'a14@25k_50k': True, 'a3@y': True, 'a5@k': True, 'a4@p': True, 'a5@c': True, 'a8@f': True, 'a2@7_14': True, 'a5@d': True, 'a5@cc': True, 'a7@7_14': True, 'a2@14_21': True, 'a5@x': True, 'a6@bb': True, 'a5@i': True, 'a10@17_33': True, 'a7@14_21': True, 'a5@e': True, 'a13@500_1k': True, 'a6@ff': True, 'a5@ff': True, 'a7@greater_21': True, 'a10@33_50': True, 'a2@greater_21': True, 'class@no': True, 'a5@aa': True, 'a5@j': True, 'a6@j': True, 'a6@z': True, 'a10@greater_50': True, 'a1@greater_64': True, 'a14@50k_75k': True, 'a12@p': True, 'a6@o': True, 'a6@dd': True, 'a6@n': True, 'a3@l': True, 'a14@greater_75k': True, 'a4@gg': True, 'a13@1k_1.5k': True, 'a13@greater_1.5k': True}
# classes_list []
# classes_dict {}
# attr_dict {'a0@a': 0, 'a0@b': 1, 'a10@17_33': 2, 'a10@33_50': 3, 'a10@greater_50': 4, 'a10@less_17': 5, 'a11@f': 6, 'a11@t': 7, 'a12@g': 8, 'a12@p': 9, 'a12@s': 10, 'a13@1k_1.5k': 11, 'a13@500_1k': 12, 'a13@greater_1.5k': 13, 'a13@less_500': 14, 'a14@25k_50k': 15, 'a14@50k_75k': 16, 'a14@greater_75k': 17, 'a14@less_25k': 18, 'a1@30_47': 19, 'a1@47_64': 20, 'a1@greater_64': 21, 'a1@less_30': 22, 'a2@14_21': 23, 'a2@7_14': 24, 'a2@greater_21': 25, 'a2@less_7': 26, 'a3@l': 27, 'a3@u': 28, 'a3@y': 29, 'a4@g': 30, 'a4@gg': 31, 'a4@p': 32, 'a5@aa': 33, 'a5@c': 34, 'a5@cc': 35, 'a5@d': 36, 'a5@e': 37, 'a5@ff': 38, 'a5@i': 39, 'a5@j': 40, 'a5@k': 41, 'a5@m': 42, 'a5@q': 43, 'a5@r': 44, 'a5@w': 45, 'a5@x': 46, 'a6@bb': 47, 'a6@dd': 48, 'a6@ff': 49, 'a6@h': 50, 'a6@j': 51, 'a6@n': 52, 'a6@o': 53, 'a6@v': 54, 'a6@z': 55, 'a7@14_21': 56, 'a7@7_14': 57, 'a7@greater_21': 58, 'a7@less_7': 59, 'a8@f': 60, 'a8@t': 61, 'a9@f': 62, 'a9@t': 63, 'class@no': 64, 'class@yes': 65}
# X_train <__main__.RelationArray2D object at 0x7f72269ac4a8>
# [[ 1.         -1.          0.01872597 ...  0.09054714 -0.02403402
#    0.02403402]
#  [-1.          1.         -0.01872597 ... -0.09054714  0.02403402
#   -0.02403402]
#  [ 0.01872597 -0.01872597  1.         ...  0.10577141 -0.06529697
#    0.06529697]
#  ...
#  [ 0.09054714 -0.09054714  0.10577141 ...  1.         -0.45018408
#    0.45018408]
#  [-0.02403402  0.02403402 -0.06529697 ... -0.45018408  1.
#   -1.        ]
#  [ 0.02403402 -0.02403402  0.06529697 ...  0.45018408 -1.
#    1.        ]]
# {'a0@a': 0, 'a0@b': 1, 'a10@17_33': 2, 'a10@33_50': 3, 'a10@greater_50': 4, 'a10@less_17': 5, 'a11@f': 6, 'a11@t': 7, 'a12@g': 8, 'a12@p': 9, 'a12@s': 10, 'a13@1k_1.5k': 11, 'a13@500_1k': 12, 'a13@greater_1.5k': 13, 'a13@less_500': 14, 'a14@25k_50k': 15, 'a14@50k_75k': 16, 'a14@greater_75k': 17, 'a14@less_25k': 18, 'a1@30_47': 19, 'a1@47_64': 20, 'a1@greater_64': 21, 'a1@less_30': 22, 'a2@14_21': 23, 'a2@7_14': 24, 'a2@greater_21': 25, 'a2@less_7': 26, 'a3@l': 27, 'a3@u': 28, 'a3@y': 29, 'a4@g': 30, 'a4@gg': 31, 'a4@p': 32, 'a5@aa': 33, 'a5@c': 34, 'a5@cc': 35, 'a5@d': 36, 'a5@e': 37, 'a5@ff': 38, 'a5@i': 39, 'a5@j': 40, 'a5@k': 41, 'a5@m': 42, 'a5@q': 43, 'a5@r': 44, 'a5@w': 45, 'a5@x': 46, 'a6@bb': 47, 'a6@dd': 48, 'a6@ff': 49, 'a6@h': 50, 'a6@j': 51, 'a6@n': 52, 'a6@o': 53, 'a6@v': 54, 'a6@z': 55, 'a7@14_21': 56, 'a7@7_14': 57, 'a7@greater_21': 58, 'a7@less_7': 59, 'a8@f': 60, 'a8@t': 61, 'a9@f': 62, 'a9@t': 63, 'class@no': 64, 'class@yes': 65}
# [[ 1.         -1.          0.01872597 ...  0.09054714 -0.02403402
#    0.02403402]
#  [-1.          1.         -0.01872597 ... -0.09054714  0.02403402
#   -0.02403402]
#  [ 0.01872597 -0.01872597  1.         ...  0.10577141 -0.06529697
#    0.06529697]
#  ...
#  [ 0.09054714 -0.09054714  0.10577141 ...  1.         -0.45018408
#    0.45018408]
#  [-0.02403402  0.02403402 -0.06529697 ... -0.45018408  1.
#   -1.        ]
#  [ 0.02403402 -0.02403402  0.06529697 ...  0.45018408 -1.
#    1.        ]]
# <class '__main__.RelationArray2D'>
# items_relationship a <__main__.RelationArray2D object at 0x7f721c82a518>
# item_names in static method ['a0@a', 'a0@b', 'a10@17_33', 'a10@33_50', 'a10@greater_50', 'a10@less_17', 'a11@f', 'a11@t', 'a12@g', 'a12@p', 'a12@s', 'a13@1k_1.5k', 'a13@500_1k', 'a13@greater_1.5k', 'a13@less_500', 'a14@25k_50k', 'a14@50k_75k', 'a14@greater_75k', 'a14@less_25k', 'a1@30_47', 'a1@47_64', 'a1@greater_64', 'a1@less_30', 'a2@14_21', 'a2@7_14', 'a2@greater_21', 'a2@less_7', 'a3@l', 'a3@u', 'a3@y', 'a4@g', 'a4@gg', 'a4@p', 'a5@aa', 'a5@c', 'a5@cc', 'a5@d', 'a5@e', 'a5@ff', 'a5@i', 'a5@j', 'a5@k', 'a5@m', 'a5@q', 'a5@r', 'a5@w', 'a5@x', 'a6@bb', 'a6@dd', 'a6@ff', 'a6@h', 'a6@j', 'a6@n', 'a6@o', 'a6@v', 'a6@z', 'a7@14_21', 'a7@7_14', 'a7@greater_21', 'a7@less_7', 'a8@f', 'a8@t', 'a9@f', 'a9@t', 'class@no', 'class@yes']
# in static method i  0
# [ 1.         -1.          0.01872597 -0.0271778  -0.0271778   0.00479542
#   0.08277155 -0.08277155  0.09501574 -0.01415514 -0.09571034 -0.0271778
#  -0.07891501  0.06163272  0.06754525  0.02438374  0.06163272 -0.0271778
#  -0.03454182 -0.10702635  0.00217903  0.00848139  0.09731891  0.01814347
#   0.09893543 -0.0773251  -0.07922361  0.02438374  0.05256254 -0.0561568
#   0.05256254  0.02438374 -0.0561568   0.0719299  -0.06217516 -0.02433211
#  -0.05260754 -0.05267201  0.12695271 -0.03196915  0.14376975 -0.05551824
#  -0.1191948   0.23078586 -0.04715238 -0.10433252 -0.02201155 -0.0857751
#  -0.02112503  0.1455989   0.05101647  0.11519538 -0.04715238  0.02438374
#  -0.08456688 -0.01415514 -0.08659899 -0.004861   -0.0271778   0.04926675
#  -0.03062871  0.03062871 -0.09054714  0.09054714 -0.02403402  0.02403402]
# in static method i  1
# [-1.          1.         -0.01872597  0.0271778   0.0271778  -0.00479542
#  -0.08277155  0.08277155 -0.09501574  0.01415514  0.09571034  0.0271778
#   0.07891501 -0.06163272 -0.06754525 -0.02438374 -0.06163272  0.0271778
#   0.03454182  0.10702635 -0.00217903 -0.00848139 -0.09731891 -0.01814347
#  -0.09893543  0.0773251   0.07922361 -0.02438374 -0.05256254  0.0561568
#  -0.05256254 -0.02438374  0.0561568  -0.0719299   0.06217516  0.02433211
#   0.05260754  0.05267201 -0.12695271  0.03196915 -0.14376975  0.05551824
#   0.1191948  -0.23078586  0.04715238  0.10433252  0.02201155  0.0857751
#   0.02112503 -0.1455989  -0.05101647 -0.11519538  0.04715238 -0.02438374
#   0.08456688  0.01415514  0.08659899  0.004861    0.0271778  -0.04926675
#   0.03062871 -0.03062871  0.09054714 -0.09054714  0.02403402 -0.02403402]
# in static method i  2
# [ 0.01872597 -0.01872597  1.         -0.00375812 -0.00375812 -0.84372783
#   0.0122502  -0.0122502   0.03009364 -0.01069244 -0.02773655 -0.00375812
#  -0.01663394 -0.00375812  0.01751779 -0.00531924 -0.00375812 -0.00375812
#   0.00753519 -0.0258741   0.14065645 -0.01314012 -0.06137413  0.1726297
#  -0.04696554 -0.01069244 -0.02950544 -0.00531924  0.00774112 -0.00705254
#   0.00774112 -0.00531924 -0.00705254 -0.02619397 -0.00166652 -0.02147074
#   0.07047723  0.07961317 -0.02619397 -0.02893044 -0.01069244 -0.02650739
#  -0.02289483  0.08280738 -0.00652018 -0.0298055  -0.02254538  0.0978737
#  -0.0084317  -0.02743276  0.04465827 -0.00924427 -0.00652018 -0.00531924
#  -0.10833712  0.14915948  0.27446287 -0.02358181 -0.00375812 -0.10805468
#  -0.08762094  0.08762094 -0.10577141  0.10577141 -0.06529697  0.06529697]
# in static method i  3
# [-0.0271778   0.0271778  -0.00375812  1.         -0.00167504 -0.37606036
#   0.03827539 -0.03827539  0.01341312 -0.00476576 -0.01236254 -0.00167504
#  -0.00741396 -0.00167504  0.00780791 -0.00237085 -0.00167504 -0.00167504
#   0.00335853 -0.02890367  0.11426055 -0.00585672 -0.0437629  -0.00818546
#  -0.02093315  0.35147452 -0.06919088 -0.00237085 -0.073682    0.0743724
#  -0.073682   -0.00237085  0.0743724  -0.01167499  0.08001864 -0.00956978
#  -0.00872572 -0.00799858 -0.01167499 -0.01289467 -0.00476576 -0.01181469
#  -0.01020452 -0.01465984 -0.00290613 -0.0132847  -0.01004877 -0.0130255
#  -0.00375812 -0.01222713 -0.02071998 -0.00412029 -0.00290613 -0.00237085
#   0.03468911 -0.00476576 -0.00533733 -0.01051072  1.         -0.13853948
#  -0.03905378  0.03905378 -0.04714368  0.04714368 -0.04556918  0.04556918]
# in static method i  4
# [-0.0271778   0.0271778  -0.00375812 -0.00167504  1.         -0.37606036
#  -0.0437629   0.0437629   0.01341312 -0.00476576 -0.01236254 -0.00167504
#  -0.00741396 -0.00167504  0.00780791 -0.00237085 -0.00167504 -0.00167504
#   0.00335853 -0.02890367 -0.01465984 -0.00585672  0.03827539 -0.00818546
#   0.08001864 -0.00476576 -0.06919088 -0.00237085  0.02273339 -0.02252236
#   0.02273339 -0.00237085 -0.02252236 -0.01167499 -0.02093315  0.17503444
#  -0.00872572 -0.00799858 -0.01167499 -0.01289467 -0.00476576 -0.01181469
#  -0.01020452 -0.01465984 -0.00290613 -0.0132847  -0.01004877 -0.0130255
#  -0.00375812 -0.01222713 -0.02071998 -0.00412029 -0.00290613 -0.00237085
#   0.03468911 -0.00476576 -0.00533733 -0.01051072 -0.00167504  0.01209072
#  -0.03905378  0.03905378 -0.04714368  0.04714368 -0.04556918  0.04556918]
# in static method i  5
# [ 0.00479542 -0.00479542 -0.84372783 -0.37606036 -0.37606036  1.
#  -0.00828623  0.00828623 -0.03566748  0.01267285  0.03287381  0.00445418
#   0.01971482  0.00445418 -0.02076237  0.00630445  0.00445418  0.00445418
#  -0.00893083  0.04386432 -0.15691352  0.01557389  0.05404289 -0.13992643
#   0.01731494 -0.12265508  0.07754702  0.00630445  0.01280076 -0.01372614
#   0.01280076  0.00630445 -0.01372614  0.03104552 -0.02103445 -0.04467966
#  -0.0530354  -0.06132219  0.03104552  0.03428883  0.01267285  0.031417
#   0.02713533 -0.05896541  0.00772783  0.03532597  0.02672115 -0.07296202
#   0.00999339  0.03251376 -0.0220648   0.01095645  0.00772783  0.00630445
#   0.06536109 -0.12265508 -0.22830055  0.02794954 -0.37606036  0.1395124
#   0.10384977 -0.10384977  0.125362   -0.125362    0.08990079 -0.08990079]
# in static method i  6
# [ 8.27715510e-02 -8.27715510e-02  1.22502030e-02  3.82753874e-02
#  -4.37628981e-02 -8.28622880e-03  1.00000000e+00 -1.00000000e+00
#  -1.20082837e-02  7.97229957e-02 -2.02501048e-02  3.82753874e-02
#  -9.81445732e-02  3.82753874e-02  7.65239698e-02 -3.88350993e-03
#   3.82753874e-02 -4.37628981e-02  5.50135063e-03 -8.64697572e-02
#   1.82217407e-02 -9.59344008e-03  7.27744632e-02  6.50285824e-02
#   3.18555434e-02 -7.80641329e-03 -5.59645353e-02 -6.19419835e-02
#   1.70343125e-03  6.75470826e-03  1.70343125e-03 -6.19419835e-02
#   6.75470826e-03  3.80565417e-02  4.01236055e-02 -3.83544502e-02
#  -8.00403979e-02  5.81245747e-02  1.14297118e-01 -5.62073346e-02
#   5.05465261e-02 -6.77345069e-03 -6.66937708e-02 -2.89570298e-03
#  -7.59268503e-02 -2.74680159e-02 -1.98489436e-03 -7.35317804e-02
#   1.22502030e-02  1.32738682e-01 -3.39397775e-02 -6.74912271e-03
#  -2.84824862e-02 -3.88350993e-03 -4.34116501e-03  2.13700564e-02
#  -8.74266605e-03 -1.49390484e-01  3.82753874e-02  1.30835871e-01
#   8.70341636e-02 -8.70341636e-02  6.45406985e-04 -6.45406985e-04
#   2.98686014e-02 -2.98686014e-02]
# in static method i  7
# [-8.27715510e-02  8.27715510e-02 -1.22502030e-02 -3.82753874e-02
#   4.37628981e-02  8.28622880e-03 -1.00000000e+00  1.00000000e+00
#   1.20082837e-02 -7.97229957e-02  2.02501048e-02 -3.82753874e-02
#   9.81445732e-02 -3.82753874e-02 -7.65239698e-02  3.88350993e-03
#  -3.82753874e-02  4.37628981e-02 -5.50135063e-03  8.64697572e-02
#  -1.82217407e-02  9.59344008e-03 -7.27744632e-02 -6.50285824e-02
#  -3.18555434e-02  7.80641329e-03  5.59645353e-02  6.19419835e-02
#  -1.70343125e-03 -6.75470826e-03 -1.70343125e-03  6.19419835e-02
#  -6.75470826e-03 -3.80565417e-02 -4.01236055e-02  3.83544502e-02
#   8.00403979e-02 -5.81245747e-02 -1.14297118e-01  5.62073346e-02
#  -5.05465261e-02  6.77345069e-03  6.66937708e-02  2.89570298e-03
#   7.59268503e-02  2.74680159e-02  1.98489436e-03  7.35317804e-02
#  -1.22502030e-02 -1.32738682e-01  3.39397775e-02  6.74912271e-03
#   2.84824862e-02  3.88350993e-03  4.34116501e-03 -2.13700564e-02
#   8.74266605e-03  1.49390484e-01 -3.82753874e-02 -1.30835871e-01
#  -8.70341636e-02  8.70341636e-02 -6.45406985e-04  6.45406985e-04
#  -2.98686014e-02  2.98686014e-02]
# in static method i  8
# [ 0.09501574 -0.09501574  0.03009364  0.01341312  0.01341312 -0.03566748
#  -0.01200828  0.01200828  1.         -0.35530545 -0.92167457 -0.12488081
#  -0.03728028  0.01341312  0.06026424  0.01898493  0.01341312 -0.12488081
#   0.04242746 -0.06834012  0.0817925   0.00660352  0.01064457  0.06554614
#   0.09793663 -0.01102105 -0.11648661 -0.17675624 -0.02230433  0.04657535
#  -0.02230433 -0.17675624  0.04657535  0.05064886 -0.04144011  0.02565744
#  -0.09637575  0.00401566  0.07206896  0.00468146  0.03816244 -0.01141817
#  -0.23121464  0.0817925   0.02327123  0.02941029  0.05606565 -0.03256621
#   0.03009364  0.07730859  0.08178661 -0.02370242  0.02327123 -0.07888565
#  -0.09448276  0.03816244 -0.0013264   0.01380542  0.01341312 -0.01363243
#  -0.1171833   0.1171833  -0.26168741  0.26168741 -0.07838594  0.07838594]
# in static method i  9
# [-0.01415514  0.01415514 -0.01069244 -0.00476576 -0.00476576  0.01267285
#   0.079723   -0.079723   -0.35530545  1.         -0.03517335 -0.00476576
#  -0.02109388 -0.00476576  0.02221471 -0.00674545 -0.00476576  0.35147452
#  -0.16901382  0.0104344  -0.04170955  0.08713513 -0.00780641 -0.0232889
#  -0.05955808  0.11313559  0.03566123  0.2453657   0.03039046 -0.06407964
#   0.03039046  0.2453657  -0.06407964 -0.03321717  0.1917626  -0.02722753
#  -0.02482605 -0.02275721  0.02196024 -0.03668736 -0.01355932 -0.03361463
#  -0.02903346 -0.04170955 -0.00826839 -0.03779704 -0.02859031 -0.03705957
#  -0.01069244 -0.03478811 -0.05895158 -0.01172286 -0.00826839  0.2453657
#   0.06918587 -0.01355932 -0.01518554 -0.02990463 -0.00476576  0.03439999
#   0.12203059 -0.12203059  0.10109004 -0.10109004 -0.04181357  0.04181357]
# in static method i  10
# [-9.57103395e-02  9.57103395e-02 -2.77365460e-02 -1.23625357e-02
#  -1.23625357e-02  3.28738071e-02 -2.02501048e-02  2.02501048e-02
#  -9.21674572e-01 -3.51733481e-02  1.00000000e+00  1.35493391e-01
#   4.86128500e-02 -1.23625357e-02 -7.36511751e-02 -1.74979266e-02
#  -1.23625357e-02 -1.23625357e-02  2.47874297e-02  6.87345748e-02
#  -7.01364722e-02 -4.32251529e-02 -8.14054213e-03 -6.04122093e-02
#  -7.99889024e-02 -3.51733481e-02  1.09739748e-01  8.71396746e-02
#   1.12330854e-02 -2.31997182e-02  1.12330854e-02  8.71396746e-02
#  -2.31997182e-02 -4.03642146e-02 -3.52848242e-02 -1.61307888e-02
#   1.13343351e-01  5.15197052e-03 -8.61664924e-02  1.02217766e-02
#  -3.51733481e-02  2.61592540e-02  2.59251610e-01 -7.01364722e-02
#  -2.14484971e-02 -1.57562962e-02 -4.80758867e-02  5.01993275e-02
#  -2.77365460e-02 -6.82152521e-02 -6.29739539e-02  3.02067850e-02
#  -2.14484971e-02 -1.74979266e-02  7.23002498e-02 -3.51733481e-02
#   7.72079695e-03 -2.34817496e-03 -1.23625357e-02  2.97449157e-04
#   7.46373972e-02 -7.46373972e-02  2.37824165e-01 -2.37824165e-01
#   1.01160271e-01 -1.01160271e-01]
# in static method i  11
# [-0.0271778   0.0271778  -0.00375812 -0.00167504 -0.00167504  0.00445418
#   0.03827539 -0.03827539 -0.12488081 -0.00476576  0.13549339  1.
#  -0.00741396 -0.00167504 -0.21453151 -0.00237085 -0.00167504 -0.00167504
#   0.00335853  0.05795258 -0.01465984 -0.00585672 -0.0437629  -0.00818546
#  -0.02093315 -0.00476576  0.024209   -0.00237085  0.02273339 -0.02252236
#   0.02273339 -0.00237085 -0.02252236 -0.01167499 -0.02093315 -0.00956978
#  -0.00872572 -0.00799858 -0.01167499  0.12990187 -0.00476576 -0.01181469
#  -0.01020452 -0.01465984 -0.00290613 -0.0132847  -0.01004877  0.12859717
#  -0.00375812 -0.01222713 -0.02071998 -0.00412029 -0.00290613 -0.00237085
#  -0.04828725 -0.00476576 -0.00533733 -0.01051072 -0.00167504  0.01209072
#   0.04289064 -0.04289064  0.03553057 -0.03553057  0.03675822 -0.03675822]
# in static method i  12
# [-0.07891501  0.07891501 -0.01663394 -0.00741396 -0.00741396  0.01971482
#  -0.09814457  0.09814457 -0.03728028 -0.02109388  0.04861285 -0.00741396
#   1.         -0.00741396 -0.9495455  -0.01049372 -0.00741396 -0.00741396
#   0.01486532  0.11487108 -0.00482128 -0.02592265 -0.09814457 -0.03622993
#  -0.04561859  0.14488166  0.02012062 -0.01049372  0.07816068 -0.07711494
#   0.07816068 -0.01049372 -0.07711494  0.05675194 -0.09265294  0.04365161
#   0.00813079  0.01524523 -0.05167509  0.04272173 -0.02109388 -0.0522934
#  -0.04516659 -0.00482128 -0.01286292 -0.05879986  0.24372954  0.10730557
#  -0.01663394 -0.05411895  0.02658703 -0.01823695 -0.01286292 -0.01049372
#  -0.03975845 -0.02109388 -0.02362375  0.0721982  -0.00741396 -0.05175479
#  -0.03923207  0.03923207 -0.01607092  0.01607092  0.00926856 -0.00926856]
# in static method i  13
# [ 0.06163272 -0.06163272 -0.00375812 -0.00167504 -0.00167504  0.00445418
#   0.03827539 -0.03827539  0.01341312 -0.00476576 -0.01236254 -0.00167504
#  -0.00741396  1.         -0.21453151 -0.00237085 -0.00167504 -0.00167504
#   0.00335853 -0.02890367 -0.01465984 -0.00585672  0.03827539 -0.00818546
#  -0.02093315 -0.00476576  0.024209   -0.00237085 -0.073682    0.0743724
#  -0.073682   -0.00237085  0.0743724  -0.01167499  0.08001864 -0.00956978
#  -0.00872572 -0.00799858 -0.01167499 -0.01289467 -0.00476576 -0.01181469
#  -0.01020452 -0.01465984 -0.00290613 -0.0132847  -0.01004877 -0.0130255
#  -0.00375812 -0.01222713 -0.02071998 -0.00412029 -0.00290613 -0.00237085
#   0.03468911 -0.00476576 -0.00533733 -0.01051072 -0.00167504  0.01209072
#   0.04289064 -0.04289064 -0.04714368  0.04714368  0.03675822 -0.03675822]
# in static method i  14
# [ 0.06754525 -0.06754525  0.01751779  0.00780791  0.00780791 -0.02076237
#   0.07652397 -0.07652397  0.06026424  0.02221471 -0.07365118 -0.21453151
#  -0.9495455  -0.21453151  1.          0.01105131  0.00780791  0.00780791
#  -0.0156552  -0.11590131  0.01110192  0.02730006  0.09473381  0.03815502
#   0.05276004 -0.13593289 -0.02991889  0.01105131 -0.06316544  0.06196893
#  -0.06316544  0.01105131  0.06196893 -0.0488924   0.07516806 -0.03734449
#  -0.00387366 -0.01097536  0.05442086 -0.06667864  0.02221471  0.05507203
#   0.04756654  0.01110192  0.0135464   0.06192422 -0.22777348 -0.12789787
#   0.01751779  0.05699459 -0.01613477  0.01920598  0.0135464   0.01105131
#   0.04090166  0.02221471  0.02487901 -0.06412703  0.00780791  0.04394637
#   0.01834109 -0.01834109  0.0178907  -0.0178907  -0.02514969  0.02514969]
# in static method i  15
# [ 0.02438374 -0.02438374 -0.00531924 -0.00237085 -0.00237085  0.00630445
#  -0.00388351  0.00388351  0.01898493 -0.00674545 -0.01749793 -0.00237085
#  -0.01049372 -0.00237085  0.01105131  1.         -0.00237085 -0.00237085
#  -0.70591936  0.02055791 -0.02074954 -0.0082896  -0.00388351 -0.01158569
#   0.04181479 -0.00674545 -0.03183367 -0.0033557   0.03217684 -0.03187814
#   0.03217684 -0.0033557  -0.03187814 -0.01652478 -0.02962876 -0.01354507
#  -0.01235039 -0.01132119 -0.01652478 -0.01825111 -0.00674545 -0.0167225
#  -0.01444347  0.07048739  0.40584899 -0.01880315 -0.01422302 -0.01843628
#  -0.00531924 -0.01730628  0.04254825 -0.00583185 -0.00411333 -0.0033557
#  -0.0096234  -0.00674545 -0.00755446 -0.01487686 -0.00237085  0.0171132
#  -0.0552767   0.0552767  -0.00821859  0.00821859 -0.06449859  0.06449859]
# in static method i  16
# [ 0.06163272 -0.06163272 -0.00375812 -0.00167504 -0.00167504  0.00445418
#   0.03827539 -0.03827539  0.01341312 -0.00476576 -0.01236254 -0.00167504
#  -0.00741396 -0.00167504  0.00780791 -0.00237085  1.         -0.00167504
#  -0.49874214 -0.02890367  0.11426055 -0.00585672 -0.0437629  -0.00818546
#   0.08001864 -0.00476576 -0.06919088 -0.00237085  0.02273339 -0.02252236
#   0.02273339 -0.00237085 -0.02252236 -0.01167499 -0.02093315 -0.00956978
#  -0.00872572  0.20941739 -0.01167499 -0.01289467 -0.00476576 -0.01181469
#  -0.01020452 -0.01465984 -0.00290613 -0.0132847  -0.01004877  0.12859717
#  -0.00375812 -0.01222713 -0.02071998 -0.00412029 -0.00290613 -0.00237085
#  -0.04828725 -0.00476576 -0.00533733 -0.01051072 -0.00167504  0.01209072
#  -0.03905378  0.03905378 -0.04714368  0.04714368 -0.04556918  0.04556918]
# in static method i  17
# [-0.0271778   0.0271778  -0.00375812 -0.00167504 -0.00167504  0.00445418
#  -0.0437629   0.0437629  -0.12488081  0.35147452 -0.01236254 -0.00167504
#  -0.00741396 -0.00167504  0.00780791 -0.00237085 -0.00167504  1.
#  -0.49874214 -0.02890367 -0.01465984 -0.00585672  0.03827539 -0.00818546
#  -0.02093315  0.35147452 -0.06919088  0.70651432 -0.073682   -0.02252236
#  -0.073682    0.70651432 -0.02252236 -0.01167499 -0.02093315 -0.00956978
#  -0.00872572 -0.00799858  0.14347266 -0.01289467 -0.00476576 -0.01181469
#  -0.01020452 -0.01465984 -0.00290613 -0.0132847  -0.01004877 -0.0130255
#  -0.00375812 -0.01222713 -0.02071998 -0.00412029 -0.00290613  0.70651432
#  -0.04828725 -0.00476576 -0.00533733 -0.01051072 -0.00167504  0.01209072
#   0.04289064 -0.04289064  0.03553057 -0.03553057 -0.04556918  0.04556918]
# in static method i  18
# [-0.03454182  0.03454182  0.00753519  0.00335853  0.00335853 -0.00893083
#   0.00550135 -0.00550135  0.04242746 -0.16901382  0.02478743  0.00335853
#   0.01486532  0.00335853 -0.0156552  -0.70591936 -0.49874214 -0.49874214
#   1.          0.01441548 -0.03522914  0.01174299  0.00550135  0.0164122
#  -0.05923451 -0.16901382  0.09191305 -0.35058285  0.00274782  0.04515833
#   0.00274782 -0.35058285  0.04515833  0.02340887  0.04197188  0.01918784
#   0.01749546 -0.09294465 -0.0543606   0.02585438  0.00955555  0.02368897
#   0.02046052 -0.03522914 -0.28454784  0.0266364   0.02014822 -0.04487323
#   0.00753519  0.02451595 -0.00936453  0.00826136  0.00582692 -0.35058285
#   0.05522525  0.00955555  0.01070159  0.02107445  0.00335853 -0.02424242
#   0.03722901 -0.03722901  0.01164239 -0.01164239  0.09136821 -0.09136821]
# in static method i  19
# [-1.07026347e-01  1.07026347e-01 -2.58740952e-02 -2.89036657e-02
#  -2.89036657e-02  4.38643181e-02 -8.64697572e-02  8.64697572e-02
#  -6.83401178e-02  1.04343977e-02  6.87345748e-02  5.79525759e-02
#   1.14871082e-01 -2.89036657e-02 -1.15901313e-01  2.05579063e-02
#  -2.89036657e-02 -2.89036657e-02  1.44154760e-02  1.00000000e+00
#  -2.52962772e-01 -1.01060608e-01 -7.55150180e-01 -4.89740590e-02
#  -1.86139061e-01  1.04343977e-02  1.90971788e-01 -4.09102335e-02
#  -6.57078437e-04  6.25220605e-03 -6.57078437e-04 -4.09102335e-02
#   6.25220605e-03 -5.34745789e-02 -5.48346118e-02  7.49769460e-02
#   7.56616266e-02 -4.37576407e-02 -4.00215717e-02  6.22828556e-02
#  -2.04555519e-02 -1.74158755e-02  6.58071318e-02 -4.05652687e-02
#   5.03146813e-02  3.83976419e-04  2.58326248e-02  1.31365737e-01
#  -6.48481731e-02 -4.27769160e-02  3.53439321e-03  1.19091436e-04
#   8.39977985e-05 -4.09102335e-02 -2.73841740e-02 -5.13455014e-02
#  -3.67467431e-02  1.13234619e-01 -2.89036657e-02 -7.87172354e-02
#  -1.30821684e-02  1.30821684e-02  5.39335809e-02 -5.39335809e-02
#   2.03536250e-02 -2.03536250e-02]
# in static method i  20
# [ 0.00217903 -0.00217903  0.14065645  0.11426055 -0.01465984 -0.15691352
#   0.01822174 -0.01822174  0.0817925  -0.04170955 -0.07013647 -0.01465984
#  -0.00482128 -0.01465984  0.01110192 -0.02074954  0.11426055 -0.01465984
#  -0.03522914 -0.25296277  1.         -0.05125761 -0.38300969  0.20227343
#   0.05066828  0.09583996 -0.16077603 -0.02074954  0.07486977 -0.07240584
#   0.07486977 -0.02074954 -0.07240584 -0.00233742 -0.01429662 -0.08375405
#  -0.02470694  0.06990941  0.13744032 -0.00258161  0.04999012  0.03497396
#   0.02289018 -0.06193119 -0.02543423 -0.0445149  -0.01970418  0.06827699
#  -0.03289078  0.14265991  0.00166126  0.01679286 -0.02543423  0.07048739
#  -0.13426113  0.04999012  0.19976222  0.1703771   0.11426055 -0.26253271
#  -0.14140965  0.14140965 -0.07209967  0.07209967 -0.12332389  0.12332389]
# in static method i  21
# [ 0.00848139 -0.00848139 -0.01314012 -0.00585672 -0.00585672  0.01557389
#  -0.00959344  0.00959344  0.00660352  0.08713513 -0.04322515 -0.00585672
#  -0.02592265 -0.00585672  0.02730006 -0.0082896  -0.00585672 -0.00585672
#   0.01174299 -0.10106061 -0.05125761  1.         -0.15301537  0.2194211
#   0.01505158  0.08713513 -0.13306696 -0.0082896   0.05139374 -0.05051619
#   0.05139374 -0.0082896  -0.05051619 -0.04082118 -0.01436294 -0.0334604
#  -0.03050918  0.22542891  0.18520718 -0.04508574 -0.01666329 -0.04130962
#  -0.03567974 -0.05125761 -0.01016118 -0.04644945  0.01636195 -0.04554317
#  -0.01314012  0.17464227 -0.04285437 -0.01440644 -0.01016118 -0.0082896
#  -0.12048062  0.3985304   0.16733399  0.0622438  -0.00585672 -0.1332829
#  -0.0649212   0.0649212  -0.09256927  0.09256927 -0.08736728  0.08736728]
# in static method i  22
# [ 0.09731891 -0.09731891 -0.06137413 -0.0437629   0.03827539  0.05404289
#   0.07277446 -0.07277446  0.01064457 -0.00780641 -0.00814054 -0.0437629
#  -0.09814457  0.03827539  0.09473381 -0.00388351 -0.0437629   0.03827539
#   0.00550135 -0.75515018 -0.38300969 -0.15301537  1.         -0.14413552
#   0.13934035 -0.09533582 -0.04066543  0.05417496 -0.06146878  0.05436943
#  -0.06146878  0.05417496  0.05436943  0.06347007  0.06492779 -0.00811587
#  -0.04716666 -0.06652167 -0.10171785 -0.04451214 -0.00780641  0.00580581
#  -0.06669377  0.09213279 -0.02848249  0.04102069 -0.0164601  -0.15472514
#   0.08587454 -0.09946715  0.00765036 -0.00674912  0.01896188 -0.00388351
#   0.14516765 -0.09533582 -0.13944552 -0.23286861 -0.0437629   0.27887722
#   0.12059086 -0.12059086  0.02095874 -0.02095874  0.08381024 -0.08381024]
# in static method i  23
# [ 0.01814347 -0.01814347  0.1726297  -0.00818546 -0.00818546 -0.13992643
#   0.06502858 -0.06502858  0.06554614 -0.0232889  -0.06041221 -0.00818546
#  -0.03622993 -0.00818546  0.03815502 -0.01158569 -0.00818546 -0.00818546
#   0.0164122  -0.04897406  0.20227343  0.2194211  -0.14413552  1.
#  -0.10229435 -0.0232889  -0.33811622 -0.01158569  0.0496367  -0.04829988
#   0.0496367  -0.01158569 -0.04829988 -0.05705237  0.02639854 -0.04676482
#   0.04264014  0.09949367  0.074802   -0.0023338   0.05240003 -0.05773503
#  -0.04986661 -0.04424731  0.10887765 -0.03530658  0.02599702  0.02661807
#  -0.01836486  0.09877131 -0.03651735 -0.02013468  0.10887765 -0.01158569
#  -0.09492889  0.20377788  0.17735778  0.05691563 -0.00818546 -0.13293881
#  -0.13861357  0.13861357 -0.10741956  0.10741956 -0.10024129  0.10024129]
# in static method i  24
# [ 0.09893543 -0.09893543 -0.04696554 -0.02093315  0.08001864  0.01731494
#   0.03185554 -0.03185554  0.09793663 -0.05955808 -0.0799889  -0.02093315
#  -0.04561859 -0.02093315  0.05276004  0.04181479  0.08001864 -0.02093315
#  -0.05923451 -0.18613906  0.05066828  0.01505158  0.13934035 -0.10229435
#   1.         -0.05955808 -0.86468452 -0.02962876  0.07032659 -0.06662641
#   0.07032659 -0.02962876 -0.06662641  0.08864023 -0.06829318  0.0106403
#  -0.04836724  0.07533565 -0.02081346 -0.06040562 -0.05955808  0.00714432
#  -0.02209681  0.07665424 -0.03631816 -0.01150959  0.05254357 -0.0343224
#   0.0436325  -0.03249214  0.09931031 -0.05149161 -0.03631816 -0.02962876
#  -0.0264303  -0.02365512  0.06196748  0.07409382 -0.02093315 -0.09179657
#  -0.16597305  0.16597305 -0.1308901   0.1308901  -0.15462206  0.15462206]
# in static method i  25
# [-0.0773251   0.0773251  -0.01069244  0.35147452 -0.00476576 -0.12265508
#  -0.00780641  0.00780641 -0.01102105  0.11313559 -0.03517335 -0.00476576
#   0.14488166 -0.00476576 -0.13593289 -0.00674545 -0.00476576  0.35147452
#  -0.16901382  0.0104344   0.09583996  0.08713513 -0.09533582 -0.0232889
#  -0.05955808  1.         -0.19685888  0.2453657  -0.03818876  0.00484055
#  -0.03818876  0.2453657   0.00484055 -0.03321717 -0.02365512 -0.02722753
#  -0.02482605  0.1318884   0.07713766 -0.03668736 -0.01355932 -0.03361463
#  -0.02903346  0.00414029 -0.00826839  0.01177013  0.03426633 -0.03705957
#  -0.01069244  0.01828151  0.01328827 -0.01172286 -0.00826839  0.2453657
#  -0.07836459  0.23983051  0.09832639  0.0305108   0.35147452 -0.12631245
#  -0.08197103  0.08197103 -0.07532585  0.07532585 -0.07109286  0.07109286]
# in static method i  26
# [-0.07922361  0.07922361 -0.02950544 -0.06919088 -0.06919088  0.07754702
#  -0.05596454  0.05596454 -0.11648661  0.03566123  0.10973975  0.024209
#   0.02012062  0.024209   -0.02991889 -0.03183367 -0.06919088 -0.06919088
#   0.09191305  0.19097179 -0.16077603 -0.13306696 -0.04066543 -0.33811622
#  -0.86468452 -0.19685888  1.         -0.03183367 -0.07683702  0.08157026
#  -0.07683702 -0.03183367  0.08157026 -0.04826212  0.05780095  0.01781766
#   0.03254475 -0.14794301 -0.03379558  0.06652985  0.03566123  0.02754112
#   0.04994054 -0.05258691 -0.01201337  0.02305747 -0.06900612  0.02978948
#  -0.02950544 -0.01807878 -0.07933898  0.05954959 -0.01201337 -0.03183367
#   0.08665982 -0.13042456 -0.16094728 -0.1015287  -0.06919088  0.1763885
#   0.23588097 -0.23588097  0.18799029 -0.18799029  0.20568683 -0.20568683]
# in static method i  27
# [ 0.02438374 -0.02438374 -0.00531924 -0.00237085 -0.00237085  0.00630445
#  -0.06194198  0.06194198 -0.17675624  0.2453657   0.08713967 -0.00237085
#  -0.01049372 -0.00237085  0.01105131 -0.0033557  -0.00237085  0.70651432
#  -0.35058285 -0.04091023 -0.02074954 -0.0082896   0.05417496 -0.01158569
#  -0.02962876  0.2453657  -0.03183367  1.         -0.10428946 -0.03187814
#  -0.10428946  1.         -0.03187814 -0.01652478 -0.02962876  0.1170993
#  -0.01235039 -0.01132119  0.09327318 -0.01825111 -0.00674545 -0.0167225
#  -0.01444347 -0.02074954 -0.00411333 -0.01880315 -0.01422302 -0.01843628
#  -0.00531924  0.08829735 -0.02932705 -0.00583185 -0.00411333  0.49832215
#  -0.06834575 -0.00674545 -0.00755446  0.10534426 -0.00237085 -0.08948776
#   0.0607074  -0.0607074   0.05028995 -0.05028995 -0.06449859  0.06449859]
# in static method i  28
# [ 5.25625444e-02 -5.25625444e-02  7.74111951e-03 -7.36819953e-02
#   2.27333946e-02  1.28007634e-02  1.70343125e-03 -1.70343125e-03
#  -2.23043303e-02  3.03904558e-02  1.12330854e-02  2.27333946e-02
#   7.81606822e-02 -7.36819953e-02 -6.31654362e-02  3.21768351e-02
#   2.27333946e-02 -7.36819953e-02  2.74781850e-03 -6.57078437e-04
#   7.48697670e-02  5.13937414e-02 -6.14687789e-02  4.96366987e-02
#   7.03265936e-02 -3.81887615e-02 -7.68370199e-02 -1.04289458e-01
#   1.00000000e+00 -9.90716968e-01  1.00000000e+00 -1.04289458e-01
#  -9.90716968e-01 -5.81861259e-03 -7.40964110e-03  5.49707542e-03
#  -1.67977456e-02  3.91947397e-03 -9.54202519e-02  2.38119943e-02
#  -7.24783701e-02 -4.66257228e-02  2.10196723e-02  1.24506264e-01
#  -1.63174121e-02  1.93152100e-02 -1.67274854e-02  4.04621953e-02
#   7.74111951e-03 -1.06954935e-01  7.48711373e-03 -2.31347020e-02
#  -1.63174121e-02 -3.60563116e-02  3.23746687e-02  3.03904558e-02
#   7.24373899e-02  2.81908854e-02 -7.36819953e-02 -4.81029873e-02
#  -1.56180254e-01  1.56180254e-01 -1.71863243e-01  1.71863243e-01
#  -1.73978012e-01  1.73978012e-01]
# in static method i  29
# [-0.0561568   0.0561568  -0.00705254  0.0743724  -0.02252236 -0.01372614
#   0.00675471 -0.00675471  0.04657535 -0.06407964 -0.02319972 -0.02252236
#  -0.07711494  0.0743724   0.06196893 -0.03187814 -0.02252236 -0.02252236
#   0.04515833  0.00625221 -0.07240584 -0.05051619  0.05436943 -0.04829988
#  -0.06662641  0.00484055  0.08157026 -0.03187814 -0.99071697  1.
#  -0.99071697 -0.03187814  1.          0.00810625  0.01149632 -0.02153025
#   0.01856939 -0.00239151  0.08314552 -0.02143571  0.07376073  0.04914327
#  -0.01914996 -0.12228912  0.01696078 -0.01684111  0.01875474 -0.03814339
#  -0.00705254  0.09541768 -0.00351574  0.02404686  0.01696078 -0.03187814
#  -0.02319372 -0.02961954 -0.07176495 -0.04273014  0.0743724   0.06057388
#   0.14865891 -0.14865891  0.16584379 -0.16584379  0.18365907 -0.18365907]
# in static method i  30
# [ 5.25625444e-02 -5.25625444e-02  7.74111951e-03 -7.36819953e-02
#   2.27333946e-02  1.28007634e-02  1.70343125e-03 -1.70343125e-03
#  -2.23043303e-02  3.03904558e-02  1.12330854e-02  2.27333946e-02
#   7.81606822e-02 -7.36819953e-02 -6.31654362e-02  3.21768351e-02
#   2.27333946e-02 -7.36819953e-02  2.74781850e-03 -6.57078437e-04
#   7.48697670e-02  5.13937414e-02 -6.14687789e-02  4.96366987e-02
#   7.03265936e-02 -3.81887615e-02 -7.68370199e-02 -1.04289458e-01
#   1.00000000e+00 -9.90716968e-01  1.00000000e+00 -1.04289458e-01
#  -9.90716968e-01 -5.81861259e-03 -7.40964110e-03  5.49707542e-03
#  -1.67977456e-02  3.91947397e-03 -9.54202519e-02  2.38119943e-02
#  -7.24783701e-02 -4.66257228e-02  2.10196723e-02  1.24506264e-01
#  -1.63174121e-02  1.93152100e-02 -1.67274854e-02  4.04621953e-02
#   7.74111951e-03 -1.06954935e-01  7.48711373e-03 -2.31347020e-02
#  -1.63174121e-02 -3.60563116e-02  3.23746687e-02  3.03904558e-02
#   7.24373899e-02  2.81908854e-02 -7.36819953e-02 -4.81029873e-02
#  -1.56180254e-01  1.56180254e-01 -1.71863243e-01  1.71863243e-01
#  -1.73978012e-01  1.73978012e-01]
# in static method i  31
# [ 0.02438374 -0.02438374 -0.00531924 -0.00237085 -0.00237085  0.00630445
#  -0.06194198  0.06194198 -0.17675624  0.2453657   0.08713967 -0.00237085
#  -0.01049372 -0.00237085  0.01105131 -0.0033557  -0.00237085  0.70651432
#  -0.35058285 -0.04091023 -0.02074954 -0.0082896   0.05417496 -0.01158569
#  -0.02962876  0.2453657  -0.03183367  1.         -0.10428946 -0.03187814
#  -0.10428946  1.         -0.03187814 -0.01652478 -0.02962876  0.1170993
#  -0.01235039 -0.01132119  0.09327318 -0.01825111 -0.00674545 -0.0167225
#  -0.01444347 -0.02074954 -0.00411333 -0.01880315 -0.01422302 -0.01843628
#  -0.00531924  0.08829735 -0.02932705 -0.00583185 -0.00411333  0.49832215
#  -0.06834575 -0.00674545 -0.00755446  0.10534426 -0.00237085 -0.08948776
#   0.0607074  -0.0607074   0.05028995 -0.05028995 -0.06449859  0.06449859]
# in static method i  32
# [-0.0561568   0.0561568  -0.00705254  0.0743724  -0.02252236 -0.01372614
#   0.00675471 -0.00675471  0.04657535 -0.06407964 -0.02319972 -0.02252236
#  -0.07711494  0.0743724   0.06196893 -0.03187814 -0.02252236 -0.02252236
#   0.04515833  0.00625221 -0.07240584 -0.05051619  0.05436943 -0.04829988
#  -0.06662641  0.00484055  0.08157026 -0.03187814 -0.99071697  1.
#  -0.99071697 -0.03187814  1.          0.00810625  0.01149632 -0.02153025
#   0.01856939 -0.00239151  0.08314552 -0.02143571  0.07376073  0.04914327
#  -0.01914996 -0.12228912  0.01696078 -0.01684111  0.01875474 -0.03814339
#  -0.00705254  0.09541768 -0.00351574  0.02404686  0.01696078 -0.03187814
#  -0.02319372 -0.02961954 -0.07176495 -0.04273014  0.0743724   0.06057388
#   0.14865891 -0.14865891  0.16584379 -0.16584379  0.18365907 -0.18365907]
# in static method i  33
# [ 0.0719299  -0.0719299  -0.02619397 -0.01167499 -0.01167499  0.03104552
#   0.03805654 -0.03805654  0.05064886 -0.03321717 -0.04036421 -0.01167499
#   0.05675194 -0.01167499 -0.0488924  -0.01652478 -0.01167499 -0.01167499
#   0.02340887 -0.05347458 -0.00233742 -0.04082118  0.06347007 -0.05705237
#   0.08864023 -0.03321717 -0.04826212 -0.01652478 -0.00581861  0.00810625
#  -0.00581861 -0.01652478  0.00810625  1.         -0.14590338 -0.0667011
#  -0.06081803 -0.05574986 -0.08137432 -0.08987546 -0.03321717 -0.082348
#  -0.0711252  -0.10217866 -0.02025563 -0.09259392 -0.07003959 -0.04691594
#  -0.02619397 -0.08522275 -0.11295614 -0.02871828 -0.02025563 -0.01652478
#   0.19037382 -0.03321717 -0.03720104 -0.02063582 -0.01167499  0.03761025
#   0.01971752 -0.01971752  0.08117854 -0.08117854  0.07768206 -0.07768206]
# in static method i  34
# [-0.06217516  0.06217516 -0.00166652  0.08001864 -0.02093315 -0.02103445
#   0.04012361 -0.04012361 -0.04144011  0.1917626  -0.03528482 -0.02093315
#  -0.09265294  0.08001864  0.07516806 -0.02962876 -0.02093315 -0.02093315
#   0.04197188 -0.05483461 -0.01429662 -0.01436294  0.06492779  0.02639854
#  -0.06829318 -0.02365512  0.05780095 -0.02962876 -0.00740964  0.01149632
#  -0.00740964 -0.02962876  0.01149632 -0.14590338  1.         -0.11959444
#  -0.10904615 -0.09995897 -0.14590338 -0.16114584 -0.05955808 -0.14764918
#  -0.12752681 -0.18320537 -0.03631816 -0.16602002 -0.12558032  0.03704337
#  -0.04696554 -0.15280358 -0.02351816 -0.01010454 -0.03631816 -0.02962876
#   0.11573397 -0.05955808 -0.00236681 -0.04575036  0.08001864  0.0296511
#   0.0157162  -0.0157162   0.01908872 -0.01908872 -0.01356967  0.01356967]
# in static method i  35
# [-0.02433211  0.02433211 -0.02147074 -0.00956978  0.17503444 -0.04467966
#  -0.03835445  0.03835445  0.02565744 -0.02722753 -0.01613079 -0.00956978
#   0.04365161 -0.00956978 -0.03734449 -0.01354507 -0.00956978 -0.00956978
#   0.01918784  0.07497695 -0.08375405 -0.0334604  -0.00811587 -0.04676482
#   0.0106403  -0.02722753  0.01781766  0.1170993   0.00549708 -0.02153025
#   0.00549708  0.1170993  -0.02153025 -0.0667011  -0.11959444  1.
#  -0.04985147 -0.04569718 -0.0667011  -0.07366933 -0.02722753 -0.06749921
#  -0.05830008 -0.08375405 -0.01660319 -0.07589761 -0.05741022 -0.07441676
#  -0.02147074 -0.04235484  0.14366697 -0.02353987 -0.01660319 -0.01354507
#  -0.03119808 -0.02722753 -0.03049304  0.09648741 -0.00956978 -0.06972614
#  -0.05699865  0.05699865 -0.04079202  0.04079202 -0.10861836  0.10861836]
# in static method i  36
# [-0.05260754  0.05260754  0.07047723 -0.00872572 -0.00872572 -0.0530354
#  -0.0800404   0.0800404  -0.09637575 -0.02482605  0.11334335 -0.00872572
#   0.00813079 -0.00872572 -0.00387366 -0.01235039 -0.00872572 -0.00872572
#   0.01749546  0.07566163 -0.02470694 -0.03050918 -0.04716666  0.04264014
#  -0.04836724 -0.02482605  0.03254475 -0.01235039 -0.01679775  0.01856939
#  -0.01679775 -0.01235039  0.01856939 -0.06081803 -0.10904615 -0.04985147
#   1.         -0.04166667 -0.06081803 -0.06717166 -0.02482605 -0.06154575
#  -0.05315798 -0.0763669  -0.01513878 -0.0692034  -0.05234661 -0.01110324
#  -0.01957701 -0.06369429 -0.00619303 -0.02146364 -0.01513878 -0.01235039
#   0.06433081 -0.02482605  0.03614459 -0.02071736 -0.00872572  0.00262432
#   0.05924779 -0.05924779  0.11883075 -0.11883075  0.07601948 -0.07601948]
# in static method i  37
# [-5.26720082e-02  5.26720082e-02  7.96131653e-02 -7.99858074e-03
#  -7.99858074e-03 -6.13221859e-02  5.81245747e-02 -5.81245747e-02
#   4.01565624e-03 -2.27572136e-02  5.15197052e-03 -7.99858074e-03
#   1.52452251e-02 -7.99858074e-03 -1.09753599e-02 -1.13211871e-02
#   2.09417387e-01 -7.99858074e-03 -9.29446456e-02 -4.37576407e-02
#   6.99094080e-02  2.25428910e-01 -6.65216700e-02  9.94936676e-02
#   7.53356457e-02  1.31888397e-01 -1.47943009e-01 -1.13211871e-02
#   3.91947397e-03 -2.39151213e-03  3.91947397e-03 -1.13211871e-02
#  -2.39151213e-03 -5.57498611e-02 -9.99589695e-02 -4.56971817e-02
#  -4.16666667e-02  1.00000000e+00 -5.57498611e-02 -6.15740229e-02
#  -2.27572136e-02 -5.64169334e-02 -4.87281500e-02 -7.00029948e-02
#  -1.38772126e-02 -6.34364533e-02 -4.79843930e-02 -7.19654746e-04
#   4.69848189e-01 -5.83864361e-02 -1.07640790e-02 -1.96750059e-02
#  -1.38772126e-02 -1.13211871e-02 -1.76548327e-01  5.95825230e-01
#   1.13067704e-01  6.04256319e-02 -7.99858074e-03 -1.05738203e-01
#  -4.41978993e-02  4.41978993e-02 -4.56718201e-02  4.56718201e-02
#  -5.67755554e-02  5.67755554e-02]
# in static method i  38
# [ 0.12695271 -0.12695271 -0.02619397 -0.01167499 -0.01167499  0.03104552
#   0.11429712 -0.11429712  0.07206896  0.02196024 -0.08616649 -0.01167499
#  -0.05167509 -0.01167499  0.05442086 -0.01652478 -0.01167499  0.14347266
#  -0.0543606  -0.04002157  0.13744032  0.18520718 -0.10171785  0.074802
#  -0.02081346  0.07713766 -0.03379558  0.09327318 -0.09542025  0.08314552
#  -0.09542025  0.09327318  0.08314552 -0.08137432 -0.14590338 -0.0667011
#  -0.06081803 -0.05574986  1.         -0.08987546 -0.03321717 -0.082348
#  -0.0711252  -0.10217866 -0.02025563 -0.09259392 -0.07003959 -0.0907873
#  -0.02619397  0.93173012 -0.1444176  -0.02871828 -0.02025563  0.09327318
#  -0.33656063 -0.03321717  0.06167105 -0.07325936 -0.01167499  0.03761025
#   0.159332   -0.159332   -0.03406886  0.03406886  0.16694286 -0.16694286]
# in static method i  39
# [-0.03196915  0.03196915 -0.02893044 -0.01289467 -0.01289467  0.03428883
#  -0.05620733  0.05620733  0.00468146 -0.03668736  0.01022178  0.12990187
#   0.04272173 -0.01289467 -0.06667864 -0.01825111 -0.01289467 -0.01289467
#   0.02585438  0.06228286 -0.00258161 -0.04508574 -0.04451214 -0.0023338
#  -0.06040562 -0.03668736  0.06652985 -0.01825111  0.02381199 -0.02143571
#   0.02381199 -0.01825111 -0.02143571 -0.08987546 -0.16114584 -0.07366933
#  -0.06717166 -0.06157402 -0.08987546  1.         -0.03668736 -0.09095086
#  -0.07855562 -0.11285322 -0.02237173 -0.10226717 -0.07735659  0.48522103
#  -0.02893044 -0.09412593 -0.02919897 -0.03171847 -0.02237173  0.08280596
#  -0.1942871  -0.03668736 -0.04108741  0.01595576 -0.01289467  0.00718177
#   0.11990463 -0.11990463  0.12030244 -0.12030244  0.13039582 -0.13039582]
# in static method i  40
# [ 0.14376975 -0.14376975 -0.01069244 -0.00476576 -0.00476576  0.01267285
#   0.05054653 -0.05054653  0.03816244 -0.01355932 -0.03517335 -0.00476576
#  -0.02109388 -0.00476576  0.02221471 -0.00674545 -0.00476576 -0.00476576
#   0.00955555 -0.02045555  0.04999012 -0.01666329 -0.00780641  0.05240003
#  -0.05955808 -0.01355932  0.03566123 -0.00674545 -0.07247837  0.07376073
#  -0.07247837 -0.00674545  0.07376073 -0.03321717 -0.05955808 -0.02722753
#  -0.02482605 -0.02275721 -0.03321717 -0.03668736  1.         -0.03361463
#  -0.02903346 -0.04170955 -0.00826839 -0.03779704 -0.02859031 -0.03705957
#  -0.01069244  0.07135113 -0.05895158  0.71851393 -0.00826839 -0.00674545
#  -0.10787468 -0.01355932 -0.01518554 -0.02990463 -0.00476576  0.03439999
#   0.03460133 -0.03460133  0.07168739 -0.07168739  0.0460243  -0.0460243 ]
# in static method i  41
# [-0.05551824  0.05551824 -0.02650739 -0.01181469 -0.01181469  0.031417
#  -0.00677345  0.00677345 -0.01141817 -0.03361463  0.02615925 -0.01181469
#  -0.0522934  -0.01181469  0.05507203 -0.0167225  -0.01181469 -0.01181469
#   0.02368897 -0.01741588  0.03497396 -0.04130962  0.00580581 -0.05773503
#   0.00714432 -0.03361463  0.02754112 -0.0167225  -0.04662572  0.04914327
#  -0.04662572 -0.0167225   0.04914327 -0.082348   -0.14764918 -0.06749921
#  -0.06154575 -0.05641693 -0.082348   -0.09095086 -0.03361463  1.
#  -0.07197625 -0.10340128 -0.020498   -0.09370185 -0.07087765 -0.07015803
#  -0.02650739 -0.04048116  0.00958332 -0.02906191 -0.020498   -0.0167225
#   0.07927473 -0.03361463 -0.03764616 -0.02204042 -0.01181469  0.0390868
#   0.0637909  -0.0637909   0.07313527 -0.07313527  0.0825389  -0.0825389 ]
# in static method i  42
# [-0.1191948   0.1191948  -0.02289483 -0.01020452 -0.01020452  0.02713533
#  -0.06669377  0.06669377 -0.23121464 -0.02903346  0.25925161 -0.01020452
#  -0.04516659 -0.01020452  0.04756654 -0.01444347 -0.01020452 -0.01020452
#   0.02046052  0.06580713  0.02289018 -0.03567974 -0.06669377 -0.04986661
#  -0.02209681 -0.02903346  0.04994054 -0.01444347  0.02101967 -0.01914996
#   0.02101967 -0.01444347 -0.01914996 -0.0711252  -0.12752681 -0.05830008
#  -0.05315798 -0.04872815 -0.0711252  -0.07855562 -0.02903346 -0.07197625
#   1.         -0.08930923 -0.01770443 -0.08093169 -0.06121808 -0.0054001
#  -0.02289483 -0.07448892 -0.09087245 -0.02510121 -0.01770443 -0.01444347
#   0.13911522 -0.02903346  0.02303959  0.02467346 -0.01020452 -0.0312169
#  -0.00970759  0.00970759 -0.01378868  0.01378868  0.00898614 -0.00898614]
# in static method i  43
# [ 0.23078586 -0.23078586  0.08280738 -0.01465984 -0.01465984 -0.05896541
#  -0.0028957   0.0028957   0.0817925  -0.04170955 -0.07013647 -0.01465984
#  -0.00482128 -0.01465984  0.01110192  0.07048739 -0.01465984 -0.01465984
#  -0.03522914 -0.04056527 -0.06193119 -0.05125761  0.09213279 -0.04424731
#   0.07665424  0.00414029 -0.05258691 -0.02074954  0.12450626 -0.12228912
#   0.12450626 -0.02074954 -0.12228912 -0.10217866 -0.18320537 -0.08375405
#  -0.0763669  -0.07000299 -0.10217866 -0.11285322 -0.04170955 -0.10340128
#  -0.08930923  1.         -0.02543423 -0.11626669 -0.08794607 -0.11399819
#  -0.03289078 -0.10701099  0.15851925 -0.03606046  0.04912298 -0.02074954
#   0.01525126 -0.04170955 -0.04671194  0.06105789 -0.01465984 -0.02989073
#  -0.17304958  0.17304958 -0.15722426  0.15722426 -0.15511169  0.15511169]
# in static method i  44
# [-0.04715238  0.04715238 -0.00652018 -0.00290613 -0.00290613  0.00772783
#  -0.07592685  0.07592685  0.02327123 -0.00826839 -0.0214485  -0.00290613
#  -0.01286292 -0.00290613  0.0135464   0.40584899 -0.00290613 -0.00290613
#  -0.28454784  0.05031468 -0.02543423 -0.01016118 -0.02848249  0.10887765
#  -0.03631816 -0.00826839 -0.01201337 -0.00411333 -0.01631741  0.01696078
#  -0.01631741 -0.00411333  0.01696078 -0.02025563 -0.03631816 -0.01660319
#  -0.01513878 -0.01387721 -0.02025563 -0.02237173 -0.00826839 -0.020498
#  -0.01770443 -0.02543423  1.         -0.02304841 -0.0174342  -0.02259871
#  -0.00652018 -0.02121358  0.02278691 -0.00714853  0.66498599 -0.00411333
#  -0.08377641 -0.00826839 -0.00926005 -0.01823566 -0.00290613  0.02097691
#  -0.02036664  0.02036664  0.01383194 -0.01383194 -0.03144911  0.03144911]
# in static method i  45
# [-1.04332525e-01  1.04332525e-01 -2.98055027e-02 -1.32846963e-02
#  -1.32846963e-02  3.53259683e-02 -2.74680159e-02  2.74680159e-02
#   2.94102867e-02 -3.77970394e-02 -1.57562962e-02 -1.32846963e-02
#  -5.87998630e-02 -1.32846963e-02  6.19242187e-02 -1.88031523e-02
#  -1.32846963e-02 -1.32846963e-02  2.66364025e-02  3.83976419e-04
#  -4.45149048e-02 -4.64494537e-02  4.10206853e-02 -3.53065782e-02
#  -1.15095941e-02  1.17701307e-02  2.30574678e-02 -1.88031523e-02
#   1.93152100e-02 -1.68411133e-02  1.93152100e-02 -1.88031523e-02
#  -1.68411133e-02 -9.25939234e-02 -1.66020022e-01 -7.58976122e-02
#  -6.92034036e-02 -6.34364533e-02 -9.25939234e-02 -1.02267167e-01
#  -3.77970394e-02 -9.37018515e-02 -8.09316920e-02 -1.16266692e-01
#  -2.30484084e-02  1.00000000e+00 -7.96963996e-02 -8.35993975e-02
#  -2.98055027e-02 -9.69729624e-02 -6.54103742e-02 -3.26778569e-02
#  -2.30484084e-02 -1.88031523e-02  1.82755650e-01 -3.77970394e-02
#   2.07937734e-03 -5.97236183e-02 -1.32846963e-02  5.39737629e-02
#  -2.46910244e-02  2.46910244e-02 -4.02999229e-02  4.02999229e-02
#  -4.06672032e-02  4.06672032e-02]
# in static method i  46
# [-0.02201155  0.02201155 -0.02254538 -0.01004877 -0.01004877  0.02672115
#  -0.00198489  0.00198489  0.05606565 -0.02859031 -0.04807589 -0.01004877
#   0.24372954 -0.01004877 -0.22777348 -0.01422302 -0.01004877 -0.01004877
#   0.02014822  0.02583262 -0.01970418  0.01636195 -0.0164601   0.02599702
#   0.05254357  0.03426633 -0.06900612 -0.01422302 -0.01672749  0.01875474
#  -0.01672749 -0.01422302  0.01875474 -0.07003959 -0.12558032 -0.05741022
#  -0.05234661 -0.04798439 -0.07003959 -0.07735659 -0.02859031 -0.07087765
#  -0.06121808 -0.08794607 -0.0174342  -0.0796964   1.         -0.05315288
#  -0.02254538 -0.07335197  0.21617912 -0.02471808 -0.0174342  -0.01422302
#  -0.08471054 -0.02859031  0.02429697  0.0568397  -0.01004877 -0.06035577
#  -0.1475362   0.1475362  -0.10777126  0.10777126 -0.18621736  0.18621736]
# in static method i  47
# [-8.57750951e-02  8.57750951e-02  9.78737034e-02 -1.30254958e-02
#  -1.30254958e-02 -7.29620175e-02 -7.35317804e-02  7.35317804e-02
#  -3.25662087e-02 -3.70595736e-02  5.01993275e-02  1.28597168e-01
#   1.07305569e-01 -1.30254958e-02 -1.27897865e-01 -1.84362801e-02
#   1.28597168e-01 -1.30254958e-02 -4.48732290e-02  1.31365737e-01
#   6.82769901e-02 -4.55431688e-02 -1.54725142e-01  2.66180706e-02
#  -3.43223972e-02 -3.70595736e-02  2.97894838e-02 -1.84362801e-02
#   4.04621953e-02 -3.81433853e-02  4.04621953e-02 -1.84362801e-02
#  -3.81433853e-02 -4.69159443e-02  3.70433661e-02 -7.44167583e-02
#  -1.11032447e-02 -7.19654746e-04 -9.07873043e-02  4.85221034e-01
#  -3.70595736e-02 -7.01580336e-02 -5.40010018e-03 -1.13998189e-01
#  -2.25987061e-02 -8.35993975e-02 -5.31528849e-02  1.00000000e+00
#  -2.92239614e-02 -9.50809030e-02 -1.61123122e-01 -3.20402726e-02
#  -2.25987061e-02 -1.84362801e-02 -3.75492310e-01 -3.70595736e-02
#   9.38751098e-02  1.43385311e-02 -1.30254958e-02 -5.50587398e-02
#  -6.03894319e-02  6.03894319e-02  3.08252553e-02 -3.08252553e-02
#  -5.15816211e-03  5.15816211e-03]
# in static method i  48
# [-0.02112503  0.02112503 -0.0084317  -0.00375812 -0.00375812  0.00999339
#   0.0122502  -0.0122502   0.03009364 -0.01069244 -0.02773655 -0.00375812
#  -0.01663394 -0.00375812  0.01751779 -0.00531924 -0.00375812 -0.00375812
#   0.00753519 -0.06484817 -0.03289078 -0.01314012  0.08587454 -0.01836486
#   0.0436325  -0.01069244 -0.02950544 -0.00531924  0.00774112 -0.00705254
#   0.00774112 -0.00531924 -0.00705254 -0.02619397 -0.04696554 -0.02147074
#  -0.01957701  0.46984819 -0.02619397 -0.02893044 -0.01069244 -0.02650739
#  -0.02289483 -0.03289078 -0.00652018 -0.0298055  -0.02254538 -0.02922396
#   1.         -0.02743276 -0.04648728 -0.00924427 -0.00652018 -0.00531924
#  -0.10833712 -0.01069244 -0.01197482 -0.02358181 -0.00375812  0.0271267
#   0.02268921 -0.02268921  0.00552121 -0.00552121  0.00858683 -0.00858683]
# in static method i  49
# [ 0.1455989  -0.1455989  -0.02743276 -0.01222713 -0.01222713  0.03251376
# ...
#   0.00774112 -0.00531924 -0.00705254 -0.02619397 -0.04696554 -0.02147074
#  -0.01957701  0.46984819 -0.02619397 -0.02893044 -0.01069244 -0.02650739
#  -0.02289483 -0.03289078 -0.00652018 -0.0298055  -0.02254538 -0.02922396
#   1.         -0.02743276 -0.04648728 -0.00924427 -0.00652018 -0.00531924
#  -0.10833712 -0.01069244 -0.01197482 -0.02358181 -0.00375812  0.0271267
#   0.02268921 -0.02268921  0.00552121 -0.00552121  0.00858683 -0.00858683]
# in static method i  49
# [ 0.1455989  -0.1455989  -0.02743276 -0.01222713 -0.01222713  0.03251376
#   0.13273868 -0.13273868  0.07730859 -0.03478811 -0.06821525 -0.01222713
#  -0.05411895 -0.01222713  0.05699459 -0.01730628 -0.01222713 -0.01222713
#   0.02451595 -0.04277692  0.14265991  0.17464227 -0.09946715  0.09877131
#  -0.03249214  0.01828151 -0.01807878  0.08829735 -0.10695493  0.09541768
#  -0.10695493  0.08829735  0.09541768 -0.08522275 -0.15280358 -0.04235484
#  -0.06369429 -0.05838644  0.93173012 -0.09412593  0.07135113 -0.04048116
#  -0.07448892 -0.10701099 -0.02121358 -0.09697296 -0.07335197 -0.0950809
#  -0.02743276  1.         -0.15124754 -0.03007645 -0.02121358 -0.01730628
#  -0.35247757 -0.03478811  0.05613475 -0.05141736 -0.01222713  0.02093862
#   0.166596   -0.166596   -0.02391136  0.02391136  0.17020485 -0.17020485]
# in static method i  50
# [ 0.05101647 -0.05101647  0.04465827 -0.02071998 -0.02071998 -0.0220648
#  -0.03393978  0.03393978  0.08178661 -0.05895158 -0.06297395 -0.02071998
#   0.02658703 -0.02071998 -0.01613477  0.04254825 -0.02071998 -0.02071998
#  -0.00936453  0.00353439  0.00166126 -0.04285437  0.00765036 -0.03651735
#   0.09931031  0.01328827 -0.07933898 -0.02932705  0.00748711 -0.00351574
#   0.00748711 -0.02932705 -0.00351574 -0.11295614 -0.02351816  0.14366697
#  -0.00619303 -0.01076408 -0.1444176  -0.02919897 -0.05895158  0.00958332
#  -0.09087245  0.15851925  0.02278691 -0.06541037  0.21617912 -0.16112312
#  -0.04648728 -0.15124754  1.         -0.05096725 -0.03594832 -0.02932705
#  -0.59730487 -0.05895158 -0.00129879  0.14556922 -0.02071998 -0.12534852
#  -0.1756736   0.1756736  -0.08020856  0.08020856 -0.18805248  0.18805248]
# in static method i  51
# [ 1.15195380e-01 -1.15195380e-01 -9.24426587e-03 -4.12028831e-03
#  -4.12028831e-03  1.09564548e-02 -6.74912271e-03  6.74912271e-03
#  -2.37024180e-02 -1.17228649e-02  3.02067850e-02 -4.12028831e-03
#  -1.82369535e-02 -4.12028831e-03  1.92059818e-02 -5.83185396e-03
#  -4.12028831e-03 -4.12028831e-03  8.26135995e-03  1.19091436e-04
#   1.67928625e-02 -1.44064371e-02 -6.74912271e-03 -2.01346817e-02
#  -5.14916067e-02 -1.17228649e-02  5.95495875e-02 -5.83185396e-03
#  -2.31347020e-02  2.40468586e-02 -2.31347020e-02 -5.83185396e-03
#   2.40468586e-02 -2.87182825e-02 -1.01045357e-02 -2.35398716e-02
#  -2.14636428e-02 -1.96750059e-02 -2.87182825e-02 -3.17184679e-02
#   7.18513927e-01 -2.90619097e-02 -2.51012065e-02 -3.60604626e-02
#  -7.14853283e-03 -3.26778569e-02 -2.47180769e-02 -3.20402726e-02
#  -9.24426587e-03 -3.00764545e-02 -5.09672511e-02  1.00000000e+00
#  -7.14853283e-03 -5.83185396e-03 -1.18777557e-01 -1.17228649e-02
#  -1.31288325e-02 -2.58543845e-02 -4.12028831e-03  2.97408958e-02
#   3.83136297e-02 -3.83136297e-02  8.73985332e-02 -8.73985332e-02
#   2.29150035e-02 -2.29150035e-02]
# in static method i  52
# [-4.71523824e-02  4.71523824e-02 -6.52018322e-03 -2.90612961e-03
#  -2.90612961e-03  7.72782759e-03 -2.84824862e-02  2.84824862e-02
#   2.32712259e-02 -8.26839341e-03 -2.14484971e-02 -2.90612961e-03
#  -1.28629228e-02 -2.90612961e-03  1.35463997e-02 -4.11333435e-03
#  -2.90612961e-03 -2.90612961e-03  5.82691815e-03  8.39977985e-05
#  -2.54342342e-02 -1.01611757e-02  1.89618780e-02  1.08877646e-01
#  -3.63181582e-02 -8.26839341e-03 -1.20133690e-02 -4.11333435e-03
#  -1.63174121e-02  1.69607761e-02 -1.63174121e-02 -4.11333435e-03
#   1.69607761e-02 -2.02556337e-02 -3.63181582e-02 -1.66031871e-02
#  -1.51387774e-02 -1.38772126e-02 -2.02556337e-02 -2.23717303e-02
#  -8.26839341e-03 -2.04980015e-02 -1.77044308e-02  4.91229817e-02
#   6.64985994e-01 -2.30484084e-02 -1.74342011e-02 -2.25987061e-02
#  -6.52018322e-03 -2.12135823e-02 -3.59483187e-02 -7.14853283e-03
#   1.00000000e+00 -4.11333435e-03 -8.37764131e-02 -8.26839341e-03
#  -9.26005319e-03 -1.82356638e-02 -2.90612961e-03  2.09769053e-02
#   2.70234423e-02 -2.70234423e-02  1.38319446e-02 -1.38319446e-02
#  -3.14491099e-02  3.14491099e-02]
# in static method i  53
# [ 0.02438374 -0.02438374 -0.00531924 -0.00237085 -0.00237085  0.00630445
#  -0.00388351  0.00388351 -0.07888565  0.2453657  -0.01749793 -0.00237085
#  -0.01049372 -0.00237085  0.01105131 -0.0033557  -0.00237085  0.70651432
#  -0.35058285 -0.04091023  0.07048739 -0.0082896  -0.00388351 -0.01158569
#  -0.02962876  0.2453657  -0.03183367  0.49832215 -0.03605631 -0.03187814
#  -0.03605631  0.49832215 -0.03187814 -0.01652478 -0.02962876 -0.01354507
#  -0.01235039 -0.01132119  0.09327318  0.08280596 -0.00674545 -0.0167225
#  -0.01444347 -0.02074954 -0.00411333 -0.01880315 -0.01422302 -0.01843628
#  -0.00531924 -0.01730628 -0.02932705 -0.00583185 -0.00411333  1.
#  -0.06834575 -0.00674545 -0.00755446 -0.01487686 -0.00237085  0.0171132
#   0.0607074  -0.0607074   0.05028995 -0.05028995 -0.00623551  0.00623551]
# in static method i  54
# [-0.08456688  0.08456688 -0.10833712  0.03468911  0.03468911  0.06536109
#  -0.00434117  0.00434117 -0.09448276  0.06918587  0.07230025 -0.04828725
#  -0.03975845  0.03468911  0.04090166 -0.0096234  -0.04828725 -0.04828725
#   0.05522525 -0.02738417 -0.13426113 -0.12048062  0.14516765 -0.09492889
#  -0.0264303  -0.07836459  0.08665982 -0.06834575  0.03237467 -0.02319372
#   0.03237467 -0.06834575 -0.02319372  0.19037382  0.11573397 -0.03119808
#   0.06433081 -0.17654833 -0.33656063 -0.1942871  -0.10787468  0.07927473
#   0.13911522  0.01525126 -0.08377641  0.18275565 -0.08471054 -0.37549231
#  -0.10833712 -0.35247757 -0.59730487 -0.11877756 -0.08377641 -0.06834575
#   1.         -0.13738477 -0.12742237 -0.10598794  0.03468911  0.1488995
#   0.08245588 -0.08245588  0.05176486 -0.05176486  0.07759523 -0.07759523]
# in static method i  55
# [-0.01415514  0.01415514  0.14915948 -0.00476576 -0.00476576 -0.12265508
#   0.02137006 -0.02137006  0.03816244 -0.01355932 -0.03517335 -0.00476576
#  -0.02109388 -0.00476576  0.02221471 -0.00674545 -0.00476576 -0.00476576
#   0.00955555 -0.0513455   0.04999012  0.3985304  -0.09533582  0.20377788
#  -0.02365512  0.23983051 -0.13042456 -0.00674545  0.03039046 -0.02961954
#   0.03039046 -0.00674545 -0.02961954 -0.03321717 -0.05955808 -0.02722753
#  -0.02482605  0.59582523 -0.03321717 -0.03668736 -0.01355932 -0.03361463
#  -0.02903346 -0.04170955 -0.00826839 -0.03779704 -0.02859031 -0.03705957
#  -0.01069244 -0.03478811 -0.05895158 -0.01172286 -0.00826839 -0.00674545
#  -0.13738477  1.          0.21183832  0.09092624 -0.00476576 -0.17988326
#  -0.08197103  0.08197103 -0.07532585  0.07532585 -0.07109286  0.07109286]
# in static method i  56
# [-0.08659899  0.08659899  0.27446287 -0.00533733 -0.00533733 -0.22830055
#  -0.00874267  0.00874267 -0.0013264  -0.01518554  0.0077208  -0.00533733
#  -0.02362375 -0.00533733  0.02487901 -0.00755446 -0.00533733 -0.00533733
#   0.01070159 -0.03674674  0.19976222  0.16733399 -0.13944552  0.17735778
#   0.06196748  0.09832639 -0.16094728 -0.00755446  0.07243739 -0.07176495
#   0.07243739 -0.00755446 -0.07176495 -0.03720104 -0.00236681 -0.03049304
#   0.03614459  0.1130677   0.06167105 -0.04108741 -0.01518554 -0.03764616
#   0.02303959 -0.04671194 -0.00926005  0.00207938  0.02429697  0.09387511
#  -0.01197482  0.05613475 -0.00129879 -0.01312883 -0.00926005 -0.00755446
#  -0.12742237  0.21183832  1.         -0.0334912  -0.00533733 -0.44144039
#  -0.12444046  0.12444046 -0.09753157  0.09753157 -0.14520103  0.14520103]
# in static method i  57
# [-0.004861    0.004861   -0.02358181 -0.01051072 -0.01051072  0.02794954
#  -0.14939048  0.14939048  0.01380542 -0.02990463 -0.00234817 -0.01051072
#   0.0721982  -0.01051072 -0.06412703 -0.01487686 -0.01051072 -0.01051072
#   0.02107445  0.11323462  0.1703771   0.0622438  -0.23286861  0.05691563
#   0.07409382  0.0305108  -0.1015287   0.10534426  0.02819089 -0.04273014
#   0.02819089  0.10534426 -0.04273014 -0.02063582 -0.04575036  0.09648741
#  -0.02071736  0.06042563 -0.07325936  0.01595576 -0.02990463 -0.02204042
#   0.02467346  0.06105789 -0.01823566 -0.05972362  0.0568397   0.01433853
#  -0.02358181 -0.05141736  0.14556922 -0.02585438 -0.01823566 -0.01487686
#  -0.10598794  0.09092624 -0.0334912   1.         -0.01051072 -0.86932097
#  -0.18947004  0.18947004 -0.07148771  0.07148771 -0.13235932  0.13235932]
# in static method i  58
# [-0.0271778   0.0271778  -0.00375812  1.         -0.00167504 -0.37606036
#   0.03827539 -0.03827539  0.01341312 -0.00476576 -0.01236254 -0.00167504
#  -0.00741396 -0.00167504  0.00780791 -0.00237085 -0.00167504 -0.00167504
#   0.00335853 -0.02890367  0.11426055 -0.00585672 -0.0437629  -0.00818546
#  -0.02093315  0.35147452 -0.06919088 -0.00237085 -0.073682    0.0743724
#  -0.073682   -0.00237085  0.0743724  -0.01167499  0.08001864 -0.00956978
#  -0.00872572 -0.00799858 -0.01167499 -0.01289467 -0.00476576 -0.01181469
#  -0.01020452 -0.01465984 -0.00290613 -0.0132847  -0.01004877 -0.0130255
#  -0.00375812 -0.01222713 -0.02071998 -0.00412029 -0.00290613 -0.00237085
#   0.03468911 -0.00476576 -0.00533733 -0.01051072  1.         -0.13853948
#  -0.03905378  0.03905378 -0.04714368  0.04714368 -0.04556918  0.04556918]
# in static method i  59
# [ 4.92667543e-02 -4.92667543e-02 -1.08054680e-01 -1.38539482e-01
#   1.20907185e-02  1.39512397e-01  1.30835871e-01 -1.30835871e-01
#  -1.36324284e-02  3.43999857e-02  2.97449157e-04  1.20907185e-02
#  -5.17547886e-02  1.20907185e-02  4.39463721e-02  1.71131967e-02
#   1.20907185e-02  1.20907185e-02 -2.42424242e-02 -7.87172354e-02
#  -2.62532708e-01 -1.33282905e-01  2.78877217e-01 -1.32938810e-01
#  -9.17965681e-02 -1.26312447e-01  1.76388498e-01 -8.94877577e-02
#  -4.81029873e-02  6.05738835e-02 -4.81029873e-02 -8.94877577e-02
#   6.05738835e-02  3.76102524e-02  2.96511039e-02 -6.97261351e-02
#   2.62431941e-03 -1.05738203e-01  3.76102524e-02  7.18177347e-03
#   3.43999857e-02  3.90867980e-02 -3.12169027e-02 -2.98907331e-02
#   2.09769053e-02  5.39737629e-02 -6.03557702e-02 -5.50587398e-02
#   2.71266978e-02  2.09386185e-02 -1.25348517e-01  2.97408958e-02
#   2.09769053e-02  1.71131967e-02  1.48899504e-01 -1.79883258e-01
#  -4.41440386e-01 -8.69320973e-01 -1.38539482e-01  1.00000000e+00
#   2.32605746e-01 -2.32605746e-01  1.16507105e-01 -1.16507105e-01
#   1.92742767e-01 -1.92742767e-01]
# in static method i  60
# [-0.03062871  0.03062871 -0.08762094 -0.03905378 -0.03905378  0.10384977
#   0.08703416 -0.08703416 -0.1171833   0.12203059  0.0746374   0.04289064
#  -0.03923207  0.04289064  0.01834109 -0.0552767  -0.03905378  0.04289064
#   0.03722901 -0.01308217 -0.14140965 -0.0649212   0.12059086 -0.13861357
#  -0.16597305 -0.08197103  0.23588097  0.0607074  -0.15618025  0.14865891
#  -0.15618025  0.0607074   0.14865891  0.01971752  0.0157162  -0.05699865
#   0.05924779 -0.0441979   0.159332    0.11990463  0.03460133  0.0637909
#  -0.00970759 -0.17304958 -0.02036664 -0.02469102 -0.1475362  -0.06038943
#   0.02268921  0.166596   -0.1756736   0.03831363  0.02702344  0.0607074
#   0.08245588 -0.08197103 -0.12444046 -0.18947004 -0.03905378  0.23260575
#   1.         -1.          0.43612395 -0.43612395  0.70885207 -0.70885207]
# in static method i  61
# [ 0.03062871 -0.03062871  0.08762094  0.03905378  0.03905378 -0.10384977
#  -0.08703416  0.08703416  0.1171833  -0.12203059 -0.0746374  -0.04289064
#   0.03923207 -0.04289064 -0.01834109  0.0552767   0.03905378 -0.04289064
#  -0.03722901  0.01308217  0.14140965  0.0649212  -0.12059086  0.13861357
#   0.16597305  0.08197103 -0.23588097 -0.0607074   0.15618025 -0.14865891
#   0.15618025 -0.0607074  -0.14865891 -0.01971752 -0.0157162   0.05699865
#  -0.05924779  0.0441979  -0.159332   -0.11990463 -0.03460133 -0.0637909
#   0.00970759  0.17304958  0.02036664  0.02469102  0.1475362   0.06038943
#  -0.02268921 -0.166596    0.1756736  -0.03831363 -0.02702344 -0.0607074
#  -0.08245588  0.08197103  0.12444046  0.18947004  0.03905378 -0.23260575
#  -1.          1.         -0.43612395  0.43612395 -0.70885207  0.70885207]
# in static method i  62
# [-9.05471436e-02  9.05471436e-02 -1.05771407e-01 -4.71436781e-02
#  -4.71436781e-02  1.25361999e-01  6.45406985e-04 -6.45406985e-04
#  -2.61687409e-01  1.01090038e-01  2.37824165e-01  3.55305726e-02
#  -1.60709190e-02 -4.71436781e-02  1.78906966e-02 -8.21859174e-03
#  -4.71436781e-02  3.55305726e-02  1.16423945e-02  5.39335809e-02
#  -7.20996729e-02 -9.25692707e-02  2.09587426e-02 -1.07419560e-01
#  -1.30890098e-01 -7.53258454e-02  1.87990288e-01  5.02899542e-02
#  -1.71863243e-01  1.65843790e-01 -1.71863243e-01  5.02899542e-02
#   1.65843790e-01  8.11785352e-02  1.90887198e-02 -4.07920193e-02
#   1.18830754e-01 -4.56718201e-02 -3.40688603e-02  1.20302442e-01
#   7.16873908e-02  7.31352734e-02 -1.37886787e-02 -1.57224262e-01
#   1.38319446e-02 -4.02999229e-02 -1.07771257e-01  3.08252553e-02
#   5.52120543e-03 -2.39113588e-02 -8.02085584e-02  8.73985332e-02
#   1.38319446e-02  5.02899542e-02  5.17648616e-02 -7.53258454e-02
#  -9.75315671e-02 -7.14877092e-02 -4.71436781e-02  1.16507105e-01
#   4.36123951e-01 -4.36123951e-01  1.00000000e+00 -1.00000000e+00
#   4.50184078e-01 -4.50184078e-01]
# in static method i  63
# [ 9.05471436e-02 -9.05471436e-02  1.05771407e-01  4.71436781e-02
#   4.71436781e-02 -1.25361999e-01 -6.45406985e-04  6.45406985e-04
#   2.61687409e-01 -1.01090038e-01 -2.37824165e-01 -3.55305726e-02
#   1.60709190e-02  4.71436781e-02 -1.78906966e-02  8.21859174e-03
#   4.71436781e-02 -3.55305726e-02 -1.16423945e-02 -5.39335809e-02
#   7.20996729e-02  9.25692707e-02 -2.09587426e-02  1.07419560e-01
#   1.30890098e-01  7.53258454e-02 -1.87990288e-01 -5.02899542e-02
#   1.71863243e-01 -1.65843790e-01  1.71863243e-01 -5.02899542e-02
#  -1.65843790e-01 -8.11785352e-02 -1.90887198e-02  4.07920193e-02
#  -1.18830754e-01  4.56718201e-02  3.40688603e-02 -1.20302442e-01
#  -7.16873908e-02 -7.31352734e-02  1.37886787e-02  1.57224262e-01
#  -1.38319446e-02  4.02999229e-02  1.07771257e-01 -3.08252553e-02
#  -5.52120543e-03  2.39113588e-02  8.02085584e-02 -8.73985332e-02
#  -1.38319446e-02 -5.02899542e-02 -5.17648616e-02  7.53258454e-02
#   9.75315671e-02  7.14877092e-02  4.71436781e-02 -1.16507105e-01
#  -4.36123951e-01  4.36123951e-01 -1.00000000e+00  1.00000000e+00
#  -4.50184078e-01  4.50184078e-01]
# in static method i  64
# [-0.02403402  0.02403402 -0.06529697 -0.04556918 -0.04556918  0.08990079
#   0.0298686  -0.0298686  -0.07838594 -0.04181357  0.10116027  0.03675822
#   0.00926856  0.03675822 -0.02514969 -0.06449859 -0.04556918 -0.04556918
#   0.09136821  0.02035363 -0.12332389 -0.08736728  0.08381024 -0.10024129
#  -0.15462206 -0.07109286  0.20568683 -0.06449859 -0.17397801  0.18365907
#  -0.17397801 -0.06449859  0.18365907  0.07768206 -0.01356967 -0.10861836
#   0.07601948 -0.05677556  0.16694286  0.13039582  0.0460243   0.0825389
#   0.00898614 -0.15511169 -0.03144911 -0.0406672  -0.18621736 -0.00515816
#   0.00858683  0.17020485 -0.18805248  0.022915   -0.03144911 -0.00623551
#   0.07759523 -0.07109286 -0.14520103 -0.13235932 -0.04556918  0.19274277
#   0.70885207 -0.70885207  0.45018408 -0.45018408  1.         -1.        ]
# in static method i  65
# [ 0.02403402 -0.02403402  0.06529697  0.04556918  0.04556918 -0.08990079
#  -0.0298686   0.0298686   0.07838594  0.04181357 -0.10116027 -0.03675822
#  -0.00926856 -0.03675822  0.02514969  0.06449859  0.04556918  0.04556918
#  -0.09136821 -0.02035363  0.12332389  0.08736728 -0.08381024  0.10024129
#   0.15462206  0.07109286 -0.20568683  0.06449859  0.17397801 -0.18365907
#   0.17397801  0.06449859 -0.18365907 -0.07768206  0.01356967  0.10861836
#  -0.07601948  0.05677556 -0.16694286 -0.13039582 -0.0460243  -0.0825389
#  -0.00898614  0.15511169  0.03144911  0.0406672   0.18621736  0.00515816
#  -0.00858683 -0.17020485  0.18805248 -0.022915    0.03144911  0.00623551
#  -0.07759523  0.07109286  0.14520103  0.13235932  0.04556918 -0.19274277
#  -0.70885207  0.70885207 -0.45018408  0.45018408 -1.          1.        ]
# <__main__.RelationArray2D object at 0x7f721c82a588>
# <class '__main__.RelationArray2D'>
# realation matrix <__main__.RelationArray2D object at 0x7f721c82a518>

# %%
get_feature_names = ruleminer._get_feature_names()
# Out:
# _get_feature_names left_filter  <function RuleFormatter.spectLeft at 0x7f721c911ae8>
# _get_feature_names right_filter <function RuleFormatter.spectRight at 0x7f721e13c2f0>
# _get_feature_names ['a0@a', 'a0@b', 'a10@17_33', 'a10@33_50', 'a10@greater_50', 'a10@less_17', 'a11@f', 'a11@t', 'a12@g', 'a12@p', 'a12@s', 'a13@1k_1.5k', 'a13@500_1k', 'a13@greater_1.5k', 'a13@less_500', 'a14@25k_50k', 'a14@50k_75k', 'a14@greater_75k', 'a14@less_25k', 'a1@30_47', 'a1@47_64', 'a1@greater_64', 'a1@less_30', 'a2@14_21', 'a2@7_14', 'a2@greater_21', 'a2@less_7', 'a3@l', 'a3@u', 'a3@y', 'a4@g', 'a4@gg', 'a4@p', 'a5@aa', 'a5@c', 'a5@cc', 'a5@d', 'a5@e', 'a5@ff', 'a5@i', 'a5@j', 'a5@k', 'a5@m', 'a5@q', 'a5@r', 'a5@w', 'a5@x', 'a6@bb', 'a6@dd', 'a6@ff', 'a6@h', 'a6@j', 'a6@n', 'a6@o', 'a6@v', 'a6@z', 'a7@14_21', 'a7@7_14', 'a7@greater_21', 'a7@less_7', 'a8@f', 'a8@t', 'a9@f', 'a9@t']
# _get_feature_names ['class@no', 'class@yes']

# %%
extract_features_4_all_rules = ruleminer.extract_features_4_all_rules()
# Out:
# Streaming output truncated to the last 5000 lines.
# _extract_features_4_itemset i  42
# _extract_features_4_itemset a -0.05830007886125355
# _extract_features_4_itemset i  43
# _extract_features_4_itemset a -0.08375405426566868
# _extract_features_4_itemset i  44
# _extract_features_4_itemset a -0.016603187100201852
# _extract_features_4_itemset i  45
# _extract_features_4_itemset a -0.07589761218206548
# _extract_features_4_itemset i  46
# _extract_features_4_itemset a -0.057410221702940994
# _extract_features_4_itemset i  47
# _extract_features_4_itemset a -0.07441675826780567
# _extract_features_4_itemset i  48
# _extract_features_4_itemset a -0.02147073802650794
# _extract_features_4_itemset i  49
# _extract_features_4_itemset a -0.04235483962044479
# _extract_features_4_itemset i  50
# _extract_features_4_itemset a 0.14366696506441062
# _extract_features_4_itemset i  51
# _extract_features_4_itemset a -0.023539871582605416
# _extract_features_4_itemset i  52
# _extract_features_4_itemset a -0.016603187100201852
# _extract_features_4_itemset i  53
# _extract_features_4_itemset a -0.013545067868355219
# _extract_features_4_itemset i  54
# _extract_features_4_itemset a -0.0311980771710924
# _extract_features_4_itemset i  55
# _extract_features_4_itemset a -0.027227533756217056
# _extract_features_4_itemset i  56
# _extract_features_4_itemset a -0.030493035153354962
# _extract_features_4_itemset i  57
# _extract_features_4_itemset a 0.09648741385465519
# _extract_features_4_itemset i  58
# _extract_features_4_itemset a -0.0095697843635303
# _extract_features_4_itemset i  59
# _extract_features_4_itemset a -0.06972613507081203
# _extract_features_4_itemset i  60
# _extract_features_4_itemset a -0.05699865187783612
# _extract_features_4_itemset i  61
# _extract_features_4_itemset a 0.05699865187783612
# _extract_features_4_itemset i  62
# _extract_features_4_itemset a -0.04079201929585164
# _extract_features_4_itemset i  63
# _extract_features_4_itemset a 0.04079201929585164
# _extract_features_4_itemset a7@less_7
# _extract_features_4_itemset i  0
# _extract_features_4_itemset a 0.049266754255307035
# _extract_features_4_itemset i  1
# _extract_features_4_itemset a -0.049266754255307035
# _extract_features_4_itemset i  2
# _extract_features_4_itemset a -0.1080546796169063
# _extract_features_4_itemset i  3
# _extract_features_4_itemset a -0.13853948232557176
# _extract_features_4_itemset i  4
# _extract_features_4_itemset a 0.012090718457504444
# _extract_features_4_itemset i  5
# _extract_features_4_itemset a 0.13951239686835193
# _extract_features_4_itemset i  6
# _extract_features_4_itemset a 0.13083587134874652
# _extract_features_4_itemset i  7
# _extract_features_4_itemset a -0.13083587134874652
# _extract_features_4_itemset i  8
# _extract_features_4_itemset a -0.013632428447761436
# _extract_features_4_itemset i  9
# _extract_features_4_itemset a 0.03439998566667563
# _extract_features_4_itemset i  10
# _extract_features_4_itemset a 0.00029744915680626836
# _extract_features_4_itemset i  11
# _extract_features_4_itemset a 0.012090718457504444
# _extract_features_4_itemset i  12
# _extract_features_4_itemset a -0.05175478864420583
# _extract_features_4_itemset i  13
# _extract_features_4_itemset a 0.012090718457504444
# _extract_features_4_itemset i  14
# _extract_features_4_itemset a 0.04394637210348902
# _extract_features_4_itemset i  15
# _extract_features_4_itemset a 0.017113196688964695
# _extract_features_4_itemset i  16
# _extract_features_4_itemset a 0.012090718457504444
# _extract_features_4_itemset i  17
# _extract_features_4_itemset a 0.012090718457504444
# _extract_features_4_itemset i  18
# _extract_features_4_itemset a -0.02424242424242424
# _extract_features_4_itemset i  19
# _extract_features_4_itemset a -0.07871723537002889
# _extract_features_4_itemset i  20
# _extract_features_4_itemset a -0.2625327077300205
# _extract_features_4_itemset i  21
# _extract_features_4_itemset a -0.1332829049325828
# _extract_features_4_itemset i  22
# _extract_features_4_itemset a 0.2788772167916045
# _extract_features_4_itemset i  23
# _extract_features_4_itemset a -0.13293881025767934
# _extract_features_4_itemset i  24
# _extract_features_4_itemset a -0.0917965680890678
# _extract_features_4_itemset i  25
# _extract_features_4_itemset a -0.12631244736982458
# _extract_features_4_itemset i  26
# _extract_features_4_itemset a 0.17638849770468032
# _extract_features_4_itemset i  27
# _extract_features_4_itemset a -0.08948775768604454
# _extract_features_4_itemset i  28
# _extract_features_4_itemset a -0.04810298731978201
# _extract_features_4_itemset i  29
# _extract_features_4_itemset a 0.060573883503240215
# _extract_features_4_itemset i  30
# _extract_features_4_itemset a -0.04810298731978201
# _extract_features_4_itemset i  31
# _extract_features_4_itemset a -0.08948775768604454
# _extract_features_4_itemset i  32
# _extract_features_4_itemset a 0.060573883503240215
# _extract_features_4_itemset i  33
# _extract_features_4_itemset a 0.03761025239767957
# _extract_features_4_itemset i  34
# _extract_features_4_itemset a 0.029651103851778538
# _extract_features_4_itemset i  35
# _extract_features_4_itemset a -0.06972613507081203
# _extract_features_4_itemset i  36
# _extract_features_4_itemset a 0.0026243194054073903
# _extract_features_4_itemset i  37
# _extract_features_4_itemset a -0.10573820270953942
# _extract_features_4_itemset i  38
# _extract_features_4_itemset a 0.03761025239767957
# _extract_features_4_itemset i  39
# _extract_features_4_itemset a 0.007181773472153044
# _extract_features_4_itemset i  40
# _extract_features_4_itemset a 0.03439998566667563
# _extract_features_4_itemset i  41
# _extract_features_4_itemset a 0.03908679799852858
# _extract_features_4_itemset i  42
# _extract_features_4_itemset a -0.031216902690231616
# _extract_features_4_itemset i  43
# _extract_features_4_itemset a -0.029890733085586433
# _extract_features_4_itemset i  44
# _extract_features_4_itemset a 0.020976905340817472
# _extract_features_4_itemset i  45
# _extract_features_4_itemset a 0.05397376291156096
# _extract_features_4_itemset i  46
# _extract_features_4_itemset a -0.06035577015423095
# _extract_features_4_itemset i  47
# _extract_features_4_itemset a -0.05505873976065356
# _extract_features_4_itemset i  48
# _extract_features_4_itemset a 0.02712669781177564
# _extract_features_4_itemset i  49
# _extract_features_4_itemset a 0.020938618456703195
# _extract_features_4_itemset i  50
# _extract_features_4_itemset a -0.12534851663681948
# _extract_features_4_itemset i  51
# _extract_features_4_itemset a 0.029740895825796584
# _extract_features_4_itemset i  52
# _extract_features_4_itemset a 0.020976905340817472
# _extract_features_4_itemset i  53
# _extract_features_4_itemset a 0.017113196688964695
# _extract_features_4_itemset i  54
# _extract_features_4_itemset a 0.14889950418861062
# _extract_features_4_itemset i  55
# _extract_features_4_itemset a -0.17988325838199132
# _extract_features_4_itemset i  56
# _extract_features_4_itemset a -0.44144038613664666
# _extract_features_4_itemset i  57
# _extract_features_4_itemset a -0.8693209730866764
# _extract_features_4_itemset i  58
# _extract_features_4_itemset a -0.13853948232557176
# _extract_features_4_itemset i  59
# _extract_features_4_itemset a 1.0
# _extract_features_4_itemset i  60
# _extract_features_4_itemset a 0.2326057458628426
# _extract_features_4_itemset i  61
# _extract_features_4_itemset a -0.2326057458628426
# _extract_features_4_itemset i  62
# _extract_features_4_itemset a 0.11650710529265221
# _extract_features_4_itemset i  63
# _extract_features_4_itemset a -0.11650710529265221
# _extract_features_4_itemset a8@t
# _extract_features_4_itemset i  0
# _extract_features_4_itemset a 0.03062870631980037
# _extract_features_4_itemset i  1
# _extract_features_4_itemset a -0.03062870631980037
# _extract_features_4_itemset i  2
# _extract_features_4_itemset a 0.08762094176048936
# _extract_features_4_itemset i  3
# _extract_features_4_itemset a 0.03905378181886877
# _extract_features_4_itemset i  4
# _extract_features_4_itemset a 0.03905378181886877
# _extract_features_4_itemset i  5
# _extract_features_4_itemset a -0.1038497704241341
# _extract_features_4_itemset i  6
# _extract_features_4_itemset a -0.08703416362209043
# _extract_features_4_itemset i  7
# _extract_features_4_itemset a 0.08703416362209043
# _extract_features_4_itemset i  8
# _extract_features_4_itemset a 0.11718330041436623
# _extract_features_4_itemset i  9
# _extract_features_4_itemset a -0.12203059433198768
# _extract_features_4_itemset i  10
# _extract_features_4_itemset a -0.07463739719072977
# _extract_features_4_itemset i  11
# _extract_features_4_itemset a -0.04289064459405588
# _extract_features_4_itemset i  12
# _extract_features_4_itemset a 0.03923206804640574
# _extract_features_4_itemset i  13
# _extract_features_4_itemset a -0.04289064459405588
# _extract_features_4_itemset i  14
# _extract_features_4_itemset a -0.01834109073719131
# _extract_features_4_itemset i  15
# _extract_features_4_itemset a 0.055276702709043196
# _extract_features_4_itemset i  16
# _extract_features_4_itemset a 0.03905378181886877
# _extract_features_4_itemset i  17
# _extract_features_4_itemset a -0.04289064459405588
# _extract_features_4_itemset i  18
# _extract_features_4_itemset a -0.03722900846257402
# _extract_features_4_itemset i  19
# _extract_features_4_itemset a 0.013082168365824485
# _extract_features_4_itemset i  20
# _extract_features_4_itemset a 0.14140965476195766
# _extract_features_4_itemset i  21
# _extract_features_4_itemset a 0.06492119592548534
# _extract_features_4_itemset i  22
# _extract_features_4_itemset a -0.12059085597928583
# _extract_features_4_itemset i  23
# _extract_features_4_itemset a 0.13861356789278742
# _extract_features_4_itemset i  24
# _extract_features_4_itemset a 0.16597305482030372
# _extract_features_4_itemset i  25
# _extract_features_4_itemset a 0.08197103021821217
# _extract_features_4_itemset i  26
# _extract_features_4_itemset a -0.23588097341597966
# _extract_features_4_itemset i  27
# _extract_features_4_itemset a -0.060707396308528144
# _extract_features_4_itemset i  28
# _extract_features_4_itemset a 0.1561802544233584
# _extract_features_4_itemset i  29
# _extract_features_4_itemset a -0.14865890729939096
# _extract_features_4_itemset i  30
# _extract_features_4_itemset a 0.1561802544233584
# _extract_features_4_itemset i  31
# _extract_features_4_itemset a -0.060707396308528144
# _extract_features_4_itemset i  32
# _extract_features_4_itemset a -0.14865890729939096
# _extract_features_4_itemset i  33
# _extract_features_4_itemset a -0.019717520120836413
# _extract_features_4_itemset i  34
# _extract_features_4_itemset a -0.01571620372653567
# _extract_features_4_itemset i  35
# _extract_features_4_itemset a 0.05699865187783612
# _extract_features_4_itemset i  36
# _extract_features_4_itemset a -0.05924778970101434
# _extract_features_4_itemset i  37
# _extract_features_4_itemset a 0.04419789934523459
# _extract_features_4_itemset i  38
# _extract_features_4_itemset a -0.15933199520680189
# _extract_features_4_itemset i  39
# _extract_features_4_itemset a -0.11990463062907628
# _extract_features_4_itemset i  40
# _extract_features_4_itemset a -0.03460132666761632
# _extract_features_4_itemset i  41
# _extract_features_4_itemset a -0.06379089768830348
# _extract_features_4_itemset i  42
# _extract_features_4_itemset a 0.00970759369318531
# _extract_features_4_itemset i  43
# _extract_features_4_itemset a 0.1730495800105174
# _extract_features_4_itemset i  44
# _extract_features_4_itemset a 0.020366641286896154
# _extract_features_4_itemset i  45
# _extract_features_4_itemset a 0.02469102443438223
# _extract_features_4_itemset i  46
# _extract_features_4_itemset a 0.14753620020655492
# _extract_features_4_itemset i  47
# _extract_features_4_itemset a 0.06038943188024827
# _extract_features_4_itemset i  48
# _extract_features_4_itemset a -0.022689212287453037
# _extract_features_4_itemset i  49
# _extract_features_4_itemset a -0.16659599889983898
# _extract_features_4_itemset i  50
# _extract_features_4_itemset a 0.17567359818104372
# _extract_features_4_itemset i  51
# _extract_features_4_itemset a -0.03831362968633817
# _extract_features_4_itemset i  52
# _extract_features_4_itemset a -0.027023442330084003
# _extract_features_4_itemset i  53
# _extract_features_4_itemset a -0.060707396308528144
# _extract_features_4_itemset i  54
# _extract_features_4_itemset a -0.08245587609395766
# _extract_features_4_itemset i  55
# _extract_features_4_itemset a 0.08197103021821217
# _extract_features_4_itemset i  56
# _extract_features_4_itemset a 0.12444045723877817
# _extract_features_4_itemset i  57
# _extract_features_4_itemset a 0.18947004178058655
# _extract_features_4_itemset i  58
# _extract_features_4_itemset a 0.03905378181886877
# _extract_features_4_itemset i  59
# _extract_features_4_itemset a -0.23260574586284258
# _extract_features_4_itemset i  60
# _extract_features_4_itemset a -1.0
# _extract_features_4_itemset i  61
# _extract_features_4_itemset a 1.0
# _extract_features_4_itemset i  62
# _extract_features_4_itemset a -0.43612395111173885
# _extract_features_4_itemset i  63
# _extract_features_4_itemset a 0.43612395111173885
# a [-1.          1.         -0.84372783 -0.37606036 -0.37606036  1.
#   0.13083587 -0.13083587  0.1171833  -0.12203059  0.09571034 -0.21453151
#  -0.9495455  -0.21453151  1.          0.0552767  -0.06163272 -0.073682
#  -0.03722901 -0.11590131 -0.26253271 -0.1332829   0.27887722 -0.13992643
#   0.16597305 -0.13593289 -0.23588097  0.1170993   1.         -0.99071697
#   1.          0.1170993  -0.99071697 -0.0719299  -0.11959444  1.
#  -0.05924779 -0.1057382  -0.159332   -0.11990463 -0.14376975 -0.06749921
#   0.1191948  -0.23078586  0.04715238  0.10433252 -0.22777348 -0.12789787
#   0.0271267  -0.166596    0.1756736  -0.11519538  0.04715238 -0.0607074
#   0.1488995  -0.17988326 -0.44144039 -0.86932097 -0.37606036  1.
#  -1.          1.         -0.43612395  0.43612395]
# _extract_features_4_itemset class@yes
# _extract_features_4_itemset i  0
# _extract_features_4_itemset a -1.0
# _extract_features_4_itemset i  1
# _extract_features_4_itemset a 1.0
# b [-1.  1.]
# f_vector [-1.          1.         -0.84372783 -0.37606036 -0.37606036  1.
#   0.13083587 -0.13083587  0.1171833  -0.12203059  0.09571034 -0.21453151
#  -0.9495455  -0.21453151  1.          0.0552767  -0.06163272 -0.073682
#  -0.03722901 -0.11590131 -0.26253271 -0.1332829   0.27887722 -0.13992643
#   0.16597305 -0.13593289 -0.23588097  0.1170993   1.         -0.99071697
#   1.          0.1170993  -0.99071697 -0.0719299  -0.11959444  1.
#  -0.05924779 -0.1057382  -0.159332   -0.11990463 -0.14376975 -0.06749921
#   0.1191948  -0.23078586  0.04715238  0.10433252 -0.22777348 -0.12789787
#   0.0271267  -0.166596    0.1756736  -0.11519538  0.04715238 -0.0607074
#   0.1488995  -0.17988326 -0.44144039 -0.86932097 -0.37606036  1.
#  -1.          1.         -0.43612395  0.43612395 -1.          1.        ]
# line a0@b,a10@less_17,a13@less_500,a4@g,a5@cc,a7@less_7,a9@t>class@yes
#
# string to rule <__main__.AssociationRule object at 0x7f7234ad81d0>
# _extract_features_4_itemset a0@b
# _extract_features_4_itemset i  0
# _extract_features_4_itemset a -1.0
# _extract_features_4_itemset i  1
# _extract_features_4_itemset a 1.0
# _extract_features_4_itemset i  2
# _extract_features_4_itemset a -0.01872597235196552
# _extract_features_4_itemset i  3
# _extract_features_4_itemset a 0.027177802038693574
# _extract_features_4_itemset i  4
# _extract_features_4_itemset a 0.027177802038693574
# _extract_features_4_itemset i  5
# _extract_features_4_itemset a -0.004795419136658074
# _extract_features_4_itemset i  6
# _extract_features_4_itemset a -0.08277155098620768
# _extract_features_4_itemset i  7
# _extract_features_4_itemset a 0.08277155098620768
# _extract_features_4_itemset i  8
# _extract_features_4_itemset a -0.09501574097857424
# _extract_features_4_itemset i  9
# _extract_features_4_itemset a 0.01415514105673962
# _extract_features_4_itemset i  10
# _extract_features_4_itemset a 0.09571033949929252
# _extract_features_4_itemset i  11
# _extract_features_4_itemset a 0.027177802038693574
# _extract_features_4_itemset i  12
# _extract_features_4_itemset a 0.07891500887871669
# _extract_features_4_itemset i  13
# _extract_features_4_itemset a -0.061632720470261394
# _extract_features_4_itemset i  14
# _extract_features_4_itemset a -0.06754524965674909
# _extract_features_4_itemset i  15
# _extract_features_4_itemset a -0.0243837369174568
# _extract_features_4_itemset i  16
# _extract_features_4_itemset a -0.061632720470261394
# _extract_features_4_itemset i  17
# _extract_features_4_itemset a 0.027177802038693574
# _extract_features_4_itemset i  18
# _extract_features_4_itemset a 0.034541816220100434
# _extract_features_4_itemset i  19
# _extract_features_4_itemset a 0.10702634714937544
# _extract_features_4_itemset i  20
# _extract_features_4_itemset a -0.002179028281461473
# _extract_features_4_itemset i  21
# _extract_features_4_itemset a -0.008481390258924526
# _extract_features_4_itemset i  22
# _extract_features_4_itemset a -0.09731890954307827
# _extract_features_4_itemset i  23
# _extract_features_4_itemset a -0.018143472513231028
# _extract_features_4_itemset i  24
# _extract_features_4_itemset a -0.09893543163429733
# _extract_features_4_itemset i  25
# _extract_features_4_itemset a 0.07732509890696568
# _extract_features_4_itemset i  26
# _extract_features_4_itemset a 0.07922361259664987
# _extract_features_4_itemset i  27
# _extract_features_4_itemset a -0.0243837369174568
# _extract_features_4_itemset i  28
# _extract_features_4_itemset a -0.052562544435199705
# _extract_features_4_itemset i  29
# _extract_features_4_itemset a 0.05615679767546025
# _extract_features_4_itemset i  30
# _extract_features_4_itemset a -0.052562544435199705
# _extract_features_4_itemset i  31
# _extract_features_4_itemset a -0.0243837369174568
# _extract_features_4_itemset i  32
# _extract_features_4_itemset a 0.05615679767546025
# _extract_features_4_itemset i  33
# _extract_features_4_itemset a -0.0719299014831805
# _extract_features_4_itemset i  34
# _extract_features_4_itemset a 0.06217515627970819
# _extract_features_4_itemset i  35
# _extract_features_4_itemset a 0.024332111134110733
# _extract_features_4_itemset i  36
# _extract_features_4_itemset a 0.0526075381831889
# _extract_features_4_itemset i  37
# _extract_features_4_itemset a 0.052672008205472215
# _extract_features_4_itemset i  38
# _extract_features_4_itemset a -0.1269527106765824
# _extract_features_4_itemset i  39
# _extract_features_4_itemset a 0.03196914521269535
# _extract_features_4_itemset i  40
# _extract_features_4_itemset a -0.14376975356882557
# _extract_features_4_itemset i  41
# _extract_features_4_itemset a 0.055518235319607104
# _extract_features_4_itemset i  42
# _extract_features_4_itemset a 0.11919480003809665
# _extract_features_4_itemset i  43
# _extract_features_4_itemset a -0.230785855003209
# _extract_features_4_itemset i  44
# _extract_features_4_itemset a 0.04715238244451047
# _extract_features_4_itemset i  45
# _extract_features_4_itemset a 0.1043325247627771
# _extract_features_4_itemset i  46
# _extract_features_4_itemset a 0.022011552875419494
# _extract_features_4_itemset i  47
# _extract_features_4_itemset a 0.08577509507413181
# _extract_features_4_itemset i  48
# _extract_features_4_itemset a 0.021125029308089217
# _extract_features_4_itemset i  49
# _extract_features_4_itemset a -0.14559889713215682
# _extract_features_4_itemset i  50
# _extract_features_4_itemset a -0.051016471375871654
# _extract_features_4_itemset i  51
# _extract_features_4_itemset a -0.11519537962111549
# _extract_features_4_itemset i  52
# _extract_features_4_itemset a 0.04715238244451047
# _extract_features_4_itemset i  53
# _extract_features_4_itemset a -0.0243837369174568
# _extract_features_4_itemset i  54
# _extract_features_4_itemset a 0.08456688003712377
# _extract_features_4_itemset i  55
# _extract_features_4_itemset a 0.01415514105673962
# _extract_features_4_itemset i  56
# _extract_features_4_itemset a 0.08659899131218095
# _extract_features_4_itemset i  57
# _extract_features_4_itemset a 0.004860997784377044
# _extract_features_4_itemset i  58
# _extract_features_4_itemset a 0.027177802038693574
# _extract_features_4_itemset i  59
# _extract_features_4_itemset a -0.04926675425530704
# _extract_features_4_itemset i  60
# _extract_features_4_itemset a 0.03062870631980037
# _extract_features_4_itemset i  61
# _extract_features_4_itemset a -0.03062870631980037
# _extract_features_4_itemset i  62
# _extract_features_4_itemset a 0.09054714360510137
# _extract_features_4_itemset i  63
# _extract_features_4_itemset a -0.09054714360510137
# _extract_features_4_itemset a10@less_17
# _extract_features_4_itemset i  0
# _extract_features_4_itemset a 0.004795419136658073
# _extract_features_4_itemset i  1
# _extract_features_4_itemset a -0.004795419136658073
# _extract_features_4_itemset i  2
# _extract_features_4_itemset a -0.8437278330287646
# _extract_features_4_itemset i  3
# _extract_features_4_itemset a -0.3760603577587966
# _extract_features_4_itemset i  4
# _extract_features_4_itemset a -0.3760603577587966
# _extract_features_4_itemset i  5
# _extract_features_4_itemset a 1.0
# _extract_features_4_itemset i  6
# _extract_features_4_itemset a -0.008286228796301346
# _extract_features_4_itemset i  7
# _extract_features_4_itemset a 0.008286228796301346
# _extract_features_4_itemset i  8
# _extract_features_4_itemset a -0.035667477539966956
# _extract_features_4_itemset i  9
# _extract_features_4_itemset a 0.012672849206097559
# _extract_features_4_itemset i  10
# _extract_features_4_itemset a 0.03287380710456257
# _extract_features_4_itemset i  11
# _extract_features_4_itemset a 0.004454183594435831
# _extract_features_4_itemset i  12
# _extract_features_4_itemset a 0.019714819180248696
# _extract_features_4_itemset i  13
# _extract_features_4_itemset a 0.004454183594435831
# _extract_features_4_itemset i  14
# _extract_features_4_itemset a -0.020762374500928833
# _extract_features_4_itemset i  15
# _extract_features_4_itemset a 0.006304449169687573
# _extract_features_4_itemset i  16
# _extract_features_4_itemset a 0.004454183594435831
# _extract_features_4_itemset i  17
# _extract_features_4_itemset a 0.004454183594435831
# _extract_features_4_itemset i  18
# _extract_features_4_itemset a -0.008930834733227831
# _extract_features_4_itemset i  19
# _extract_features_4_itemset a 0.04386431808081058
# _extract_features_4_itemset i  20
# _extract_features_4_itemset a -0.15691351574132925
# _extract_features_4_itemset i  21
# _extract_features_4_itemset a 0.015573889701545014
# _extract_features_4_itemset i  22
# _extract_features_4_itemset a 0.05404288843877043
# _extract_features_4_itemset i  23
# _extract_features_4_itemset a -0.13992642840509933
# _extract_features_4_itemset i  24
# _extract_features_4_itemset a 0.017314939973247526
# _extract_features_4_itemset i  25
# _extract_features_4_itemset a -0.12265507624472995
# _extract_features_4_itemset i  26
# _extract_features_4_itemset a 0.07754702029705542
# _extract_features_4_itemset i  27
# _extract_features_4_itemset a 0.006304449169687573
# _extract_features_4_itemset i  28
# _extract_features_4_itemset a 0.012800763365539265
# _extract_features_4_itemset i  29
# _extract_features_4_itemset a -0.013726137962496698
# _extract_features_4_itemset i  30
# _extract_features_4_itemset a 0.012800763365539265
# _extract_features_4_itemset i  31
# _extract_features_4_itemset a 0.006304449169687573
# _extract_features_4_itemset i  32
# _extract_features_4_itemset a -0.013726137962496698
# _extract_features_4_itemset i  33
# _extract_features_4_itemset a 0.03104552230900912
# _extract_features_4_itemset i  34
# _extract_features_4_itemset a -0.021034445597130327
# _extract_features_4_itemset i  35
# _extract_features_4_itemset a -0.04467965786736804
# _extract_features_4_itemset i  36
# _extract_features_4_itemset a -0.0530354040409764
# _extract_features_4_itemset i  37
# _extract_features_4_itemset a -0.06132218592237895
# _extract_features_4_itemset i  38
# _extract_features_4_itemset a 0.03104552230900912
# _extract_features_4_itemset i  39
# _extract_features_4_itemset a 0.03428883341184556
# _extract_features_4_itemset i  40
# _extract_features_4_itemset a 0.012672849206097559
# _extract_features_4_itemset i  41
# _extract_features_4_itemset a 0.031416995985832724
# _extract_features_4_itemset i  42
# _extract_features_4_itemset a 0.02713532979987805
# _extract_features_4_itemset i  43
# _extract_features_4_itemset a -0.058965413013443144
# _extract_features_4_itemset i  44
# _extract_features_4_itemset a 0.007727827586052959
# _extract_features_4_itemset i  45
# _extract_features_4_itemset a 0.035325968297314686
# _extract_features_4_itemset i  46
# _extract_features_4_itemset a 0.026721152530528914
# _extract_features_4_itemset i  47
# _extract_features_4_itemset a -0.07296201748261465
# _extract_features_4_itemset i  48
# _extract_features_4_itemset a 0.00999339226937623
# _extract_features_4_itemset i  49
# _extract_features_4_itemset a 0.03251375638311077
# _extract_features_4_itemset i  50
# _extract_features_4_itemset a -0.022064797898989352
# _extract_features_4_itemset i  51
# _extract_features_4_itemset a 0.010956454799331309
# _extract_features_4_itemset i  52
# _extract_features_4_itemset a 0.007727827586052959
# _extract_features_4_itemset i  53
# _extract_features_4_itemset a 0.006304449169687573
# _extract_features_4_itemset i  54
# _extract_features_4_itemset a 0.06536109184663895
# _extract_features_4_itemset i  55
# _extract_features_4_itemset a -0.12265507624472995
# _extract_features_4_itemset i  56
# _extract_features_4_itemset a -0.22830055487674264
# _extract_features_4_itemset i  57
# _extract_features_4_itemset a 0.027949542986757264
# _extract_features_4_itemset i  58
# _extract_features_4_itemset a -0.3760603577587966
# _extract_features_4_itemset i  59
# _extract_features_4_itemset a 0.13951239686835193
# _extract_features_4_itemset i  60
# _extract_features_4_itemset a 0.1038497704241341
# _extract_features_4_itemset i  61
# _extract_features_4_itemset a -0.1038497704241341
# _extract_features_4_itemset i  62
# _extract_features_4_itemset a 0.125361998624536
# _extract_features_4_itemset i  63
# _extract_features_4_itemset a -0.125361998624536
# _extract_features_4_itemset a13@less_500
# _extract_features_4_itemset i  0
# _extract_features_4_itemset a 0.06754524965674909
# _extract_features_4_itemset i  1
# _extract_features_4_itemset a -0.06754524965674909
# _extract_features_4_itemset i  2
# _extract_features_4_itemset a 0.017517793246200366
# _extract_features_4_itemset i  3
# _extract_features_4_itemset a 0.007807905982741414
# _extract_features_4_itemset i  4
# _extract_features_4_itemset a 0.007807905982741414
# _extract_features_4_itemset i  5
# _extract_features_4_itemset a -0.020762374500928833
# _extract_features_4_itemset i  6
# _extract_features_4_itemset a 0.07652396977193382
# _extract_features_4_itemset i  7
# _extract_features_4_itemset a -0.07652396977193382
# _extract_features_4_itemset i  8
# _extract_features_4_itemset a 0.06026423754179057
# _extract_features_4_itemset i  9
# _extract_features_4_itemset a 0.022214714107940084
# _extract_features_4_itemset i  10
# _extract_features_4_itemset a -0.07365117511731413
# _extract_features_4_itemset i  11
# _extract_features_4_itemset a -0.21453151200199028
# _extract_features_4_itemset i  12
# _extract_features_4_itemset a -0.9495454953558767
# _extract_features_4_itemset i  13
# _extract_features_4_itemset a -0.21453151200199028
# _extract_features_4_itemset i  14
# _extract_features_4_itemset a 1.0
# _extract_features_4_itemset i  15
# _extract_features_4_itemset a 0.011051306113960836
# _extract_features_4_itemset i  16
# _extract_features_4_itemset a 0.007807905982741414
# _extract_features_4_itemset i  17
# _extract_features_4_itemset a 0.007807905982741414
# _extract_features_4_itemset i  18
# _extract_features_4_itemset a -0.01565519616918184
# _extract_features_4_itemset i  19
# _extract_features_4_itemset a -0.11590131267560883
# _extract_features_4_itemset i  20
# _extract_features_4_itemset a 0.01110191862711875
# _extract_features_4_itemset i  21
# _extract_features_4_itemset a 0.027300057125429305
# _extract_features_4_itemset i  22
# _extract_features_4_itemset a 0.09473381216095747
# _extract_features_4_itemset i  23
# _extract_features_4_itemset a 0.0381550244731629
# _extract_features_4_itemset i  24
# _extract_features_4_itemset a 0.05276003651442742
# _extract_features_4_itemset i  25
# _extract_features_4_itemset a -0.13593289347001428
# _extract_features_4_itemset i  26
# _extract_features_4_itemset a -0.029918893619587526
# _extract_features_4_itemset i  27
# _extract_features_4_itemset a 0.011051306113960836
# _extract_features_4_itemset i  28
# _extract_features_4_itemset a -0.06316543617576494
# _extract_features_4_itemset i  29
# _extract_features_4_itemset a 0.061968927607563846
# _extract_features_4_itemset i  30
# _extract_features_4_itemset a -0.06316543617576494
# _extract_features_4_itemset i  31
# _extract_features_4_itemset a 0.011051306113960836
# _extract_features_4_itemset i  32
# _extract_features_4_itemset a 0.061968927607563846
# _extract_features_4_itemset i  33
# _extract_features_4_itemset a -0.04889239522576945
# _extract_features_4_itemset i  34
# _extract_features_4_itemset a 0.07516806338632201
# _extract_features_4_itemset i  35
# _extract_features_4_itemset a -0.03734449336675667
# _extract_features_4_itemset i  36
# _extract_features_4_itemset a -0.0038736564524972286
# _extract_features_4_itemset i  37
# _extract_features_4_itemset a -0.010975359948742148
# _extract_features_4_itemset i  38
# _extract_features_4_itemset a 0.054420863943877656
# _extract_features_4_itemset i  39
# _extract_features_4_itemset a -0.06667864371152493
# _extract_features_4_itemset i  40
# _extract_features_4_itemset a 0.022214714107940084
# _extract_features_4_itemset i  41
# _extract_features_4_itemset a 0.055072034126293405
# _extract_features_4_itemset i  42
# _extract_features_4_itemset a 0.047566540398738276
# _extract_features_4_itemset i  43
# _extract_features_4_itemset a 0.01110191862711875
# _extract_features_4_itemset i  44
# _extract_features_4_itemset a 0.013546399685480298
# _extract_features_4_itemset i  45
# _extract_features_4_itemset a 0.06192421874107159
# _extract_features_4_itemset i  46
# _extract_features_4_itemset a -0.22777347732684214
# _extract_features_4_itemset i  47
# _extract_features_4_itemset a -0.12789786517265156
# _extract_features_4_itemset i  48
# _extract_features_4_itemset a 0.017517793246200366
# _extract_features_4_itemset i  49
# _extract_features_4_itemset a 0.0569945866852491
# _extract_features_4_itemset i  50
# _extract_features_4_itemset a -0.01613477165041377
# _extract_features_4_itemset i  51
# _extract_features_4_itemset a 0.01920598178400193
# _extract_features_4_itemset i  52
# _extract_features_4_itemset a 0.013546399685480298
# _extract_features_4_itemset i  53
# _extract_features_4_itemset a 0.011051306113960836
# _extract_features_4_itemset i  54
# _extract_features_4_itemset a 0.04090165628049296
# _extract_features_4_itemset i  55
# _extract_features_4_itemset a 0.022214714107940084
# _extract_features_4_itemset i  56
# _extract_features_4_itemset a 0.024879009031086894
# _extract_features_4_itemset i  57
# _extract_features_4_itemset a -0.06412702704512485
# _extract_features_4_itemset i  58
# _extract_features_4_itemset a 0.007807905982741414
# _extract_features_4_itemset i  59
# _extract_features_4_itemset a 0.04394637210348902
# _extract_features_4_itemset i  60
# _extract_features_4_itemset a 0.01834109073719131
# _extract_features_4_itemset i  61
# _extract_features_4_itemset a -0.01834109073719131
# _extract_features_4_itemset i  62
# _extract_features_4_itemset a 0.017890696553676873
# _extract_features_4_itemset i  63
# _extract_features_4_itemset a -0.017890696553676873
# _extract_features_4_itemset a4@g
# _extract_features_4_itemset i  0
# _extract_features_4_itemset a 0.052562544435199705
# _extract_features_4_itemset i  1
# _extract_features_4_itemset a -0.052562544435199705
# _extract_features_4_itemset i  2
# _extract_features_4_itemset a 0.007741119513210345
# _extract_features_4_itemset i  3
# _extract_features_4_itemset a -0.0736819953253896
# _extract_features_4_itemset i  4
# _extract_features_4_itemset a 0.022733394618993295
# _extract_features_4_itemset i  5
# _extract_features_4_itemset a 0.012800763365539264
# _extract_features_4_itemset i  6
# _extract_features_4_itemset a 0.0017034312520208413
# _extract_features_4_itemset i  7
# _extract_features_4_itemset a -0.0017034312520208413
# _extract_features_4_itemset i  8
# _extract_features_4_itemset a -0.0223043303327218
# _extract_features_4_itemset i  9
# _extract_features_4_itemset a 0.030390455813109476
# _extract_features_4_itemset i  10
# _extract_features_4_itemset a 0.011233085405767167
# _extract_features_4_itemset i  11
# _extract_features_4_itemset a 0.022733394618993295
# _extract_features_4_itemset i  12
# _extract_features_4_itemset a 0.07816068223311565
# _extract_features_4_itemset i  13
# _extract_features_4_itemset a -0.0736819953253896
# _extract_features_4_itemset i  14
# _extract_features_4_itemset a -0.06316543617576494
# _extract_features_4_itemset i  15
# _extract_features_4_itemset a 0.032176835056581324
# _extract_features_4_itemset i  16
# _extract_features_4_itemset a 0.022733394618993295
# _extract_features_4_itemset i  17
# _extract_features_4_itemset a -0.0736819953253896
# _extract_features_4_itemset i  18
# _extract_features_4_itemset a 0.002747818496089699
# _extract_features_4_itemset i  19
# _extract_features_4_itemset a -0.000657078437175169
# _extract_features_4_itemset i  20
# _extract_features_4_itemset a 0.07486976696185249
# _extract_features_4_itemset i  21
# _extract_features_4_itemset a 0.05139374136113802
# _extract_features_4_itemset i  22
# _extract_features_4_itemset a -0.061468778900441993
# _extract_features_4_itemset i  23
# _extract_features_4_itemset a 0.04963669865102504
# _extract_features_4_itemset i  24
# _extract_features_4_itemset a 0.07032659364207196
# _extract_features_4_itemset i  25
# _extract_features_4_itemset a -0.0381887614557187
# _extract_features_4_itemset i  26
# _extract_features_4_itemset a -0.07683701987461389
# _extract_features_4_itemset i  27
# _extract_features_4_itemset a -0.10428945830395504
# _extract_features_4_itemset i  28
# _extract_features_4_itemset a 0.9999999999999999
# _extract_features_4_itemset i  29
# _extract_features_4_itemset a -0.9907169676623393
# _extract_features_4_itemset i  30
# _extract_features_4_itemset a 0.9999999999999999
# _extract_features_4_itemset i  31
# _extract_features_4_itemset a -0.10428945830395504
# _extract_features_4_itemset i  32
# _extract_features_4_itemset a -0.9907169676623393
# _extract_features_4_itemset i  33
# _extract_features_4_itemset a -0.0058186125873148095
# _extract_features_4_itemset i  34
# _extract_features_4_itemset a -0.007409641104617564
# _extract_features_4_itemset i  35
# _extract_features_4_itemset a 0.005497075421772257
# _extract_features_4_itemset i  36
# _extract_features_4_itemset a -0.01679774557131127
# _extract_features_4_itemset i  37
# _extract_features_4_itemset a 0.003919473966639296
# _extract_features_4_itemset i  38
# _extract_features_4_itemset a -0.09542025191472055
# _extract_features_4_itemset i  39
# _extract_features_4_itemset a 0.02381199426521688
# _extract_features_4_itemset i  40
# _extract_features_4_itemset a -0.07247837009013279
# _extract_features_4_itemset i  41
# _extract_features_4_itemset a -0.04662572279531743
# _extract_features_4_itemset i  42
# _extract_features_4_itemset a 0.021019672334381966
# _extract_features_4_itemset i  43
# _extract_features_4_itemset a 0.12450626434897866
# _extract_features_4_itemset i  44
# _extract_features_4_itemset a -0.016317412108231684
# _extract_features_4_itemset i  45
# _extract_features_4_itemset a 0.019315210019219497
# _extract_features_4_itemset i  46
# _extract_features_4_itemset a -0.01672748538874644
# _extract_features_4_itemset i  47
# _extract_features_4_itemset a 0.04046219525458784
# _extract_features_4_itemset i  48
# _extract_features_4_itemset a 0.007741119513210345
# _extract_features_4_itemset i  49
# _extract_features_4_itemset a -0.10695493460814003
# _extract_features_4_itemset i  50
# _extract_features_4_itemset a 0.0074871137263666215
# _extract_features_4_itemset i  51
# _extract_features_4_itemset a -0.023134701986436974
# _extract_features_4_itemset i  52
# _extract_features_4_itemset a -0.016317412108231684
# _extract_features_4_itemset i  53
# _extract_features_4_itemset a -0.03605631162368687
# _extract_features_4_itemset i  54
# _extract_features_4_itemset a 0.032374668698513555
# _extract_features_4_itemset i  55
# _extract_features_4_itemset a 0.030390455813109476
# _extract_features_4_itemset i  56
# _extract_features_4_itemset a 0.07243738990753261
# _extract_features_4_itemset i  57
# _extract_features_4_itemset a 0.028190885409749622
# _extract_features_4_itemset i  58
# _extract_features_4_itemset a -0.0736819953253896
# _extract_features_4_itemset i  59
# _extract_features_4_itemset a -0.04810298731978201
# _extract_features_4_itemset i  60
# _extract_features_4_itemset a -0.15618025442335842
# _extract_features_4_itemset i  61
# _extract_features_4_itemset a 0.15618025442335842
# _extract_features_4_itemset i  62
# _extract_features_4_itemset a -0.17186324318372334
# _extract_features_4_itemset i  63
# _extract_features_4_itemset a 0.17186324318372334
# _extract_features_4_itemset a5@cc
# _extract_features_4_itemset i  0
# _extract_features_4_itemset a -0.024332111134110733
# _extract_features_4_itemset i  1
# _extract_features_4_itemset a 0.024332111134110733
# _extract_features_4_itemset i  2
# _extract_features_4_itemset a -0.02147073802650794
# _extract_features_4_itemset i  3
# _extract_features_4_itemset a -0.0095697843635303
# _extract_features_4_itemset i  4
# _extract_features_4_itemset a 0.1750344430361832
# _extract_features_4_itemset i  5
# _extract_features_4_itemset a -0.04467965786736804
# _extract_features_4_itemset i  6
# _extract_features_4_itemset a -0.03835445016621658
# _extract_features_4_itemset i  7
# _extract_features_4_itemset a 0.03835445016621658
# _extract_features_4_itemset i  8
# _extract_features_4_itemset a 0.025657435050543197
# _extract_features_4_itemset i  9
# _extract_features_4_itemset a -0.027227533756217056
# _extract_features_4_itemset i  10
# _extract_features_4_itemset a -0.01613078877119235
# _extract_features_4_itemset i  11
# _extract_features_4_itemset a -0.0095697843635303
# _extract_features_4_itemset i  12
# _extract_features_4_itemset a 0.043651606580030894
# _extract_features_4_itemset i  13
# _extract_features_4_itemset a -0.0095697843635303
# _extract_features_4_itemset i  14
# _extract_features_4_itemset a -0.03734449336675667
# _extract_features_4_itemset i  15
# _extract_features_4_itemset a -0.013545067868355219
# _extract_features_4_itemset i  16
# _extract_features_4_itemset a -0.0095697843635303
# _extract_features_4_itemset i  17
# _extract_features_4_itemset a -0.0095697843635303
# _extract_features_4_itemset i  18
# _extract_features_4_itemset a 0.01918784009938014
# _extract_features_4_itemset i  19
# _extract_features_4_itemset a 0.07497694597840211
# _extract_features_4_itemset i  20
# _extract_features_4_itemset a -0.08375405426566868
# _extract_features_4_itemset i  21
# _extract_features_4_itemset a -0.03346040031474463
# _extract_features_4_itemset i  22
# _extract_features_4_itemset a -0.008115872447828295
# _extract_features_4_itemset i  23
# _extract_features_4_itemset a -0.04676482496081344
# _extract_features_4_itemset i  24
# _extract_features_4_itemset a 0.010640296161868934
# _extract_features_4_itemset i  25
# _extract_features_4_itemset a -0.027227533756217056
# _extract_features_4_itemset i  26
# _extract_features_4_itemset a 0.01781765561309784
# _extract_features_4_itemset i  27
# _extract_features_4_itemset a 0.1170992964102967
# _extract_features_4_itemset i  28
# _extract_features_4_itemset a 0.005497075421772256
# _extract_features_4_itemset i  29
# _extract_features_4_itemset a -0.02153025360742736
# _extract_features_4_itemset i  30
# _extract_features_4_itemset a 0.005497075421772256
# _extract_features_4_itemset i  31
# _extract_features_4_itemset a 0.1170992964102967
# _extract_features_4_itemset i  32
# _extract_features_4_itemset a -0.02153025360742736
# _extract_features_4_itemset i  33
# _extract_features_4_itemset a -0.06670110193067091
# _extract_features_4_itemset i  34
# _extract_features_4_itemset a -0.11959443990124029
# _extract_features_4_itemset i  35
# _extract_features_4_itemset a 0.9999999999999998
# _extract_features_4_itemset i  36
# _extract_features_4_itemset a -0.049851470909450794
# _extract_features_4_itemset i  37
# _extract_features_4_itemset a -0.04569718166699655
# _extract_features_4_itemset i  38
# _extract_features_4_itemset a -0.06670110193067091
# _extract_features_4_itemset i  39
# _extract_features_4_itemset a -0.0736693346538934
# _extract_features_4_itemset i  40
# _extract_features_4_itemset a -0.027227533756217056
# _extract_features_4_itemset i  41
# _extract_features_4_itemset a -0.06749921069932842
# _extract_features_4_itemset i  42
# _extract_features_4_itemset a -0.05830007886125355
# _extract_features_4_itemset i  43
# _extract_features_4_itemset a -0.08375405426566868
# _extract_features_4_itemset i  44
# _extract_features_4_itemset a -0.016603187100201852
# _extract_features_4_itemset i  45
# _extract_features_4_itemset a -0.07589761218206548
# _extract_features_4_itemset i  46
# _extract_features_4_itemset a -0.057410221702940994
# _extract_features_4_itemset i  47
# _extract_features_4_itemset a -0.07441675826780567
# _extract_features_4_itemset i  48
# _extract_features_4_itemset a -0.02147073802650794
# _extract_features_4_itemset i  49
# _extract_features_4_itemset a -0.04235483962044479
# _extract_features_4_itemset i  50
# _extract_features_4_itemset a 0.14366696506441062
# _extract_features_4_itemset i  51
# _extract_features_4_itemset a -0.023539871582605416
# _extract_features_4_itemset i  52
# _extract_features_4_itemset a -0.016603187100201852
# _extract_features_4_itemset i  53
# _extract_features_4_itemset a -0.013545067868355219
# _extract_features_4_itemset i  54
# _extract_features_4_itemset a -0.0311980771710924
# _extract_features_4_itemset i  55
# _extract_features_4_itemset a -0.027227533756217056
# _extract_features_4_itemset i  56
# _extract_features_4_itemset a -0.030493035153354962
# _extract_features_4_itemset i  57
# _extract_features_4_itemset a 0.09648741385465519
# _extract_features_4_itemset i  58
# _extract_features_4_itemset a -0.0095697843635303
# _extract_features_4_itemset i  59
# _extract_features_4_itemset a -0.06972613507081203
# _extract_features_4_itemset i  60
# _extract_features_4_itemset a -0.05699865187783612
# _extract_features_4_itemset i  61
# _extract_features_4_itemset a 0.05699865187783612
# _extract_features_4_itemset i  62
# _extract_features_4_itemset a -0.04079201929585164
# _extract_features_4_itemset i  63
# _extract_features_4_itemset a 0.04079201929585164
# _extract_features_4_itemset a7@less_7
# _extract_features_4_itemset i  0
# _extract_features_4_itemset a 0.049266754255307035
# _extract_features_4_itemset i  1
# _extract_features_4_itemset a -0.049266754255307035
# _extract_features_4_itemset i  2
# _extract_features_4_itemset a -0.1080546796169063
# _extract_features_4_itemset i  3
# _extract_features_4_itemset a -0.13853948232557176
# _extract_features_4_itemset i  4
# _extract_features_4_itemset a 0.012090718457504444
# _extract_features_4_itemset i  5
# _extract_features_4_itemset a 0.13951239686835193
# _extract_features_4_itemset i  6
# _extract_features_4_itemset a 0.13083587134874652
# _extract_features_4_itemset i  7
# _extract_features_4_itemset a -0.13083587134874652
# _extract_features_4_itemset i  8
# _extract_features_4_itemset a -0.013632428447761436
# _extract_features_4_itemset i  9
# _extract_features_4_itemset a 0.03439998566667563
# _extract_features_4_itemset i  10
# _extract_features_4_itemset a 0.00029744915680626836
# _extract_features_4_itemset i  11
# _extract_features_4_itemset a 0.012090718457504444
# _extract_features_4_itemset i  12
# _extract_features_4_itemset a -0.05175478864420583
# _extract_features_4_itemset i  13
# _extract_features_4_itemset a 0.012090718457504444
# _extract_features_4_itemset i  14
# _extract_features_4_itemset a 0.04394637210348902
# _extract_features_4_itemset i  15
# _extract_features_4_itemset a 0.017113196688964695
# _extract_features_4_itemset i  16
# _extract_features_4_itemset a 0.012090718457504444
# _extract_features_4_itemset i  17
# _extract_features_4_itemset a 0.012090718457504444
# _extract_features_4_itemset i  18
# _extract_features_4_itemset a -0.02424242424242424
# _extract_features_4_itemset i  19
# _extract_features_4_itemset a -0.07871723537002889
# _extract_features_4_itemset i  20
# _extract_features_4_itemset a -0.2625327077300205
# _extract_features_4_itemset i  21
# _extract_features_4_itemset a -0.1332829049325828
# _extract_features_4_itemset i  22
# _extract_features_4_itemset a 0.2788772167916045
# _extract_features_4_itemset i  23
# _extract_features_4_itemset a -0.13293881025767934
# _extract_features_4_itemset i  24
# _extract_features_4_itemset a -0.0917965680890678
# _extract_features_4_itemset i  25
# _extract_features_4_itemset a -0.12631244736982458
# _extract_features_4_itemset i  26
# _extract_features_4_itemset a 0.17638849770468032
# _extract_features_4_itemset i  27
# _extract_features_4_itemset a -0.08948775768604454
# _extract_features_4_itemset i  28
# _extract_features_4_itemset a -0.04810298731978201
# _extract_features_4_itemset i  29
# _extract_features_4_itemset a 0.060573883503240215
# _extract_features_4_itemset i  30
# _extract_features_4_itemset a -0.04810298731978201
# _extract_features_4_itemset i  31
# _extract_features_4_itemset a -0.08948775768604454
# _extract_features_4_itemset i  32
# _extract_features_4_itemset a 0.060573883503240215
# _extract_features_4_itemset i  33
# _extract_features_4_itemset a 0.03761025239767957
# _extract_features_4_itemset i  34
# _extract_features_4_itemset a 0.029651103851778538
# _extract_features_4_itemset i  35
# _extract_features_4_itemset a -0.06972613507081203
# _extract_features_4_itemset i  36
# _extract_features_4_itemset a 0.0026243194054073903
# _extract_features_4_itemset i  37
# _extract_features_4_itemset a -0.10573820270953942
# _extract_features_4_itemset i  38
# _extract_features_4_itemset a 0.03761025239767957
# _extract_features_4_itemset i  39
# _extract_features_4_itemset a 0.007181773472153044
# _extract_features_4_itemset i  40
# _extract_features_4_itemset a 0.03439998566667563
# _extract_features_4_itemset i  41
# _extract_features_4_itemset a 0.03908679799852858
# _extract_features_4_itemset i  42
# _extract_features_4_itemset a -0.031216902690231616
# _extract_features_4_itemset i  43
# _extract_features_4_itemset a -0.029890733085586433
# _extract_features_4_itemset i  44
# _extract_features_4_itemset a 0.020976905340817472
# _extract_features_4_itemset i  45
# _extract_features_4_itemset a 0.05397376291156096
# _extract_features_4_itemset i  46
# _extract_features_4_itemset a -0.06035577015423095
# _extract_features_4_itemset i  47
# _extract_features_4_itemset a -0.05505873976065356
# _extract_features_4_itemset i  48
# _extract_features_4_itemset a 0.02712669781177564
# _extract_features_4_itemset i  49
# _extract_features_4_itemset a 0.020938618456703195
# _extract_features_4_itemset i  50
# _extract_features_4_itemset a -0.12534851663681948
# _extract_features_4_itemset i  51
# _extract_features_4_itemset a 0.029740895825796584
# _extract_features_4_itemset i  52
# _extract_features_4_itemset a 0.020976905340817472
# _extract_features_4_itemset i  53
# _extract_features_4_itemset a 0.017113196688964695
# _extract_features_4_itemset i  54
# _extract_features_4_itemset a 0.14889950418861062
# _extract_features_4_itemset i  55
# _extract_features_4_itemset a -0.17988325838199132
# _extract_features_4_itemset i  56
# _extract_features_4_itemset a -0.44144038613664666
# _extract_features_4_itemset i  57
# _extract_features_4_itemset a -0.8693209730866764
# _extract_features_4_itemset i  58
# _extract_features_4_itemset a -0.13853948232557176
# _extract_features_4_itemset i  59
# _extract_features_4_itemset a 1.0
# _extract_features_4_itemset i  60
# _extract_features_4_itemset a 0.2326057458628426
# _extract_features_4_itemset i  61
# _extract_features_4_itemset a -0.2326057458628426
# _extract_features_4_itemset i  62
# _extract_features_4_itemset a 0.11650710529265221
# _extract_features_4_itemset i  63
# _extract_features_4_itemset a -0.11650710529265221
# _extract_features_4_itemset a9@t
# _extract_features_4_itemset i  0
# _extract_features_4_itemset a 0.09054714360510138
# _extract_features_4_itemset i  1
# _extract_features_4_itemset a -0.09054714360510138
# _extract_features_4_itemset i  2
# _extract_features_4_itemset a 0.10577140744363477
# _extract_features_4_itemset i  3
# _extract_features_4_itemset a 0.04714367805210078
# _extract_features_4_itemset i  4
# _extract_features_4_itemset a 0.04714367805210078
# _extract_features_4_itemset i  5
# _extract_features_4_itemset a -0.125361998624536
# _extract_features_4_itemset i  6
# _extract_features_4_itemset a -0.00064540698506549
# _extract_features_4_itemset i  7
# _extract_features_4_itemset a 0.00064540698506549
# _extract_features_4_itemset i  8
# ...
# _extract_features_4_itemset i  24
# _extract_features_4_itemset a -0.0917965680890678
# _extract_features_4_itemset i  25
# _extract_features_4_itemset a -0.12631244736982458
# _extract_features_4_itemset i  26
# _extract_features_4_itemset a 0.17638849770468032
# _extract_features_4_itemset i  27
# _extract_features_4_itemset a -0.08948775768604454
# _extract_features_4_itemset i  28
# _extract_features_4_itemset a -0.04810298731978201
# _extract_features_4_itemset i  29
# _extract_features_4_itemset a 0.060573883503240215
# _extract_features_4_itemset i  30
# _extract_features_4_itemset a -0.04810298731978201
# _extract_features_4_itemset i  31
# _extract_features_4_itemset a -0.08948775768604454
# _extract_features_4_itemset i  32
# _extract_features_4_itemset a 0.060573883503240215
# _extract_features_4_itemset i  33
# _extract_features_4_itemset a 0.03761025239767957
# _extract_features_4_itemset i  34
# _extract_features_4_itemset a 0.029651103851778538
# _extract_features_4_itemset i  35
# _extract_features_4_itemset a -0.06972613507081203
# _extract_features_4_itemset i  36
# _extract_features_4_itemset a 0.0026243194054073903
# _extract_features_4_itemset i  37
# _extract_features_4_itemset a -0.10573820270953942
# _extract_features_4_itemset i  38
# _extract_features_4_itemset a 0.03761025239767957
# _extract_features_4_itemset i  39
# _extract_features_4_itemset a 0.007181773472153044
# _extract_features_4_itemset i  40
# _extract_features_4_itemset a 0.03439998566667563
# _extract_features_4_itemset i  41
# _extract_features_4_itemset a 0.03908679799852858
# _extract_features_4_itemset i  42
# _extract_features_4_itemset a -0.031216902690231616
# _extract_features_4_itemset i  43
# _extract_features_4_itemset a -0.029890733085586433
# _extract_features_4_itemset i  44
# _extract_features_4_itemset a 0.020976905340817472
# _extract_features_4_itemset i  45
# _extract_features_4_itemset a 0.05397376291156096
# _extract_features_4_itemset i  46
# _extract_features_4_itemset a -0.06035577015423095
# _extract_features_4_itemset i  47
# _extract_features_4_itemset a -0.05505873976065356
# _extract_features_4_itemset i  48
# _extract_features_4_itemset a 0.02712669781177564
# _extract_features_4_itemset i  49
# _extract_features_4_itemset a 0.020938618456703195
# _extract_features_4_itemset i  50
# _extract_features_4_itemset a -0.12534851663681948
# _extract_features_4_itemset i  51
# _extract_features_4_itemset a 0.029740895825796584
# _extract_features_4_itemset i  52
# _extract_features_4_itemset a 0.020976905340817472
# _extract_features_4_itemset i  53
# _extract_features_4_itemset a 0.017113196688964695
# _extract_features_4_itemset i  54
# _extract_features_4_itemset a 0.14889950418861062
# _extract_features_4_itemset i  55
# _extract_features_4_itemset a -0.17988325838199132
# _extract_features_4_itemset i  56
# _extract_features_4_itemset a -0.44144038613664666
# _extract_features_4_itemset i  57
# _extract_features_4_itemset a -0.8693209730866764
# _extract_features_4_itemset i  58
# _extract_features_4_itemset a -0.13853948232557176
# _extract_features_4_itemset i  59
# _extract_features_4_itemset a 1.0
# _extract_features_4_itemset i  60
# _extract_features_4_itemset a 0.2326057458628426
# _extract_features_4_itemset i  61
# _extract_features_4_itemset a -0.2326057458628426
# _extract_features_4_itemset i  62
# _extract_features_4_itemset a 0.11650710529265221
# _extract_features_4_itemset i  63
# _extract_features_4_itemset a -0.11650710529265221
# _extract_features_4_itemset a8@t
# _extract_features_4_itemset i  0
# _extract_features_4_itemset a 0.03062870631980037
# _extract_features_4_itemset i  1
# _extract_features_4_itemset a -0.03062870631980037
# _extract_features_4_itemset i  2
# _extract_features_4_itemset a 0.08762094176048936
# _extract_features_4_itemset i  3
# _extract_features_4_itemset a 0.03905378181886877
# _extract_features_4_itemset i  4
# _extract_features_4_itemset a 0.03905378181886877
# _extract_features_4_itemset i  5
# _extract_features_4_itemset a -0.1038497704241341
# _extract_features_4_itemset i  6
# _extract_features_4_itemset a -0.08703416362209043
# _extract_features_4_itemset i  7
# _extract_features_4_itemset a 0.08703416362209043
# _extract_features_4_itemset i  8
# _extract_features_4_itemset a 0.11718330041436623
# _extract_features_4_itemset i  9
# _extract_features_4_itemset a -0.12203059433198768
# _extract_features_4_itemset i  10
# _extract_features_4_itemset a -0.07463739719072977
# _extract_features_4_itemset i  11
# _extract_features_4_itemset a -0.04289064459405588
# _extract_features_4_itemset i  12
# _extract_features_4_itemset a 0.03923206804640574
# _extract_features_4_itemset i  13
# _extract_features_4_itemset a -0.04289064459405588
# _extract_features_4_itemset i  14
# _extract_features_4_itemset a -0.01834109073719131
# _extract_features_4_itemset i  15
# _extract_features_4_itemset a 0.055276702709043196
# _extract_features_4_itemset i  16
# _extract_features_4_itemset a 0.03905378181886877
# _extract_features_4_itemset i  17
# _extract_features_4_itemset a -0.04289064459405588
# _extract_features_4_itemset i  18
# _extract_features_4_itemset a -0.03722900846257402
# _extract_features_4_itemset i  19
# _extract_features_4_itemset a 0.013082168365824485
# _extract_features_4_itemset i  20
# _extract_features_4_itemset a 0.14140965476195766
# _extract_features_4_itemset i  21
# _extract_features_4_itemset a 0.06492119592548534
# _extract_features_4_itemset i  22
# _extract_features_4_itemset a -0.12059085597928583
# _extract_features_4_itemset i  23
# _extract_features_4_itemset a 0.13861356789278742
# _extract_features_4_itemset i  24
# _extract_features_4_itemset a 0.16597305482030372
# _extract_features_4_itemset i  25
# _extract_features_4_itemset a 0.08197103021821217
# _extract_features_4_itemset i  26
# _extract_features_4_itemset a -0.23588097341597966
# _extract_features_4_itemset i  27
# _extract_features_4_itemset a -0.060707396308528144
# _extract_features_4_itemset i  28
# _extract_features_4_itemset a 0.1561802544233584
# _extract_features_4_itemset i  29
# _extract_features_4_itemset a -0.14865890729939096
# _extract_features_4_itemset i  30
# _extract_features_4_itemset a 0.1561802544233584
# _extract_features_4_itemset i  31
# _extract_features_4_itemset a -0.060707396308528144
# _extract_features_4_itemset i  32
# _extract_features_4_itemset a -0.14865890729939096
# _extract_features_4_itemset i  33
# _extract_features_4_itemset a -0.019717520120836413
# _extract_features_4_itemset i  34
# _extract_features_4_itemset a -0.01571620372653567
# _extract_features_4_itemset i  35
# _extract_features_4_itemset a 0.05699865187783612
# _extract_features_4_itemset i  36
# _extract_features_4_itemset a -0.05924778970101434
# _extract_features_4_itemset i  37
# _extract_features_4_itemset a 0.04419789934523459
# _extract_features_4_itemset i  38
# _extract_features_4_itemset a -0.15933199520680189
# _extract_features_4_itemset i  39
# _extract_features_4_itemset a -0.11990463062907628
# _extract_features_4_itemset i  40
# _extract_features_4_itemset a -0.03460132666761632
# _extract_features_4_itemset i  41
# _extract_features_4_itemset a -0.06379089768830348
# _extract_features_4_itemset i  42
# _extract_features_4_itemset a 0.00970759369318531
# _extract_features_4_itemset i  43
# _extract_features_4_itemset a 0.1730495800105174
# _extract_features_4_itemset i  44
# _extract_features_4_itemset a 0.020366641286896154
# _extract_features_4_itemset i  45
# _extract_features_4_itemset a 0.02469102443438223
# _extract_features_4_itemset i  46
# _extract_features_4_itemset a 0.14753620020655492
# _extract_features_4_itemset i  47
# _extract_features_4_itemset a 0.06038943188024827
# _extract_features_4_itemset i  48
# _extract_features_4_itemset a -0.022689212287453037
# _extract_features_4_itemset i  49
# _extract_features_4_itemset a -0.16659599889983898
# _extract_features_4_itemset i  50
# _extract_features_4_itemset a 0.17567359818104372
# _extract_features_4_itemset i  51
# _extract_features_4_itemset a -0.03831362968633817
# _extract_features_4_itemset i  52
# _extract_features_4_itemset a -0.027023442330084003
# _extract_features_4_itemset i  53
# _extract_features_4_itemset a -0.060707396308528144
# _extract_features_4_itemset i  54
# _extract_features_4_itemset a -0.08245587609395766
# _extract_features_4_itemset i  55
# _extract_features_4_itemset a 0.08197103021821217
# _extract_features_4_itemset i  56
# _extract_features_4_itemset a 0.12444045723877817
# _extract_features_4_itemset i  57
# _extract_features_4_itemset a 0.18947004178058655
# _extract_features_4_itemset i  58
# _extract_features_4_itemset a 0.03905378181886877
# _extract_features_4_itemset i  59
# _extract_features_4_itemset a -0.23260574586284258
# _extract_features_4_itemset i  60
# _extract_features_4_itemset a -1.0
# _extract_features_4_itemset i  61
# _extract_features_4_itemset a 1.0
# _extract_features_4_itemset i  62
# _extract_features_4_itemset a -0.43612395111173885
# _extract_features_4_itemset i  63
# _extract_features_4_itemset a 0.43612395111173885
# _extract_features_4_itemset a9@t
# _extract_features_4_itemset i  0
# _extract_features_4_itemset a 0.09054714360510138
# _extract_features_4_itemset i  1
# _extract_features_4_itemset a -0.09054714360510138
# _extract_features_4_itemset i  2
# _extract_features_4_itemset a 0.10577140744363477
# _extract_features_4_itemset i  3
# _extract_features_4_itemset a 0.04714367805210078
# _extract_features_4_itemset i  4
# _extract_features_4_itemset a 0.04714367805210078
# _extract_features_4_itemset i  5
# _extract_features_4_itemset a -0.125361998624536
# _extract_features_4_itemset i  6
# _extract_features_4_itemset a -0.00064540698506549
# _extract_features_4_itemset i  7
# _extract_features_4_itemset a 0.00064540698506549
# _extract_features_4_itemset i  8
# _extract_features_4_itemset a 0.2616874088326434
# _extract_features_4_itemset i  9
# _extract_features_4_itemset a -0.10109003801106606
# _extract_features_4_itemset i  10
# _extract_features_4_itemset a -0.23782416531067402
# _extract_features_4_itemset i  11
# _extract_features_4_itemset a -0.03553057260818153
# _extract_features_4_itemset i  12
# _extract_features_4_itemset a 0.016070918997665565
# _extract_features_4_itemset i  13
# _extract_features_4_itemset a 0.04714367805210078
# _extract_features_4_itemset i  14
# _extract_features_4_itemset a -0.017890696553676873
# _extract_features_4_itemset i  15
# _extract_features_4_itemset a 0.00821859173753752
# _extract_features_4_itemset i  16
# _extract_features_4_itemset a 0.04714367805210078
# _extract_features_4_itemset i  17
# _extract_features_4_itemset a -0.03553057260818153
# _extract_features_4_itemset i  18
# _extract_features_4_itemset a -0.011642394533170097
# _extract_features_4_itemset i  19
# _extract_features_4_itemset a -0.05393358088630943
# _extract_features_4_itemset i  20
# _extract_features_4_itemset a 0.07209967289092271
# _extract_features_4_itemset i  21
# _extract_features_4_itemset a 0.09256927069381621
# _extract_features_4_itemset i  22
# _extract_features_4_itemset a -0.020958742620284593
# _extract_features_4_itemset i  23
# _extract_features_4_itemset a 0.10741955992281588
# _extract_features_4_itemset i  24
# _extract_features_4_itemset a 0.13089009751649266
# _extract_features_4_itemset i  25
# _extract_features_4_itemset a 0.07532584544404339
# _extract_features_4_itemset i  26
# _extract_features_4_itemset a -0.18799028766219336
# _extract_features_4_itemset i  27
# _extract_features_4_itemset a -0.05028995420350339
# _extract_features_4_itemset i  28
# _extract_features_4_itemset a 0.1718632431837233
# _extract_features_4_itemset i  29
# _extract_features_4_itemset a -0.16584378976465164
# _extract_features_4_itemset i  30
# _extract_features_4_itemset a 0.1718632431837233
# _extract_features_4_itemset i  31
# _extract_features_4_itemset a -0.05028995420350339
# _extract_features_4_itemset i  32
# _extract_features_4_itemset a -0.16584378976465164
# _extract_features_4_itemset i  33
# _extract_features_4_itemset a -0.0811785352298723
# _extract_features_4_itemset i  34
# _extract_features_4_itemset a -0.019088719778326057
# _extract_features_4_itemset i  35
# _extract_features_4_itemset a 0.04079201929585165
# _extract_features_4_itemset i  36
# _extract_features_4_itemset a -0.1188307539564323
# _extract_features_4_itemset i  37
# _extract_features_4_itemset a 0.04567182008123483
# _extract_features_4_itemset i  38
# _extract_features_4_itemset a 0.03406886034047134
# _extract_features_4_itemset i  39
# _extract_features_4_itemset a -0.12030244225509851
# _extract_features_4_itemset i  40
# _extract_features_4_itemset a -0.07168739076854783
# _extract_features_4_itemset i  41
# _extract_features_4_itemset a -0.07313527339347746
# _extract_features_4_itemset i  42
# _extract_features_4_itemset a 0.013788678677757904
# _extract_features_4_itemset i  43
# _extract_features_4_itemset a 0.15722426200991932
# _extract_features_4_itemset i  44
# _extract_features_4_itemset a -0.013831944629268813
# _extract_features_4_itemset i  45
# _extract_features_4_itemset a 0.04029992294469457
# _extract_features_4_itemset i  46
# _extract_features_4_itemset a 0.10777125738223135
# _extract_features_4_itemset i  47
# _extract_features_4_itemset a -0.030825255331381668
# _extract_features_4_itemset i  48
# _extract_features_4_itemset a -0.005521205432541639
# _extract_features_4_itemset i  49
# _extract_features_4_itemset a 0.023911358803509312
# _extract_features_4_itemset i  50
# _extract_features_4_itemset a 0.08020855836988247
# _extract_features_4_itemset i  51
# _extract_features_4_itemset a -0.08739853320419938
# _extract_features_4_itemset i  52
# _extract_features_4_itemset a -0.013831944629268813
# _extract_features_4_itemset i  53
# _extract_features_4_itemset a -0.05028995420350339
# _extract_features_4_itemset i  54
# _extract_features_4_itemset a -0.05176486161591021
# _extract_features_4_itemset i  55
# _extract_features_4_itemset a 0.07532584544404339
# _extract_features_4_itemset i  56
# _extract_features_4_itemset a 0.09753156709840313
# _extract_features_4_itemset i  57
# _extract_features_4_itemset a 0.07148770921248737
# _extract_features_4_itemset i  58
# _extract_features_4_itemset a 0.04714367805210078
# _extract_features_4_itemset i  59
# _extract_features_4_itemset a -0.11650710529265222
# _extract_features_4_itemset i  60
# _extract_features_4_itemset a -0.43612395111173874
# _extract_features_4_itemset i  61
# _extract_features_4_itemset a 0.43612395111173874
# _extract_features_4_itemset i  62
# _extract_features_4_itemset a -0.9999999999999998
# _extract_features_4_itemset i  63
# _extract_features_4_itemset a 0.9999999999999998
# a [-1.          1.         -0.84372783 -0.37606036 -0.37606036  1.
#   0.13083587 -0.13083587  0.26168741 -0.12203059 -0.23782417 -0.21453151
#  -0.9495455  -0.21453151  1.          0.0552767  -0.06163272 -0.04828725
#   0.05522525 -0.11590131 -0.26253271 -0.1332829   0.27887722 -0.13992643
#   0.16597305 -0.13593289 -0.23588097 -0.08948776  0.17186324 -0.16584379
#   0.17186324 -0.08948776 -0.16584379  0.19037382  0.11573397 -0.06972614
#  -0.11883075 -0.17654833 -0.33656063 -0.1942871  -0.14376975  0.07927473
#   0.13911522 -0.23078586 -0.08377641  0.18275565 -0.22777348 -0.37549231
#  -0.10833712 -0.35247757 -0.59730487 -0.11877756 -0.08377641 -0.06834575
#   1.         -0.17988326 -0.44144039 -0.86932097 -0.37606036  1.
#  -1.          1.         -1.          1.        ]
# _extract_features_4_itemset class@yes
# _extract_features_4_itemset i  0
# _extract_features_4_itemset a -1.0
# _extract_features_4_itemset i  1
# _extract_features_4_itemset a 1.0
# b [-1.  1.]
# f_vector [-1.          1.         -0.84372783 -0.37606036 -0.37606036  1.
#   0.13083587 -0.13083587  0.26168741 -0.12203059 -0.23782417 -0.21453151
#  -0.9495455  -0.21453151  1.          0.0552767  -0.06163272 -0.04828725
#   0.05522525 -0.11590131 -0.26253271 -0.1332829   0.27887722 -0.13992643
#   0.16597305 -0.13593289 -0.23588097 -0.08948776  0.17186324 -0.16584379
#   0.17186324 -0.08948776 -0.16584379  0.19037382  0.11573397 -0.06972614
#  -0.11883075 -0.17654833 -0.33656063 -0.1942871  -0.14376975  0.07927473
#   0.13911522 -0.23078586 -0.08377641  0.18275565 -0.22777348 -0.37549231
#  -0.10833712 -0.35247757 -0.59730487 -0.11877756 -0.08377641 -0.06834575
#   1.         -0.17988326 -0.44144039 -0.86932097 -0.37606036  1.
#  -1.          1.         -1.          1.         -1.          1.        ]
